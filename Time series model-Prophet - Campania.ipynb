# %%
spark.stop()

# %%
#Campania

from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pyproj

# Create a SparkSession
spark = SparkSession.builder.appName("timeseries").config('spark.sql.shuffle.partitions',500).config('spark.driver.maxResultSize', '10G') .config("spark.driver.memory", "32g").config("spark.executor.memory", "16g").config("spark.task.maxFailures", "10").config("spark.executor.instances", "16").config("spark.local.dir", "/afs/enea.it/por/user/nafis/PFS/tmp").getOrCreate()


# Load the data from the CSV file


schema = StructType(
   [StructField('x', DoubleType(), True),
    StructField('y', DoubleType(), True),
    StructField('z', DoubleType(), True),
    StructField('time', TimestampType(), True),
    StructField('c_PM25', DoubleType(), True),
    StructField('c_PM10', DoubleType(), True),
    StructField('c_O3', DoubleType(), True),
    StructField('c_NO2', DoubleType(), True),
    StructField('geometry', StringType(), True),
    StructField('index_right', IntegerType(), True),
    StructField('OBJECTID', IntegerType(), True),
    StructField('COD_REG', IntegerType(), True),
    StructField('COD_PRO', IntegerType(), True),
    StructField('NOME', StringType(), True),
    StructField('SIGLA', StringType(), True),
    StructField('Shape_Leng', DoubleType(), True),
    StructField('Shape_Area', DoubleType(), True),
   ]
  )


df = spark.read.format("csv").load("/afs/enea.it/por/user/nafis/PFS/tmp/nafi2/nafi/data_chunk/campania_prov/", header=True, schema=schema)

# Select the columns in the desired order
df = df.select( 'x', 'y', 'z', 'time', 'c_PM25', 'c_PM10', 'c_O3', 'c_NO2', 'geometry', 'NOME')


df = df.withColumn("x", df["x"].cast(DoubleType())) \
    .withColumn("y", df["y"].cast(DoubleType())) \
    .withColumn("z", df["z"].cast(DoubleType())) \
    .withColumn("time", df["time"].cast(TimestampType())) \
    .withColumn("c_PM25", df["c_PM25"].cast(DoubleType())) \
    .withColumn("c_PM10", df["c_PM10"].cast(DoubleType())) \
    .withColumn("c_O3", df["c_O3"].cast(DoubleType())) \
    .withColumn("c_NO2", df["c_NO2"].cast(DoubleType())) \
    .withColumn("geometry", df["geometry"].cast(StringType()))\
    .withColumn("NOME", df["NOME"].cast(StringType()))

df = df.withColumnRenamed("c_PM25", "c_PM2_5")

df.show()

df.printSchema()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/06/26 22:38:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/06/26 22:38:03 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# 23/06/26 22:38:06 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# [Stage 0:>                                                          (0 + 1) / 1]
# +--------+---------+----+-------------------+------------------+------------------+------------------+------------------+--------------------+-------+
# |       x|        y|   z|               time|           c_PM2_5|            c_PM10|              c_O3|             c_NO2|            geometry|   NOME|
# +--------+---------+----+-------------------+------------------+------------------+------------------+------------------+--------------------+-------+
# |902000.0|4576000.0|20.0|2021-05-21 00:00:00|2.5389232999999995|         2.9607124|         102.89293|         2.4104354|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 01:00:00|         2.5921166|         2.9856164| 98.94353000000001|2.6902790000000003|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 02:00:00|2.5095107999999997|2.8129014999999997|102.21184000000001|2.9086206000000003|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 03:00:00|         2.4757087|         2.7655613|          102.6552|         3.2857485|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 04:00:00|2.4431244999999997|          2.733494|          99.22969|            2.8583|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 05:00:00|          2.602668|         2.9043045|         91.063896|         3.1135564|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 06:00:00|         2.9900506|3.3243476999999997|          86.42286|          4.102874|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 07:00:00|         3.1773403|          3.527025| 92.17261500000001|          4.456797|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 08:00:00|2.9301939999999997|3.2793129999999997|         103.37425|          3.982049|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 09:00:00|2.4819592999999998|         2.7998161|         112.91657|         2.0289207|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 10:00:00|1.9674328999999997|         2.3240533|         117.71718|        0.98944813|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 11:00:00|         1.7692596|         2.1361778|         117.36697|        0.75310564|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 12:00:00|1.7476258000000002|         2.1464431|         117.83322|         0.6366417|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 13:00:00|2.1857892999999997|         2.9506361|        119.379616|         0.6609495|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 14:00:00|2.3429406000000004|         3.6170475|         116.32994|0.6980888000000001|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 15:00:00|         2.7623644|          4.243285|119.94583999999999|0.7787763000000001|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 16:00:00|         2.9903412|4.7465269999999995|         122.55632|        0.98343766|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 17:00:00|         3.0250092|         5.0886664|        123.061676|1.0989118999999998|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 18:00:00|         3.0932174|         5.3077917|121.08698999999999|         1.4064169|POINT (902000 457...|Caserta|
# |902000.0|4576000.0|20.0|2021-05-21 19:00:00|         2.9959621|         5.2067146|         118.31918|         1.4490062|POINT (902000 457...|Caserta|
# +--------+---------+----+-------------------+------------------+------------------+------------------+------------------+--------------------+-------+
# only showing top 20 rows
#
# root
#  |-- x: double (nullable = true)
#  |-- y: double (nullable = true)
#  |-- z: double (nullable = true)
#  |-- time: timestamp (nullable = true)
#  |-- c_PM2_5: double (nullable = true)
#  |-- c_PM10: double (nullable = true)
#  |-- c_O3: double (nullable = true)
#  |-- c_NO2: double (nullable = true)
#  |-- geometry: string (nullable = true)
#  |-- NOME: string (nullable = true)

# %%
from pyspark.sql import functions as F
import pandas as pd

data = df.withColumnRenamed("time", "date_time")


# Convert the "date_time" column to a datetime object
data = data.withColumn("date_time", F.to_timestamp("date_time"))

# Extract the date and time values and store them in separate columns
data = data.withColumn("date", F.date_trunc("day", "date_time"))
data = data.withColumn("time", F.date_trunc("hour", "date_time"))

data = data.withColumnRenamed("date_time", "original_date_time")

# data.show()

# %%
from pyspark.sql.functions import col, when

# Create the season column based on the month of the date_column
data = data.withColumn(
    "season",
    when(col("original_date_time").between("2019-01-01 00:00:00", "2019-03-19 23:00:00") | col("original_date_time").between("2019-12-21 00:00:00", "2020-03-19 23:00:00") | col("original_date_time").between("2020-12-21 00:00:00", "2021-03-19 23:00:00") | col("original_date_time").between("2021-12-21 00:00:00", "2022-03-19 23:00:00") | col("original_date_time").between("2022-12-21 00:00:00", "2023-03-19 23:00:00"), "Winter")
    .when(col("original_date_time").between("2019-03-20 00:00:00", "2019-06-20 23:00:00") | col("original_date_time").between("2020-03-20 00:00:00", "2020-06-20 23:00:00") | col("original_date_time").between("2021-03-20 00:00:00", "2021-06-20 23:00:00") | col("original_date_time").between("2022-03-20 00:00:00", "2022-06-20 23:00:00") | col("original_date_time").between("2023-03-20 00:00:00", "2023-06-20 23:00:00"), "Spring")
    .when(col("original_date_time").between("2019-06-21 00:00:00", "2019-09-21 23:00:00") | col("original_date_time").between("2020-06-21 00:00:00", "2020-09-21 23:00:00") | col("original_date_time").between("2021-06-21 00:00:00", "2021-09-21 23:00:00") | col("original_date_time").between("2022-06-21 00:00:00", "2022-09-21 23:00:00") | col("original_date_time").between("2023-06-21 00:00:00", "2023-09-21 23:00:00"), "Summer")
    .when(col("original_date_time").between("2019-09-22 00:00:00", "2019-12-20 23:00:00") | col("original_date_time").between("2020-09-22 00:00:00", "2020-12-20 23:00:00") | col("original_date_time").between("2021-09-22 00:00:00", "2021-12-20 23:00:00") | col("original_date_time").between("2022-09-22 00:00:00", "2022-12-20 23:00:00") | col("original_date_time").between("2023-09-22 00:00:00", "2023-12-20 23:00:00"), "Autumn")
)


# data.show()

# %%
dataset = data.select(col("c_PM2_5"), col("c_PM10"), col("c_O3"), col("c_NO2"))
dataset_stat = dataset.describe()
dataset_stat.show()
# Out:
# [Stage 1:===============================================>       (97 + 16) / 113]
# +-------+-----------------+------------------+------------------+------------------+
# |summary|          c_PM2_5|            c_PM10|              c_O3|             c_NO2|
# +-------+-----------------+------------------+------------------+------------------+
# |  count|         26497200|          26497200|          26497200|          26497200|
# |   mean|7.253877547295835| 9.881282553262267|  72.5298536256201|5.9930447874230035|
# | stddev|7.244904460091311| 8.722953120667986|20.476166461887257|11.353874650098401|
# |    min|     0.0040953453|       0.004988223|      9.947703E-31|        0.03262893|
# |    max|        407.13245|424.41900000000004|          474.4772|         286.42676|
# +-------+-----------------+------------------+------------------+------------------+

# %%
data_PM25 = data.select(col("original_date_time"),col("c_PM2_5"), col("x"), col("y"), col("NOME"))
data_PM25.show()
# Out:
# +-------------------+------------------+--------+---------+-------+
# | original_date_time|           c_PM2_5|       x|        y|   NOME|
# +-------------------+------------------+--------+---------+-------+
# |2021-05-21 00:00:00|2.5389232999999995|902000.0|4576000.0|Caserta|
# |2021-05-21 01:00:00|         2.5921166|902000.0|4576000.0|Caserta|
# |2021-05-21 02:00:00|2.5095107999999997|902000.0|4576000.0|Caserta|
# |2021-05-21 03:00:00|         2.4757087|902000.0|4576000.0|Caserta|
# |2021-05-21 04:00:00|2.4431244999999997|902000.0|4576000.0|Caserta|
# |2021-05-21 05:00:00|          2.602668|902000.0|4576000.0|Caserta|
# |2021-05-21 06:00:00|         2.9900506|902000.0|4576000.0|Caserta|
# |2021-05-21 07:00:00|         3.1773403|902000.0|4576000.0|Caserta|
# |2021-05-21 08:00:00|2.9301939999999997|902000.0|4576000.0|Caserta|
# |2021-05-21 09:00:00|2.4819592999999998|902000.0|4576000.0|Caserta|
# |2021-05-21 10:00:00|1.9674328999999997|902000.0|4576000.0|Caserta|
# |2021-05-21 11:00:00|         1.7692596|902000.0|4576000.0|Caserta|
# |2021-05-21 12:00:00|1.7476258000000002|902000.0|4576000.0|Caserta|
# |2021-05-21 13:00:00|2.1857892999999997|902000.0|4576000.0|Caserta|
# |2021-05-21 14:00:00|2.3429406000000004|902000.0|4576000.0|Caserta|
# |2021-05-21 15:00:00|         2.7623644|902000.0|4576000.0|Caserta|
# |2021-05-21 16:00:00|         2.9903412|902000.0|4576000.0|Caserta|
# |2021-05-21 17:00:00|         3.0250092|902000.0|4576000.0|Caserta|
# |2021-05-21 18:00:00|         3.0932174|902000.0|4576000.0|Caserta|
# |2021-05-21 19:00:00|         2.9959621|902000.0|4576000.0|Caserta|
# +-------------------+------------------+--------+---------+-------+
# only showing top 20 rows

# %%
data_PM10 = data.select(col("original_date_time"),col("c_PM10"), col("x"), col("y"), col("NOME"))
data_PM10.show()
# Out:
# +-------------------+------------------+--------+---------+-------+
# | original_date_time|            c_PM10|       x|        y|   NOME|
# +-------------------+------------------+--------+---------+-------+
# |2021-05-21 00:00:00|         2.9607124|902000.0|4576000.0|Caserta|
# |2021-05-21 01:00:00|         2.9856164|902000.0|4576000.0|Caserta|
# |2021-05-21 02:00:00|2.8129014999999997|902000.0|4576000.0|Caserta|
# |2021-05-21 03:00:00|         2.7655613|902000.0|4576000.0|Caserta|
# |2021-05-21 04:00:00|          2.733494|902000.0|4576000.0|Caserta|
# |2021-05-21 05:00:00|         2.9043045|902000.0|4576000.0|Caserta|
# |2021-05-21 06:00:00|3.3243476999999997|902000.0|4576000.0|Caserta|
# |2021-05-21 07:00:00|          3.527025|902000.0|4576000.0|Caserta|
# |2021-05-21 08:00:00|3.2793129999999997|902000.0|4576000.0|Caserta|
# |2021-05-21 09:00:00|         2.7998161|902000.0|4576000.0|Caserta|
# |2021-05-21 10:00:00|         2.3240533|902000.0|4576000.0|Caserta|
# |2021-05-21 11:00:00|         2.1361778|902000.0|4576000.0|Caserta|
# |2021-05-21 12:00:00|         2.1464431|902000.0|4576000.0|Caserta|
# |2021-05-21 13:00:00|         2.9506361|902000.0|4576000.0|Caserta|
# |2021-05-21 14:00:00|         3.6170475|902000.0|4576000.0|Caserta|
# |2021-05-21 15:00:00|          4.243285|902000.0|4576000.0|Caserta|
# |2021-05-21 16:00:00|4.7465269999999995|902000.0|4576000.0|Caserta|
# |2021-05-21 17:00:00|         5.0886664|902000.0|4576000.0|Caserta|
# |2021-05-21 18:00:00|         5.3077917|902000.0|4576000.0|Caserta|
# |2021-05-21 19:00:00|         5.2067146|902000.0|4576000.0|Caserta|
# +-------------------+------------------+--------+---------+-------+
# only showing top 20 rows

# %%
data_NO2 = data.select(col("original_date_time"),col("c_NO2"), col("x"), col("y"), col("NOME"))
data_NO2.show()
# Out:
# +-------------------+------------------+--------+---------+-------+
# | original_date_time|             c_NO2|       x|        y|   NOME|
# +-------------------+------------------+--------+---------+-------+
# |2021-05-21 00:00:00|         2.4104354|902000.0|4576000.0|Caserta|
# |2021-05-21 01:00:00|2.6902790000000003|902000.0|4576000.0|Caserta|
# |2021-05-21 02:00:00|2.9086206000000003|902000.0|4576000.0|Caserta|
# |2021-05-21 03:00:00|         3.2857485|902000.0|4576000.0|Caserta|
# |2021-05-21 04:00:00|            2.8583|902000.0|4576000.0|Caserta|
# |2021-05-21 05:00:00|         3.1135564|902000.0|4576000.0|Caserta|
# |2021-05-21 06:00:00|          4.102874|902000.0|4576000.0|Caserta|
# |2021-05-21 07:00:00|          4.456797|902000.0|4576000.0|Caserta|
# |2021-05-21 08:00:00|          3.982049|902000.0|4576000.0|Caserta|
# |2021-05-21 09:00:00|         2.0289207|902000.0|4576000.0|Caserta|
# |2021-05-21 10:00:00|        0.98944813|902000.0|4576000.0|Caserta|
# |2021-05-21 11:00:00|        0.75310564|902000.0|4576000.0|Caserta|
# |2021-05-21 12:00:00|         0.6366417|902000.0|4576000.0|Caserta|
# |2021-05-21 13:00:00|         0.6609495|902000.0|4576000.0|Caserta|
# |2021-05-21 14:00:00|0.6980888000000001|902000.0|4576000.0|Caserta|
# |2021-05-21 15:00:00|0.7787763000000001|902000.0|4576000.0|Caserta|
# |2021-05-21 16:00:00|        0.98343766|902000.0|4576000.0|Caserta|
# |2021-05-21 17:00:00|1.0989118999999998|902000.0|4576000.0|Caserta|
# |2021-05-21 18:00:00|         1.4064169|902000.0|4576000.0|Caserta|
# |2021-05-21 19:00:00|         1.4490062|902000.0|4576000.0|Caserta|
# +-------------------+------------------+--------+---------+-------+
# only showing top 20 rows

# %%
data_O3 = data.select(col("original_date_time"),col("c_O3"), col("x"), col("y"), col("NOME"))
data_O3.show()
# Out:
# +-------------------+------------------+--------+---------+-------+
# | original_date_time|              c_O3|       x|        y|   NOME|
# +-------------------+------------------+--------+---------+-------+
# |2021-05-21 00:00:00|         102.89293|902000.0|4576000.0|Caserta|
# |2021-05-21 01:00:00| 98.94353000000001|902000.0|4576000.0|Caserta|
# |2021-05-21 02:00:00|102.21184000000001|902000.0|4576000.0|Caserta|
# |2021-05-21 03:00:00|          102.6552|902000.0|4576000.0|Caserta|
# |2021-05-21 04:00:00|          99.22969|902000.0|4576000.0|Caserta|
# |2021-05-21 05:00:00|         91.063896|902000.0|4576000.0|Caserta|
# |2021-05-21 06:00:00|          86.42286|902000.0|4576000.0|Caserta|
# |2021-05-21 07:00:00| 92.17261500000001|902000.0|4576000.0|Caserta|
# |2021-05-21 08:00:00|         103.37425|902000.0|4576000.0|Caserta|
# |2021-05-21 09:00:00|         112.91657|902000.0|4576000.0|Caserta|
# |2021-05-21 10:00:00|         117.71718|902000.0|4576000.0|Caserta|
# |2021-05-21 11:00:00|         117.36697|902000.0|4576000.0|Caserta|
# |2021-05-21 12:00:00|         117.83322|902000.0|4576000.0|Caserta|
# |2021-05-21 13:00:00|        119.379616|902000.0|4576000.0|Caserta|
# |2021-05-21 14:00:00|         116.32994|902000.0|4576000.0|Caserta|
# |2021-05-21 15:00:00|119.94583999999999|902000.0|4576000.0|Caserta|
# |2021-05-21 16:00:00|         122.55632|902000.0|4576000.0|Caserta|
# |2021-05-21 17:00:00|        123.061676|902000.0|4576000.0|Caserta|
# |2021-05-21 18:00:00|121.08698999999999|902000.0|4576000.0|Caserta|
# |2021-05-21 19:00:00|         118.31918|902000.0|4576000.0|Caserta|
# +-------------------+------------------+--------+---------+-------+
# only showing top 20 rows

# %% [markdown]
# # Prophet Model

# %%
import io, os, sys, setuptools, tokenize
from pyspark.sql.types import StructType,StructField,StringType,TimestampType,ArrayType,DoubleType
from pyspark.sql.functions import current_date
from pyspark.sql.functions import pandas_udf, PandasUDFType
import matplotlib.pyplot as plt
from prophet import Prophet
from datetime import datetime
import pandas as pd
from time import time

# %%
# select the "first_name" and "last_name" columns and get distinct values
unique_coordinates = data.select(col("x"), col("y"), col("NOME")).distinct()

# show the unique values
unique_coordinates.show(60)
# Out:
# [Stage 8:======================================================>(112 + 1) / 113]
# +---------+---------+---------+
# |        x|        y|     NOME|
# +---------+---------+---------+
# | 978000.0|4520000.0|  Salerno|
# | 982000.0|4524000.0|  Salerno|
# |1046000.0|4472000.0|  Salerno|
# |1034000.0|4564000.0| Avellino|
# | 970000.0|4560000.0|Benevento|
# |1022000.0|4496000.0|  Salerno|
# |1026000.0|4512000.0|  Salerno|
# |1026000.0|4532000.0| Avellino|
# | 966000.0|4532000.0|   Napoli|
# | 978000.0|4564000.0|Benevento|
# | 970000.0|4524000.0|  Salerno|
# | 974000.0|4520000.0|  Salerno|
# | 990000.0|4520000.0|  Salerno|
# | 942000.0|4596000.0|  Caserta|
# | 926000.0|4540000.0|   Napoli|
# |1002000.0|4512000.0|  Salerno|
# |1050000.0|4512000.0|  Salerno|
# | 958000.0|4568000.0|Benevento|
# | 914000.0|4592000.0|  Caserta|
# |1002000.0|4540000.0| Avellino|
# |1014000.0|4484000.0|  Salerno|
# |1078000.0|4480000.0|  Salerno|
# |1018000.0|4572000.0| Avellino|
# | 958000.0|4592000.0|Benevento|
# | 966000.0|4564000.0|Benevento|
# | 990000.0|4540000.0| Avellino|
# |1018000.0|4544000.0| Avellino|
# |1050000.0|4560000.0| Avellino|
# |1010000.0|4524000.0|  Salerno|
# |1006000.0|4596000.0|Benevento|
# |1034000.0|4508000.0|  Salerno|
# |1022000.0|4564000.0| Avellino|
# |1014000.0|4564000.0| Avellino|
# |1030000.0|4540000.0| Avellino|
# | 962000.0|4516000.0|   Napoli|
# | 914000.0|4580000.0|  Caserta|
# |1002000.0|4544000.0| Avellino|
# | 910000.0|4572000.0|  Caserta|
# |1014000.0|4544000.0| Avellino|
# | 910000.0|4588000.0|  Caserta|
# | 918000.0|4596000.0|  Caserta|
# | 922000.0|4568000.0|  Caserta|
# |1034000.0|4540000.0| Avellino|
# | 934000.0|4596000.0|  Caserta|
# |1070000.0|4484000.0|  Salerno|
# |1010000.0|4584000.0| Avellino|
# |1010000.0|4548000.0| Avellino|
# |1066000.0|4464000.0|  Salerno|
# | 990000.0|4596000.0|Benevento|
# |1002000.0|4588000.0|Benevento|
# |1014000.0|4496000.0|  Salerno|
# |1014000.0|4584000.0| Avellino|
# | 926000.0|4572000.0|  Caserta|
# |1034000.0|4500000.0|  Salerno|
# | 974000.0|4560000.0|Benevento|
# | 982000.0|4596000.0|Benevento|
# |1038000.0|4456000.0|  Salerno|
# |1054000.0|4480000.0|  Salerno|
# | 962000.0|4560000.0|Benevento|
# | 986000.0|4596000.0|Benevento|
# +---------+---------+---------+
# only showing top 60 rows

# %% [markdown]
# PM2.5

# %%
from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_PM25_prophet = data_PM25.groupBy("NOME", "original_date_time").agg(avg("c_PM2_5").alias("avg_c_PM25"))
data_PM25_prophet.show()

data_PM25_prophet_u = data_PM25_prophet.withColumnRenamed("avg_c_PM25", "y").withColumnRenamed("original_date_time", "ds")

data_PM25_prophet = data_PM25_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

data_PM25_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    # Initiate the model
    
    # Convert "ds" column to pandas datetime format and set timezone to Europe/Rome
    group["ds"] = pd.to_datetime(group["ds"])
    
    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    # Fit the model
    m.fit(group[group['ds'] <= cutoff_date])
    
    # Make predictions
    forecast = m.predict(group)

    # Create the directory if it does not exist
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/PM25/'

    if not os.path.exists(path):
        os.makedirs(path)
        
    try:
        fig1 = m.plot(forecast)
        fig1.suptitle(f"PM2.5 Concentration Forecast for {group['NOME'].iloc[0]}")
        fig1.legend(['Actual', 'Forecasted'], loc='upper right')
        fig1.subplots_adjust(top=0.9)
      
        fig2 = m.plot_components(forecast)
        fig2.suptitle(f"PM2.5 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        fig2.subplots_adjust(top=0.9)

        #Save the plots as images using Matplotlib's savefig method
        fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/PM25/{group['NOME'].iloc[0]}_prophet_forecast.png")
        fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/PM25/{group['NOME'].iloc[0]}_prophet_components.png")
    
    except Exception as e:
        print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    #Return the forecasted results
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

# Define the result schema
result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_PM25_prophet_train = data_PM25_prophet.filter(col('ds') <= cutoff_date)
data_PM25_prophet_test = data_PM25_prophet.filter((col('ds') > cutoff_date))

max_date = data_PM25_prophet_test.agg(max('ds')).collect()[0][0]

period = data_PM25_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_PM25 = data_PM25_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

spark_forecast_PM25.show()
# Out:
# +---------+-------------------+------------------+
# |     NOME| original_date_time|        avg_c_PM25|
# +---------+-------------------+------------------+
# |   Napoli|2022-01-24 05:00:00|1.9080459330136983|
# |  Salerno|2022-01-24 05:00:00|1.2905052128205123|
# | Avellino|2021-05-21 15:00:00|2.5817250942196543|
# |  Caserta|2019-01-24 20:00:00| 5.925371732121215|
# | Avellino|2019-01-24 01:00:00|2.6685952549132943|
# |  Salerno|2021-11-01 00:00:00|1.8152010012499995|
# |  Salerno|2019-02-01 19:00:00|3.1785722868589743|
# |Benevento|2022-01-08 13:00:00| 3.817865104651163|
# |   Napoli|2021-06-11 17:00:00| 5.092540517808218|
# |   Napoli|2021-12-06 16:00:00| 4.307729954794521|
# |  Salerno|2021-12-30 20:00:00| 4.245515649679492|
# | Avellino|2019-11-03 04:00:00|1.8226615982658958|
# |  Caserta|2019-02-01 05:00:00|1.5999065662424254|
# | Avellino|2021-11-01 02:00:00| 2.165750578439308|
# |Benevento|2020-11-21 02:00:00| 2.454471720155038|
# |Benevento|2020-11-21 06:00:00|3.3558390837209306|
# | Avellino|2021-12-30 12:00:00| 4.926109620809248|
# | Avellino|2021-06-11 10:00:00| 3.650081851445089|
# |  Salerno|2022-01-24 13:00:00|2.2011435961538455|
# |  Caserta|2021-11-01 19:00:00| 8.123739536363642|
# +---------+-------------------+------------------+
# only showing top 20 rows
#
# root
#  |-- NOME: string (nullable = true)
#  |-- ds: timestamp (nullable = true)
#  |-- y: double (nullable = true)
# The time used for the Spark forecast is  0.5624914169311523
# Processing group: Benevento with 29862 data points                  (0 + 1) / 1]
# 14:30:43 - cmdstanpy - INFO - Chain [1] start processing
# 14:30:55 - cmdstanpy - INFO - Chain [1] done processing
# +-------------------+---------+------------------+---------+----------+----------+----------+---------+------------+-----------+
# |                 ds|     NOME|                 y|     yhat|yhat_upper|yhat_lower|     trend|   yearly|      weekly|      daily|
# +-------------------+---------+------------------+---------+----------+----------+----------+---------+------------+-----------+
# |2019-01-01 01:00:00|Benevento| 2.169198713953488| 5.738675| 14.395861|-2.7751412|0.44086233|3.5849354| -0.10496267|  1.8178399|
# |2019-01-01 02:00:00|Benevento| 2.157824851937985| 5.394815| 14.095106|-3.3022373|0.44883448|3.5882342| -0.08308938|  1.4408357|
# |2019-01-01 03:00:00|Benevento|2.0612024728682186|5.0022283| 12.891183|-3.1864626|0.45680666|3.5915477|-0.062140923|  1.0160148|
# |2019-01-01 04:00:00|Benevento|1.9697721821705418|4.6698785|  12.81242|-4.2470865| 0.4647788| 3.594876|-0.042122923|  0.6523467|
# |2019-01-01 05:00:00|Benevento|2.0178646961240316|4.4730763| 13.041539|-4.6251855|  0.472751| 3.598219|-0.023036182| 0.42514262|
# |2019-01-01 06:00:00|Benevento|2.1401975612403104|4.4364243| 12.844744|-3.8143854|0.48072314|3.6015763|-0.004877306|  0.3590019|
# |2019-01-01 07:00:00|Benevento| 2.342315401550388| 4.511504| 12.902979|-3.5916479| 0.4886953| 3.604948| 0.012360735| 0.40549988|
# |2019-01-01 08:00:00|Benevento|3.0404866294573636|4.5799546| 12.693422| -4.230888|0.49666747|3.6083338|  0.02868803|   0.446265|
# |2019-01-01 09:00:00|Benevento| 4.342145829457365|4.5058956| 12.829863| -4.068687| 0.5046396|3.6117337| 0.044117194| 0.34540504|
# |2019-01-01 10:00:00|Benevento| 4.288559609302325| 4.217074|  12.85926| -4.262815| 0.5126118| 3.615147| 0.058662873|0.030652277|
# |2019-01-01 11:00:00|Benevento| 4.067431656589147|3.7557814| 13.260349| -5.169941|  0.520584|3.6185741|  0.07234128|  -0.455718|
# |2019-01-01 12:00:00|Benevento|3.9836793899224823|3.2535589| 11.951031|-5.2102065| 0.5285561|3.6220145|  0.08516979|-0.98218155|
# |2019-01-01 13:00:00|Benevento| 3.947978053488372|2.8445501| 11.541913| -5.469314| 0.5365283|3.6254683|  0.09716662| -1.4146129|
# |2019-01-01 14:00:00|Benevento| 3.900522859689924|2.5872228|11.2122965| -6.170753|0.54450047|3.6289349|  0.10835048| -1.6945632|
# |2019-01-01 15:00:00|Benevento| 3.725134929457365|2.4590712| 11.319542| -6.374093| 0.5524726|3.6324146| 0.118740365| -1.8445563|
# |2019-01-01 16:00:00|Benevento| 3.541979827906978|2.4239652| 10.905899|-5.9025044| 0.5604448|3.6359067|  0.12835543| -1.9007417|
# |2019-01-01 17:00:00|Benevento|3.9148590201550384|2.5049577| 10.778498|-5.6031213|0.56841695|3.6394114|   0.1372148| -1.8400856|
# |2019-01-01 18:00:00|Benevento| 4.546222552713181| 2.789141| 11.218666|-5.0290117|0.57638913|3.6429284|  0.14533758| -1.5755142|
# |2019-01-01 19:00:00|Benevento| 4.970289165116279|3.3529902| 11.394149|-4.6244845|0.58436126|3.6464577|  0.15274288| -1.0305715|
# |2019-01-01 20:00:00|Benevento|5.6157238976744175| 4.170574| 12.640448|-4.2646904|0.59233344|3.6499987|  0.15944986|-0.23120765|
# +-------------------+---------+------------------+---------+----------+----------+----------+---------+------------+-----------+
# only showing top 20 rows
# Processing group: Salerno with 29862 data points

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import pow, sqrt

# Calculate MAE
mae_PM25 = spark_forecast_PM25.select(col("NOME"), abs(col("y") - col("yhat")).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MAE")

# Calculate MSE
mse_PM25 = spark_forecast_PM25.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MSE")

# Calculate RMSE
rmse_PM25 = spark_forecast_PM25.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                     .groupBy("NOME") \
                     .agg({"error": "mean"}) \
                     .withColumnRenamed("avg(error)", "MSE") \
                     .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE"))

# Show the results
mae_PM25.show()
mse_PM25.show()
rmse_PM25.show()
# Out:
# 14:31:13 - cmdstanpy - INFO - Chain [1] start processing        (55 + 58) / 113]
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 14:31:25 - cmdstanpy - INFO - Chain [1] done processing
# 14:31:28 - cmdstanpy - INFO - Chain [1] start processing14:31:28 - cmdstanpy - INFO - Chain [1] start processing
#
# Optimization terminated abnormally. Falling back to Newton.
# Optimization terminated abnormally. Falling back to Newton.
# 14:31:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:37:05 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# Processing group: Caserta with 29862 data points
# 14:37:17 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:37:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:37:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:37:54 - cmdstanpy - INFO - Chain [1] done processing
# 14:40:04 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Salerno with 29862 data points
# 14:40:14 - cmdstanpy - INFO - Chain [1] start processing
# 14:40:24 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+
# |     NOME|               MAE|
# +---------+------------------+
# |Benevento|4.1179194255826905|
# |  Salerno|2.6367373284868822|
# | Avellino|3.3334214264284214|
# |   Napoli| 6.991005137972531|
# |  Caserta|4.3487020108438825|
# +---------+------------------+
# Processing group: Benevento with 29862 data points======>       (98 + 15) / 113]
# 14:40:38 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 14:40:45 - cmdstanpy - INFO - Chain [1] start processing
# 14:40:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 14:41:00 - cmdstanpy - INFO - Chain [1] start processing
# 14:41:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:41:12 - cmdstanpy - INFO - Chain [1] start processing
# 14:41:14 - cmdstanpy - INFO - Chain [1] done processing
# 14:41:23 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Napoli with 29862 data points
# 14:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 14:41:46 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+
# |     NOME|               MSE|
# +---------+------------------+
# |Benevento| 21.34154225299777|
# |  Salerno|12.351801258840519|
# | Avellino|16.141038288808694|
# |   Napoli| 90.68375816241436|
# |  Caserta|  34.5930508905164|
# +---------+------------------+
# Processing group: Benevento with 29862 data points=========>    (104 + 9) / 113]
# Processing group: Avellino with 29862 data points
# 14:42:06 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:42:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:42:21 - cmdstanpy - INFO - Chain [1] done processing
# 14:42:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 14:42:30 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 14:42:33 - cmdstanpy - INFO - Chain [1] start processing
# 14:42:48 - cmdstanpy - INFO - Chain [1] done processing
# 14:42:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:42:58 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 14:43:13 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+-----------------+
# |     NOME|               MSE|             RMSE|
# +---------+------------------+-----------------+
# |Benevento| 21.34154225299777|4.619690709668535|
# |  Salerno|12.351801258840519| 3.51451294759893|
# | Avellino|16.141038288808694|4.017591105228193|
# |   Napoli| 90.68375816241436| 9.52280201213983|
# |  Caserta|  34.5930508905164|5.881585746252145|
# +---------+------------------+-----------------+

# %%
#For Long and Short Term Forecast

from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_PM25_prophet = data_PM25.groupBy("NOME", "original_date_time").agg(avg("c_PM2_5").alias("avg_c_PM25"))
data_PM25_prophet.show()

data_PM25_prophet_u = data_PM25_prophet.withColumnRenamed("avg_c_PM25", "y").withColumnRenamed("original_date_time", "ds")

data_PM25_prophet = data_PM25_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

data_PM25_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    # Initiate the model
    
    # Convert "ds" column to pandas datetime format and set timezone to Europe/Rome
    group["ds"] = pd.to_datetime(group["ds"])
    
    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    # Fit the model
    m.fit(group[group['ds'] <= cutoff_date])
    
    # Make predictions
    forecast = m.predict(group)

    # Create the directory if it does not exist
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/PM25/'

    if not os.path.exists(path):
        os.makedirs(path)
    
   # try:
    #    fig1 = m.plot(forecast)
     #   fig1.suptitle(f"PM2.5 Concentration Forecast for {group['NOME'].iloc[0]}")
     #   fig1.legend(['Actual', 'Forecasted'], loc='upper right')
     #   fig1.subplots_adjust(top=0.9)
        
      #  fig2 = m.plot_components(forecast)
       # fig2.suptitle(f"PM2.5 Concentration Component Forecast for {group['NOME'].iloc[0]}")
       # fig2.subplots_adjust(top=0.9)

        # Save the plots as images using Matplotlib's savefig method
        #fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/PM25/{group['NOME'].iloc[0]}_prophet_forecast.png")
        #fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/PM25/{group['NOME'].iloc[0]}_prophet_components.png")
    
    #except Exception as e:
     #   print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    #Return the forecasted results
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

# Define the result schema
result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_PM25_prophet_train = data_PM25_prophet.filter(col('ds') <= cutoff_date)
data_PM25_prophet_test = data_PM25_prophet.filter((col('ds') > cutoff_date))

max_date = data_PM25_prophet_test.agg(max('ds')).collect()[0][0]

period = data_PM25_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_PM25 = data_PM25_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

#spark_forecast_PM25.show()
# Out:
# +---------+-------------------+------------------+
# |     NOME| original_date_time|        avg_c_PM25|
# +---------+-------------------+------------------+
# |   Napoli|2022-01-24 05:00:00|1.9080459330136983|
# |  Salerno|2022-01-24 05:00:00|1.2905052128205123|
# | Avellino|2021-05-21 15:00:00|2.5817250942196543|
# |  Caserta|2019-01-24 20:00:00| 5.925371732121215|
# | Avellino|2019-01-24 01:00:00|2.6685952549132943|
# |  Salerno|2021-11-01 00:00:00|1.8152010012499995|
# |  Salerno|2019-02-01 19:00:00|3.1785722868589743|
# |Benevento|2022-01-08 13:00:00| 3.817865104651163|
# |   Napoli|2021-06-11 17:00:00| 5.092540517808218|
# |   Napoli|2021-12-06 16:00:00| 4.307729954794521|
# |  Salerno|2021-12-30 20:00:00| 4.245515649679492|
# | Avellino|2019-11-03 04:00:00|1.8226615982658958|
# |  Caserta|2019-02-01 05:00:00|1.5999065662424254|
# | Avellino|2021-11-01 02:00:00| 2.165750578439308|
# |Benevento|2020-11-21 02:00:00| 2.454471720155038|
# |Benevento|2020-11-21 06:00:00|3.3558390837209306|
# | Avellino|2021-12-30 12:00:00| 4.926109620809248|
# | Avellino|2021-06-11 10:00:00| 3.650081851445089|
# |  Salerno|2022-01-24 13:00:00|2.2011435961538455|
# |  Caserta|2021-11-01 19:00:00| 8.123739536363642|
# +---------+-------------------+------------------+
# only showing top 20 rows
#
# root
#  |-- NOME: string (nullable = true)
#  |-- ds: timestamp (nullable = true)
#  |-- y: double (nullable = true)
# The time used for the Spark forecast is  0.26251983642578125

# %%
from pyspark.sql.functions import col, pow, sqrt

# Define cutoff dates
cutoff_dates = {
    "5 Days": "2021-07-05 23:00:00",
    "30 Days": "2021-07-30 23:00:00",
    "90 Days": "2021-09-28 23:00:00",
    "180 Days": "2021-12-27 23:00:00",
    "365 Days": "2022-06-29 23:00:00"
}

# Define a list to store the evaluation results
results = []

# Compute evaluation metrics for each time period and NOME
for period, cutoff in cutoff_dates.items():
    for nome in spark_forecast_PM25.select("NOME").distinct().rdd.flatMap(lambda x: x).collect():
        # Filter the forecast data based on the cutoff date and NOME
        forecast_data_PM25 = spark_forecast_PM25.filter((col("ds") <= cutoff) & (col("NOME") == nome))

        # Calculate MAE
        mae = forecast_data_PM25.select(abs(col("y") - col("yhat")).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MAE") \
                             .collect()[0]["MAE"]

        # Calculate MSE
        mse = forecast_data_PM25.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MSE") \
                             .collect()[0]["MSE"]

        # Calculate RMSE
        rmse = forecast_data_PM25.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                              .agg({"error": "mean"}) \
                              .withColumnRenamed("avg(error)", "MSE") \
                              .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE")) \
                              .collect()[0]["RMSE"]

        # Calculate coverage
        coverage = forecast_data_PM25.filter((col("y") >= col("yhat_lower")) & (col("y") <= col("yhat_upper"))) \
                                  .count() / forecast_data_PM25.count() * 100

        # Add the results to the list
        results.append((period, nome, mse, rmse, mae, coverage))

# Create a Spark DataFrame from the results list
result_df_PM25 = spark.createDataFrame(results, ["Time", "NOME", "MSE", "RMSE", "MAE", "Coverage"])

# Show the results
result_df_PM25.show(100)
# Out:
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 07:36:27 - cmdstanpy - INFO - Chain [1] start processing
# 07:36:27 - cmdstanpy - INFO - Chain [1] start processing
# 07:36:42 - cmdstanpy - INFO - Chain [1] done processing
# 07:36:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:36:50 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:36:52 - cmdstanpy - INFO - Chain [1] start processing
# 07:37:04 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 07:37:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:37:12 - cmdstanpy - INFO - Chain [1] start processing
# 07:37:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 07:38:02 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:38:03 - cmdstanpy - INFO - Chain [1] start processing
# 07:38:17 - cmdstanpy - INFO - Chain [1] done processing
# 07:38:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:38:25 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:38:28 - cmdstanpy - INFO - Chain [1] start processing
# 07:38:36 - cmdstanpy - INFO - Chain [1] done processing
# 07:38:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:38:45 - cmdstanpy - INFO - Chain [1] start processing
# 07:38:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>     (102 + 11) / 113]
# Processing group: Avellino with 29862 data points
# 07:39:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:39:36 - cmdstanpy - INFO - Chain [1] start processing
# 07:39:46 - cmdstanpy - INFO - Chain [1] done processing
# 07:39:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:39:54 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:39:57 - cmdstanpy - INFO - Chain [1] start processing
# 07:40:06 - cmdstanpy - INFO - Chain [1] done processing
# 07:40:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:40:17 - cmdstanpy - INFO - Chain [1] start processing
# 07:40:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 07:41:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:41:04 - cmdstanpy - INFO - Chain [1] start processing
# 07:41:18 - cmdstanpy - INFO - Chain [1] done processing
# 07:41:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:41:26 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 07:41:37 - cmdstanpy - INFO - Chain [1] done processing
# 07:41:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 07:41:45 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 07:41:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 07:42:32 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:42:32 - cmdstanpy - INFO - Chain [1] start processing
# 07:42:48 - cmdstanpy - INFO - Chain [1] done processing
# 07:42:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:42:56 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:42:58 - cmdstanpy - INFO - Chain [1] start processing
# 07:43:07 - cmdstanpy - INFO - Chain [1] done processing
# 07:43:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:43:17 - cmdstanpy - INFO - Chain [1] start processing
# 07:43:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 07:44:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:44:03 - cmdstanpy - INFO - Chain [1] start processing
# 07:44:19 - cmdstanpy - INFO - Chain [1] done processing
# 07:44:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:44:27 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:44:29 - cmdstanpy - INFO - Chain [1] start processing
# 07:44:42 - cmdstanpy - INFO - Chain [1] done processing
# 07:44:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:44:50 - cmdstanpy - INFO - Chain [1] start processing
# 07:45:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 07:45:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:45:39 - cmdstanpy - INFO - Chain [1] start processing
# 07:45:51 - cmdstanpy - INFO - Chain [1] done processing
# 07:45:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:45:59 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:46:03 - cmdstanpy - INFO - Chain [1] start processing
# 07:46:12 - cmdstanpy - INFO - Chain [1] done processing
# 07:46:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:46:22 - cmdstanpy - INFO - Chain [1] start processing
# 07:46:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 07:47:09 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:47:09 - cmdstanpy - INFO - Chain [1] start processing
# 07:47:19 - cmdstanpy - INFO - Chain [1] done processing
# 07:47:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:47:27 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:47:30 - cmdstanpy - INFO - Chain [1] start processing
# 07:47:42 - cmdstanpy - INFO - Chain [1] done processing
# 07:47:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 07:47:50 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 07:48:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (98 + 15) / 113]
# Processing group: Benevento with 29862 data points
# 07:48:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:48:36 - cmdstanpy - INFO - Chain [1] start processing
# 07:48:49 - cmdstanpy - INFO - Chain [1] done processing
# 07:48:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 07:48:57 - cmdstanpy - INFO - Chain [1] start processing
# 07:48:58 - cmdstanpy - INFO - Chain [1] start processing
# 07:49:11 - cmdstanpy - INFO - Chain [1] done processing
# 07:49:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:49:20 - cmdstanpy - INFO - Chain [1] start processing
# 07:49:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 07:50:09 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:50:09 - cmdstanpy - INFO - Chain [1] start processing
# 07:50:24 - cmdstanpy - INFO - Chain [1] done processing
# 07:50:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 07:50:32 - cmdstanpy - INFO - Chain [1] start processing
# 07:50:34 - cmdstanpy - INFO - Chain [1] start processing
# 07:50:43 - cmdstanpy - INFO - Chain [1] done processing
# 07:50:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:50:52 - cmdstanpy - INFO - Chain [1] start processing
# 07:51:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 07:51:38 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:51:38 - cmdstanpy - INFO - Chain [1] start processing
# 07:51:49 - cmdstanpy - INFO - Chain [1] done processing
# 07:51:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:51:57 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:51:59 - cmdstanpy - INFO - Chain [1] start processing
# 07:52:09 - cmdstanpy - INFO - Chain [1] done processing
# 07:52:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 07:52:17 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 07:52:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 07:53:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:53:04 - cmdstanpy - INFO - Chain [1] start processing
# 07:53:15 - cmdstanpy - INFO - Chain [1] done processing
# 07:53:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 07:53:23 - cmdstanpy - INFO - Chain [1] start processing
# 07:53:25 - cmdstanpy - INFO - Chain [1] start processing
# 07:53:34 - cmdstanpy - INFO - Chain [1] done processing
# 07:53:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:53:42 - cmdstanpy - INFO - Chain [1] start processing
# 07:53:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 07:54:30 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:54:30 - cmdstanpy - INFO - Chain [1] start processing
# 07:54:44 - cmdstanpy - INFO - Chain [1] done processing
# 07:54:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:54:52 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:54:55 - cmdstanpy - INFO - Chain [1] start processing
# 07:55:02 - cmdstanpy - INFO - Chain [1] done processing
# 07:55:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:55:13 - cmdstanpy - INFO - Chain [1] start processing
# 07:55:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points==>                (5 + 2) / 7]
# Processing group: Benevento with 29862 data points
# 07:56:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:56:04 - cmdstanpy - INFO - Chain [1] start processing
# 07:56:18 - cmdstanpy - INFO - Chain [1] done processing
# 07:56:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:56:26 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:56:29 - cmdstanpy - INFO - Chain [1] start processing
# 07:56:38 - cmdstanpy - INFO - Chain [1] done processing
# 07:56:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:56:48 - cmdstanpy - INFO - Chain [1] start processing
# 07:57:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 07:57:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:57:35 - cmdstanpy - INFO - Chain [1] start processing
# 07:57:47 - cmdstanpy - INFO - Chain [1] done processing
# 07:57:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 07:57:55 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 07:57:57 - cmdstanpy - INFO - Chain [1] start processing
# 07:58:09 - cmdstanpy - INFO - Chain [1] done processing
# 07:58:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 07:58:17 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 07:58:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>      (99 + 14) / 113]
# Processing group: Avellino with 29862 data points
# 07:59:07 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:59:07 - cmdstanpy - INFO - Chain [1] start processing
# 07:59:22 - cmdstanpy - INFO - Chain [1] done processing
# 07:59:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 07:59:30 - cmdstanpy - INFO - Chain [1] start processing
# 07:59:31 - cmdstanpy - INFO - Chain [1] start processing
# 07:59:44 - cmdstanpy - INFO - Chain [1] done processing
# 07:59:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 07:59:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:00:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:00:40 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:00:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:00:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:00:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:01:03 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:01:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:01:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:01:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:01:25 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 08:01:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 08:02:15 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:02:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:02:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:02:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:02:37 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:02:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:02:49 - cmdstanpy - INFO - Chain [1] done processing
# 08:02:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:03:01 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:03:48 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:03:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 08:04:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:04:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:44 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:05:18 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:05:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:05:41 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:05:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:06:01 - cmdstanpy - INFO - Chain [1] start processing
# 08:06:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 08:06:47 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:06:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:06:58 - cmdstanpy - INFO - Chain [1] done processing
# 08:06:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 08:07:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:07:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:07:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:07:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:07:27 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 08:07:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 08:08:16 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:08:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:08:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:08:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:08:35 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:08:37 - cmdstanpy - INFO - Chain [1] start processing
# 08:08:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:08:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:08:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:09:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 08:09:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:09:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:10:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:10:05 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:10:08 - cmdstanpy - INFO - Chain [1] start processing
# 08:10:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:10:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:10:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:10:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:11:16 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:11:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:11:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:11:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:11:39 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:11:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:11:53 - cmdstanpy - INFO - Chain [1] done processing
# 08:11:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:12:02 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 08:12:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:12:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:12:49 - cmdstanpy - INFO - Chain [1] start processing
# 08:13:03 - cmdstanpy - INFO - Chain [1] done processing
# 08:13:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:13:11 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:13:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:13:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:13:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:13:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:13:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:14:21 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:14:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:14:36 - cmdstanpy - INFO - Chain [1] done processing
# 08:14:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:14:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:14:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:14:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:14:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:15:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:15:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points==========>    (104 + 9) / 113]
# Processing group: Benevento with 29862 data points
# 08:15:52 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:15:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:16:03 - cmdstanpy - INFO - Chain [1] done processing
# 08:16:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:16:11 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:16:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:16:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:16:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:16:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:16:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:17:20 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:17:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:17:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:17:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:17:42 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:17:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:17:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:17:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:18:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:18:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points==============(113 + 0) / 113]
# Processing group: Avellino with 29862 data points
# 08:18:53 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:18:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:19:08 - cmdstanpy - INFO - Chain [1] done processing
# 08:19:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:19:16 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:19:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:19:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:19:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:19:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:19:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:20:27 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:20:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:20:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:20:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:20:51 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:20:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:21:06 - cmdstanpy - INFO - Chain [1] done processing
# 08:21:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:21:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:21:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points========>     (101 + 12) / 113]
# Processing group: Benevento with 29862 data points
# 08:22:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:22:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:22:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:22:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:22:27 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:22:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:22:38 - cmdstanpy - INFO - Chain [1] done processing
# 08:22:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:22:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:23:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:23:40 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:23:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:23:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:23:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 08:24:00 - cmdstanpy - INFO - Chain [1] start processing
# 08:24:02 - cmdstanpy - INFO - Chain [1] start processing
# 08:24:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:24:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:24:22 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 08:24:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:25:11 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:25:11 - cmdstanpy - INFO - Chain [1] start processing
# 08:25:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:25:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:25:34 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:25:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:25:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:25:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:25:58 - cmdstanpy - INFO - Chain [1] start processing
# 08:26:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 08:26:51 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:26:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:27:04 - cmdstanpy - INFO - Chain [1] done processing
# 08:27:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:27:12 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:27:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:27:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:27:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:27:35 - cmdstanpy - INFO - Chain [1] start processing
# 08:27:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points==========>   (106 + 7) / 113]
# Processing group: Avellino with 29862 data points
# 08:28:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:28:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:28:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:28:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:28:49 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:28:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:29:00 - cmdstanpy - INFO - Chain [1] done processing
# 08:29:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:29:10 - cmdstanpy - INFO - Chain [1] start processing
# 08:29:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>     (101 + 12) / 113]
# Processing group: Avellino with 29862 data points
# 08:29:59 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:29:59 - cmdstanpy - INFO - Chain [1] start processing
# 08:30:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:30:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:30:21 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:30:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:30:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:30:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:30:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:30:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:31:31 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:31:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:31:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:31:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:31:54 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:31:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:32:05 - cmdstanpy - INFO - Chain [1] done processing
# 08:32:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:32:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:32:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=>                (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 08:33:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:33:03 - cmdstanpy - INFO - Chain [1] start processing
# 08:33:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:33:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:33:25 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:33:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:33:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:33:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:33:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:34:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points============> (109 + 4) / 113]
# Processing group: Avellino with 29862 data points
# 08:34:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:34:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:34:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:34:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 08:34:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:34:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:35:07 - cmdstanpy - INFO - Chain [1] done processing
# 08:35:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:35:15 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 08:35:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 08:36:05 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:36:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:36:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:36:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 08:36:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:36:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:36:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:36:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:36:47 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 08:37:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:37:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:37:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:37:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:37:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 08:37:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:37:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:38:06 - cmdstanpy - INFO - Chain [1] done processing
# 08:38:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:38:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:38:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 08:39:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:39:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:39:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:39:27 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:39:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:39:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:39:49 - cmdstanpy - INFO - Chain [1] start processing
# 08:40:03 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points                  (3 + 4) / 7]
# Processing group: Avellino with 29862 data points
# 08:40:37 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:40:37 - cmdstanpy - INFO - Chain [1] start processing
# 08:40:52 - cmdstanpy - INFO - Chain [1] done processing
# 08:40:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:41:00 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:41:02 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:12 - cmdstanpy - INFO - Chain [1] done processing
# 08:41:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:41:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:42:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:42:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:42:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:42:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 08:42:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:42:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:42:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:42:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:42:52 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 08:43:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:43:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:43:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:43:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:43:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:44:02 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:44:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:44:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:44:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:44:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:44:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:45:08 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:45:08 - cmdstanpy - INFO - Chain [1] start processing
# 08:45:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:45:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:45:27 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:45:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:45:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:45:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:45:50 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 08:46:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 08:46:38 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:46:38 - cmdstanpy - INFO - Chain [1] start processing
# 08:46:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:46:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 08:47:02 - cmdstanpy - INFO - Chain [1] start processing
# 08:47:03 - cmdstanpy - INFO - Chain [1] start processing
# 08:47:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:47:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:47:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:47:37 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:48:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:48:10 - cmdstanpy - INFO - Chain [1] start processing
# 08:48:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:48:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 08:48:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:48:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:48:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:48:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:48:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:49:07 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:49:41 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:49:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:49:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:50:05 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:50:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:50:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:50:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:50:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:50:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 08:51:11 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:51:11 - cmdstanpy - INFO - Chain [1] start processing
# 08:51:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:51:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:51:33 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:51:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:51:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:51:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:51:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:52:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 08:52:41 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:52:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:52:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:52:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 08:53:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:53:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:53:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:53:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:53:24 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 08:53:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:54:13 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:54:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:54:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:54:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:54:37 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:54:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:54:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:54:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 08:54:59 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 08:55:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:55:47 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:55:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:56:03 - cmdstanpy - INFO - Chain [1] done processing
# 08:56:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:56:11 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 08:56:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:56:22 - cmdstanpy - INFO - Chain [1] done processing
# 08:56:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 08:56:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:56:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 08:57:23 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:57:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:57:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:57:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 08:57:43 - cmdstanpy - INFO - Chain [1] start processing
# ...
# 10:32:31 - cmdstanpy - INFO - Chain [1] done processing
# 10:32:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:32:39 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:32:41 - cmdstanpy - INFO - Chain [1] start processing
# 10:32:53 - cmdstanpy - INFO - Chain [1] done processing
# 10:32:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:33:02 - cmdstanpy - INFO - Chain [1] start processing
# 10:33:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 10:33:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:33:50 - cmdstanpy - INFO - Chain [1] start processing
# 10:34:04 - cmdstanpy - INFO - Chain [1] done processing
# 10:34:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:34:12 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:34:16 - cmdstanpy - INFO - Chain [1] start processing
# 10:34:22 - cmdstanpy - INFO - Chain [1] done processing
# 10:34:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:34:34 - cmdstanpy - INFO - Chain [1] start processing
# 10:34:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points===>               (5 + 2) / 7]
# Processing group: Benevento with 29862 data points
# 10:35:23 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:35:23 - cmdstanpy - INFO - Chain [1] start processing
# 10:35:38 - cmdstanpy - INFO - Chain [1] done processing
# 10:35:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 10:35:46 - cmdstanpy - INFO - Chain [1] start processing
# 10:35:46 - cmdstanpy - INFO - Chain [1] start processing
# 10:35:59 - cmdstanpy - INFO - Chain [1] done processing
# 10:36:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 10:36:07 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 10:36:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 10:36:54 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:36:54 - cmdstanpy - INFO - Chain [1] start processing
# 10:37:10 - cmdstanpy - INFO - Chain [1] done processing
# 10:37:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 10:37:18 - cmdstanpy - INFO - Chain [1] start processing
# 10:37:19 - cmdstanpy - INFO - Chain [1] start processing
# 10:37:28 - cmdstanpy - INFO - Chain [1] done processing
# 10:37:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:37:37 - cmdstanpy - INFO - Chain [1] start processing
# 10:37:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 10:38:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:38:26 - cmdstanpy - INFO - Chain [1] start processing
# 10:38:38 - cmdstanpy - INFO - Chain [1] done processing
# 10:38:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:38:46 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:38:48 - cmdstanpy - INFO - Chain [1] start processing
# 10:38:58 - cmdstanpy - INFO - Chain [1] done processing
# 10:38:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 10:39:06 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 10:39:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>     (101 + 12) / 113]
# Processing group: Avellino with 29862 data points
# 10:39:53 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:39:53 - cmdstanpy - INFO - Chain [1] start processing
# 10:40:08 - cmdstanpy - INFO - Chain [1] done processing
# 10:40:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:40:16 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:40:18 - cmdstanpy - INFO - Chain [1] start processing
# 10:40:29 - cmdstanpy - INFO - Chain [1] done processing
# 10:40:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 10:40:37 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 10:40:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 10:41:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 10:41:41 - cmdstanpy - INFO - Chain [1] done processing
# 10:41:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:41:49 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:41:52 - cmdstanpy - INFO - Chain [1] start processing
# 10:42:03 - cmdstanpy - INFO - Chain [1] done processing
# 10:42:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:42:11 - cmdstanpy - INFO - Chain [1] start processing
# 10:42:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 10:43:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:43:00 - cmdstanpy - INFO - Chain [1] start processing
# 10:43:12 - cmdstanpy - INFO - Chain [1] done processing
# 10:43:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:43:20 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:43:23 - cmdstanpy - INFO - Chain [1] start processing
# 10:43:35 - cmdstanpy - INFO - Chain [1] done processing
# 10:43:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:43:44 - cmdstanpy - INFO - Chain [1] start processing
# 10:43:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>     (101 + 12) / 113]
# Processing group: Avellino with 29862 data points
# 10:44:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:44:34 - cmdstanpy - INFO - Chain [1] start processing
# 10:44:48 - cmdstanpy - INFO - Chain [1] done processing
# 10:44:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:44:56 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:44:58 - cmdstanpy - INFO - Chain [1] start processing
# 10:45:09 - cmdstanpy - INFO - Chain [1] done processing
# 10:45:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:45:19 - cmdstanpy - INFO - Chain [1] start processing
# 10:45:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 10:46:07 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:46:07 - cmdstanpy - INFO - Chain [1] start processing
# 10:46:22 - cmdstanpy - INFO - Chain [1] done processing
# 10:46:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:46:30 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:46:32 - cmdstanpy - INFO - Chain [1] start processing
# 10:46:41 - cmdstanpy - INFO - Chain [1] done processing
# 10:46:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:46:50 - cmdstanpy - INFO - Chain [1] start processing
# 10:47:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points===========>  (108 + 5) / 113]
# Processing group: Avellino with 29862 data points
# 10:47:38 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:47:38 - cmdstanpy - INFO - Chain [1] start processing
# 10:47:49 - cmdstanpy - INFO - Chain [1] done processing
# 10:47:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:47:57 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:47:59 - cmdstanpy - INFO - Chain [1] start processing
# 10:48:10 - cmdstanpy - INFO - Chain [1] done processing
# 10:48:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 10:48:18 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 10:48:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points========>    (102 + 11) / 113]
# Processing group: Avellino with 29862 data points
# 10:49:05 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:49:05 - cmdstanpy - INFO - Chain [1] start processing
# 10:49:16 - cmdstanpy - INFO - Chain [1] done processing
# 10:49:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:49:24 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:49:26 - cmdstanpy - INFO - Chain [1] start processing
# 10:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 10:49:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 10:49:45 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 10:49:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 10:50:31 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:50:31 - cmdstanpy - INFO - Chain [1] start processing
# 10:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 10:50:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:50:54 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:50:56 - cmdstanpy - INFO - Chain [1] start processing
# 10:51:05 - cmdstanpy - INFO - Chain [1] done processing
# 10:51:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:51:14 - cmdstanpy - INFO - Chain [1] start processing
# 10:51:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 10:52:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:52:04 - cmdstanpy - INFO - Chain [1] start processing
# 10:52:20 - cmdstanpy - INFO - Chain [1] done processing
# 10:52:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:52:28 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:52:30 - cmdstanpy - INFO - Chain [1] start processing
# 10:52:40 - cmdstanpy - INFO - Chain [1] done processing
# 10:52:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:52:50 - cmdstanpy - INFO - Chain [1] start processing
# 10:53:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>     (100 + 13) / 113]
# Processing group: Avellino with 29862 data points
# 10:53:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:53:35 - cmdstanpy - INFO - Chain [1] start processing
# 10:53:50 - cmdstanpy - INFO - Chain [1] done processing
# 10:53:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 10:53:58 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 10:54:00 - cmdstanpy - INFO - Chain [1] start processing
# 10:54:12 - cmdstanpy - INFO - Chain [1] done processing
# 10:54:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:54:21 - cmdstanpy - INFO - Chain [1] start processing
# 10:54:34 - cmdstanpy - INFO - Chain [1] done processing
# +--------+---------+------------------+------------------+------------------+-----------------+
# |    Time|     NOME|               MSE|              RMSE|               MAE|         Coverage|
# +--------+---------+------------------+------------------+------------------+-----------------+
# |  5 Days|Benevento|18.698557277982307| 4.324182845114474|3.2076624461469576|95.02332089552239|
# |  5 Days|  Salerno|10.100288828998792| 3.178095157322825| 2.351939575044667|94.86473880597015|
# |  5 Days| Avellino|13.312248485004357|3.6485954126217335| 2.629176152557534|94.90671641791046|
# |  5 Days|   Napoli| 74.21461316826144| 8.614790372856524| 6.029997574461622|95.10261194029852|
# |  5 Days|  Caserta|30.630310644577804| 5.534465705429731| 4.010426380050726|94.64085820895522|
# | 30 Days|Benevento|18.376847937208662| 4.286822592224766|  3.17850779722537|95.19963702359347|
# | 30 Days|  Salerno|10.073425511994486| 3.173866019855672|2.3563783997724164|94.94555353901997|
# | 30 Days| Avellino|13.118110531523675| 3.621893224754655| 2.613092394444237|95.09528130671507|
# | 30 Days|   Napoli| 73.27582874759032| 8.560130182864647| 5.999725202780006|95.17241379310344|
# | 30 Days|  Caserta| 30.16550898527858| 5.492313627723619|3.9798486838184552|94.79582577132486|
# | 90 Days|Benevento| 17.92066450009168| 4.233280583671685|3.1536698110890233|95.49403747870528|
# | 90 Days|  Salerno|10.089699804074181|3.1764287815208734| 2.381389496246787|95.30664395229984|
# | 90 Days| Avellino| 13.07786643145503| 3.616333285450199|  2.63983906714344| 95.3236797274276|
# | 90 Days|   Napoli| 71.57458457321307| 8.460176391377018| 5.962284471552178| 95.4855195911414|
# | 90 Days|  Caserta| 29.41035005547815| 5.423131019575145|3.9514410313930495|95.05962521294718|
# |180 Days|Benevento| 19.34982836624383| 4.398843980666265| 3.323543433133082|95.81562219709082|
# |180 Days|  Salerno|10.922600161303295|3.3049357272575355|2.5077023367624505|95.63233631010412|
# |180 Days| Avellino|  14.6266538248546|3.8244808569078494|2.8408352891020687|95.74152790235152|
# |180 Days|   Napoli| 79.93153811984347|  8.94044395541091| 6.435507381328639|95.54654291619545|
# |180 Days|  Caserta| 31.89100732830453| 5.647212350204703| 4.175456454673259|95.40225402643996|
# |365 Days|Benevento| 21.34154225299777| 4.619690709668535|  3.46694691103018|96.35060934779698|
# |365 Days|  Salerno|12.351801258840519|  3.51451294759893|2.6367373284868822|96.22338288469264|
# |365 Days| Avellino|16.141038288808694| 4.017591105228193| 2.956106754830933|96.34726128297844|
# |365 Days|   Napoli| 90.68375816241436|  9.52280201213983| 6.991005137972531|96.21333869023704|
# |365 Days|  Caserta|  34.5930508905164| 5.881585746252145|4.3487020108438825|96.06937190304005|
# +--------+---------+------------------+------------------+------------------+-----------------+

# %%
result_df_PM25_pd = result_df_PM25.pandas_api()
result_df_PM25_pd

# %% [markdown]
# PM10

# %%
from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_PM10_prophet = data_PM10.groupBy("NOME", "original_date_time").agg(avg("c_PM10").alias("avg_c_PM10"))
data_PM10_prophet.show()

data_PM10_prophet_u = data_PM10_prophet.withColumnRenamed("avg_c_PM10", "y").withColumnRenamed("original_date_time", "ds")
data_PM10_prophet = data_PM10_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

data_PM10_prophet.printSchema()


def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    # Initiate the model
    
    # Convert "ds" column to pandas datetime format and set timezone to Europe/Rome
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    #m.add_country_holidays(country_name="IT")
    
    # Fit the model
    m.fit(group[group['ds'] <= cutoff_date])
    
    
    # Make predictions
    forecast = m.predict(group)

    # Create the directory if it does not exist
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/PM10/'

    if not os.path.exists(path):
        os.makedirs(path)
    
    try:
        fig1 = m.plot(forecast)
        fig1.suptitle(f"PM10 Concentration Forecast for {group['NOME'].iloc[0]}")
        fig1.legend(['Actual', 'Forecasted'], loc='upper right')
        fig1.subplots_adjust(top=0.9)
        
        fig2 = m.plot_components(forecast)
        fig2.suptitle(f"PM10 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        fig2.subplots_adjust(top=0.9)

        # Save the plots as images using Matplotlib's savefig method
        fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/PM10/{group['NOME'].iloc[0]}_prophet_forecast.png")
        fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/PM10/{group['NOME'].iloc[0]}_prophet_components.png")
    except Exception as e:
        print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    #Return the forecasted results
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

# Define the restult schema
result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_PM10_prophet_train = data_PM10_prophet.filter(col('ds') <= cutoff_date)
data_PM10_prophet_test = data_PM10_prophet.filter((col('ds') > cutoff_date))

max_date = data_PM10_prophet_test.agg(max('ds')).collect()[0][0]

period = data_PM10_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_PM10 = data_PM10_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

spark_forecast_PM10.show()
# Out:
# +---------+-------------------+------------------+
# |     NOME| original_date_time|        avg_c_PM10|
# +---------+-------------------+------------------+
# |   Napoli|2022-01-24 05:00:00|  2.19421393561644|
# |  Salerno|2022-01-24 05:00:00| 1.951264651057693|
# | Avellino|2021-05-21 15:00:00|2.9013350687861266|
# |  Caserta|2019-01-24 20:00:00| 7.254402715757577|
# | Avellino|2019-01-24 01:00:00|3.4991190641618517|
# |  Salerno|2021-11-01 00:00:00|2.1814328497435893|
# |  Salerno|2019-02-01 19:00:00|  5.94134689775641|
# |Benevento|2022-01-08 13:00:00| 5.350933993798452|
# |   Napoli|2021-06-11 17:00:00|5.7778270589041085|
# |   Napoli|2021-12-06 16:00:00| 5.087223741095889|
# |  Salerno|2021-12-30 20:00:00| 4.955298324038458|
# | Avellino|2019-11-03 04:00:00| 3.701815800578033|
# |  Caserta|2019-02-01 05:00:00| 5.011559084242426|
# | Avellino|2021-11-01 02:00:00|2.3479436712138733|
# |Benevento|2020-11-21 02:00:00| 4.134004267441858|
# |Benevento|2020-11-21 06:00:00| 6.151227803100771|
# | Avellino|2021-12-30 12:00:00| 5.442934412138726|
# | Avellino|2021-06-11 10:00:00| 4.129052556069364|
# |  Salerno|2022-01-24 13:00:00|3.5995860102564117|
# |  Caserta|2021-11-01 19:00:00| 8.712652753939388|
# +---------+-------------------+------------------+
# only showing top 20 rows
#
# root
#  |-- NOME: string (nullable = true)
#  |-- ds: timestamp (nullable = true)
#  |-- y: double (nullable = true)
# The time used for the Spark forecast is  0.04328560829162598
# Processing group: Benevento with 29862 data points>             (85 + 28) / 113]
# 14:43:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 1) / 1]
# 14:43:49 - cmdstanpy - INFO - Chain [1] done processing
# +-------------------+---------+------------------+---------+----------+----------+---------+---------+-----------+-----------+
# |                 ds|     NOME|                 y|     yhat|yhat_upper|yhat_lower|    trend|   yearly|     weekly|      daily|
# +-------------------+---------+------------------+---------+----------+----------+---------+---------+-----------+-----------+
# |2019-01-01 01:00:00|Benevento| 6.449259526356591| 7.895175|   19.7369|-3.3848724|2.1233678|3.7960894|0.123790376|  1.8519274|
# |2019-01-01 02:00:00|Benevento| 6.512501393023254| 7.545446| 17.923363|-3.6291122|2.1319215|3.7946844| 0.14671066|  1.4721295|
# |2019-01-01 03:00:00|Benevento| 6.333786593023259|7.1371117| 18.484673| -4.349808| 2.140475|3.7933025| 0.16871823|  1.0346159|
# |2019-01-01 04:00:00|Benevento|5.8128533441860455| 6.768056| 17.984974| -4.086628|2.1490285|3.7919436|  0.1897584|  0.6373255|
# |2019-01-01 05:00:00|Benevento| 5.554195050387596| 6.526956| 17.954464|-5.3307576| 2.157582| 3.790608| 0.20977616| 0.36899006|
# |2019-01-01 06:00:00|Benevento| 5.500685613953489|6.4752736|  17.42913| -4.139703|2.1661355|3.7892954| 0.22871628| 0.29112616|
# |2019-01-01 07:00:00|Benevento|5.6382669844961235|6.5941815|  18.43095| -4.924467|2.1746893| 3.788006| 0.24652356| 0.38496268|
# |2019-01-01 08:00:00|Benevento| 6.425872685271315|6.7547216|  17.37826|-4.7675924|2.1832428|3.7867398| 0.26314318|  0.5215959|
# |2019-01-01 09:00:00|Benevento|7.9386950844961275|6.7691646| 19.021341| -5.169023|2.1917963|3.7854972| 0.27852112| 0.51334995|
# |2019-01-01 10:00:00|Benevento| 9.189698725581398|6.5088177| 17.938503| -4.641666|2.2003498|3.7842774| 0.29260448| 0.23158601|
# |2019-01-01 11:00:00|Benevento| 8.966433049612407| 5.998866| 17.318586|-5.2714605|2.2089033|3.7830813| 0.30534223|-0.29846075|
# |2019-01-01 12:00:00|Benevento| 8.488076863565892|5.4049773| 16.975204|-6.5058284| 2.217457|3.7819085| 0.31668562|-0.91107386|
# |2019-01-01 13:00:00|Benevento| 7.974010713953488|4.9157486| 16.114136|-5.7598867|2.2260106| 3.780759|   0.326589| -1.4176099|
# |2019-01-01 14:00:00|Benevento|7.4397110341085275| 4.619112|  16.45095|  -5.96139| 2.234564| 3.779633| 0.33501035| -1.7300955|
# |2019-01-01 15:00:00|Benevento|6.8370109821705425| 4.478195|15.3007345| -6.752891|2.2431176|3.7785304| 0.34191224| -1.8853649|
# |2019-01-01 16:00:00|Benevento|  6.20729080387597| 4.421254| 15.055082|-6.6135993|2.2516713|3.7774513| 0.34726232| -1.9551308|
# |2019-01-01 17:00:00|Benevento| 5.614953354263566| 4.454298| 15.868474|-6.9587545|2.2602248|3.7763956| 0.35103428| -1.9333566|
# |2019-01-01 18:00:00|Benevento| 6.036188596124033| 4.684088| 16.242476|-6.2802444|2.2687783|3.7753634| 0.35320854| -1.7132622|
# |2019-01-01 19:00:00|Benevento|6.4208450573643425|5.2238827| 16.159445|-5.8033824|2.2773318| 3.774355| 0.35377303| -1.1815771|
# |2019-01-01 20:00:00|Benevento| 7.144277747286823|6.0653524| 17.127596|-4.6889033|2.2858853|3.7733698|  0.3527239| -0.3466266|
# +-------------------+---------+------------------+---------+----------+----------+---------+---------+-----------+-----------+
# only showing top 20 rows
# Processing group: Salerno with 29862 data points

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import pow, sqrt
from prophet.diagnostics import performance_metrics


# Calculate MAE
mae_PM10 = spark_forecast_PM10.select(col("NOME"), abs(col("y") - col("yhat")).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MAE")


# Calculate MSE
mse_PM10 = spark_forecast_PM10.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MSE")

# Calculate RMSE
rmse_PM10 = spark_forecast_PM10.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                     .groupBy("NOME") \
                     .agg({"error": "mean"}) \
                     .withColumnRenamed("avg(error)", "MSE") \
                     .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE"))

# Show the results
mae_PM10.show()
mse_PM10.show()
rmse_PM10.show()
# Out:
# 14:43:59 - cmdstanpy - INFO - Chain [1] start processing        (58 + 55) / 113]
# Processing group: Benevento with 29862 data points==>           (88 + 25) / 113]
# 14:44:02 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 14:44:14 - cmdstanpy - INFO - Chain [1] done processing
# 14:44:21 - cmdstanpy - INFO - Chain [1] start processing
# Optimization terminated abnormally. Falling back to Newton.
# 14:44:23 - cmdstanpy - INFO - Chain [1] start processing
# 14:44:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 14:44:33 - cmdstanpy - INFO - Chain [1] start processing
# 14:44:46 - cmdstanpy - INFO - Chain [1] done processing
# 14:49:00 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Caserta with 29862 data points
# 14:49:15 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:47 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+
# |     NOME|               MAE|
# +---------+------------------+
# |Benevento| 4.158243410603779|
# |  Salerno|3.4816548071620828|
# | Avellino|4.5388499573042145|
# |   Napoli| 7.064490407417741|
# |  Caserta| 5.072139471964799|
# +---------+------------------+
# Processing group: Benevento with 29862 data points=============>(112 + 1) / 113]
# 14:50:02 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 14:50:12 - cmdstanpy - INFO - Chain [1] start processing
# 14:50:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 14:50:27 - cmdstanpy - INFO - Chain [1] done processing
# 14:50:28 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 14:50:37 - cmdstanpy - INFO - Chain [1] start processing
# 14:50:43 - cmdstanpy - INFO - Chain [1] done processing
# 14:50:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 14:51:03 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:15 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+
# |     NOME|               MSE|
# +---------+------------------+
# |Benevento| 37.82701124247217|
# |  Salerno| 31.22884880618204|
# | Avellino|30.921080037702307|
# |   Napoli|  97.4481522058115|
# |  Caserta| 52.57019428466397|
# +---------+------------------+
# Processing group: Avellino with 29862 data points===>           (89 + 24) / 113]
# Processing group: Benevento with 29862 data points
# 14:51:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:51:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:46 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:51:55 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:56 - cmdstanpy - INFO - Chain [1] start processing
# 14:52:10 - cmdstanpy - INFO - Chain [1] done processing
# 14:52:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:52:21 - cmdstanpy - INFO - Chain [1] start processing
# 14:52:34 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+------------------+
# |     NOME|               MSE|              RMSE|
# +---------+------------------+------------------+
# |Benevento| 37.82701124247217|  6.15036675674485|
# |  Salerno| 31.22884880618204|5.5882778032397455|
# | Avellino|30.921080037702307| 5.560672624575403|
# |   Napoli|  97.4481522058115| 9.871583064828634|
# |  Caserta| 52.57019428466397| 7.250530620903822|
# +---------+------------------+------------------+

# %%
#For Long and Short Term Forecast

from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_PM10_prophet = data_PM10.groupBy("NOME", "original_date_time").agg(avg("c_PM10").alias("avg_c_PM10"))
data_PM10_prophet.show()

data_PM10_prophet_u = data_PM10_prophet.withColumnRenamed("avg_c_PM10", "y").withColumnRenamed("original_date_time", "ds")
data_PM10_prophet = data_PM10_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

#data_PM10_prophet.printSchema()


def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    # Initiate the model
    
    # Convert "ds" column to pandas datetime format and set timezone to Europe/Rome
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    #m.add_country_holidays(country_name="IT")
    
    # Fit the model
    m.fit(group[group['ds'] <= cutoff_date])
    
    
    # Make predictions
    forecast = m.predict(group)

    # Create the directory if it does not exist
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/PM10/'

    if not os.path.exists(path):
        os.makedirs(path)
    
    #try:
     #   fig1 = m.plot(forecast)
      #  fig1.suptitle(f"PM10 Concentration Forecast for {group['NOME'].iloc[0]}")
       # fig1.legend(['Actual', 'Forecasted'], loc='upper right')
       # fig1.subplots_adjust(top=0.9)
        
       # fig2 = m.plot_components(forecast)
       # fig2.suptitle(f"PM10 Concentration Component Forecast for {group['NOME'].iloc[0]}")
       # fig2.subplots_adjust(top=0.9)

        # Save the plots as images using Matplotlib's savefig method
        #fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/PM10/{group['NOME'].iloc[0]}_prophet_forecast.png")
       # fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/PM10/{group['NOME'].iloc[0]}_prophet_components.png")
   # except Exception as e:
   #     print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    #Return the forecasted results
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

# Define the restult schema
result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_PM10_prophet_train = data_PM10_prophet.filter(col('ds') <= cutoff_date)
data_PM10_prophet_test = data_PM10_prophet.filter((col('ds') > cutoff_date))

max_date = data_PM10_prophet_test.agg(max('ds')).collect()[0][0]

period = data_PM10_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_PM10 = data_PM10_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

#spark_forecast_PM10.show()
# Out:
# +---------+-------------------+------------------+
# |     NOME| original_date_time|        avg_c_PM10|
# +---------+-------------------+------------------+
# |   Napoli|2022-01-24 05:00:00|  2.19421393561644|
# |  Salerno|2022-01-24 05:00:00| 1.951264651057693|
# | Avellino|2021-05-21 15:00:00|2.9013350687861266|
# |  Caserta|2019-01-24 20:00:00| 7.254402715757577|
# | Avellino|2019-01-24 01:00:00|3.4991190641618517|
# |  Salerno|2021-11-01 00:00:00|2.1814328497435893|
# |  Salerno|2019-02-01 19:00:00|  5.94134689775641|
# |Benevento|2022-01-08 13:00:00| 5.350933993798452|
# |   Napoli|2021-06-11 17:00:00|5.7778270589041085|
# |   Napoli|2021-12-06 16:00:00| 5.087223741095889|
# |  Salerno|2021-12-30 20:00:00| 4.955298324038458|
# | Avellino|2019-11-03 04:00:00| 3.701815800578033|
# |  Caserta|2019-02-01 05:00:00| 5.011559084242426|
# | Avellino|2021-11-01 02:00:00|2.3479436712138733|
# |Benevento|2020-11-21 02:00:00| 4.134004267441858|
# |Benevento|2020-11-21 06:00:00| 6.151227803100771|
# | Avellino|2021-12-30 12:00:00| 5.442934412138726|
# | Avellino|2021-06-11 10:00:00| 4.129052556069364|
# |  Salerno|2022-01-24 13:00:00|3.5995860102564117|
# |  Caserta|2021-11-01 19:00:00| 8.712652753939388|
# +---------+-------------------+------------------+
# only showing top 20 rows
# [Stage 1333:==============================================>    (102 + 11) / 113]
# The time used for the Spark forecast is  0.03779244422912598

# %%
from pyspark.sql.functions import col, pow, sqrt

# Define cutoff dates
cutoff_dates = {
    "5 Days": "2021-07-05 23:00:00",
    "30 Days": "2021-07-30 23:00:00",
    "90 Days": "2021-09-28 23:00:00",
    "180 Days": "2021-12-27 23:00:00",
    "365 Days": "2022-06-29 23:00:00"
}

# Define a list to store the evaluation results
results = []

# Compute evaluation metrics for each time period and NOME
for period, cutoff in cutoff_dates.items():
    for nome in spark_forecast_PM10.select("NOME").distinct().rdd.flatMap(lambda x: x).collect():
        # Filter the forecast data based on the cutoff date and NOME
        forecast_data_PM10 = spark_forecast_PM10.filter((col("ds") <= cutoff) & (col("NOME") == nome))

        # Calculate MAE
        mae = forecast_data_PM10.select(abs(col("y") - col("yhat")).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MAE") \
                             .collect()[0]["MAE"]

        # Calculate MSE
        mse = forecast_data_PM10.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MSE") \
                             .collect()[0]["MSE"]

        # Calculate RMSE
        rmse = forecast_data_PM10.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                              .agg({"error": "mean"}) \
                              .withColumnRenamed("avg(error)", "MSE") \
                              .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE")) \
                              .collect()[0]["RMSE"]

        # Calculate coverage
        coverage = forecast_data_PM10.filter((col("y") >= col("yhat_lower")) & (col("y") <= col("yhat_upper"))) \
                                  .count() / forecast_data_PM10.count() * 100

        # Add the results to the list
        results.append((period, nome, mse, rmse, mae, coverage))

# Create a Spark DataFrame from the results list
result_df_PM10 = spark.createDataFrame(results, ["Time", "NOME", "MSE", "RMSE", "MAE", "Coverage"])

# Show the results
result_df_PM10.show(100)
# Out:
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 10:57:02 - cmdstanpy - INFO - Chain [1] start processing
# 10:57:02 - cmdstanpy - INFO - Chain [1] start processing
# 10:57:16 - cmdstanpy - INFO - Chain [1] done processing
# 10:57:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 10:57:23 - cmdstanpy - INFO - Chain [1] start processing
# 10:57:24 - cmdstanpy - INFO - Chain [1] start processing
# 10:57:39 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 10:57:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 10:57:47 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 10:57:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 10:58:32 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:58:32 - cmdstanpy - INFO - Chain [1] start processing
# 10:58:47 - cmdstanpy - INFO - Chain [1] done processing
# 10:58:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 10:58:55 - cmdstanpy - INFO - Chain [1] start processing
# 10:58:56 - cmdstanpy - INFO - Chain [1] start processing
# 10:59:06 - cmdstanpy - INFO - Chain [1] done processing
# 10:59:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 10:59:14 - cmdstanpy - INFO - Chain [1] start processing
# 10:59:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 11:00:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:00:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:00:16 - cmdstanpy - INFO - Chain [1] done processing
# 11:00:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:00:24 - cmdstanpy - INFO - Chain [1] start processing
# 11:00:25 - cmdstanpy - INFO - Chain [1] start processing
# 11:00:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:00:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:00:45 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 11:00:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:01:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:01:29 - cmdstanpy - INFO - Chain [1] start processing
# 11:01:46 - cmdstanpy - INFO - Chain [1] done processing
# 11:01:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:01:54 - cmdstanpy - INFO - Chain [1] start processing
# 11:01:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:02:04 - cmdstanpy - INFO - Chain [1] done processing
# 11:02:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:02:12 - cmdstanpy - INFO - Chain [1] start processing
# 11:02:24 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:02:59 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:02:59 - cmdstanpy - INFO - Chain [1] start processing
# 11:03:11 - cmdstanpy - INFO - Chain [1] done processing
# 11:03:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 11:03:19 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 11:03:21 - cmdstanpy - INFO - Chain [1] start processing
# 11:03:29 - cmdstanpy - INFO - Chain [1] done processing
# 11:03:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:03:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:03:49 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 11:04:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:04:26 - cmdstanpy - INFO - Chain [1] start processing
# 11:04:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:04:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 11:04:45 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 11:04:48 - cmdstanpy - INFO - Chain [1] start processing
# 11:04:57 - cmdstanpy - INFO - Chain [1] done processing
# 11:05:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:05:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:05:17 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 11:05:51 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:05:51 - cmdstanpy - INFO - Chain [1] start processing
# 11:06:08 - cmdstanpy - INFO - Chain [1] done processing
# 11:06:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:06:16 - cmdstanpy - INFO - Chain [1] start processing
# 11:06:16 - cmdstanpy - INFO - Chain [1] start processing
# 11:06:29 - cmdstanpy - INFO - Chain [1] done processing
# 11:06:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:06:37 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 11:06:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 11:07:23 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:07:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:07:36 - cmdstanpy - INFO - Chain [1] done processing
# 11:07:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 11:07:44 - cmdstanpy - INFO - Chain [1] start processing
# 11:07:44 - cmdstanpy - INFO - Chain [1] start processing
# 11:07:57 - cmdstanpy - INFO - Chain [1] done processing
# 11:07:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 11:08:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:08:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 11:08:50 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:08:50 - cmdstanpy - INFO - Chain [1] start processing
# 11:09:05 - cmdstanpy - INFO - Chain [1] done processing
# 11:09:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 11:09:13 - cmdstanpy - INFO - Chain [1] start processing
# 11:09:14 - cmdstanpy - INFO - Chain [1] start processing
# 11:09:24 - cmdstanpy - INFO - Chain [1] done processing
# 11:09:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:09:32 - cmdstanpy - INFO - Chain [1] start processing
# 11:09:44 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 11:10:20 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:10:20 - cmdstanpy - INFO - Chain [1] start processing
# 11:10:34 - cmdstanpy - INFO - Chain [1] done processing
# 11:10:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 11:10:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:10:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:10:55 - cmdstanpy - INFO - Chain [1] done processing
# 11:10:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:11:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:11:14 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>     (101 + 12) / 113]
# Processing group: Avellino with 29862 data points
# 11:11:46 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:11:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:12:00 - cmdstanpy - INFO - Chain [1] done processing
# 11:12:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 11:12:08 - cmdstanpy - INFO - Chain [1] start processing
# 11:12:08 - cmdstanpy - INFO - Chain [1] start processing
# 11:12:20 - cmdstanpy - INFO - Chain [1] done processing
# 11:12:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:12:28 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 11:12:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:13:14 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:13:14 - cmdstanpy - INFO - Chain [1] start processing
# 11:13:30 - cmdstanpy - INFO - Chain [1] done processing
# 11:13:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:13:38 - cmdstanpy - INFO - Chain [1] start processing
# 11:13:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:13:49 - cmdstanpy - INFO - Chain [1] done processing
# 11:13:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:13:57 - cmdstanpy - INFO - Chain [1] start processing
# 11:14:08 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points========>     (100 + 13) / 113]
# Processing group: Benevento with 29862 data points
# 11:14:46 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:14:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:15:01 - cmdstanpy - INFO - Chain [1] done processing
# 11:15:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:15:09 - cmdstanpy - INFO - Chain [1] start processing
# 11:15:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:15:24 - cmdstanpy - INFO - Chain [1] done processing
# 11:15:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:15:32 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 11:15:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (4 + 3) / 7]
# Processing group: Avellino with 29862 data points
# 11:16:17 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:16:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:16:36 - cmdstanpy - INFO - Chain [1] done processing
# 11:16:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:16:44 - cmdstanpy - INFO - Chain [1] start processing
# 11:16:45 - cmdstanpy - INFO - Chain [1] start processing
# 11:16:54 - cmdstanpy - INFO - Chain [1] done processing
# 11:16:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:17:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:17:13 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 11:17:50 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:17:50 - cmdstanpy - INFO - Chain [1] start processing
# 11:18:03 - cmdstanpy - INFO - Chain [1] done processing
# 11:18:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 11:18:11 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 11:18:13 - cmdstanpy - INFO - Chain [1] start processing
# 11:18:21 - cmdstanpy - INFO - Chain [1] done processing
# 11:18:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:18:29 - cmdstanpy - INFO - Chain [1] start processing
# 11:18:40 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 11:19:13 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:19:13 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:24 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 11:19:32 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 11:19:34 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:46 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:19:54 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:06 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:20:40 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:20:40 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:57 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 11:21:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:06 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:15 - cmdstanpy - INFO - Chain [1] done processing
# 11:21:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:21:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:22:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:22:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:22:26 - cmdstanpy - INFO - Chain [1] done processing
# 11:22:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:22:34 - cmdstanpy - INFO - Chain [1] start processing
# 11:22:35 - cmdstanpy - INFO - Chain [1] start processing
# 11:22:46 - cmdstanpy - INFO - Chain [1] done processing
# 11:22:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:22:54 - cmdstanpy - INFO - Chain [1] start processing
# 11:23:06 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:23:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:23:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:23:55 - cmdstanpy - INFO - Chain [1] done processing
# 11:23:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:24:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:24:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:24:15 - cmdstanpy - INFO - Chain [1] done processing
# 11:24:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:24:23 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 11:24:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 11:25:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:25:12 - cmdstanpy - INFO - Chain [1] start processing
# 11:25:28 - cmdstanpy - INFO - Chain [1] done processing
# 11:25:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:25:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:25:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:25:49 - cmdstanpy - INFO - Chain [1] done processing
# 11:25:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:25:57 - cmdstanpy - INFO - Chain [1] start processing
# 11:26:08 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:26:40 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:26:40 - cmdstanpy - INFO - Chain [1] start processing
# 11:26:54 - cmdstanpy - INFO - Chain [1] done processing
# 11:26:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 11:27:02 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 11:27:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:14 - cmdstanpy - INFO - Chain [1] done processing
# 11:27:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 11:27:24 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 11:28:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:28:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:26 - cmdstanpy - INFO - Chain [1] done processing
# 11:28:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:28:34 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:35 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:44 - cmdstanpy - INFO - Chain [1] done processing
# 11:28:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:28:52 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:04 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 11:29:38 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:29:38 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:54 - cmdstanpy - INFO - Chain [1] done processing
# 11:29:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:30:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:15 - cmdstanpy - INFO - Chain [1] done processing
# 11:30:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:30:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:34 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:31:08 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:31:08 - cmdstanpy - INFO - Chain [1] start processing
# 11:31:24 - cmdstanpy - INFO - Chain [1] done processing
# 11:31:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:31:32 - cmdstanpy - INFO - Chain [1] start processing
# 11:31:32 - cmdstanpy - INFO - Chain [1] start processing
# 11:31:46 - cmdstanpy - INFO - Chain [1] done processing
# 11:31:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:31:53 - cmdstanpy - INFO - Chain [1] start processing
# 11:32:04 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 11:32:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:32:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:32:56 - cmdstanpy - INFO - Chain [1] done processing
# 11:32:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 11:33:04 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 11:33:06 - cmdstanpy - INFO - Chain [1] start processing
# 11:33:15 - cmdstanpy - INFO - Chain [1] done processing
# 11:33:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:33:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:33:34 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==========>   (106 + 7) / 113]
# Processing group: Avellino with 29862 data points
# 11:34:07 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:34:07 - cmdstanpy - INFO - Chain [1] start processing
# 11:34:20 - cmdstanpy - INFO - Chain [1] done processing
# 11:34:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 11:34:28 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 11:34:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:34:40 - cmdstanpy - INFO - Chain [1] done processing
# 11:34:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:34:48 - cmdstanpy - INFO - Chain [1] start processing
# 11:35:00 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=============>(111 + 2) / 113]
# Processing group: Avellino with 29862 data points
# 11:35:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:35:34 - cmdstanpy - INFO - Chain [1] start processing
# 11:35:49 - cmdstanpy - INFO - Chain [1] done processing
# 11:35:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 11:35:57 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 11:36:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:36:07 - cmdstanpy - INFO - Chain [1] done processing
# 11:36:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:36:15 - cmdstanpy - INFO - Chain [1] start processing
# 11:36:27 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:37:01 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:37:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:37:14 - cmdstanpy - INFO - Chain [1] done processing
# 11:37:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:37:22 - cmdstanpy - INFO - Chain [1] start processing
# 11:37:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:37:35 - cmdstanpy - INFO - Chain [1] done processing
# 11:37:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:37:43 - cmdstanpy - INFO - Chain [1] start processing
# 11:37:55 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:38:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:38:29 - cmdstanpy - INFO - Chain [1] start processing
# 11:38:46 - cmdstanpy - INFO - Chain [1] done processing
# 11:38:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:38:54 - cmdstanpy - INFO - Chain [1] start processing
# 11:38:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:39:06 - cmdstanpy - INFO - Chain [1] done processing
# 11:39:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:39:14 - cmdstanpy - INFO - Chain [1] start processing
# 11:39:26 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:40:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:40:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:40:17 - cmdstanpy - INFO - Chain [1] done processing
# 11:40:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:40:25 - cmdstanpy - INFO - Chain [1] start processing
# 11:40:25 - cmdstanpy - INFO - Chain [1] start processing
# 11:40:35 - cmdstanpy - INFO - Chain [1] done processing
# 11:40:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:40:43 - cmdstanpy - INFO - Chain [1] start processing
# 11:40:54 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:41:28 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 11:41:43 - cmdstanpy - INFO - Chain [1] done processing
# 11:41:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 11:41:51 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 11:41:53 - cmdstanpy - INFO - Chain [1] start processing
# 11:42:06 - cmdstanpy - INFO - Chain [1] done processing
# 11:42:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:42:14 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 11:42:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:42:56 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:42:56 - cmdstanpy - INFO - Chain [1] start processing
# 11:43:10 - cmdstanpy - INFO - Chain [1] done processing
# 11:43:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:43:18 - cmdstanpy - INFO - Chain [1] start processing
# 11:43:18 - cmdstanpy - INFO - Chain [1] start processing
# 11:43:30 - cmdstanpy - INFO - Chain [1] done processing
# 11:43:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:43:38 - cmdstanpy - INFO - Chain [1] start processing
# 11:43:49 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:44:24 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:44:24 - cmdstanpy - INFO - Chain [1] start processing
# 11:44:36 - cmdstanpy - INFO - Chain [1] done processing
# 11:44:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 11:44:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 11:44:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:44:57 - cmdstanpy - INFO - Chain [1] done processing
# 11:45:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:45:06 - cmdstanpy - INFO - Chain [1] start processing
# 11:45:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 11:45:50 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:45:50 - cmdstanpy - INFO - Chain [1] start processing
# 11:46:07 - cmdstanpy - INFO - Chain [1] done processing
# 11:46:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:46:15 - cmdstanpy - INFO - Chain [1] start processing
# 11:46:15 - cmdstanpy - INFO - Chain [1] start processing
# 11:46:28 - cmdstanpy - INFO - Chain [1] done processing
# 11:46:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:46:36 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 11:46:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:47:21 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:47:21 - cmdstanpy - INFO - Chain [1] start processing
# 11:47:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:47:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:47:45 - cmdstanpy - INFO - Chain [1] start processing
# 11:47:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:47:55 - cmdstanpy - INFO - Chain [1] done processing
# 11:47:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:48:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:48:13 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:48:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:48:49 - cmdstanpy - INFO - Chain [1] start processing
# 11:49:02 - cmdstanpy - INFO - Chain [1] done processing
# 11:49:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:49:09 - cmdstanpy - INFO - Chain [1] start processing
# 11:49:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:49:19 - cmdstanpy - INFO - Chain [1] done processing
# 11:49:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:49:27 - cmdstanpy - INFO - Chain [1] start processing
# 11:49:38 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 11:50:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:50:12 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:25 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:50:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 11:50:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:50:54 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:05 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:51:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:51:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:51:59 - cmdstanpy - INFO - Chain [1] done processing
# 11:52:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:52:07 - cmdstanpy - INFO - Chain [1] start processing
# 11:52:07 - cmdstanpy - INFO - Chain [1] start processing
# 11:52:20 - cmdstanpy - INFO - Chain [1] done processing
# 11:52:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:52:28 - cmdstanpy - INFO - Chain [1] start processing
# 11:52:39 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:53:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:53:12 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:28 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:53:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:38 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:46 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:53:54 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:06 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:54:40 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:54:40 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:52 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:55:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:12 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:55:20 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:32 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 11:56:08 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:56:08 - cmdstanpy - INFO - Chain [1] start processing
# 11:56:23 - cmdstanpy - INFO - Chain [1] done processing
# 11:56:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 11:56:31 - cmdstanpy - INFO - Chain [1] start processing
# 11:56:31 - cmdstanpy - INFO - Chain [1] start processing
# 11:56:44 - cmdstanpy - INFO - Chain [1] done processing
# 11:56:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:56:52 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 11:57:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 11:57:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:57:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:57:50 - cmdstanpy - INFO - Chain [1] done processing
# 11:57:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:57:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:57:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:58:10 - cmdstanpy - INFO - Chain [1] done processing
# 11:58:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:58:18 - cmdstanpy - INFO - Chain [1] start processing
# 11:58:29 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 11:59:06 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:59:06 - cmdstanpy - INFO - Chain [1] start processing
# 11:59:22 - cmdstanpy - INFO - Chain [1] done processing
# 11:59:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 11:59:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:59:31 - cmdstanpy - INFO - Chain [1] start processing
# 11:59:44 - cmdstanpy - INFO - Chain [1] done processing
# 11:59:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 11:59:52 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 12:00:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 12:00:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 12:00:49 - cmdstanpy - INFO - Chain [1] done processing
# 12:00:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 12:00:57 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 12:01:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:01:08 - cmdstanpy - INFO - Chain [1] done processing
# 12:01:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 12:01:16 - cmdstanpy - INFO - Chain [1] start processing
# 12:01:27 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points========>    (103 + 10) / 113]
# Processing group: Avellino with 29862 data points
# 12:02:01 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:02:01 - cmdstanpy - INFO - Chain [1] start processing
# 12:02:16 - cmdstanpy - INFO - Chain [1] done processing
# 12:02:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 12:02:24 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 12:02:27 - cmdstanpy - INFO - Chain [1] start processing
# 12:02:36 - cmdstanpy - INFO - Chain [1] done processing
# 12:02:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 12:02:44 - cmdstanpy - INFO - Chain [1] start processing
# 12:02:55 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 12:03:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:03:29 - cmdstanpy - INFO - Chain [1] start processing
# 12:03:46 - cmdstanpy - INFO - Chain [1] done processing
# 12:03:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 12:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 12:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 12:04:04 - cmdstanpy - INFO - Chain [1] done processing
# 12:04:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 12:04:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:04:25 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 12:04:57 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:04:57 - cmdstanpy - INFO - Chain [1] start processing
# 12:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 12:05:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 12:05:21 - cmdstanpy - INFO - Chain [1] start processing
# 12:05:22 - cmdstanpy - INFO - Chain [1] start processing
# 12:05:31 - cmdstanpy - INFO - Chain [1] done processing
# 12:05:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 12:05:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:05:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (99 + 14) / 113]
# Processing group: Avellino with 29862 data points
# 12:06:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:06:26 - cmdstanpy - INFO - Chain [1] start processing
# 12:06:38 - cmdstanpy - INFO - Chain [1] done processing
# 12:06:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 12:06:46 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 12:06:49 - cmdstanpy - INFO - Chain [1] start processing
# 12:06:56 - cmdstanpy - INFO - Chain [1] done processing
# 12:07:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 12:07:04 - cmdstanpy - INFO - Chain [1] start processing
# 12:07:17 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 12:07:51 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:07:51 - cmdstanpy - INFO - Chain [1] start processing
# 12:08:05 - cmdstanpy - INFO - Chain [1] done processing
# 12:08:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 12:08:13 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 12:08:16 - cmdstanpy - INFO - Chain [1] start processing
# 12:08:26 - cmdstanpy - INFO - Chain [1] done processing
# 12:08:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 12:08:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:08:44 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 12:09:19 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:09:19 - cmdstanpy - INFO - Chain [1] start processing
# 12:09:31 - cmdstanpy - INFO - Chain [1] done processing
# 12:09:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 12:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 12:09:52 - cmdstanpy - INFO - Chain [1] done processing
# 12:09:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 12:10:00 - cmdstanpy - INFO - Chain [1] start processing
# 12:10:13 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 12:10:47 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:10:47 - cmdstanpy - INFO - Chain [1] start processing
# 12:11:01 - cmdstanpy - INFO - Chain [1] done processing
# 12:11:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 12:11:09 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 12:11:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:11:19 - cmdstanpy - INFO - Chain [1] done processing
# 12:11:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 12:11:27 - cmdstanpy - INFO - Chain [1] start processing
# 12:11:38 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==========>       (6 + 1) / 7]
# Processing group: Avellino with 29862 data points
# 12:12:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:12:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:12:28 - cmdstanpy - INFO - Chain [1] done processing
# 12:12:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 12:12:36 - cmdstanpy - INFO - Chain [1] start processing
# 12:12:37 - cmdstanpy - INFO - Chain [1] start processing
# 12:12:46 - cmdstanpy - INFO - Chain [1] done processing
# 12:12:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 12:12:54 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:06 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points===>               (5 + 2) / 7]
# Processing group: Benevento with 29862 data points
# 12:13:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:13:42 - cmdstanpy - INFO - Chain [1] start processing
# 12:13:58 - cmdstanpy - INFO - Chain [1] done processing
# 12:14:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 12:14:06 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 12:14:07 - cmdstanpy - INFO - Chain [1] start processing
# 12:14:16 - cmdstanpy - INFO - Chain [1] done processing
# 12:14:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 12:14:23 - cmdstanpy - INFO - Chain [1] start processing
# 12:14:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 12:15:07 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 12:15:07 - cmdstanpy - INFO - Chain [1] start processing
# 12:15:24 - cmdstanpy - INFO - Chain [1] done processing
# 12:15:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 12:15:32 - cmdstanpy - INFO - Chain [1] start processing
# 12:15:32 - cmdstanpy - INFO - Chain [1] start processing
# 12:15:46 - cmdstanpy - INFO - Chain [1] done processing
# 12:15:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# ...
# 13:45:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:46:06 - cmdstanpy - INFO - Chain [1] done processing
# 13:46:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 13:46:14 - cmdstanpy - INFO - Chain [1] start processing
# 13:46:15 - cmdstanpy - INFO - Chain [1] start processing
# 13:46:27 - cmdstanpy - INFO - Chain [1] done processing
# 13:46:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 13:46:35 - cmdstanpy - INFO - Chain [1] start processing
# 13:46:46 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points                   (4 + 3) / 7]
# Processing group: Benevento with 29862 data points
# 13:47:22 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:47:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:47:35 - cmdstanpy - INFO - Chain [1] done processing
# 13:47:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 13:47:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:47:44 - cmdstanpy - INFO - Chain [1] start processing
# 13:47:53 - cmdstanpy - INFO - Chain [1] done processing
# 13:47:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 13:48:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:48:13 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 13:48:46 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:48:46 - cmdstanpy - INFO - Chain [1] start processing
# 13:49:01 - cmdstanpy - INFO - Chain [1] done processing
# 13:49:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 13:49:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:49:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:49:22 - cmdstanpy - INFO - Chain [1] done processing
# 13:49:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 13:49:31 - cmdstanpy - INFO - Chain [1] start processing
# 13:49:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 13:50:16 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:50:16 - cmdstanpy - INFO - Chain [1] start processing
# 13:50:27 - cmdstanpy - INFO - Chain [1] done processing
# 13:50:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 13:50:35 - cmdstanpy - INFO - Chain [1] start processing
# 13:50:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 13:50:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 13:50:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:51:04 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points========>    (102 + 11) / 113]
# Processing group: Avellino with 29862 data points
# 13:51:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:51:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:51:53 - cmdstanpy - INFO - Chain [1] done processing
# 13:51:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 13:52:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:52:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:52:14 - cmdstanpy - INFO - Chain [1] done processing
# 13:52:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 13:52:22 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 13:52:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points========>      (98 + 15) / 113]
# Processing group: Benevento with 29862 data points
# 13:53:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:53:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:53:22 - cmdstanpy - INFO - Chain [1] done processing
# 13:53:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 13:53:29 - cmdstanpy - INFO - Chain [1] start processing
# 13:53:31 - cmdstanpy - INFO - Chain [1] start processing
# 13:53:39 - cmdstanpy - INFO - Chain [1] done processing
# 13:53:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 13:53:47 - cmdstanpy - INFO - Chain [1] start processing
# 13:53:57 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 13:54:32 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:54:32 - cmdstanpy - INFO - Chain [1] start processing
# 13:54:48 - cmdstanpy - INFO - Chain [1] done processing
# 13:54:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 13:54:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:54:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:55:08 - cmdstanpy - INFO - Chain [1] done processing
# 13:55:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 13:55:16 - cmdstanpy - INFO - Chain [1] start processing
# 13:55:27 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 13:56:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:56:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:56:18 - cmdstanpy - INFO - Chain [1] done processing
# 13:56:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 13:56:26 - cmdstanpy - INFO - Chain [1] start processing
# 13:56:26 - cmdstanpy - INFO - Chain [1] start processing
# 13:56:38 - cmdstanpy - INFO - Chain [1] done processing
# 13:56:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 13:56:46 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 13:56:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 13:57:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:57:29 - cmdstanpy - INFO - Chain [1] start processing
# 13:57:46 - cmdstanpy - INFO - Chain [1] done processing
# 13:57:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 13:57:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:57:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:58:05 - cmdstanpy - INFO - Chain [1] done processing
# 13:58:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 13:58:13 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 13:58:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 13:58:57 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:58:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:59:14 - cmdstanpy - INFO - Chain [1] done processing
# 13:59:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 13:59:21 - cmdstanpy - INFO - Chain [1] start processing
# 13:59:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:59:34 - cmdstanpy - INFO - Chain [1] done processing
# 13:59:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 13:59:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:59:54 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:00:27 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:00:27 - cmdstanpy - INFO - Chain [1] start processing
# 14:00:39 - cmdstanpy - INFO - Chain [1] done processing
# 14:00:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:00:47 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:00:49 - cmdstanpy - INFO - Chain [1] start processing
# 14:00:57 - cmdstanpy - INFO - Chain [1] done processing
# 14:01:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:01:05 - cmdstanpy - INFO - Chain [1] start processing
# 14:01:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points========>      (98 + 15) / 113]
# Processing group: Benevento with 29862 data points
# 14:01:53 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:01:53 - cmdstanpy - INFO - Chain [1] start processing
# 14:02:09 - cmdstanpy - INFO - Chain [1] done processing
# 14:02:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:02:17 - cmdstanpy - INFO - Chain [1] start processing
# 14:02:18 - cmdstanpy - INFO - Chain [1] start processing
# 14:02:28 - cmdstanpy - INFO - Chain [1] done processing
# 14:02:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:02:37 - cmdstanpy - INFO - Chain [1] start processing
# 14:02:47 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points===>               (5 + 2) / 7]
# Processing group: Benevento with 29862 data points
# 14:03:23 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:03:23 - cmdstanpy - INFO - Chain [1] start processing
# 14:03:39 - cmdstanpy - INFO - Chain [1] done processing
# 14:03:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:03:47 - cmdstanpy - INFO - Chain [1] start processing
# 14:03:48 - cmdstanpy - INFO - Chain [1] start processing
# 14:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 14:04:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 14:04:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:04:51 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:04:51 - cmdstanpy - INFO - Chain [1] start processing
# 14:05:05 - cmdstanpy - INFO - Chain [1] done processing
# 14:05:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:05:13 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 14:05:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:05:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:05:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:05:41 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 14:06:17 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:06:17 - cmdstanpy - INFO - Chain [1] start processing
# 14:06:33 - cmdstanpy - INFO - Chain [1] done processing
# 14:06:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:06:41 - cmdstanpy - INFO - Chain [1] start processing
# 14:06:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:06:52 - cmdstanpy - INFO - Chain [1] done processing
# 14:06:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:07:00 - cmdstanpy - INFO - Chain [1] start processing
# 14:07:11 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +--------+---------+------------------+------------------+------------------+-----------------+
# |    Time|     NOME|               MSE|              RMSE|               MAE|         Coverage|
# +--------+---------+------------------+------------------+------------------+-----------------+
# |  5 Days|Benevento|  33.1437854726761| 5.757063962878656|3.9214986767209346|96.56716417910448|
# |  5 Days|  Salerno|27.818981700451072| 5.274370265771172|3.2389082039797583| 97.2714552238806|
# |  5 Days| Avellino|27.625060951434666| 5.255954808732155| 3.362473053107414|97.08022388059702|
# |  5 Days|   Napoli|  90.6881208900541| 9.523031076818667|6.6225859088951005|95.47108208955224|
# |  5 Days|  Caserta| 46.66384959965485| 6.831094319335289| 4.773255586930724| 95.8115671641791|
# | 30 Days|Benevento|  32.4904415659933| 5.700038733727456|3.8766033526109696| 96.6016333938294|
# | 30 Days|  Salerno|27.251442744245967| 5.220291442462381| 3.202910617558943|97.36388384754991|
# | 30 Days| Avellino|27.050433235360117|  5.20100309895698|3.3229172768374386|97.12341197822141|
# | 30 Days|   Napoli| 89.52986649593025| 9.462022325905295|6.5937953292733225|95.60798548094374|
# | 30 Days|  Caserta|45.858218995179016| 6.771869682383072| 4.728005236653666|95.91651542649727|
# | 90 Days|Benevento|31.110623668826978| 5.577689814683762| 3.784366130123047|96.85689948892676|
# | 90 Days|  Salerno| 26.17826073845592| 5.116469558050348|3.1639057129642336|97.55536626916525|
# | 90 Days| Avellino| 25.93738563803863| 5.092875969237679|3.2621307276190543|97.25298126064736|
# | 90 Days|   Napoli| 86.49433116751989| 9.300232855553666| 6.509000946708329|  95.809199318569|
# | 90 Days|  Caserta|44.054076425855555| 6.637324493035997| 4.627960680786828|96.12862010221464|
# |180 Days|Benevento|30.271544713078733| 5.501958261662726|3.7832230309619495|97.09472370627462|
# |180 Days|  Salerno|25.958380892214088| 5.094936789815364|3.2357640525638818|97.69527746363529|
# |180 Days| Avellino| 25.52574836942102|5.0523012944024845| 3.313269488364599|97.41449908357056|
# |180 Days|   Napoli|  88.1174999577686| 9.387092199279211|6.6510328638855825|95.95211168740006|
# |180 Days|  Caserta|  43.5815723446158| 6.601634066245705| 4.660805659008078|96.42007565417462|
# |365 Days|Benevento| 37.82701124247217|  6.15036675674485| 4.158243410603779|97.42199008972814|
# |365 Days|  Salerno| 31.22884880618204|5.5882778032397455|3.4816548071620828|97.86058658095621|
# |365 Days| Avellino|30.921080037702307| 5.560672624575403|3.5648936649998006|97.80701754385966|
# |365 Days|   Napoli|  97.4481522058115| 9.871583064828634| 7.064490407417741|96.19659836614437|
# |365 Days|  Caserta| 52.57019428466397| 7.250530620903822| 5.072139471964799| 96.7557251908397|
# +--------+---------+------------------+------------------+------------------+-----------------+

# %%
result_df_PM10_pd = result_df_PM10.pandas_api()
result_df_PM10_pd

# %% [markdown]
# NO2

# %%
from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_NO2_prophet = data_NO2.groupBy("NOME", "original_date_time").agg(avg("c_NO2").alias("avg_c_NO2"))
data_NO2_prophet.show()

data_NO2_prophet_u = data_NO2_prophet.withColumnRenamed("avg_c_NO2", "y").withColumnRenamed("original_date_time", "ds")

data_NO2_prophet = data_NO2_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

data_NO2_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    m.fit(group[group['ds'] <= cutoff_date])
    
    forecast = m.predict(group)
    
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/NO2/'

    if not os.path.exists(path):
        os.makedirs(path)
    
    try:
        fig1 = m.plot(forecast)
        fig1.suptitle(f"NO2 Concentration Forecast for {group['NOME'].iloc[0]}")
        fig1.legend(['Actual', 'Forecasted'], loc='upper right')
        fig1.subplots_adjust(top=0.9)
        
        fig2 = m.plot_components(forecast)
        fig2.suptitle(f"NO2 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        fig2.subplots_adjust(top=0.9)

        fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/NO2/{group['NOME'].iloc[0]}_prophet_forecast.png")
        fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/NO2/{group['NOME'].iloc[0]}_prophet_components.png")
    except Exception as e:
        print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_NO2_prophet_train = data_NO2_prophet.filter(col('ds') <= cutoff_date)
data_NO2_prophet_test = data_NO2_prophet.filter((col('ds') > cutoff_date))

max_date = data_NO2_prophet_test.agg(max('ds')).collect()[0][0]

period = data_NO2_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_NO2 = data_NO2_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

spark_forecast_NO2.show()
# Out:
# +---------+-------------------+------------------+
# |     NOME| original_date_time|         avg_c_NO2|
# +---------+-------------------+------------------+
# |   Napoli|2022-01-24 05:00:00|2.4796764530136994|
# |  Salerno|2022-01-24 05:00:00|0.7855931627564102|
# | Avellino|2021-05-21 15:00:00|2.2238616741040476|
# |  Caserta|2019-01-24 20:00:00|11.365544946666663|
# | Avellino|2019-01-24 01:00:00|3.3922221037572227|
# |  Salerno|2021-11-01 00:00:00|1.3968887011217943|
# |  Salerno|2019-02-01 19:00:00| 4.649749127403843|
# |Benevento|2022-01-08 13:00:00|1.3910119166666668|
# |   Napoli|2021-06-11 17:00:00|  16.4437593479452|
# |   Napoli|2021-12-06 16:00:00|12.150923263013699|
# |  Salerno|2021-12-30 20:00:00|3.7652926806089737|
# | Avellino|2019-11-03 04:00:00|0.7913184238150286|
# |  Caserta|2019-02-01 05:00:00|  2.41413039939394|
# | Avellino|2021-11-01 02:00:00| 1.461723894450867|
# |Benevento|2020-11-21 02:00:00|1.3438488387596899|
# |Benevento|2020-11-21 06:00:00| 1.129760739534884|
# | Avellino|2021-12-30 12:00:00| 2.254878589479769|
# | Avellino|2021-06-11 10:00:00|2.8219188198843943|
# |  Salerno|2022-01-24 13:00:00|1.4749628033333344|
# |  Caserta|2021-11-01 19:00:00|22.040294909090907|
# +---------+-------------------+------------------+
# only showing top 20 rows
#
# root
#  |-- NOME: string (nullable = true)
#  |-- ds: timestamp (nullable = true)
#  |-- y: double (nullable = true)
# The time used for the Spark forecast is  0.03812456130981445
# Processing group: Benevento with 29862 data points=>            (86 + 27) / 113]
# 14:52:55 - cmdstanpy - INFO - Chain [1] start processing            (0 + 1) / 1]
# 14:53:02 - cmdstanpy - INFO - Chain [1] done processing
# +-------------------+---------+------------------+---------+----------+-----------+---------+---------+----------+----------+
# |                 ds|     NOME|                 y|     yhat|yhat_upper| yhat_lower|    trend|   yearly|    weekly|     daily|
# +-------------------+---------+------------------+---------+----------+-----------+---------+---------+----------+----------+
# |2019-01-01 01:00:00|Benevento|1.4448653317829456|10.110842| 18.042543|  2.4420707| 3.983498|2.0012298|0.96626616| 3.1598482|
# |2019-01-01 02:00:00|Benevento|1.3546963558139544| 9.059948| 16.599417|   1.131604|3.9851723|1.9976169|  0.990464|  2.086695|
# |2019-01-01 03:00:00|Benevento| 1.229843376744186| 8.016592|  16.01909|  0.3578356|3.9868464|1.9940137|  1.008158|  1.027574|
# |2019-01-01 04:00:00|Benevento| 1.174048741162791| 7.097469|  14.63753|-0.79321045|3.9885209|1.9904202| 1.0197421|0.09878564|
# |2019-01-01 05:00:00|Benevento| 1.155459176434108| 6.371493| 13.753676| -1.5162152| 3.990195|1.9868367| 1.0256498|-0.6311889|
# |2019-01-01 06:00:00|Benevento|1.1807792623255817| 5.876752| 13.342098| -2.0231643|3.9918694|1.9832631| 1.0263474|-1.1247281|
# |2019-01-01 07:00:00|Benevento|1.3678771821705429| 5.600865|13.2118225| -2.6814313|3.9935436|1.9796997|  1.022328|-1.3947066|
# |2019-01-01 08:00:00|Benevento| 2.145930711937984|5.4622474| 13.324784| -2.0680585|3.9952178|1.9761465| 1.0141039|-1.5232211|
# |2019-01-01 09:00:00|Benevento| 3.532926166666668| 5.338818| 12.415407| -2.4291193|3.9968922|1.9726037| 1.0022008|-1.6328785|
# |2019-01-01 10:00:00|Benevento| 3.148365782170543|5.1397486| 12.918559| -2.8142152|3.9985664|1.9690713|0.98715055|-1.8150399|
# |2019-01-01 11:00:00|Benevento| 2.604875439534885|4.8621683|12.4921255|  -2.177406| 4.000241|1.9655495| 0.9694845|-2.0731065|
# |2019-01-01 12:00:00|Benevento|  2.28937238992248|4.5801606| 12.194078|  -3.210529| 4.001915|1.9620384|0.94972754|-2.3335204|
# |2019-01-01 13:00:00|Benevento|2.1119949356589154|4.3773384| 11.902035| -3.2972066| 4.003589| 1.958538|0.92839175|-2.5131807|
# |2019-01-01 14:00:00|Benevento| 2.063602431782946| 4.291778| 11.567422| -3.6334498|4.0052633|1.9550487| 0.9059708|-2.5745049|
# |2019-01-01 15:00:00|Benevento| 2.153392741085272| 4.330195| 11.973742| -3.0820367| 4.006938|1.9515704| 0.8829345|-2.5112476|
# |2019-01-01 16:00:00|Benevento|2.5817202255813947|4.5336437|11.7040615| -3.4133403| 4.008612|1.9481032|0.85972404|-2.2827954|
# |2019-01-01 17:00:00|Benevento| 4.669665349612406| 5.013801| 12.745726| -2.9664838|4.0102863|1.9446473| 0.8367478|-1.7778801|
# |2019-01-01 18:00:00|Benevento| 6.681228669767442| 5.895744| 13.434904|  -1.450436|4.0119605|1.9412028|0.81437755|-0.8717971|
# |2019-01-01 19:00:00|Benevento| 7.359914202325581| 7.192064| 15.115164| -0.6591143|4.0136347|1.9377697|0.79294515|0.44771406|
# |2019-01-01 20:00:00|Benevento| 8.583151693798447| 8.711831| 16.133331|  1.0504442|4.0153093|1.9343482| 0.7727405| 1.9894338|
# +-------------------+---------+------------------+---------+----------+-----------+---------+---------+----------+----------+
# only showing top 20 rows
# Processing group: Salerno with 29862 data points

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import pow, sqrt
from prophet.diagnostics import performance_metrics


# Calculate MAE
mae_NO2 = spark_forecast_NO2.select(col("NOME"), abs(col("y") - col("yhat")).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MAE")

# Calculate MSE
mse_NO2 = spark_forecast_NO2.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MSE")

# Calculate RMSE
rmse_NO2 = spark_forecast_NO2.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                     .groupBy("NOME") \
                     .agg({"error": "mean"}) \
                     .withColumnRenamed("avg(error)", "MSE") \
                     .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE"))

# Show the results
mae_NO2.show()
mse_NO2.show()
rmse_NO2.show()
# Out:
# 14:53:12 - cmdstanpy - INFO - Chain [1] start processing        (67 + 46) / 113]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# 14:53:14 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:53:23 - cmdstanpy - INFO - Chain [1] done processing
# 14:53:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:53:35 - cmdstanpy - INFO - Chain [1] start processing
# 14:53:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:53:42 - cmdstanpy - INFO - Chain [1] done processing
# 14:53:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points                    (1 + 1) / 2]
# 14:53:58 - cmdstanpy - INFO - Chain [1] start processing
# 14:54:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:54:14 - cmdstanpy - INFO - Chain [1] start processing
# 14:54:21 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+
# |     NOME|               MAE|
# +---------+------------------+
# |Benevento|2.8688415107425516|
# |  Salerno| 1.900808450808384|
# | Avellino|2.2757902227786073|
# |   Napoli| 10.40138608624887|
# |  Caserta| 4.200234812582728|
# +---------+------------------+
# Processing group: Avellino with 29862 data points==>                (5 + 2) / 7]
# Processing group: Benevento with 29862 data points
# 14:54:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:54:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:54:43 - cmdstanpy - INFO - Chain [1] done processing
# 14:54:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:54:54 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:54:56 - cmdstanpy - INFO - Chain [1] start processing
# 14:54:59 - cmdstanpy - INFO - Chain [1] done processing
# 14:55:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:55:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:55:17 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# /gporq3/store_0/usr/nafis/Thesis/myenv2/lib/python3.7/site-packages/prophet/plot.py:67: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(facecolor='w', figsize=figsize)
# +---------+------------------+
# |     NOME|               MSE|
# +---------+------------------+
# |Benevento|15.538966892580591|
# |  Salerno| 6.658907596624998|
# | Avellino| 10.26953190984369|
# |   Napoli|185.98135580787326|
# |  Caserta|30.660439967329978|
# +---------+------------------+
# Processing group: Benevento with 29862 data points=>                (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 14:55:31 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:55:31 - cmdstanpy - INFO - Chain [1] start processing
# 14:55:37 - cmdstanpy - INFO - Chain [1] done processing
# 14:55:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:55:47 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:55:50 - cmdstanpy - INFO - Chain [1] start processing
# 14:55:55 - cmdstanpy - INFO - Chain [1] done processing
# 14:56:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:56:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:56:13 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+------------------+
# |     NOME|               MSE|              RMSE|
# +---------+------------------+------------------+
# |Benevento|15.538966892580591|3.9419496309035447|
# |  Salerno| 6.658907596624998| 2.580485922578342|
# | Avellino| 10.26953190984369|3.2046110387757967|
# |   Napoli|185.98135580787326|13.637498150609343|
# |  Caserta|30.660439967329978|  5.53718700852066|
# +---------+------------------+------------------+

# %%
#For Long and Short Term Forecast


from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_NO2_prophet = data_NO2.groupBy("NOME", "original_date_time").agg(avg("c_NO2").alias("avg_c_NO2"))
#data_NO2_prophet.show()

data_NO2_prophet_u = data_NO2_prophet.withColumnRenamed("avg_c_NO2", "y").withColumnRenamed("original_date_time", "ds")

data_NO2_prophet = data_NO2_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

#data_NO2_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    m.fit(group[group['ds'] <= cutoff_date])
    
    forecast = m.predict(group)
    
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/NO2/'

    if not os.path.exists(path):
        os.makedirs(path)
    
    #try:
     #   fig1 = m.plot(forecast)
      #  fig1.suptitle(f"NO2 Concentration Forecast for {group['NOME'].iloc[0]}")
       # fig1.legend(['Actual', 'Forecasted'], loc='upper right')
        #fig1.subplots_adjust(top=0.9)
        
        #fig2 = m.plot_components(forecast)
        #fig2.suptitle(f"NO2 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        #fig2.subplots_adjust(top=0.9)

        #fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/NO2/{group['NOME'].iloc[0]}_prophet_forecast.png")
        #fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/NO2/{group['NOME'].iloc[0]}_prophet_components.png")
    #except Exception as e:
     #   print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_NO2_prophet_train = data_NO2_prophet.filter(col('ds') <= cutoff_date)
data_NO2_prophet_test = data_NO2_prophet.filter((col('ds') > cutoff_date))

max_date = data_NO2_prophet_test.agg(max('ds')).collect()[0][0]

period = data_NO2_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_NO2 = data_NO2_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

#spark_forecast_NO2.show()
# Out:
# [Stage 2646:============================================>       (97 + 16) / 113]
# The time used for the Spark forecast is  0.03347587585449219

# %%
from pyspark.sql.functions import col, pow, sqrt

# Define cutoff dates
cutoff_dates = {
    "5 Days": "2021-07-05 23:00:00",
    "30 Days": "2021-07-30 23:00:00",
    "90 Days": "2021-09-28 23:00:00",
    "180 Days": "2021-12-27 23:00:00",
    "365 Days": "2022-06-29 23:00:00"
}

# Define a list to store the evaluation results
results = []

# Compute evaluation metrics for each time period and NOME
for period, cutoff in cutoff_dates.items():
    for nome in spark_forecast_NO2.select("NOME").distinct().rdd.flatMap(lambda x: x).collect():
        # Filter the forecast data based on the cutoff date and NOME
        forecast_data_NO2 = spark_forecast_NO2.filter((col("ds") <= cutoff) & (col("NOME") == nome))

        # Calculate MAE
        mae = forecast_data_NO2.select(abs(col("y") - col("yhat")).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MAE") \
                             .collect()[0]["MAE"]

        # Calculate MSE
        mse = forecast_data_NO2.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MSE") \
                             .collect()[0]["MSE"]

        # Calculate RMSE
        rmse = forecast_data_NO2.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                              .agg({"error": "mean"}) \
                              .withColumnRenamed("avg(error)", "MSE") \
                              .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE")) \
                              .collect()[0]["RMSE"]

        # Calculate coverage
        coverage = forecast_data_NO2.filter((col("y") >= col("yhat_lower")) & (col("y") <= col("yhat_upper"))) \
                                  .count() / forecast_data_NO2.count() * 100

        # Add the results to the list
        results.append((period, nome, mse, rmse, mae, coverage))

# Create a Spark DataFrame from the results list
result_df_NO2 = spark.createDataFrame(results, ["Time", "NOME", "MSE", "RMSE", "MAE", "Coverage"])

# Show the results
result_df_NO2.show(100)
# Out:
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 14:09:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:09:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:09:13 - cmdstanpy - INFO - Chain [1] done processing
# 14:09:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:09:21 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:09:23 - cmdstanpy - INFO - Chain [1] start processing
# 14:09:27 - cmdstanpy - INFO - Chain [1] done processing
# 14:09:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:09:35 - cmdstanpy - INFO - Chain [1] start processing
# 14:09:43 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>     (101 + 12) / 113]
# Processing group: Avellino with 29862 data points
# 14:10:17 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:10:18 - cmdstanpy - INFO - Chain [1] start processing
# 14:10:23 - cmdstanpy - INFO - Chain [1] done processing
# 14:10:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:10:31 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:10:33 - cmdstanpy - INFO - Chain [1] start processing
# 14:10:37 - cmdstanpy - INFO - Chain [1] done processing
# 14:10:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:10:45 - cmdstanpy - INFO - Chain [1] start processing
# 14:10:52 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points===>               (5 + 2) / 7]
# Processing group: Benevento with 29862 data points
# 14:11:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:11:26 - cmdstanpy - INFO - Chain [1] start processing
# 14:11:31 - cmdstanpy - INFO - Chain [1] done processing
# 14:11:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:11:39 - cmdstanpy - INFO - Chain [1] start processing
# 14:11:41 - cmdstanpy - INFO - Chain [1] start processing
# 14:11:46 - cmdstanpy - INFO - Chain [1] done processing
# 14:11:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:11:54 - cmdstanpy - INFO - Chain [1] start processing
# 14:12:01 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points                  (3 + 4) / 7]
# Processing group: Avellino with 29862 data points
# 14:12:37 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:12:37 - cmdstanpy - INFO - Chain [1] start processing
# 14:12:41 - cmdstanpy - INFO - Chain [1] done processing
# 14:12:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:12:49 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:12:51 - cmdstanpy - INFO - Chain [1] start processing
# 14:12:55 - cmdstanpy - INFO - Chain [1] done processing
# 14:12:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:13:03 - cmdstanpy - INFO - Chain [1] start processing
# 14:13:11 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:13:47 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:13:47 - cmdstanpy - INFO - Chain [1] start processing
# 14:13:52 - cmdstanpy - INFO - Chain [1] done processing
# 14:13:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:14:00 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:14:04 - cmdstanpy - INFO - Chain [1] start processing
# 14:14:06 - cmdstanpy - INFO - Chain [1] done processing
# 14:14:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:14:14 - cmdstanpy - INFO - Chain [1] start processing
# 14:14:22 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==========>   (105 + 8) / 113]
# Processing group: Avellino with 29862 data points
# 14:15:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:15:00 - cmdstanpy - INFO - Chain [1] start processing
# 14:15:07 - cmdstanpy - INFO - Chain [1] done processing
# 14:15:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:15:15 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:15:17 - cmdstanpy - INFO - Chain [1] start processing
# 14:15:20 - cmdstanpy - INFO - Chain [1] done processing
# 14:15:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:15:28 - cmdstanpy - INFO - Chain [1] start processing
# 14:15:36 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:16:14 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:16:14 - cmdstanpy - INFO - Chain [1] start processing
# 14:16:21 - cmdstanpy - INFO - Chain [1] done processing
# 14:16:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:16:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:16:31 - cmdstanpy - INFO - Chain [1] start processing
# 14:16:37 - cmdstanpy - INFO - Chain [1] done processing
# 14:16:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:16:45 - cmdstanpy - INFO - Chain [1] start processing
# 14:16:52 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points========>      (99 + 14) / 113]
# Processing group: Benevento with 29862 data points
# 14:17:32 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:17:32 - cmdstanpy - INFO - Chain [1] start processing
# 14:17:38 - cmdstanpy - INFO - Chain [1] done processing
# 14:17:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:17:46 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:17:49 - cmdstanpy - INFO - Chain [1] start processing
# 14:17:53 - cmdstanpy - INFO - Chain [1] done processing
# 14:17:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:18:01 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:08 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 14:18:48 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:18:48 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:53 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:19:01 - cmdstanpy - INFO - Chain [1] start processing
# 14:19:02 - cmdstanpy - INFO - Chain [1] start processing
# 14:19:07 - cmdstanpy - INFO - Chain [1] done processing
# 14:19:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:19:15 - cmdstanpy - INFO - Chain [1] start processing
# 14:19:23 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:20:01 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:20:01 - cmdstanpy - INFO - Chain [1] start processing
# 14:20:07 - cmdstanpy - INFO - Chain [1] done processing
# 14:20:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:20:15 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:20:18 - cmdstanpy - INFO - Chain [1] start processing
# 14:20:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:20:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:20:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:20:37 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:21:16 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:21:16 - cmdstanpy - INFO - Chain [1] start processing
# 14:21:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:21:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:21:30 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:21:32 - cmdstanpy - INFO - Chain [1] start processing
# 14:21:38 - cmdstanpy - INFO - Chain [1] done processing
# 14:21:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:21:46 - cmdstanpy - INFO - Chain [1] start processing
# 14:21:52 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:22:31 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:22:31 - cmdstanpy - INFO - Chain [1] start processing
# 14:22:37 - cmdstanpy - INFO - Chain [1] done processing
# 14:22:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:22:45 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:22:48 - cmdstanpy - INFO - Chain [1] start processing
# 14:22:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:22:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:22:58 - cmdstanpy - INFO - Chain [1] start processing
# 14:23:05 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 14:23:46 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:23:46 - cmdstanpy - INFO - Chain [1] start processing
# 14:23:52 - cmdstanpy - INFO - Chain [1] done processing
# 14:23:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:24:00 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:24:03 - cmdstanpy - INFO - Chain [1] start processing
# 14:24:06 - cmdstanpy - INFO - Chain [1] done processing
# 14:24:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:24:14 - cmdstanpy - INFO - Chain [1] start processing
# 14:24:22 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:25:01 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:25:01 - cmdstanpy - INFO - Chain [1] start processing
# 14:25:06 - cmdstanpy - INFO - Chain [1] done processing
# 14:25:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:25:14 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:25:18 - cmdstanpy - INFO - Chain [1] start processing
# 14:25:20 - cmdstanpy - INFO - Chain [1] done processing
# 14:25:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:25:28 - cmdstanpy - INFO - Chain [1] start processing
# 14:25:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=========>    (104 + 9) / 113]
# Processing group: Avellino with 29862 data points
# 14:26:14 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:26:14 - cmdstanpy - INFO - Chain [1] start processing
# 14:26:20 - cmdstanpy - INFO - Chain [1] done processing
# 14:26:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:26:28 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:26:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:26:35 - cmdstanpy - INFO - Chain [1] done processing
# 14:26:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:26:43 - cmdstanpy - INFO - Chain [1] start processing
# 14:26:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 14:27:28 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:27:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:27:34 - cmdstanpy - INFO - Chain [1] done processing
# 14:27:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:27:42 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:27:44 - cmdstanpy - INFO - Chain [1] start processing
# 14:27:49 - cmdstanpy - INFO - Chain [1] done processing
# 14:27:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:27:57 - cmdstanpy - INFO - Chain [1] start processing
# 14:28:04 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 14:28:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:28:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:28:48 - cmdstanpy - INFO - Chain [1] done processing
# 14:28:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:28:56 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:28:59 - cmdstanpy - INFO - Chain [1] start processing
# 14:29:01 - cmdstanpy - INFO - Chain [1] done processing
# 14:29:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:29:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:29:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points========>     (101 + 12) / 113]
# Processing group: Benevento with 29862 data points
# 14:29:54 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:29:54 - cmdstanpy - INFO - Chain [1] start processing
# 14:29:59 - cmdstanpy - INFO - Chain [1] done processing
# 14:30:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:30:07 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:30:10 - cmdstanpy - INFO - Chain [1] start processing
# 14:30:14 - cmdstanpy - INFO - Chain [1] done processing
# 14:30:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:30:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:30:29 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:31:07 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:31:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:12 - cmdstanpy - INFO - Chain [1] done processing
# 14:31:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:31:20 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:31:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:25 - cmdstanpy - INFO - Chain [1] done processing
# 14:31:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:31:33 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:41 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 14:32:19 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:32:19 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:24 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:32:32 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:32:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:38 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:32:46 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:53 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:33:30 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:33:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:33:35 - cmdstanpy - INFO - Chain [1] done processing
# 14:33:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:33:43 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:33:46 - cmdstanpy - INFO - Chain [1] start processing
# 14:33:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:33:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:33:58 - cmdstanpy - INFO - Chain [1] start processing
# 14:34:05 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:34:41 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:34:41 - cmdstanpy - INFO - Chain [1] start processing
# 14:34:46 - cmdstanpy - INFO - Chain [1] done processing
# 14:34:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:34:53 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:34:56 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:01 - cmdstanpy - INFO - Chain [1] done processing
# 14:35:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:35:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==========>   (105 + 8) / 113]
# Processing group: Avellino with 29862 data points
# 14:35:54 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:35:54 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:00 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:36:08 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:36:10 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:15 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:36:23 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:30 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 14:37:08 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:37:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:37:15 - cmdstanpy - INFO - Chain [1] done processing
# 14:37:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:37:23 - cmdstanpy - INFO - Chain [1] start processing
# 14:37:24 - cmdstanpy - INFO - Chain [1] start processing
# 14:37:30 - cmdstanpy - INFO - Chain [1] done processing
# 14:37:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:37:38 - cmdstanpy - INFO - Chain [1] start processing
# 14:37:47 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:38:23 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:38:23 - cmdstanpy - INFO - Chain [1] start processing
# 14:38:28 - cmdstanpy - INFO - Chain [1] done processing
# 14:38:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:38:36 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:38:38 - cmdstanpy - INFO - Chain [1] start processing
# 14:38:42 - cmdstanpy - INFO - Chain [1] done processing
# 14:38:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:38:50 - cmdstanpy - INFO - Chain [1] start processing
# 14:38:57 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:39:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:39:34 - cmdstanpy - INFO - Chain [1] start processing
# 14:39:38 - cmdstanpy - INFO - Chain [1] done processing
# 14:39:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:39:46 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:39:48 - cmdstanpy - INFO - Chain [1] start processing
# 14:39:53 - cmdstanpy - INFO - Chain [1] done processing
# 14:39:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:40:01 - cmdstanpy - INFO - Chain [1] start processing
# 14:40:07 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:40:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:40:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:40:47 - cmdstanpy - INFO - Chain [1] done processing
# 14:40:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:40:55 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:40:57 - cmdstanpy - INFO - Chain [1] start processing
# 14:41:01 - cmdstanpy - INFO - Chain [1] done processing
# 14:41:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:41:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:41:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:41:51 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:41:51 - cmdstanpy - INFO - Chain [1] start processing
# 14:41:58 - cmdstanpy - INFO - Chain [1] done processing
# 14:42:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:42:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:42:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:42:13 - cmdstanpy - INFO - Chain [1] done processing
# 14:42:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:42:21 - cmdstanpy - INFO - Chain [1] start processing
# 14:42:28 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>     (100 + 13) / 113]
# Processing group: Avellino with 29862 data points
# 14:43:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:43:03 - cmdstanpy - INFO - Chain [1] start processing
# 14:43:09 - cmdstanpy - INFO - Chain [1] done processing
# 14:43:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:43:17 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:43:19 - cmdstanpy - INFO - Chain [1] start processing
# 14:43:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:43:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:43:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:43:38 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 14:44:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:44:12 - cmdstanpy - INFO - Chain [1] start processing
# 14:44:18 - cmdstanpy - INFO - Chain [1] done processing
# 14:44:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:44:26 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:44:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:44:33 - cmdstanpy - INFO - Chain [1] done processing
# 14:44:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:44:41 - cmdstanpy - INFO - Chain [1] start processing
# 14:44:49 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 14:45:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:45:26 - cmdstanpy - INFO - Chain [1] start processing
# 14:45:33 - cmdstanpy - INFO - Chain [1] done processing
# 14:45:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:45:41 - cmdstanpy - INFO - Chain [1] start processing
# 14:45:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:45:49 - cmdstanpy - INFO - Chain [1] done processing
# 14:45:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:45:57 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 14:46:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>      (99 + 14) / 113]
# Processing group: Avellino with 29862 data points
# 14:46:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:46:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:46:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:46:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:46:58 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:47:00 - cmdstanpy - INFO - Chain [1] start processing
# 14:47:05 - cmdstanpy - INFO - Chain [1] done processing
# 14:47:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:47:13 - cmdstanpy - INFO - Chain [1] start processing
# 14:47:20 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>     (100 + 13) / 113]
# Processing group: Avellino with 29862 data points
# 14:48:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:48:00 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:06 - cmdstanpy - INFO - Chain [1] done processing
# 14:48:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:48:14 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:48:17 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:20 - cmdstanpy - INFO - Chain [1] done processing
# 14:48:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:48:28 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 14:49:14 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:49:14 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:21 - cmdstanpy - INFO - Chain [1] done processing
# 14:49:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:49:28 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:49:32 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:35 - cmdstanpy - INFO - Chain [1] done processing
# 14:49:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 14:49:51 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 14:50:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:50:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:50:35 - cmdstanpy - INFO - Chain [1] done processing
# 14:50:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:50:43 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 14:50:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:50:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:50:58 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:05 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points========>    (102 + 11) / 113]
# Processing group: Avellino with 29862 data points
# 14:51:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:51:39 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:45 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:51:52 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:51:55 - cmdstanpy - INFO - Chain [1] start processing
# 14:52:00 - cmdstanpy - INFO - Chain [1] done processing
# 14:52:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:52:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:52:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:52:50 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:52:50 - cmdstanpy - INFO - Chain [1] start processing
# 14:52:55 - cmdstanpy - INFO - Chain [1] done processing
# 14:52:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:53:03 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:53:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:53:12 - cmdstanpy - INFO - Chain [1] done processing
# 14:53:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:53:19 - cmdstanpy - INFO - Chain [1] start processing
# 14:53:27 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:54:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:54:00 - cmdstanpy - INFO - Chain [1] start processing
# 14:54:06 - cmdstanpy - INFO - Chain [1] done processing
# 14:54:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:54:14 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:54:16 - cmdstanpy - INFO - Chain [1] start processing
# 14:54:21 - cmdstanpy - INFO - Chain [1] done processing
# 14:54:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:54:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:54:36 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:55:09 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:55:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:55:15 - cmdstanpy - INFO - Chain [1] done processing
# 14:55:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:55:23 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:55:27 - cmdstanpy - INFO - Chain [1] start processing
# 14:55:29 - cmdstanpy - INFO - Chain [1] done processing
# 14:55:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:55:37 - cmdstanpy - INFO - Chain [1] start processing
# 14:55:44 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:56:20 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:56:20 - cmdstanpy - INFO - Chain [1] start processing
# 14:56:27 - cmdstanpy - INFO - Chain [1] done processing
# 14:56:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 14:56:35 - cmdstanpy - INFO - Chain [1] start processing
# 14:56:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:56:42 - cmdstanpy - INFO - Chain [1] done processing
# 14:56:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:56:50 - cmdstanpy - INFO - Chain [1] start processing
# 14:56:57 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:57:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:57:35 - cmdstanpy - INFO - Chain [1] start processing
# 14:57:41 - cmdstanpy - INFO - Chain [1] done processing
# 14:57:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:57:49 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:57:52 - cmdstanpy - INFO - Chain [1] start processing
# 14:57:56 - cmdstanpy - INFO - Chain [1] done processing
# 14:58:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:58:03 - cmdstanpy - INFO - Chain [1] start processing
# 14:58:11 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 14:58:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:58:49 - cmdstanpy - INFO - Chain [1] start processing
# 14:58:56 - cmdstanpy - INFO - Chain [1] done processing
# 14:58:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 14:59:04 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 14:59:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:59:10 - cmdstanpy - INFO - Chain [1] done processing
# 14:59:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 14:59:18 - cmdstanpy - INFO - Chain [1] start processing
# 14:59:25 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points==>               (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 15:00:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:00:03 - cmdstanpy - INFO - Chain [1] start processing
# 15:00:08 - cmdstanpy - INFO - Chain [1] done processing
# 15:00:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:00:16 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:00:18 - cmdstanpy - INFO - Chain [1] start processing
# 15:00:21 - cmdstanpy - INFO - Chain [1] done processing
# 15:00:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:00:30 - cmdstanpy - INFO - Chain [1] start processing
# 15:00:38 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 15:01:16 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:01:16 - cmdstanpy - INFO - Chain [1] start processing
# 15:01:22 - cmdstanpy - INFO - Chain [1] done processing
# 15:01:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:01:30 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:01:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:01:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:01:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:01:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:01:53 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 15:02:32 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:02:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:02:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:02:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 15:02:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:02:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:02:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:02:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:03:00 - cmdstanpy - INFO - Chain [1] start processing
# 15:03:07 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 15:03:46 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:03:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:03:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:03:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:03:59 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:04:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:05 - cmdstanpy - INFO - Chain [1] done processing
# 15:04:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:04:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:20 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 15:04:59 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:04:59 - cmdstanpy - INFO - Chain [1] start processing
# 15:05:04 - cmdstanpy - INFO - Chain [1] done processing
# 15:05:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:05:12 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:05:17 - cmdstanpy - INFO - Chain [1] done processing
# 15:05:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:05:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:05:32 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (99 + 14) / 113]
# Processing group: Avellino with 29862 data points
# 15:06:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:06:11 - cmdstanpy - INFO - Chain [1] start processing
# 15:06:16 - cmdstanpy - INFO - Chain [1] done processing
# 15:06:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:06:24 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:06:25 - cmdstanpy - INFO - Chain [1] start processing
# 15:06:29 - cmdstanpy - INFO - Chain [1] done processing
# 15:06:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:06:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:06:43 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 15:07:21 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:07:21 - cmdstanpy - INFO - Chain [1] start processing
# 15:07:26 - cmdstanpy - INFO - Chain [1] done processing
# 15:07:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:07:35 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:07:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:07:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:07:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:07:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:07:57 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=========>    (103 + 10) / 113]
# Processing group: Benevento with 29862 data points
# 15:08:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:08:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:08:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:08:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:08:47 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:08:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:08:54 - cmdstanpy - INFO - Chain [1] done processing
# 15:08:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:09:02 - cmdstanpy - INFO - Chain [1] start processing
# 15:09:09 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 15:09:46 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:09:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:09:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:09:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:09:59 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:10:01 - cmdstanpy - INFO - Chain [1] start processing
# 15:10:04 - cmdstanpy - INFO - Chain [1] done processing
# 15:10:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:10:12 - cmdstanpy - INFO - Chain [1] start processing
# 15:10:19 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (99 + 14) / 113]
# Processing group: Avellino with 29862 data points
# 15:10:55 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:10:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:00 - cmdstanpy - INFO - Chain [1] done processing
# 15:11:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:11:08 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:11:10 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:14 - cmdstanpy - INFO - Chain [1] done processing
# 15:11:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:11:21 - cmdstanpy - INFO - Chain [1] start processing
# 15:11:28 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 15:12:05 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:12:05 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:10 - cmdstanpy - INFO - Chain [1] done processing
# 15:12:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:12:18 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:12:20 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:24 - cmdstanpy - INFO - Chain [1] done processing
# 15:12:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:12:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:12:40 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 15:13:19 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:13:19 - cmdstanpy - INFO - Chain [1] start processing
# 15:13:26 - cmdstanpy - INFO - Chain [1] done processing
# 15:13:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 15:13:34 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 15:13:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:13:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:13:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# ...
# 16:28:58 - cmdstanpy - INFO - Chain [1] start processing
# 16:29:04 - cmdstanpy - INFO - Chain [1] done processing
# 16:29:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 16:29:12 - cmdstanpy - INFO - Chain [1] start processing
# 16:29:14 - cmdstanpy - INFO - Chain [1] start processing
# 16:29:20 - cmdstanpy - INFO - Chain [1] done processing
# 16:29:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:29:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:29:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 16:30:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:30:12 - cmdstanpy - INFO - Chain [1] start processing
# 16:30:17 - cmdstanpy - INFO - Chain [1] done processing
# 16:30:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:30:25 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:30:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:30:31 - cmdstanpy - INFO - Chain [1] done processing
# 16:30:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:30:39 - cmdstanpy - INFO - Chain [1] start processing
# 16:30:46 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 16:31:23 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:31:23 - cmdstanpy - INFO - Chain [1] start processing
# 16:31:29 - cmdstanpy - INFO - Chain [1] done processing
# 16:31:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:31:38 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:31:40 - cmdstanpy - INFO - Chain [1] start processing
# 16:31:45 - cmdstanpy - INFO - Chain [1] done processing
# 16:31:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:31:53 - cmdstanpy - INFO - Chain [1] start processing
# 16:32:00 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points===========>  (107 + 6) / 113]
# Processing group: Avellino with 29862 data points
# 16:32:37 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:32:37 - cmdstanpy - INFO - Chain [1] start processing
# 16:32:44 - cmdstanpy - INFO - Chain [1] done processing
# 16:32:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:32:52 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:32:54 - cmdstanpy - INFO - Chain [1] start processing
# 16:32:58 - cmdstanpy - INFO - Chain [1] done processing
# 16:33:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:33:06 - cmdstanpy - INFO - Chain [1] start processing
# 16:33:14 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 16:33:51 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:33:51 - cmdstanpy - INFO - Chain [1] start processing
# 16:33:57 - cmdstanpy - INFO - Chain [1] done processing
# 16:33:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:34:05 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:34:07 - cmdstanpy - INFO - Chain [1] start processing
# 16:34:12 - cmdstanpy - INFO - Chain [1] done processing
# 16:34:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:34:20 - cmdstanpy - INFO - Chain [1] start processing
# 16:34:28 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 16:35:05 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:35:05 - cmdstanpy - INFO - Chain [1] start processing
# 16:35:11 - cmdstanpy - INFO - Chain [1] done processing
# 16:35:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:35:19 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:35:22 - cmdstanpy - INFO - Chain [1] start processing
# 16:35:25 - cmdstanpy - INFO - Chain [1] done processing
# 16:35:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:35:33 - cmdstanpy - INFO - Chain [1] start processing
# 16:35:40 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points===========>  (107 + 6) / 113]
# Processing group: Avellino with 29862 data points
# 16:36:17 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:36:17 - cmdstanpy - INFO - Chain [1] start processing
# 16:36:23 - cmdstanpy - INFO - Chain [1] done processing
# 16:36:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:36:31 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:36:34 - cmdstanpy - INFO - Chain [1] start processing
# 16:36:37 - cmdstanpy - INFO - Chain [1] done processing
# 16:36:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:36:45 - cmdstanpy - INFO - Chain [1] start processing
# 16:36:52 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 16:37:30 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:37:30 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:35 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:37:43 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:37:45 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:50 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:37:58 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:06 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 16:38:45 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:38:45 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:50 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 16:38:58 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:59 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:07 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:39:15 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 16:39:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 16:39:58 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:39:58 - cmdstanpy - INFO - Chain [1] start processing
# 16:40:04 - cmdstanpy - INFO - Chain [1] done processing
# 16:40:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:40:12 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:40:14 - cmdstanpy - INFO - Chain [1] start processing
# 16:40:20 - cmdstanpy - INFO - Chain [1] done processing
# 16:40:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:40:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:40:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=============>(112 + 1) / 113]
# Processing group: Avellino with 29862 data points
# 16:41:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:41:10 - cmdstanpy - INFO - Chain [1] start processing
# 16:41:16 - cmdstanpy - INFO - Chain [1] done processing
# 16:41:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:41:24 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 16:41:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:41:39 - cmdstanpy - INFO - Chain [1] start processing
# 16:41:46 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 16:42:22 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:42:22 - cmdstanpy - INFO - Chain [1] start processing
# 16:42:26 - cmdstanpy - INFO - Chain [1] done processing
# 16:42:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:42:34 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:42:37 - cmdstanpy - INFO - Chain [1] start processing
# 16:42:40 - cmdstanpy - INFO - Chain [1] done processing
# 16:42:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:42:48 - cmdstanpy - INFO - Chain [1] start processing
# 16:42:55 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 16:43:30 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:43:30 - cmdstanpy - INFO - Chain [1] start processing
# 16:43:35 - cmdstanpy - INFO - Chain [1] done processing
# 16:43:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:43:42 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:43:44 - cmdstanpy - INFO - Chain [1] start processing
# 16:43:48 - cmdstanpy - INFO - Chain [1] done processing
# 16:43:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:43:56 - cmdstanpy - INFO - Chain [1] start processing
# 16:44:03 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 16:44:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:44:39 - cmdstanpy - INFO - Chain [1] start processing
# 16:44:45 - cmdstanpy - INFO - Chain [1] done processing
# 16:44:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:44:53 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:44:55 - cmdstanpy - INFO - Chain [1] start processing
# 16:45:01 - cmdstanpy - INFO - Chain [1] done processing
# 16:45:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:45:08 - cmdstanpy - INFO - Chain [1] start processing
# 16:45:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 16:45:52 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 16:45:52 - cmdstanpy - INFO - Chain [1] start processing
# 16:45:58 - cmdstanpy - INFO - Chain [1] done processing
# 16:46:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 16:46:06 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 16:46:08 - cmdstanpy - INFO - Chain [1] start processing
# 16:46:14 - cmdstanpy - INFO - Chain [1] done processing
# 16:46:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 16:46:22 - cmdstanpy - INFO - Chain [1] start processing
# 16:46:29 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +--------+---------+------------------+------------------+------------------+-----------------+
# |    Time|     NOME|               MSE|              RMSE|               MAE|         Coverage|
# +--------+---------+------------------+------------------+------------------+-----------------+
# |  5 Days|Benevento|15.883797523857158|  3.98544822119886|2.7857546306761476|94.78544776119404|
# |  5 Days|  Salerno| 6.468074292705023|2.5432409033957093|1.8025959243476621|93.96455223880596|
# |  5 Days| Avellino|10.631426313586132|3.2605868050990656| 2.197703992235896| 94.6035447761194|
# |  5 Days|   Napoli|146.63395822540443|12.109250935768257| 9.102701454176271|93.51212686567165|
# |  5 Days|  Caserta| 30.39538727545387|5.5132011822038445| 4.069779938903085| 94.2723880597015|
# | 30 Days|Benevento|15.676834384240577| 3.959398235116111|2.7743112200776254|94.93194192377496|
# | 30 Days|  Salerno| 6.452182863755967|2.5401147343685024| 1.805778253650868|94.00635208711434|
# | 30 Days| Avellino| 10.47240669850752|3.2361098094019494|2.1870562090445893| 94.7141560798548|
# | 30 Days|   Napoli|151.83994274612024| 12.32233511742479| 9.242136544348202|93.16696914700545|
# | 30 Days|  Caserta|30.290479442587245|  5.50367871905576| 4.072620395854853|94.37840290381125|
# | 90 Days|Benevento| 15.28708980550102|  3.90987081698373| 2.753821726778981|95.15758091993186|
# | 90 Days|  Salerno| 6.447036271410199| 2.539101469301729|1.8159896090600274| 94.0587734241908|
# | 90 Days| Avellino|10.201822720029734| 3.194029229676794|2.1704056908384057| 94.9403747870528|
# | 90 Days|   Napoli|159.24246150465575|12.619130774528639| 9.496067996349119|92.56388415672913|
# | 90 Days|  Caserta|30.074323872460592| 5.484006188222311|4.0785340013750995|94.53577512776832|
# |180 Days|Benevento|15.000542673184551|3.8730534043806513|2.7482091078512325|95.44905042311743|
# |180 Days|  Salerno|6.5958216451909975|  2.56823317578272| 1.857510301915837|93.91646843193074|
# |180 Days| Avellino|10.105995830519076| 3.178992895638346|2.1868284893741716|95.08637834886714|
# |180 Days|   Napoli| 170.8816230052755|13.072169789490783| 9.921661932080173|91.72873688725967|
# |180 Days|  Caserta|30.772510761190322| 5.547297608853371| 4.157855089766573|94.44682759427523|
# |365 Days|Benevento|15.538966892580591|3.9419496309035447|2.8688415107425516|95.77474219900898|
# |365 Days|  Salerno| 6.658907596624998| 2.580485922578342| 1.900808450808384|94.56274273469934|
# |365 Days| Avellino| 10.26953190984369|3.2046110387757967|2.2757902227786073| 95.6240792821749|
# |365 Days|   Napoli|185.98135580787326|13.637498150609343| 10.40138608624887|91.48587116646578|
# |365 Days|  Caserta|30.660439967329978|  5.53718700852066| 4.200234812582728|94.94442212401232|
# +--------+---------+------------------+------------------+------------------+-----------------+

# %%
result_df_NO2_pd = result_df_NO2.pandas_api()
result_df_NO2_pd

# %% [markdown]
# O3

# %%
from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_O3_prophet = data_O3.groupBy("NOME", "original_date_time").agg(avg("c_O3").alias("avg_c_O3"))
data_O3_prophet.show()

data_O3_prophet_u = data_O3_prophet.withColumnRenamed("avg_c_O3", "y").withColumnRenamed("original_date_time", "ds")

data_O3_prophet = data_O3_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

data_O3_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    m.fit(group[group['ds'] <= cutoff_date])
    
    forecast = m.predict(group)
    
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/O3/'

    if not os.path.exists(path):
        os.makedirs(path)
    
    try:
        fig1 = m.plot(forecast)
        fig1.suptitle(f"O3 Concentration Forecast for {group['NOME'].iloc[0]}")
        fig1.legend(['Actual', 'Forecasted'], loc='upper right')
        fig1.subplots_adjust(top=0.9)
        
        fig2 = m.plot_components(forecast)
        fig2.suptitle(f"O3 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        fig2.subplots_adjust(top=0.9)

        fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/O3/{group['NOME'].iloc[0]}_prophet_forecast.png")
        fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/O3/{group['NOME'].iloc[0]}_prophet_components.png")
    except Exception as e:
        print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])


# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_O3_prophet_train = data_O3_prophet.filter(col('ds') <= cutoff_date)
data_O3_prophet_test = data_O3_prophet.filter((col('ds') > cutoff_date))

max_date = data_O3_prophet_test.agg(max('ds')).collect()[0][0]

period = data_O3_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_O3 = data_O3_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

spark_forecast_O3.show()
# Out:
# +---------+-------------------+------------------+
# |     NOME| original_date_time|          avg_c_O3|
# +---------+-------------------+------------------+
# |   Napoli|2022-01-24 05:00:00|61.108973219178104|
# |  Salerno|2022-01-24 05:00:00|58.490383118589726|
# | Avellino|2021-05-21 15:00:00|120.98329703468211|
# |  Caserta|2019-01-24 20:00:00|48.119171763636366|
# | Avellino|2019-01-24 01:00:00| 53.53818496531796|
# |  Salerno|2021-11-01 00:00:00| 71.46073684615389|
# |  Salerno|2019-02-01 19:00:00|57.773951512820545|
# |Benevento|2022-01-08 13:00:00| 62.87799679844961|
# |   Napoli|2021-06-11 17:00:00|114.55085634246574|
# |   Napoli|2021-12-06 16:00:00| 46.85498116438357|
# |  Salerno|2021-12-30 20:00:00| 55.20029793269234|
# | Avellino|2019-11-03 04:00:00| 71.69187458959537|
# |  Caserta|2019-02-01 05:00:00| 49.26924827272726|
# | Avellino|2021-11-01 02:00:00| 62.49715756647398|
# |Benevento|2020-11-21 02:00:00| 51.80687717829457|
# |Benevento|2020-11-21 06:00:00|52.173485038759694|
# | Avellino|2021-12-30 12:00:00| 61.35639165895958|
# | Avellino|2021-06-11 10:00:00|  103.837146450867|
# |  Salerno|2022-01-24 13:00:00|60.006318961538504|
# |  Caserta|2021-11-01 19:00:00|39.398321051515154|
# +---------+-------------------+------------------+
# only showing top 20 rows
#
# root
#  |-- NOME: string (nullable = true)
#  |-- ds: timestamp (nullable = true)
#  |-- y: double (nullable = true)
# The time used for the Spark forecast is  0.0359349250793457
# Processing group: Benevento with 29862 data points=======>     (101 + 12) / 113]
# 14:56:33 - cmdstanpy - INFO - Chain [1] start processing            (0 + 1) / 1]
# 14:56:43 - cmdstanpy - INFO - Chain [1] done processing
# +-------------------+---------+------------------+---------+----------+----------+---------+----------+----------+------------+
# |                 ds|     NOME|                 y|     yhat|yhat_upper|yhat_lower|    trend|    yearly|    weekly|       daily|
# +-------------------+---------+------------------+---------+----------+----------+---------+----------+----------+------------+
# |2019-01-01 01:00:00|Benevento| 60.72303379069767|37.707584| 58.719906| 17.391811| 71.69005|-23.926624|-1.5209005|   -8.534935|
# |2019-01-01 02:00:00|Benevento| 60.46292085271317|38.205368|   58.1786| 17.201944|  71.6827|-23.932486|-1.5605963|   -7.984248|
# |2019-01-01 03:00:00|Benevento|59.605359007751936|38.686245| 59.886116|    18.397|71.675354|-23.938345|-1.5957298|   -7.455035|
# |2019-01-01 04:00:00|Benevento|58.356536356589125|38.916092| 58.890896| 18.012447| 71.66801|-23.944199|    -1.626|  -7.1817174|
# |2019-01-01 05:00:00|Benevento| 57.46576033333333| 38.90148| 58.458042|  18.00571| 71.66066| -23.95005|-1.6511306|  -7.1580005|
# |2019-01-01 06:00:00|Benevento|56.699817945736434| 38.90889|  58.68576| 17.980778| 71.65332|-23.955894|-1.6708727|   -7.117659|
# |2019-01-01 07:00:00|Benevento|55.562653139534866|39.359108| 59.521725| 17.418009| 71.64597|-23.961737| -1.685008|  -6.6401215|
# |2019-01-01 08:00:00|Benevento| 54.00421031007753|40.632446| 61.461536| 20.683487|71.638626|-23.967571|-1.6933517|   -5.345259|
# |2019-01-01 09:00:00|Benevento|52.055031426356585|42.889107| 61.636097| 22.310625| 71.63128|  -23.9734|-1.6957546|  -3.0730195|
# |2019-01-01 10:00:00|Benevento|56.683356961240314| 46.00332|   66.6106| 24.932024| 71.62394|-23.979223|-1.6921059|  0.05071215|
# |2019-01-01 11:00:00|Benevento| 59.64161205426357| 49.62787|  69.84082| 30.978933| 71.61659| -23.98504|-1.6823341|    3.678652|
# |2019-01-01 12:00:00|Benevento|60.869936945736406| 53.31663|  73.48709| 32.677876|71.609245| -23.99085|-1.6664094|   7.3646464|
# |2019-01-01 13:00:00|Benevento|61.722343953488384| 56.61353|  76.54763|  36.28246|  71.6019|-23.996655|-1.6443444|    10.65263|
# |2019-01-01 14:00:00|Benevento| 63.18303413953489| 59.07889|  78.35321|  38.08372| 71.59455|-24.002449|-1.6161947|   13.102981|
# |2019-01-01 15:00:00|Benevento|  65.5366677131783|60.303276|  80.55223| 40.667114| 71.58721|-24.008236|-1.5820594|   14.306365|
# |2019-01-01 16:00:00|Benevento|  66.8968141395349|59.975384|  78.97095|  38.92258|71.579865|-24.014015|-1.5420804|   13.951619|
# |2019-01-01 17:00:00|Benevento| 60.88077654263567|58.007435|  78.49052|  36.86641| 71.57252|-24.019787|-1.4964427|   11.951147|
# |2019-01-01 18:00:00|Benevento| 54.44900979069766| 54.64086|  74.61327|  35.17968| 71.56517|-24.025549|-1.4453722|     8.54661|
# |2019-01-01 19:00:00|Benevento| 51.88729826356588|  50.4376|  71.42713|   29.6386| 71.55782|  -24.0313|-1.3891355|    4.300208|
# |2019-01-01 20:00:00|Benevento| 49.54953488372094|  46.1302|  65.79091| 25.833984| 71.55048|-24.037043| -1.328037|-0.055202603|
# +-------------------+---------+------------------+---------+----------+----------+---------+----------+----------+------------+
# only showing top 20 rows
# Processing group: Salerno with 29862 data points

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import pow, sqrt
from prophet.diagnostics import performance_metrics


# Calculate MAE
mae_O3 = spark_forecast_O3.select(col("NOME"), abs(col("y") - col("yhat")).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MAE")


# Calculate MSE
mse_O3 = spark_forecast_O3.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MSE")

# Calculate RMSE
rmse_O3 = spark_forecast_O3.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                     .groupBy("NOME") \
                     .agg({"error": "mean"}) \
                     .withColumnRenamed("avg(error)", "MSE") \
                     .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE"))

# Show the results
mae_O3.show()
mse_O3.show()
rmse_O3.show()
# Out:
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 15:14:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:14:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:14:56 - cmdstanpy - INFO - Chain [1] done processing
# 15:14:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 15:15:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:15:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:15:22 - cmdstanpy - INFO - Chain [1] done processing
# 15:15:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (0 + 2) / 2]
# 15:15:32 - cmdstanpy - INFO - Chain [1] start processing
# 15:15:40 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+
# |     NOME|               MAE|
# +---------+------------------+
# |Benevento| 9.017186850638417|
# |  Salerno| 7.743955757389471|
# | Avellino| 8.650666892810463|
# |   Napoli|12.753057089825983|
# |  Caserta|  9.95513096688605|
# +---------+------------------+
# Processing group: Benevento with 29862 data points====>         (93 + 20) / 113]
# Processing group: Avellino with 29862 data points
# 15:15:53 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:15:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:16:03 - cmdstanpy - INFO - Chain [1] done processing
# 15:16:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 15:16:13 - cmdstanpy - INFO - Chain [1] start processing
# 15:16:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:16:25 - cmdstanpy - INFO - Chain [1] done processing
# 15:16:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 15:16:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:16:43 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+
# |     NOME|               MSE|
# +---------+------------------+
# |Benevento|139.62034911169712|
# |  Salerno| 99.46340991568502|
# | Avellino|126.06034415777752|
# |   Napoli|260.37679754097036|
# |  Caserta| 166.0431161258783|
# +---------+------------------+
# Processing group: Benevento with 29862 data points=============>(111 + 2) / 113]
# Processing group: Avellino with 29862 data points
# 15:16:55 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:16:55 - cmdstanpy - INFO - Chain [1] start processing
# 15:17:08 - cmdstanpy - INFO - Chain [1] done processing
# 15:17:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 15:17:18 - cmdstanpy - INFO - Chain [1] start processing
# 15:17:18 - cmdstanpy - INFO - Chain [1] start processing
# 15:17:29 - cmdstanpy - INFO - Chain [1] done processing
# 15:17:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 15:17:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:17:48 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+------------------+
# |     NOME|               MSE|              RMSE|
# +---------+------------------+------------------+
# |Benevento|139.62034911169712|11.816105496808039|
# |  Salerno| 99.46340991568502|  9.97313440778199|
# | Avellino|126.06034415777752|11.227659780995214|
# |   Napoli|260.37679754097036| 16.13619526223485|
# |  Caserta| 166.0431161258783|12.885771848278173|
# +---------+------------------+------------------+

# %%
#For Long and Short Term Forecast

from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_O3_prophet = data_O3.groupBy("NOME", "original_date_time").agg(avg("c_O3").alias("avg_c_O3"))
#data_O3_prophet.show()

data_O3_prophet_u = data_O3_prophet.withColumnRenamed("avg_c_O3", "y").withColumnRenamed("original_date_time", "ds")

data_O3_prophet = data_O3_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

#data_O3_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    m.fit(group[group['ds'] <= cutoff_date])
    
    forecast = m.predict(group)
    
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_campania/O3/'

    if not os.path.exists(path):
        os.makedirs(path)
    
   # try:
    #    fig1 = m.plot(forecast)
     #   fig1.suptitle(f"O3 Concentration Forecast for {group['NOME'].iloc[0]}")
     #   fig1.legend(['Actual', 'Forecasted'], loc='upper right')
      #  fig1.subplots_adjust(top=0.9)
        
       # fig2 = m.plot_components(forecast)
       # fig2.suptitle(f"O3 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        #fig2.subplots_adjust(top=0.9)

       # fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/O3/{group['NOME'].iloc[0]}_prophet_forecast.png")
        #fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/O3/{group['NOME'].iloc[0]}_prophet_components.png")
    #except Exception as e:
     #   print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])


# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_O3_prophet_train = data_O3_prophet.filter(col('ds') <= cutoff_date)
data_O3_prophet_test = data_O3_prophet.filter((col('ds') > cutoff_date))

max_date = data_O3_prophet_test.agg(max('ds')).collect()[0][0]

period = data_O3_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_O3 = data_O3_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

#spark_forecast_O3.show()
# Out:
# The time used for the Spark forecast is  0.45984888076782227

# %%
from pyspark.sql.functions import col, pow, sqrt

# Define cutoff dates
cutoff_dates = {
    "5 Days": "2021-07-05 23:00:00",
    "30 Days": "2021-07-30 23:00:00",
    "90 Days": "2021-09-28 23:00:00",
    "180 Days": "2021-12-27 23:00:00",
    "365 Days": "2022-06-29 23:00:00"
}

# Define a list to store the evaluation results
results = []

# Compute evaluation metrics for each time period and NOME
for period, cutoff in cutoff_dates.items():
    for nome in spark_forecast_O3.select("NOME").distinct().rdd.flatMap(lambda x: x).collect():
        # Filter the forecast data based on the cutoff date and NOME
        forecast_data_O3 = spark_forecast_O3.filter((col("ds") <= cutoff) & (col("NOME") == nome))

        # Calculate MAE
        mae = forecast_data_O3.select(abs(col("y") - col("yhat")).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MAE") \
                             .collect()[0]["MAE"]

        # Calculate MSE
        mse = forecast_data_O3.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MSE") \
                             .collect()[0]["MSE"]

        # Calculate RMSE
        rmse = forecast_data_O3.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                              .agg({"error": "mean"}) \
                              .withColumnRenamed("avg(error)", "MSE") \
                              .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE")) \
                              .collect()[0]["RMSE"]

        # Calculate coverage
        coverage = forecast_data_O3.filter((col("y") >= col("yhat_lower")) & (col("y") <= col("yhat_upper"))) \
                                  .count() / forecast_data_O3.count() * 100

        # Add the results to the list
        results.append((period, nome, mse, rmse, mae, coverage))

# Create a Spark DataFrame from the results list
result_df_O3 = spark.createDataFrame(results, ["Time", "NOME", "MSE", "RMSE", "MAE", "Coverage"])

# Show the results
result_df_O3.show(100)
# Out:
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 22:42:07 - cmdstanpy - INFO - Chain [1] start processing
# 22:42:07 - cmdstanpy - INFO - Chain [1] start processing
# 22:42:20 - cmdstanpy - INFO - Chain [1] done processing
# 22:42:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 22:42:29 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 22:42:31 - cmdstanpy - INFO - Chain [1] start processing
# 22:42:42 - cmdstanpy - INFO - Chain [1] done processing
# 22:42:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 22:42:50 - cmdstanpy - INFO - Chain [1] start processing
# 22:43:00 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 22:45:17 - cmdstanpy - INFO - Chain [1] start processing
# 22:45:17 - cmdstanpy - INFO - Chain [1] start processing
# 22:45:30 - cmdstanpy - INFO - Chain [1] done processing
# 22:45:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 22:45:38 - cmdstanpy - INFO - Chain [1] start processing
# 22:45:40 - cmdstanpy - INFO - Chain [1] start processing
# 22:45:51 - cmdstanpy - INFO - Chain [1] done processing
# 22:45:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 22:46:00 - cmdstanpy - INFO - Chain [1] start processing
# 22:46:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 22:47:47 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:47 - cmdstanpy - INFO - Chain [1] start processing
# 22:48:00 - cmdstanpy - INFO - Chain [1] done processing
# 22:48:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 22:48:08 - cmdstanpy - INFO - Chain [1] start processing
# 22:48:08 - cmdstanpy - INFO - Chain [1] start processing
# 22:48:20 - cmdstanpy - INFO - Chain [1] done processing
# 22:48:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 22:48:28 - cmdstanpy - INFO - Chain [1] start processing
# 22:48:38 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 22:51:40 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:40 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:53 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 22:52:01 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 22:52:03 - cmdstanpy - INFO - Chain [1] start processing
# 22:52:15 - cmdstanpy - INFO - Chain [1] done processing
# 22:52:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 22:52:25 - cmdstanpy - INFO - Chain [1] start processing
# 22:52:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points====>         (94 + 19) / 113]
# Processing group: Avellino with 29862 data points
# 22:52:53 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 22:52:53 - cmdstanpy - INFO - Chain [1] start processing
# 22:53:07 - cmdstanpy - INFO - Chain [1] done processing
# 22:53:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 22:53:17 - cmdstanpy - INFO - Chain [1] start processing
# 22:53:18 - cmdstanpy - INFO - Chain [1] start processing
# 22:53:31 - cmdstanpy - INFO - Chain [1] done processing
# 22:53:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 22:53:43 - cmdstanpy - INFO - Chain [1] start processing
# 22:53:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points============> (109 + 4) / 113]
# Processing group: Avellino with 29862 data points
# 22:54:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 22:54:26 - cmdstanpy - INFO - Chain [1] start processing
# 22:54:37 - cmdstanpy - INFO - Chain [1] done processing
# 22:54:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 22:54:47 - cmdstanpy - INFO - Chain [1] start processing
# 22:54:50 - cmdstanpy - INFO - Chain [1] start processing
# 22:55:03 - cmdstanpy - INFO - Chain [1] done processing
# 22:55:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 22:55:17 - cmdstanpy - INFO - Chain [1] start processing
# 22:55:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 22:56:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 22:56:03 - cmdstanpy - INFO - Chain [1] start processing
# 22:56:14 - cmdstanpy - INFO - Chain [1] done processing
# 22:56:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 22:56:22 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 22:56:27 - cmdstanpy - INFO - Chain [1] start processing
# 22:56:41 - cmdstanpy - INFO - Chain [1] done processing
# 22:56:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 22:56:51 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 22:57:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 22:57:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 22:57:34 - cmdstanpy - INFO - Chain [1] start processing
# 22:57:48 - cmdstanpy - INFO - Chain [1] done processing
# 22:57:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 22:57:56 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 22:57:57 - cmdstanpy - INFO - Chain [1] start processing
# 22:58:07 - cmdstanpy - INFO - Chain [1] done processing
# 22:58:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 22:58:18 - cmdstanpy - INFO - Chain [1] start processing
# 22:58:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 23:00:56 - cmdstanpy - INFO - Chain [1] start processing
# 23:00:56 - cmdstanpy - INFO - Chain [1] start processing
# 23:01:09 - cmdstanpy - INFO - Chain [1] done processing
# 23:01:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:01:17 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:01:21 - cmdstanpy - INFO - Chain [1] start processing
# 23:01:30 - cmdstanpy - INFO - Chain [1] done processing
# 23:01:34 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:01:43 - cmdstanpy - INFO - Chain [1] start processing
# 23:01:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 23:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 23:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 23:04:18 - cmdstanpy - INFO - Chain [1] done processing
# 23:04:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:04:26 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:04:28 - cmdstanpy - INFO - Chain [1] start processing
# 23:04:39 - cmdstanpy - INFO - Chain [1] done processing
# 23:04:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:04:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:04:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 23:07:18 - cmdstanpy - INFO - Chain [1] start processing
# 23:07:18 - cmdstanpy - INFO - Chain [1] start processing
# 23:07:29 - cmdstanpy - INFO - Chain [1] done processing
# 23:07:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 23:07:37 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 23:07:39 - cmdstanpy - INFO - Chain [1] start processing
# 23:07:49 - cmdstanpy - INFO - Chain [1] done processing
# 23:07:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 23:07:57 - cmdstanpy - INFO - Chain [1] start processing
# 23:08:08 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points=======>       (98 + 15) / 113]
# Processing group: Benevento with 29862 data points
# 23:09:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:09:00 - cmdstanpy - INFO - Chain [1] start processing
# 23:09:11 - cmdstanpy - INFO - Chain [1] done processing
# 23:09:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 23:09:20 - cmdstanpy - INFO - Chain [1] start processing
# 23:09:21 - cmdstanpy - INFO - Chain [1] start processing
# 23:09:33 - cmdstanpy - INFO - Chain [1] done processing
# 23:09:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 23:09:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=============>(111 + 2) / 113]
# Processing group: Avellino with 29862 data points
# 23:10:25 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:10:25 - cmdstanpy - INFO - Chain [1] start processing
# 23:10:38 - cmdstanpy - INFO - Chain [1] done processing
# 23:10:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 23:10:48 - cmdstanpy - INFO - Chain [1] start processing
# 23:10:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:11:08 - cmdstanpy - INFO - Chain [1] done processing
# 23:11:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:11:18 - cmdstanpy - INFO - Chain [1] start processing
# 23:11:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>      (99 + 14) / 113]
# Processing group: Avellino with 29862 data points
# 23:11:59 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:11:59 - cmdstanpy - INFO - Chain [1] start processing
# 23:12:10 - cmdstanpy - INFO - Chain [1] done processing
# 23:12:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 23:12:18 - cmdstanpy - INFO - Chain [1] start processing
# 23:12:19 - cmdstanpy - INFO - Chain [1] start processing
# 23:12:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 23:12:41 - cmdstanpy - INFO - Chain [1] start processing
# 23:12:49 - cmdstanpy - INFO - Chain [1] done processing
# 23:12:59 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=>                (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 23:13:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:13:34 - cmdstanpy - INFO - Chain [1] start processing
# 23:13:47 - cmdstanpy - INFO - Chain [1] done processing
# 23:13:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 23:13:55 - cmdstanpy - INFO - Chain [1] start processing
# 23:13:56 - cmdstanpy - INFO - Chain [1] start processing
# 23:14:08 - cmdstanpy - INFO - Chain [1] done processing
# 23:14:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:14:17 - cmdstanpy - INFO - Chain [1] start processing
# 23:14:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 23:15:19 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:15:19 - cmdstanpy - INFO - Chain [1] start processing
# 23:15:32 - cmdstanpy - INFO - Chain [1] done processing
# 23:15:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:15:40 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:15:42 - cmdstanpy - INFO - Chain [1] start processing
# 23:15:54 - cmdstanpy - INFO - Chain [1] done processing
# 23:15:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:16:03 - cmdstanpy - INFO - Chain [1] start processing
# 23:16:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 23:18:42 - cmdstanpy - INFO - Chain [1] start processing
# 23:18:43 - cmdstanpy - INFO - Chain [1] start processing
# 23:18:55 - cmdstanpy - INFO - Chain [1] done processing
# 23:18:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:19:04 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:19:06 - cmdstanpy - INFO - Chain [1] start processing
# 23:19:18 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:19:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:19:31 - cmdstanpy - INFO - Chain [1] start processing
# 23:19:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 23:22:14 - cmdstanpy - INFO - Chain [1] start processing
# 23:22:14 - cmdstanpy - INFO - Chain [1] start processing
# 23:22:26 - cmdstanpy - INFO - Chain [1] done processing
# 23:22:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# Processing group: Salerno with 29862 data points
# 23:22:34 - cmdstanpy - INFO - Chain [1] start processing
# 23:22:35 - cmdstanpy - INFO - Chain [1] start processing
# 23:22:45 - cmdstanpy - INFO - Chain [1] done processing
# 23:22:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:22:55 - cmdstanpy - INFO - Chain [1] start processing
# 23:23:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 23:24:41 - cmdstanpy - INFO - Chain [1] start processing
# 23:24:41 - cmdstanpy - INFO - Chain [1] start processing
# 23:24:52 - cmdstanpy - INFO - Chain [1] done processing
# 23:24:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:25:00 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:25:04 - cmdstanpy - INFO - Chain [1] start processing
# 23:25:14 - cmdstanpy - INFO - Chain [1] done processing
# 23:25:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:25:25 - cmdstanpy - INFO - Chain [1] start processing
# 23:25:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 23:28:25 - cmdstanpy - INFO - Chain [1] start processing
# 23:28:25 - cmdstanpy - INFO - Chain [1] start processing
# 23:28:38 - cmdstanpy - INFO - Chain [1] done processing
# 23:28:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:28:46 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:28:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:28:59 - cmdstanpy - INFO - Chain [1] done processing
# 23:29:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:29:10 - cmdstanpy - INFO - Chain [1] start processing
# 23:29:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 23:30:54 - cmdstanpy - INFO - Chain [1] start processing
# 23:30:54 - cmdstanpy - INFO - Chain [1] start processing
# 23:31:04 - cmdstanpy - INFO - Chain [1] done processing
# 23:31:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:31:12 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:31:16 - cmdstanpy - INFO - Chain [1] start processing
# 23:31:26 - cmdstanpy - INFO - Chain [1] done processing
# 23:31:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:31:36 - cmdstanpy - INFO - Chain [1] start processing
# 23:31:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 23:34:32 - cmdstanpy - INFO - Chain [1] start processing
# 23:34:32 - cmdstanpy - INFO - Chain [1] start processing
# 23:34:45 - cmdstanpy - INFO - Chain [1] done processing
# 23:34:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:34:53 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:34:56 - cmdstanpy - INFO - Chain [1] start processing
# 23:35:06 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:35:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:35:18 - cmdstanpy - INFO - Chain [1] start processing
# 23:35:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 23:37:48 - cmdstanpy - INFO - Chain [1] start processing
# 23:37:48 - cmdstanpy - INFO - Chain [1] start processing
# 23:38:00 - cmdstanpy - INFO - Chain [1] done processing
# 23:38:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:38:08 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:38:10 - cmdstanpy - INFO - Chain [1] start processing
# 23:38:21 - cmdstanpy - INFO - Chain [1] done processing
# 23:38:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:38:31 - cmdstanpy - INFO - Chain [1] start processing
# 23:38:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 23:41:06 - cmdstanpy - INFO - Chain [1] start processing
# 23:41:06 - cmdstanpy - INFO - Chain [1] start processing
# 23:41:19 - cmdstanpy - INFO - Chain [1] done processing
# 23:41:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 23:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 23:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 23:41:40 - cmdstanpy - INFO - Chain [1] done processing
# 23:41:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:41:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:41:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data pointsProcessing group: Benevento with 29862 data points
#
# 23:44:14 - cmdstanpy - INFO - Chain [1] start processing
# 23:44:14 - cmdstanpy - INFO - Chain [1] start processing
# 23:44:23 - cmdstanpy - INFO - Chain [1] done processing
# 23:44:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:44:32 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:44:37 - cmdstanpy - INFO - Chain [1] start processing
# 23:44:43 - cmdstanpy - INFO - Chain [1] done processing
# 23:44:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:44:57 - cmdstanpy - INFO - Chain [1] start processing
# 23:45:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 23:45:30 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:45:30 - cmdstanpy - INFO - Chain [1] start processing
# 23:45:43 - cmdstanpy - INFO - Chain [1] done processing
# 23:45:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 23:45:52 - cmdstanpy - INFO - Chain [1] start processing
# 23:45:53 - cmdstanpy - INFO - Chain [1] start processing
# 23:46:06 - cmdstanpy - INFO - Chain [1] done processing
# 23:46:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:46:14 - cmdstanpy - INFO - Chain [1] start processing
# 23:46:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=============>(111 + 2) / 113]
# Processing group: Avellino with 29862 data points
# 23:46:59 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:46:59 - cmdstanpy - INFO - Chain [1] start processing
# 23:47:08 - cmdstanpy - INFO - Chain [1] done processing
# 23:47:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:47:16 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:47:22 - cmdstanpy - INFO - Chain [1] start processing
# 23:47:29 - cmdstanpy - INFO - Chain [1] done processing
# 23:47:45 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Napoli with 29862 data points
# 23:47:54 - cmdstanpy - INFO - Chain [1] start processing
# 23:48:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=>                (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 23:48:40 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:48:40 - cmdstanpy - INFO - Chain [1] start processing
# 23:48:52 - cmdstanpy - INFO - Chain [1] done processing
# 23:48:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:49:00 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:49:02 - cmdstanpy - INFO - Chain [1] start processing
# 23:49:12 - cmdstanpy - INFO - Chain [1] done processing
# 23:49:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 23:49:21 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 23:49:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=>                (5 + 2) / 7]
# Processing group: Avellino with 29862 data points
# 23:50:18 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:50:18 - cmdstanpy - INFO - Chain [1] start processing
# 23:50:31 - cmdstanpy - INFO - Chain [1] done processing
# 23:50:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 23:50:39 - cmdstanpy - INFO - Chain [1] start processing
# 23:50:41 - cmdstanpy - INFO - Chain [1] start processing
# 23:50:54 - cmdstanpy - INFO - Chain [1] done processing
# 23:50:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 23:51:02 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 23:51:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 23:54:06 - cmdstanpy - INFO - Chain [1] start processing
# 23:54:06 - cmdstanpy - INFO - Chain [1] start processing
# 23:54:18 - cmdstanpy - INFO - Chain [1] done processing
# 23:54:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 23:54:26 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 23:54:29 - cmdstanpy - INFO - Chain [1] start processing
# 23:54:39 - cmdstanpy - INFO - Chain [1] done processing
# 23:54:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 23:54:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:55:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 23:57:32 - cmdstanpy - INFO - Chain [1] start processing
# 23:57:32 - cmdstanpy - INFO - Chain [1] start processing
# 23:57:45 - cmdstanpy - INFO - Chain [1] done processing
# 23:57:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 23:57:54 - cmdstanpy - INFO - Chain [1] start processing
# 23:57:55 - cmdstanpy - INFO - Chain [1] start processing
# 23:58:08 - cmdstanpy - INFO - Chain [1] done processing
# 23:58:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 23:58:16 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 23:58:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 00:00:21 - cmdstanpy - INFO - Chain [1] start processing
# 00:00:21 - cmdstanpy - INFO - Chain [1] start processing
# 00:00:35 - cmdstanpy - INFO - Chain [1] done processing
# 00:00:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 00:00:44 - cmdstanpy - INFO - Chain [1] start processing
# 00:00:44 - cmdstanpy - INFO - Chain [1] start processing
# 00:00:58 - cmdstanpy - INFO - Chain [1] done processing
# 00:00:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (0 + 2) / 2]
# 00:01:06 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:01:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 00:03:19 - cmdstanpy - INFO - Chain [1] start processing
# 00:03:19 - cmdstanpy - INFO - Chain [1] start processing
# 00:03:30 - cmdstanpy - INFO - Chain [1] done processing
# 00:03:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:03:38 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:03:40 - cmdstanpy - INFO - Chain [1] start processing
# 00:03:52 - cmdstanpy - INFO - Chain [1] done processing
# 00:03:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 00:04:02 - cmdstanpy - INFO - Chain [1] start processing
# 00:04:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 00:06:15 - cmdstanpy - INFO - Chain [1] start processing
# 00:06:15 - cmdstanpy - INFO - Chain [1] start processing
# 00:06:28 - cmdstanpy - INFO - Chain [1] done processing
# 00:06:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 00:06:37 - cmdstanpy - INFO - Chain [1] start processing
# 00:06:38 - cmdstanpy - INFO - Chain [1] start processing
# 00:06:51 - cmdstanpy - INFO - Chain [1] done processing
# 00:06:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 00:07:00 - cmdstanpy - INFO - Chain [1] start processing
# 00:07:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data pointsProcessing group: Avellino with 29862 data points
#
# 00:09:17 - cmdstanpy - INFO - Chain [1] start processing
# 00:09:17 - cmdstanpy - INFO - Chain [1] start processing
# 00:09:29 - cmdstanpy - INFO - Chain [1] done processing
# 00:09:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:09:37 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 00:09:51 - cmdstanpy - INFO - Chain [1] done processing
# 00:09:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:09:59 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:10:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (98 + 15) / 113]
# Processing group: Avellino with 29862 data points
# 00:10:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:10:35 - cmdstanpy - INFO - Chain [1] start processing
# 00:10:46 - cmdstanpy - INFO - Chain [1] done processing
# 00:10:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:10:56 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:10:59 - cmdstanpy - INFO - Chain [1] start processing
# 00:11:09 - cmdstanpy - INFO - Chain [1] done processing
# 00:11:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:11:17 - cmdstanpy - INFO - Chain [1] start processing
# 00:11:26 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points============> (109 + 4) / 113]
# Processing group: Avellino with 29862 data points
# 00:12:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:12:03 - cmdstanpy - INFO - Chain [1] start processing
# 00:12:15 - cmdstanpy - INFO - Chain [1] done processing
# 00:12:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:12:25 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:12:28 - cmdstanpy - INFO - Chain [1] start processing
# 00:12:42 - cmdstanpy - INFO - Chain [1] done processing
# 00:12:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 00:12:52 - cmdstanpy - INFO - Chain [1] start processing
# 00:13:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=====>        (94 + 19) / 113]
# Processing group: Avellino with 29862 data points
# 00:13:33 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:13:33 - cmdstanpy - INFO - Chain [1] start processing
# 00:13:46 - cmdstanpy - INFO - Chain [1] done processing
# 00:13:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 00:13:54 - cmdstanpy - INFO - Chain [1] start processing
# 00:13:55 - cmdstanpy - INFO - Chain [1] start processing
# 00:14:09 - cmdstanpy - INFO - Chain [1] done processing
# 00:14:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:14:20 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:14:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 00:15:06 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:15:06 - cmdstanpy - INFO - Chain [1] start processing
# 00:15:18 - cmdstanpy - INFO - Chain [1] done processing
# 00:15:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:15:26 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:15:29 - cmdstanpy - INFO - Chain [1] start processing
# 00:15:39 - cmdstanpy - INFO - Chain [1] done processing
# 00:15:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:15:47 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:15:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 00:18:40 - cmdstanpy - INFO - Chain [1] start processing
# 00:18:40 - cmdstanpy - INFO - Chain [1] start processing
# 00:18:50 - cmdstanpy - INFO - Chain [1] done processing
# 00:18:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 00:18:58 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 00:19:01 - cmdstanpy - INFO - Chain [1] start processing
# 00:19:10 - cmdstanpy - INFO - Chain [1] done processing
# 00:19:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:19:17 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:19:28 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points===========>   (106 + 7) / 113]
# Processing group: Benevento with 29862 data points
# 00:19:56 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:19:56 - cmdstanpy - INFO - Chain [1] start processing
# 00:20:09 - cmdstanpy - INFO - Chain [1] done processing
# 00:20:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 00:20:18 - cmdstanpy - INFO - Chain [1] start processing
# 00:20:19 - cmdstanpy - INFO - Chain [1] start processing
# 00:20:32 - cmdstanpy - INFO - Chain [1] done processing
# 00:20:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 00:20:40 - cmdstanpy - INFO - Chain [1] start processing
# 00:20:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points======>       (97 + 16) / 113]
# Processing group: Avellino with 29862 data points
# 00:21:27 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:21:27 - cmdstanpy - INFO - Chain [1] start processing
# 00:21:38 - cmdstanpy - INFO - Chain [1] done processing
# 00:21:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:21:47 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:21:50 - cmdstanpy - INFO - Chain [1] start processing
# 00:22:19 - cmdstanpy - INFO - Chain [1] done processing
# 00:22:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:22:27 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:22:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>     (100 + 13) / 113]
# Processing group: Avellino with 29862 data points
# 00:23:11 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:23:11 - cmdstanpy - INFO - Chain [1] start processing
# 00:23:23 - cmdstanpy - INFO - Chain [1] done processing
# 00:23:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 00:23:31 - cmdstanpy - INFO - Chain [1] start processing
# 00:23:31 - cmdstanpy - INFO - Chain [1] start processing
# 00:23:44 - cmdstanpy - INFO - Chain [1] done processing
# 00:23:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:23:54 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:24:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=============>(112 + 1) / 113]
# Processing group: Avellino with 29862 data points
# 00:24:47 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:24:47 - cmdstanpy - INFO - Chain [1] start processing
# 00:24:59 - cmdstanpy - INFO - Chain [1] done processing
# 00:25:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 00:25:07 - cmdstanpy - INFO - Chain [1] start processing
# 00:25:08 - cmdstanpy - INFO - Chain [1] start processing
# 00:25:20 - cmdstanpy - INFO - Chain [1] done processing
# 00:25:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 00:25:30 - cmdstanpy - INFO - Chain [1] start processing
# 00:25:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 00:27:24 - cmdstanpy - INFO - Chain [1] start processing
# 00:27:24 - cmdstanpy - INFO - Chain [1] start processing
# 00:27:34 - cmdstanpy - INFO - Chain [1] done processing
# 00:27:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Caserta with 29862 data points
# 00:27:41 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Salerno with 29862 data points
# 00:27:45 - cmdstanpy - INFO - Chain [1] start processing
# 00:27:54 - cmdstanpy - INFO - Chain [1] done processing
# 00:27:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:28:02 - cmdstanpy - INFO - Chain [1] start processing
# 00:28:12 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points=======>      (99 + 14) / 113]
# Processing group: Avellino with 29862 data points
# 00:28:43 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:28:43 - cmdstanpy - INFO - Chain [1] start processing
# 00:28:56 - cmdstanpy - INFO - Chain [1] done processing
# 00:28:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:29:06 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:29:09 - cmdstanpy - INFO - Chain [1] start processing
# 00:29:20 - cmdstanpy - INFO - Chain [1] done processing
# 00:29:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 00:29:31 - cmdstanpy - INFO - Chain [1] start processing
# 00:29:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (3 + 4) / 7]
# Processing group: Avellino with 29862 data points
# 00:30:18 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:30:18 - cmdstanpy - INFO - Chain [1] start processing
# 00:30:30 - cmdstanpy - INFO - Chain [1] done processing
# 00:30:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 00:30:40 - cmdstanpy - INFO - Chain [1] start processing
# 00:30:42 - cmdstanpy - INFO - Chain [1] start processing
# 00:30:56 - cmdstanpy - INFO - Chain [1] done processing
# 00:30:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:31:05 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:31:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 00:31:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:31:49 - cmdstanpy - INFO - Chain [1] start processing
# 00:32:02 - cmdstanpy - INFO - Chain [1] done processing
# 00:32:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:32:10 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:32:12 - cmdstanpy - INFO - Chain [1] start processing
# 00:32:22 - cmdstanpy - INFO - Chain [1] done processing
# 00:32:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:32:31 - cmdstanpy - INFO - Chain [1] start processing
# 00:32:41 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 00:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 00:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 00:34:15 - cmdstanpy - INFO - Chain [1] done processing
# 00:34:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:34:23 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:34:29 - cmdstanpy - INFO - Chain [1] start processing
# 00:34:35 - cmdstanpy - INFO - Chain [1] done processing
# 00:34:42 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Napoli with 29862 data points
# 00:34:51 - cmdstanpy - INFO - Chain [1] start processing
# 00:34:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 00:37:20 - cmdstanpy - INFO - Chain [1] start processing
# 00:37:20 - cmdstanpy - INFO - Chain [1] start processing
# 00:37:33 - cmdstanpy - INFO - Chain [1] done processing
# 00:37:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:37:41 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:37:44 - cmdstanpy - INFO - Chain [1] start processing
# 00:37:56 - cmdstanpy - INFO - Chain [1] done processing
# 00:37:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 00:38:06 - cmdstanpy - INFO - Chain [1] start processing
# 00:38:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 00:40:43 - cmdstanpy - INFO - Chain [1] start processing
# 00:40:43 - cmdstanpy - INFO - Chain [1] start processing
# 00:40:57 - cmdstanpy - INFO - Chain [1] done processing
# 00:40:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:41:05 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:41:07 - cmdstanpy - INFO - Chain [1] start processing
# 00:41:19 - cmdstanpy - INFO - Chain [1] done processing
# 00:41:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 00:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 00:41:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points==============>(112 + 1) / 113]
# Processing group: Benevento with 29862 data points
# 00:42:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:42:50 - cmdstanpy - INFO - Chain [1] start processing
# 00:43:02 - cmdstanpy - INFO - Chain [1] done processing
# 00:43:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:43:10 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:43:12 - cmdstanpy - INFO - Chain [1] start processing
# 00:43:23 - cmdstanpy - INFO - Chain [1] done processing
# 00:43:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 00:43:35 - cmdstanpy - INFO - Chain [1] start processing
# 00:43:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 00:45:57 - cmdstanpy - INFO - Chain [1] start processing
# 00:45:57 - cmdstanpy - INFO - Chain [1] start processing
# 00:46:10 - cmdstanpy - INFO - Chain [1] done processing
# 00:46:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:46:18 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:46:20 - cmdstanpy - INFO - Chain [1] start processing
# 00:46:33 - cmdstanpy - INFO - Chain [1] done processing
# 00:46:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 00:46:42 - cmdstanpy - INFO - Chain [1] start processing
# 00:46:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 00:48:20 - cmdstanpy - INFO - Chain [1] start processing
# 00:48:20 - cmdstanpy - INFO - Chain [1] start processing
# 00:48:33 - cmdstanpy - INFO - Chain [1] done processing
# 00:48:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 00:48:41 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 00:48:43 - cmdstanpy - INFO - Chain [1] start processing
# 00:48:55 - cmdstanpy - INFO - Chain [1] done processing
# 00:48:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 00:49:03 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:49:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 00:51:04 - cmdstanpy - INFO - Chain [1] start processing
# 00:51:04 - cmdstanpy - INFO - Chain [1] start processing
# ...
# 02:51:33 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 02:51:33 - cmdstanpy - INFO - Chain [1] start processing
# 02:51:46 - cmdstanpy - INFO - Chain [1] done processing
# 02:51:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 02:51:55 - cmdstanpy - INFO - Chain [1] start processing
# 02:51:57 - cmdstanpy - INFO - Chain [1] start processing
# 02:52:13 - cmdstanpy - INFO - Chain [1] done processing
# 02:52:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 02:52:22 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 02:52:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=========>    (104 + 9) / 113]
# Processing group: Avellino with 29862 data points
# 02:53:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 02:53:04 - cmdstanpy - INFO - Chain [1] start processing
# 02:53:16 - cmdstanpy - INFO - Chain [1] done processing
# 02:53:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 02:53:25 - cmdstanpy - INFO - Chain [1] start processing
# 02:53:26 - cmdstanpy - INFO - Chain [1] start processing
# 02:53:36 - cmdstanpy - INFO - Chain [1] done processing
# 02:53:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 02:53:44 - cmdstanpy - INFO - Chain [1] start processing
# 02:53:53 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 02:56:24 - cmdstanpy - INFO - Chain [1] start processing
# 02:56:24 - cmdstanpy - INFO - Chain [1] start processing
# 02:56:37 - cmdstanpy - INFO - Chain [1] done processing
# 02:56:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 02:56:45 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 02:56:48 - cmdstanpy - INFO - Chain [1] start processing
# 02:56:59 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 02:57:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 02:57:09 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=============> (110 + 3) / 113]
# Processing group: Benevento with 29862 data points
# 02:57:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 02:57:39 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:51 - cmdstanpy - INFO - Chain [1] done processing
# 02:57:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 02:57:59 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 02:58:01 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:13 - cmdstanpy - INFO - Chain [1] done processing
# 02:58:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 02:58:21 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 02:58:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points============> (110 + 3) / 113]
# Processing group: Avellino with 29862 data points
# 02:59:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 02:59:04 - cmdstanpy - INFO - Chain [1] start processing
# 02:59:13 - cmdstanpy - INFO - Chain [1] done processing
# 02:59:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 02:59:21 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 02:59:26 - cmdstanpy - INFO - Chain [1] start processing
# 02:59:52 - cmdstanpy - INFO - Chain [1] done processing
# 02:59:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 03:00:03 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=======>       (97 + 16) / 113]
# Processing group: Benevento with 29862 data points
# 03:00:46 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:00:46 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:58 - cmdstanpy - INFO - Chain [1] done processing
# 03:01:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 03:01:08 - cmdstanpy - INFO - Chain [1] start processing
# 03:01:09 - cmdstanpy - INFO - Chain [1] start processing
# 03:01:28 - cmdstanpy - INFO - Chain [1] done processing
# 03:01:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 03:01:37 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 03:01:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=============>(111 + 2) / 113]
# Processing group: Avellino with 29862 data points
# 03:02:22 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:02:22 - cmdstanpy - INFO - Chain [1] start processing
# 03:02:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:02:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 03:02:40 - cmdstanpy - INFO - Chain [1] start processing
# 03:02:41 - cmdstanpy - INFO - Chain [1] start processing
# 03:02:53 - cmdstanpy - INFO - Chain [1] done processing
# 03:02:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 03:03:01 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 03:03:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points=========>    (102 + 11) / 113]
# Processing group: Benevento with 29862 data points
# 03:03:30 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:03:30 - cmdstanpy - INFO - Chain [1] start processing
# 03:03:42 - cmdstanpy - INFO - Chain [1] done processing
# 03:03:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 03:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 03:03:52 - cmdstanpy - INFO - Chain [1] start processing
# 03:04:04 - cmdstanpy - INFO - Chain [1] done processing
# 03:04:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 03:04:13 - cmdstanpy - INFO - Chain [1] start processing
# 03:04:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 03:07:13 - cmdstanpy - INFO - Chain [1] start processing
# 03:07:13 - cmdstanpy - INFO - Chain [1] start processing
# 03:07:26 - cmdstanpy - INFO - Chain [1] done processing
# 03:07:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 03:07:34 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 03:07:36 - cmdstanpy - INFO - Chain [1] start processing
# 03:07:47 - cmdstanpy - INFO - Chain [1] done processing
# 03:07:50 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 03:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 03:08:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 03:10:44 - cmdstanpy - INFO - Chain [1] start processing
# 03:10:44 - cmdstanpy - INFO - Chain [1] start processing
# 03:10:55 - cmdstanpy - INFO - Chain [1] done processing
# 03:10:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 03:11:03 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 03:11:08 - cmdstanpy - INFO - Chain [1] start processing
# 03:11:16 - cmdstanpy - INFO - Chain [1] done processing
# 03:11:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 03:11:29 - cmdstanpy - INFO - Chain [1] start processing
# 03:11:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 03:13:28 - cmdstanpy - INFO - Chain [1] start processing
# 03:13:28 - cmdstanpy - INFO - Chain [1] start processing
# 03:13:38 - cmdstanpy - INFO - Chain [1] done processing
# 03:13:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 03:13:46 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 03:13:52 - cmdstanpy - INFO - Chain [1] start processing
# 03:13:56 - cmdstanpy - INFO - Chain [1] done processing
# 03:14:04 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Napoli with 29862 data points
# 03:14:12 - cmdstanpy - INFO - Chain [1] start processing
# 03:14:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Avellino with 29862 data points                   (0 + 2) / 2]
# Processing group: Benevento with 29862 data points
# 03:15:58 - cmdstanpy - INFO - Chain [1] start processing
# 03:15:58 - cmdstanpy - INFO - Chain [1] start processing
# 03:16:07 - cmdstanpy - INFO - Chain [1] done processing
# 03:16:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 03:16:15 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 03:16:21 - cmdstanpy - INFO - Chain [1] start processing
# 03:16:30 - cmdstanpy - INFO - Chain [1] done processing
# 03:16:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 03:16:41 - cmdstanpy - INFO - Chain [1] start processing
# 03:16:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points                  (0 + 2) / 2]
# Processing group: Avellino with 29862 data points
# 03:20:01 - cmdstanpy - INFO - Chain [1] start processing
# 03:20:01 - cmdstanpy - INFO - Chain [1] start processing
# 03:20:14 - cmdstanpy - INFO - Chain [1] done processing
# 03:20:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 03:20:22 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 03:20:24 - cmdstanpy - INFO - Chain [1] start processing
# 03:20:37 - cmdstanpy - INFO - Chain [1] done processing
# 03:20:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points                     (1 + 1) / 2]
# 03:20:46 - cmdstanpy - INFO - Chain [1] start processing
# 03:20:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points===========>  (108 + 5) / 113]
# Processing group: Avellino with 29862 data points
# 03:21:19 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:21:19 - cmdstanpy - INFO - Chain [1] start processing
# 03:21:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:21:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# Processing group: Caserta with 29862 data points
# 03:21:40 - cmdstanpy - INFO - Chain [1] start processing
# 03:21:42 - cmdstanpy - INFO - Chain [1] start processing
# 03:21:56 - cmdstanpy - INFO - Chain [1] done processing
# 03:21:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 03:22:04 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 03:22:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Benevento with 29862 data points=======>      (99 + 14) / 113]
# Processing group: Avellino with 29862 data points
# 03:22:52 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:22:52 - cmdstanpy - INFO - Chain [1] start processing
# 03:23:02 - cmdstanpy - INFO - Chain [1] done processing
# 03:23:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Salerno with 29862 data points
# 03:23:10 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Caserta with 29862 data points
# 03:23:15 - cmdstanpy - INFO - Chain [1] start processing
# 03:23:39 - cmdstanpy - INFO - Chain [1] done processing
# 03:23:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Napoli with 29862 data points
# 03:23:47 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 03:23:58 - cmdstanpy - INFO - Chain [1] done processing
# +--------+---------+------------------+------------------+------------------+-----------------+
# |    Time|     NOME|               MSE|              RMSE|               MAE|         Coverage|
# +--------+---------+------------------+------------------+------------------+-----------------+
# |  5 Days|Benevento|111.49921207060365|10.559318731367268| 8.038409436404741| 95.0839552238806|
# |  5 Days|  Salerno| 76.41245686159458| 8.741421901589842| 6.888117479069134|94.83208955223881|
# |  5 Days| Avellino|102.54056883916843|10.126231719606679| 7.846251306090871|94.71548507462687|
# |  5 Days|   Napoli|213.59893091249313|14.615024150253504|11.477565958623332|94.65951492537313|
# |  5 Days|  Caserta|  115.858126940655|10.763741307772824| 8.402822909684414|95.01865671641792|
# | 30 Days|Benevento|118.05055569997076|10.865107256717293| 8.233870490527094| 94.4010889292196|
# | 30 Days|  Salerno| 80.15540987314985| 8.952955370890098| 7.017278227831938|94.25589836660617|
# | 30 Days| Avellino|110.96821968637022|10.534145417943034| 8.077440068712837|94.07441016333938|
# | 30 Days|   Napoli|217.36661848234226|14.743358453294903|11.580805085148247|  94.505444646098|
# | 30 Days|  Caserta|120.84464971870389|10.992936355619635| 8.551133596526816|  94.505444646098|
# | 90 Days|Benevento|  129.315180138334|11.371683258793924|  8.55597910903681|93.34752981260648|
# | 90 Days|  Salerno| 93.07167528194054| 9.647366235503892| 7.434398969325468|92.83219761499149|
# | 90 Days| Avellino| 121.4389688033133| 11.01993506347988| 8.398146790020807|92.99403747870528|
# | 90 Days|   Napoli| 233.9127289238554|15.294205730401805|11.972468478334614|93.80323679727428|
# | 90 Days|  Caserta|139.20381887084656|11.798466801701252| 9.031038147619762|92.96848381601363|
# |180 Days|Benevento|138.20261162869366|11.755960685060735| 8.922556319506949|93.18332488398393|
# |180 Days|  Salerno| 97.68924712858859| 9.883787084341133| 7.662695265770568|93.18722458370705|
# |180 Days| Avellino|125.17675110610412|11.188241644963883| 8.586514962210739|93.13652848730648|
# |180 Days|   Napoli|247.95218397540157|15.746497514539593|12.405869435289265| 93.6161915532504|
# |180 Days|  Caserta|154.71724874026236|12.438538850695542| 9.557490813301346|92.53207503022267|
# |365 Days|Benevento|139.62034911169712|11.816105496808039| 9.017186850638417|94.11410204901567|
# |365 Days|  Salerno| 99.46340991568502|  9.97313440778199| 7.743955757389471|94.11075398419713|
# |365 Days| Avellino|126.06034415777752|11.227659780995214| 8.650666892810463|94.15093076201956|
# |365 Days|   Napoli|260.37679754097036| 16.13619526223485|12.753057089825983|94.14423463238248|
# |365 Days|  Caserta| 166.0431161258783|12.885771848278173|  9.95513096688605| 93.5516271595018|
# +--------+---------+------------------+------------------+------------------+-----------------+

# %%
spark.stop()
