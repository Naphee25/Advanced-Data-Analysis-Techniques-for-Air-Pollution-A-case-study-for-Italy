# %%
#Lazio

from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pyproj

# Create a SparkSession
spark = SparkSession.builder.appName("timeseries").config('spark.sql.shuffle.partitions',500).config('spark.driver.maxResultSize', '10G') .config("spark.driver.memory", "32g").config("spark.executor.memory", "16g").config("spark.task.maxFailures", "10").config("spark.executor.instances", "16").config("spark.local.dir", "/afs/enea.it/por/user/nafis/PFS/tmp").getOrCreate()


schema = StructType(
   [StructField('x', DoubleType(), True),
    StructField('y', DoubleType(), True),
    StructField('z', DoubleType(), True),
    StructField('time', TimestampType(), True),
    StructField('c_PM25', DoubleType(), True),
    StructField('c_PM10', DoubleType(), True),
    StructField('c_O3', DoubleType(), True),
    StructField('c_NO2', DoubleType(), True),
    StructField('geometry', StringType(), True),
    StructField('index_right', IntegerType(), True),
    StructField('OBJECTID', IntegerType(), True),
    StructField('COD_REG', IntegerType(), True),
    StructField('COD_PRO', IntegerType(), True),
    StructField('NOME', StringType(), True),
    StructField('SIGLA', StringType(), True),
    StructField('Shape_Leng', DoubleType(), True),
    StructField('Shape_Area', DoubleType(), True),
   ]
  )


df = spark.read.format("csv").load("/afs/enea.it/por/user/nafis/PFS/tmp/nafi2/nafi/data_chunk/lazio_prov/", header=True, schema=schema)

# Select the columns in the desired order
df = df.select( 'x', 'y', 'z', 'time', 'c_PM25', 'c_PM10', 'c_O3', 'c_NO2', 'geometry', 'NOME')


df = df.withColumn("x", df["x"].cast(DoubleType())) \
    .withColumn("y", df["y"].cast(DoubleType())) \
    .withColumn("z", df["z"].cast(DoubleType())) \
    .withColumn("time", df["time"].cast(TimestampType())) \
    .withColumn("c_PM25", df["c_PM25"].cast(DoubleType())) \
    .withColumn("c_PM10", df["c_PM10"].cast(DoubleType())) \
    .withColumn("c_O3", df["c_O3"].cast(DoubleType())) \
    .withColumn("c_NO2", df["c_NO2"].cast(DoubleType())) \
    .withColumn("geometry", df["geometry"].cast(StringType()))\
    .withColumn("NOME", df["NOME"].cast(StringType()))

df = df.withColumnRenamed("c_PM25", "c_PM2_5")

df.show()

df.printSchema()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/06/26 22:32:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/06/26 22:32:38 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# [Stage 0:>                                                          (0 + 1) / 1]
# +--------+---------+----+-------------------+------------------+------------------+------------------+------------------+--------------------+-------+
# |       x|        y|   z|               time|           c_PM2_5|            c_PM10|              c_O3|             c_NO2|            geometry|   NOME|
# +--------+---------+----+-------------------+------------------+------------------+------------------+------------------+--------------------+-------+
# |702000.0|4696000.0|20.0|2021-12-11 00:00:00|         1.2706414|1.5203451000000001|60.837047999999996|         2.0367115|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 01:00:00|          1.230251|          1.375211|         57.657654|         2.0870926|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 02:00:00|1.9736630000000002|          2.107126|          54.05386|          2.587756|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 03:00:00|1.7445994999999999|1.8961723000000001|          54.00688|         2.1309106|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 04:00:00|         1.2854077|1.5713663999999998|54.418915000000005|1.6039573999999999|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 05:00:00|0.8523575999999999|         1.1182661| 53.96324499999999|         1.8012519|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 06:00:00|        0.78199506|        0.94059986|         48.937576|          2.225234|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 07:00:00|         1.2314979|         1.4721483|46.245734999999996|         2.2615266|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 08:00:00|         2.3940308|         3.0101209|          51.23545|2.1766273999999997|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 09:00:00|         3.0954514|3.8334242999999995|         51.540134|2.1541189999999997|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 10:00:00|         2.8416717|3.5963568999999995|           54.0782|1.7994093999999998|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 11:00:00|3.1728162999999996|          3.890354|          54.80785|1.9321240000000002|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 12:00:00|         2.9845037|         3.5793805|52.454944999999995|         2.0442376|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 13:00:00|3.3172165999999996|         4.0856614|         52.290283|         2.3790326|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 14:00:00|         3.1035097|         3.9299242|52.074946999999995|2.6943377999999996|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 15:00:00|           2.73482|3.7316300000000004|         52.074814|2.7827827999999997|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 16:00:00|2.6398816000000003|          3.834493|         54.961468|         2.8663425|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 17:00:00|         2.5602984|         3.5236087|          57.12959|          2.730953|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 18:00:00|2.3228847999999997|         3.1005373| 63.62944399999999|         2.3298986|POINT (702000 469...|Viterbo|
# |702000.0|4696000.0|20.0|2021-12-11 19:00:00|         2.3371992|         3.0020676| 64.78435999999999|2.1526132000000002|POINT (702000 469...|Viterbo|
# +--------+---------+----+-------------------+------------------+------------------+------------------+------------------+--------------------+-------+
# only showing top 20 rows
#
# root
#  |-- x: double (nullable = true)
#  |-- y: double (nullable = true)
#  |-- z: double (nullable = true)
#  |-- time: timestamp (nullable = true)
#  |-- c_PM2_5: double (nullable = true)
#  |-- c_PM10: double (nullable = true)
#  |-- c_O3: double (nullable = true)
#  |-- c_NO2: double (nullable = true)
#  |-- geometry: string (nullable = true)
#  |-- NOME: string (nullable = true)

# %%
from pyspark.sql import functions as F
import pandas as pd

data = df.withColumnRenamed("time", "date_time")


# Convert the "date_time" column to a datetime object
data = data.withColumn("date_time", F.to_timestamp("date_time"))

# Extract the date and time values and store them in separate columns
data = data.withColumn("date", F.date_trunc("day", "date_time"))
data = data.withColumn("time", F.date_trunc("hour", "date_time"))

data = data.withColumnRenamed("date_time", "original_date_time")

# data.show()

# %%
from pyspark.sql.functions import col, when

# Create the season column based on the month of the date_column
data = data.withColumn(
    "season",
    when(col("original_date_time").between("2019-01-01 00:00:00", "2019-03-19 23:00:00") | col("original_date_time").between("2019-12-21 00:00:00", "2020-03-19 23:00:00") | col("original_date_time").between("2020-12-21 00:00:00", "2021-03-19 23:00:00") | col("original_date_time").between("2021-12-21 00:00:00", "2022-03-19 23:00:00") | col("original_date_time").between("2022-12-21 00:00:00", "2023-03-19 23:00:00"), "Winter")
    .when(col("original_date_time").between("2019-03-20 00:00:00", "2019-06-20 23:00:00") | col("original_date_time").between("2020-03-20 00:00:00", "2020-06-20 23:00:00") | col("original_date_time").between("2021-03-20 00:00:00", "2021-06-20 23:00:00") | col("original_date_time").between("2022-03-20 00:00:00", "2022-06-20 23:00:00") | col("original_date_time").between("2023-03-20 00:00:00", "2023-06-20 23:00:00"), "Spring")
    .when(col("original_date_time").between("2019-06-21 00:00:00", "2019-09-21 23:00:00") | col("original_date_time").between("2020-06-21 00:00:00", "2020-09-21 23:00:00") | col("original_date_time").between("2021-06-21 00:00:00", "2021-09-21 23:00:00") | col("original_date_time").between("2022-06-21 00:00:00", "2022-09-21 23:00:00") | col("original_date_time").between("2023-06-21 00:00:00", "2023-09-21 23:00:00"), "Summer")
    .when(col("original_date_time").between("2019-09-22 00:00:00", "2019-12-20 23:00:00") | col("original_date_time").between("2020-09-22 00:00:00", "2020-12-20 23:00:00") | col("original_date_time").between("2021-09-22 00:00:00", "2021-12-20 23:00:00") | col("original_date_time").between("2022-09-22 00:00:00", "2022-12-20 23:00:00") | col("original_date_time").between("2023-09-22 00:00:00", "2023-12-20 23:00:00"), "Autumn")
)


# data.show()

# %%
dataset = data.select(col("c_PM2_5"), col("c_PM10"), col("c_O3"), col("c_NO2"))
dataset_stat = dataset.describe()
dataset_stat.show()
# Out:
# [Stage 1:======================================================>(118 + 1) / 119]
# +-------+------------------+--------------------+--------------------+--------------------+
# |summary|           c_PM2_5|              c_PM10|                c_O3|               c_NO2|
# +-------+------------------+--------------------+--------------------+--------------------+
# |  count|          33650200|            33650200|            33650200|            33650200|
# |   mean| 7.518901573640087|   9.895731412864988|    70.6286214955896|  7.2519637674854085|
# | stddev| 7.556449815429103|   8.763785837638139|   22.40800767042539|  12.206253204229768|
# |    min|       0.003801894|0.004714028400000...|9.932134999999999...|0.022215692000000002|
# |    max|473.63754000000006|  499.67792000000003|           283.12817|            278.2284|
# +-------+------------------+--------------------+--------------------+--------------------+

# %%
data_PM25 = data.select(col("original_date_time"),col("c_PM2_5"), col("x"), col("y"), col("NOME"))
data_PM25.show()
# Out:
# +-------------------+------------------+--------+---------+-------+
# | original_date_time|           c_PM2_5|       x|        y|   NOME|
# +-------------------+------------------+--------+---------+-------+
# |2021-12-11 00:00:00|         1.2706414|702000.0|4696000.0|Viterbo|
# |2021-12-11 01:00:00|          1.230251|702000.0|4696000.0|Viterbo|
# |2021-12-11 02:00:00|1.9736630000000002|702000.0|4696000.0|Viterbo|
# |2021-12-11 03:00:00|1.7445994999999999|702000.0|4696000.0|Viterbo|
# |2021-12-11 04:00:00|         1.2854077|702000.0|4696000.0|Viterbo|
# |2021-12-11 05:00:00|0.8523575999999999|702000.0|4696000.0|Viterbo|
# |2021-12-11 06:00:00|        0.78199506|702000.0|4696000.0|Viterbo|
# |2021-12-11 07:00:00|         1.2314979|702000.0|4696000.0|Viterbo|
# |2021-12-11 08:00:00|         2.3940308|702000.0|4696000.0|Viterbo|
# |2021-12-11 09:00:00|         3.0954514|702000.0|4696000.0|Viterbo|
# |2021-12-11 10:00:00|         2.8416717|702000.0|4696000.0|Viterbo|
# |2021-12-11 11:00:00|3.1728162999999996|702000.0|4696000.0|Viterbo|
# |2021-12-11 12:00:00|         2.9845037|702000.0|4696000.0|Viterbo|
# |2021-12-11 13:00:00|3.3172165999999996|702000.0|4696000.0|Viterbo|
# |2021-12-11 14:00:00|         3.1035097|702000.0|4696000.0|Viterbo|
# |2021-12-11 15:00:00|           2.73482|702000.0|4696000.0|Viterbo|
# |2021-12-11 16:00:00|2.6398816000000003|702000.0|4696000.0|Viterbo|
# |2021-12-11 17:00:00|         2.5602984|702000.0|4696000.0|Viterbo|
# |2021-12-11 18:00:00|2.3228847999999997|702000.0|4696000.0|Viterbo|
# |2021-12-11 19:00:00|         2.3371992|702000.0|4696000.0|Viterbo|
# +-------------------+------------------+--------+---------+-------+
# only showing top 20 rows

# %%
data_PM10 = data.select(col("original_date_time"),col("c_PM10"), col("x"), col("y"), col("NOME"))
data_PM10.show()
# Out:
# +-------------------+------------------+--------+---------+-------+
# | original_date_time|            c_PM10|       x|        y|   NOME|
# +-------------------+------------------+--------+---------+-------+
# |2021-12-11 00:00:00|1.5203451000000001|702000.0|4696000.0|Viterbo|
# |2021-12-11 01:00:00|          1.375211|702000.0|4696000.0|Viterbo|
# |2021-12-11 02:00:00|          2.107126|702000.0|4696000.0|Viterbo|
# |2021-12-11 03:00:00|1.8961723000000001|702000.0|4696000.0|Viterbo|
# |2021-12-11 04:00:00|1.5713663999999998|702000.0|4696000.0|Viterbo|
# |2021-12-11 05:00:00|         1.1182661|702000.0|4696000.0|Viterbo|
# |2021-12-11 06:00:00|        0.94059986|702000.0|4696000.0|Viterbo|
# |2021-12-11 07:00:00|         1.4721483|702000.0|4696000.0|Viterbo|
# |2021-12-11 08:00:00|         3.0101209|702000.0|4696000.0|Viterbo|
# |2021-12-11 09:00:00|3.8334242999999995|702000.0|4696000.0|Viterbo|
# |2021-12-11 10:00:00|3.5963568999999995|702000.0|4696000.0|Viterbo|
# |2021-12-11 11:00:00|          3.890354|702000.0|4696000.0|Viterbo|
# |2021-12-11 12:00:00|         3.5793805|702000.0|4696000.0|Viterbo|
# |2021-12-11 13:00:00|         4.0856614|702000.0|4696000.0|Viterbo|
# |2021-12-11 14:00:00|         3.9299242|702000.0|4696000.0|Viterbo|
# |2021-12-11 15:00:00|3.7316300000000004|702000.0|4696000.0|Viterbo|
# |2021-12-11 16:00:00|          3.834493|702000.0|4696000.0|Viterbo|
# |2021-12-11 17:00:00|         3.5236087|702000.0|4696000.0|Viterbo|
# |2021-12-11 18:00:00|         3.1005373|702000.0|4696000.0|Viterbo|
# |2021-12-11 19:00:00|         3.0020676|702000.0|4696000.0|Viterbo|
# +-------------------+------------------+--------+---------+-------+
# only showing top 20 rows

# %%
data_NO2 = data.select(col("original_date_time"),col("c_NO2"), col("x"), col("y"), col("NOME"))
data_NO2.show()
# Out:
# +-------------------+------------------+--------+---------+-------+
# | original_date_time|             c_NO2|       x|        y|   NOME|
# +-------------------+------------------+--------+---------+-------+
# |2021-12-11 00:00:00|         2.0367115|702000.0|4696000.0|Viterbo|
# |2021-12-11 01:00:00|         2.0870926|702000.0|4696000.0|Viterbo|
# |2021-12-11 02:00:00|          2.587756|702000.0|4696000.0|Viterbo|
# |2021-12-11 03:00:00|         2.1309106|702000.0|4696000.0|Viterbo|
# |2021-12-11 04:00:00|1.6039573999999999|702000.0|4696000.0|Viterbo|
# |2021-12-11 05:00:00|         1.8012519|702000.0|4696000.0|Viterbo|
# |2021-12-11 06:00:00|          2.225234|702000.0|4696000.0|Viterbo|
# |2021-12-11 07:00:00|         2.2615266|702000.0|4696000.0|Viterbo|
# |2021-12-11 08:00:00|2.1766273999999997|702000.0|4696000.0|Viterbo|
# |2021-12-11 09:00:00|2.1541189999999997|702000.0|4696000.0|Viterbo|
# |2021-12-11 10:00:00|1.7994093999999998|702000.0|4696000.0|Viterbo|
# |2021-12-11 11:00:00|1.9321240000000002|702000.0|4696000.0|Viterbo|
# |2021-12-11 12:00:00|         2.0442376|702000.0|4696000.0|Viterbo|
# |2021-12-11 13:00:00|         2.3790326|702000.0|4696000.0|Viterbo|
# |2021-12-11 14:00:00|2.6943377999999996|702000.0|4696000.0|Viterbo|
# |2021-12-11 15:00:00|2.7827827999999997|702000.0|4696000.0|Viterbo|
# |2021-12-11 16:00:00|         2.8663425|702000.0|4696000.0|Viterbo|
# |2021-12-11 17:00:00|          2.730953|702000.0|4696000.0|Viterbo|
# |2021-12-11 18:00:00|         2.3298986|702000.0|4696000.0|Viterbo|
# |2021-12-11 19:00:00|2.1526132000000002|702000.0|4696000.0|Viterbo|
# +-------------------+------------------+--------+---------+-------+
# only showing top 20 rows

# %%
data_O3 = data.select(col("original_date_time"),col("c_O3"), col("x"), col("y"), col("NOME"))
data_O3.show()
# Out:
# +-------------------+------------------+--------+---------+-------+
# | original_date_time|              c_O3|       x|        y|   NOME|
# +-------------------+------------------+--------+---------+-------+
# |2021-12-11 00:00:00|60.837047999999996|702000.0|4696000.0|Viterbo|
# |2021-12-11 01:00:00|         57.657654|702000.0|4696000.0|Viterbo|
# |2021-12-11 02:00:00|          54.05386|702000.0|4696000.0|Viterbo|
# |2021-12-11 03:00:00|          54.00688|702000.0|4696000.0|Viterbo|
# |2021-12-11 04:00:00|54.418915000000005|702000.0|4696000.0|Viterbo|
# |2021-12-11 05:00:00| 53.96324499999999|702000.0|4696000.0|Viterbo|
# |2021-12-11 06:00:00|         48.937576|702000.0|4696000.0|Viterbo|
# |2021-12-11 07:00:00|46.245734999999996|702000.0|4696000.0|Viterbo|
# |2021-12-11 08:00:00|          51.23545|702000.0|4696000.0|Viterbo|
# |2021-12-11 09:00:00|         51.540134|702000.0|4696000.0|Viterbo|
# |2021-12-11 10:00:00|           54.0782|702000.0|4696000.0|Viterbo|
# |2021-12-11 11:00:00|          54.80785|702000.0|4696000.0|Viterbo|
# |2021-12-11 12:00:00|52.454944999999995|702000.0|4696000.0|Viterbo|
# |2021-12-11 13:00:00|         52.290283|702000.0|4696000.0|Viterbo|
# |2021-12-11 14:00:00|52.074946999999995|702000.0|4696000.0|Viterbo|
# |2021-12-11 15:00:00|         52.074814|702000.0|4696000.0|Viterbo|
# |2021-12-11 16:00:00|         54.961468|702000.0|4696000.0|Viterbo|
# |2021-12-11 17:00:00|          57.12959|702000.0|4696000.0|Viterbo|
# |2021-12-11 18:00:00| 63.62944399999999|702000.0|4696000.0|Viterbo|
# |2021-12-11 19:00:00| 64.78435999999999|702000.0|4696000.0|Viterbo|
# +-------------------+------------------+--------+---------+-------+
# only showing top 20 rows

# %% [markdown]
# # Prophet Model

# %%
import io, os, sys, setuptools, tokenize
from pyspark.sql.types import StructType,StructField,StringType,TimestampType,ArrayType,DoubleType
from pyspark.sql.functions import current_date
from pyspark.sql.functions import pandas_udf, PandasUDFType
import matplotlib.pyplot as plt
from prophet import Prophet
from datetime import datetime
import pandas as pd
from time import time

# %%
# select the "first_name" and "last_name" columns and get distinct values
unique_coordinates = data.select(col("x"), col("y"), col("NOME")).distinct()

# show the unique values
unique_coordinates.show(60)
# Out:
# [Stage 8:===============================================>      (104 + 15) / 119]
# +--------+---------+-------+
# |       x|        y|   NOME|
# +--------+---------+-------+
# |806000.0|4632000.0|   Roma|
# |822000.0|4672000.0|  Rieti|
# |778000.0|4660000.0|   Roma|
# |822000.0|4716000.0|  Rieti|
# |814000.0|4600000.0| Latina|
# |822000.0|4636000.0|   Roma|
# |814000.0|4640000.0|   Roma|
# |754000.0|4708000.0|Viterbo|
# |742000.0|4684000.0|Viterbo|
# |786000.0|4664000.0|   Roma|
# |746000.0|4708000.0|Viterbo|
# |818000.0|4612000.0| Latina|
# |814000.0|4708000.0|  Rieti|
# |774000.0|4696000.0|Viterbo|
# |750000.0|4680000.0|Viterbo|
# |798000.0|4680000.0|   Roma|
# |766000.0|4680000.0|Viterbo|
# |782000.0|4660000.0|   Roma|
# |742000.0|4736000.0|Viterbo|
# |766000.0|4676000.0|Viterbo|
# |778000.0|4696000.0|Viterbo|
# |738000.0|4676000.0|   Roma|
# |738000.0|4740000.0|Viterbo|
# |782000.0|4696000.0|Viterbo|
# |790000.0|4672000.0|   Roma|
# |818000.0|4656000.0|   Roma|
# |706000.0|4696000.0|Viterbo|
# |730000.0|4724000.0|Viterbo|
# |714000.0|4688000.0|Viterbo|
# |742000.0|4724000.0|Viterbo|
# |758000.0|4720000.0|Viterbo|
# |802000.0|4648000.0|   Roma|
# |822000.0|4668000.0|   Roma|
# |786000.0|4692000.0|  Rieti|
# |818000.0|4708000.0|  Rieti|
# |798000.0|4660000.0|   Roma|
# |810000.0|4704000.0|  Rieti|
# |778000.0|4692000.0|Viterbo|
# |814000.0|4652000.0|   Roma|
# |738000.0|4688000.0|Viterbo|
# |778000.0|4636000.0|   Roma|
# |750000.0|4684000.0|Viterbo|
# |798000.0|4648000.0|   Roma|
# |738000.0|4712000.0|Viterbo|
# |754000.0|4724000.0|Viterbo|
# |762000.0|4676000.0|Viterbo|
# |746000.0|4668000.0|   Roma|
# |726000.0|4712000.0|Viterbo|
# |738000.0|4684000.0|Viterbo|
# |814000.0|4612000.0|   Roma|
# |806000.0|4608000.0| Latina|
# |766000.0|4708000.0|Viterbo|
# |750000.0|4716000.0|Viterbo|
# |790000.0|4676000.0|   Roma|
# |762000.0|4692000.0|Viterbo|
# |766000.0|4684000.0|Viterbo|
# |814000.0|4684000.0|  Rieti|
# |734000.0|4696000.0|Viterbo|
# |818000.0|4676000.0|  Rieti|
# |722000.0|4680000.0|Viterbo|
# +--------+---------+-------+
# only showing top 60 rows

# %% [markdown]
# PM2.5

# %%
from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_PM25_prophet = data_PM25.groupBy("NOME", "original_date_time").agg(avg("c_PM2_5").alias("avg_c_PM25"))
data_PM25_prophet.show()

data_PM25_prophet_u = data_PM25_prophet.withColumnRenamed("avg_c_PM25", "y").withColumnRenamed("original_date_time", "ds")

data_PM25_prophet = data_PM25_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

data_PM25_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    # Initiate the model
    
    # Convert "ds" column to pandas datetime format and set timezone to Europe/Rome
    group["ds"] = pd.to_datetime(group["ds"])
    
    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    # Fit the model
    m.fit(group[group['ds'] <= cutoff_date])
    
    # Make predictions
    forecast = m.predict(group)

    # Create the directory if it does not exist
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/PM25/'

    if not os.path.exists(path):
        os.makedirs(path)
        
    try:
        fig1 = m.plot(forecast)
        fig1.suptitle(f"PM2.5 Concentration Forecast for {group['NOME'].iloc[0]}")
        fig1.legend(['Actual', 'Forecasted'], loc='upper right')
        fig1.subplots_adjust(top=0.9)
      
        fig2 = m.plot_components(forecast)
        fig2.suptitle(f"PM2.5 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        fig2.subplots_adjust(top=0.9)

        #Save the plots as images using Matplotlib's savefig method
        fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/PM25/{group['NOME'].iloc[0]}_prophet_forecast.png")
        fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/PM25/{group['NOME'].iloc[0]}_prophet_components.png")
    
    except Exception as e:
        print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    #Return the forecasted results
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

# Define the result schema
result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_PM25_prophet_train = data_PM25_prophet.filter(col('ds') <= cutoff_date)
data_PM25_prophet_test = data_PM25_prophet.filter((col('ds') > cutoff_date))

max_date = data_PM25_prophet_test.agg(max('ds')).collect()[0][0]

period = data_PM25_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_PM25 = data_PM25_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

spark_forecast_PM25.show()
# Out:
# +-------+-------------------+------------------+
# |   NOME| original_date_time|        avg_c_PM25|
# +-------+-------------------+------------------+
# |Viterbo|2022-02-02 01:00:00|1.8850021646017705|
# |  Rieti|2021-11-01 05:00:00|2.8075066410404617|
# |   Roma|2021-12-12 02:00:00|2.2928461067359045|
# |  Rieti|2021-12-19 15:00:00| 6.343829013872831|
# |  Rieti|2021-05-20 22:00:00| 1.867738284393064|
# |  Rieti|2021-10-08 15:00:00|1.5961037958381503|
# |   Roma|2021-05-22 11:00:00|3.5715732362017802|
# | Latina|2021-06-10 21:00:00|4.2314189214285705|
# | Latina|2021-12-13 00:00:00| 7.768597213214285|
# |   Roma|2021-10-11 14:00:00|  2.76334225222552|
# |Viterbo|2021-06-27 07:00:00|3.2851764265486727|
# |   Roma|2021-10-11 19:00:00|3.1654847890207707|
# |Viterbo|2021-10-08 00:00:00| 1.489313195353982|
# |  Rieti|2021-10-08 07:00:00| 1.947233283526011|
# |Viterbo|2021-12-07 13:00:00|2.9378791163716818|
# | Latina|2021-05-21 09:00:00| 4.230126760714284|
# |Viterbo|2021-11-29 20:00:00|2.7331635827433627|
# |  Rieti|2021-03-09 07:00:00|0.7547961775144509|
# |  Rieti|2021-11-29 03:00:00|1.5867574882080924|
# | Latina|2021-05-22 04:00:00|2.5972598242857137|
# +-------+-------------------+------------------+
# only showing top 20 rows
#
# root
#  |-- NOME: string (nullable = true)
#  |-- ds: timestamp (nullable = true)
#  |-- y: double (nullable = true)
# The time used for the Spark forecast is  0.05734062194824219
# Processing group: Rieti with 29862 data points                      (0 + 1) / 1]
# 14:59:03 - cmdstanpy - INFO - Chain [1] start processing
# 14:59:18 - cmdstanpy - INFO - Chain [1] done processing
# +-------------------+-----+------------------+---------+----------+-----------+----------+---------+-----------+------------+
# |                 ds| NOME|                 y|     yhat|yhat_upper| yhat_lower|     trend|   yearly|     weekly|       daily|
# +-------------------+-----+------------------+---------+----------+-----------+----------+---------+-----------+------------+
# |2019-01-01 01:00:00|Rieti| 7.184400588439304|5.5260086| 11.956094|-0.90522933|0.96959853|2.8750517| 0.05885533|   1.6225029|
# |2019-01-01 02:00:00|Rieti|  6.35735458150289|5.2553344|  11.70554| -0.9260314|0.97456086|2.8789773| 0.07901918|    1.322777|
# |2019-01-01 03:00:00|Rieti| 5.176235379190753|4.8768744| 11.135719| -1.4033744| 0.9795232|2.8829155| 0.09737682|   0.9170589|
# |2019-01-01 04:00:00|Rieti|4.5984373115606925| 4.495203| 10.598423| -1.7664592|0.98448557|2.8868659| 0.11379738|   0.5100541|
# |2019-01-01 05:00:00|Rieti| 4.466292086127169|4.2132306| 10.511659|  -2.591771| 0.9894479|2.8908284| 0.12816855|  0.20478614|
# |2019-01-01 06:00:00|Rieti| 4.373945990751446|4.0882363| 10.284632|  -1.818315| 0.9944102|2.8948026| 0.14039779| 0.058625672|
# |2019-01-01 07:00:00|Rieti| 4.325997898843931|4.0902443| 10.007797|  -2.139111|0.99937254|2.8987887|  0.1504135| 0.041669726|
# |2019-01-01 08:00:00|Rieti| 4.527287015606937|  4.10669| 10.383912| -2.1963022| 1.0043349| 2.902786| 0.15816577| 0.041403163|
# |2019-01-01 09:00:00|Rieti|5.1042537346820795|4.0094557| 10.202383| -2.5608938| 1.0092973|2.9067948| 0.16362713| -0.07026378|
# |2019-01-01 10:00:00|Rieti| 4.281565163005782|3.7446246|   9.83149| -2.8345675| 1.0142596|2.9108148| 0.16679285|  -0.3472426|
# |2019-01-01 11:00:00|Rieti|  3.51037125433526|3.3751276|  9.899391| -2.9113472| 1.0192219|2.9148457| 0.16768116| -0.72662115|
# |2019-01-01 12:00:00|Rieti| 2.919746116763006| 3.037364|  9.788994|  -3.181016| 1.0241842|2.9188871|  0.1663331|  -1.0720404|
# |2019-01-01 13:00:00|Rieti|2.6721152745664742|2.8434682|  9.597941|  -3.550497| 1.0291466|2.9229393| 0.16281226|  -1.2714298|
# |2019-01-01 14:00:00|Rieti|2.6551423479768794|2.8086777|  9.144715|  -3.419372| 1.0341089|2.9270017| 0.15720415|   -1.309637|
# |2019-01-01 15:00:00|Rieti|  2.70639185317919|2.8627415| 9.6075325| -3.3656607| 1.0390712|2.9310741| 0.14961538|  -1.2570193|
# |2019-01-01 16:00:00|Rieti| 2.801928282080924|2.9314747|   9.30939| -3.3006556| 1.0440335|2.9351566| 0.14017263|   -1.187888|
# |2019-01-01 17:00:00|Rieti| 3.285910856647399| 3.014179| 9.3054695|  -3.826464| 1.0489959|2.9392486| 0.12902142|   -1.103087|
# |2019-01-01 18:00:00|Rieti| 4.125688108092484|3.1885853|  9.316525|  -2.804545| 1.0539583|  2.94335|0.116324574| -0.92504776|
# |2019-01-01 19:00:00|Rieti| 4.739912723121387|3.5404513|  9.477503| -3.1859818| 1.0589206|2.9474611| 0.10226062| -0.56819093|
# |2019-01-01 20:00:00|Rieti|5.0722571011560715|4.0797615| 10.439535| -1.8570349|  1.063883| 2.951581|0.087021925|-0.022724114|
# +-------------------+-----+------------------+---------+----------+-----------+----------+---------+-----------+------------+
# only showing top 20 rows
# Processing group: Viterbo with 29862 data points

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import pow, sqrt

# Calculate MAE
mae_PM25 = spark_forecast_PM25.select(col("NOME"), abs(col("y") - col("yhat")).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MAE")

# Calculate MSE
mse_PM25 = spark_forecast_PM25.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MSE")

# Calculate RMSE
rmse_PM25 = spark_forecast_PM25.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                     .groupBy("NOME") \
                     .agg({"error": "mean"}) \
                     .withColumnRenamed("avg(error)", "MSE") \
                     .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE"))

# Show the results
mae_PM25.show()
mse_PM25.show()
rmse_PM25.show()
# Out:
# 14:59:29 - cmdstanpy - INFO - Chain [1] start processing         (0 + 96) / 119]
# 14:59:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 15:00:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:00:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:00:32 - cmdstanpy - INFO - Chain [1] done processing
# 15:00:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 15:00:42 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 15:00:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:01:02 - cmdstanpy - INFO - Chain [1] done processing
# 15:01:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 15:01:11 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 15:01:23 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+
# |     NOME|               MAE|
# +---------+------------------+
# |  Viterbo| 3.155507109172206|
# |    Rieti|2.7115033544297553|
# |   Latina| 3.580196274905541|
# |Frosinone| 3.862957565730451|
# |     Roma| 4.534959517075816|
# +---------+------------------+
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 15:02:14 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:02:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:02:33 - cmdstanpy - INFO - Chain [1] done processing
# 15:02:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 15:02:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:02:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:03:02 - cmdstanpy - INFO - Chain [1] done processing
# 15:03:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 15:03:12 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 15:03:23 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+
# |     NOME|               MSE|
# +---------+------------------+
# |  Viterbo|17.675396610709733|
# |    Rieti|13.232938597060423|
# |   Latina| 22.86308769936046|
# |Frosinone| 28.50381361550869|
# |     Roma|34.991957228262685|
# +---------+------------------+
# Processing group: Rieti with 29862 data points==========>          (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 15:04:14 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:04:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:31 - cmdstanpy - INFO - Chain [1] done processing
# 15:04:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 15:04:42 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 15:04:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:05:03 - cmdstanpy - INFO - Chain [1] done processing
# 15:05:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 15:05:14 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 15:05:25 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+------------------+
# |     NOME|               MSE|              RMSE|
# +---------+------------------+------------------+
# |  Viterbo|17.675396610709733| 4.204211770440415|
# |    Rieti|13.232938597060423|3.6377106258003016|
# |   Latina| 22.86308769936046| 4.781536123398051|
# |Frosinone| 28.50381361550869| 5.338896291885495|
# |     Roma|34.991957228262685|5.9154000057699125|
# +---------+------------------+------------------+

# %%
#Long and Short Term Forecast

from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_PM25_prophet = data_PM25.groupBy("NOME", "original_date_time").agg(avg("c_PM2_5").alias("avg_c_PM25"))
data_PM25_prophet.show()

data_PM25_prophet_u = data_PM25_prophet.withColumnRenamed("avg_c_PM25", "y").withColumnRenamed("original_date_time", "ds")

data_PM25_prophet = data_PM25_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

data_PM25_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    # Initiate the model
    
    # Convert "ds" column to pandas datetime format and set timezone to Europe/Rome
    group["ds"] = pd.to_datetime(group["ds"])
    
    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    # Fit the model
    m.fit(group[group['ds'] <= cutoff_date])
    
    # Make predictions
    forecast = m.predict(group)

    # Create the directory if it does not exist
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/PM25/'

    if not os.path.exists(path):
        os.makedirs(path)
    
   # try:
    #    fig1 = m.plot(forecast)
     #   fig1.suptitle(f"PM2.5 Concentration Forecast for {group['NOME'].iloc[0]}")
     #   fig1.legend(['Actual', 'Forecasted'], loc='upper right')
     #   fig1.subplots_adjust(top=0.9)
        
      #  fig2 = m.plot_components(forecast)
       # fig2.suptitle(f"PM2.5 Concentration Component Forecast for {group['NOME'].iloc[0]}")
       # fig2.subplots_adjust(top=0.9)

        # Save the plots as images using Matplotlib's savefig method
        #fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/PM25/{group['NOME'].iloc[0]}_prophet_forecast.png")
        #fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/PM25/{group['NOME'].iloc[0]}_prophet_components.png")
    
    #except Exception as e:
     #   print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    #Return the forecasted results
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

# Define the result schema
result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_PM25_prophet_train = data_PM25_prophet.filter(col('ds') <= cutoff_date)
data_PM25_prophet_test = data_PM25_prophet.filter((col('ds') > cutoff_date))

max_date = data_PM25_prophet_test.agg(max('ds')).collect()[0][0]

period = data_PM25_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_PM25 = data_PM25_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

#spark_forecast_PM25.show()
# Out:
# +-------+-------------------+------------------+
# |   NOME| original_date_time|        avg_c_PM25|
# +-------+-------------------+------------------+
# |Viterbo|2022-02-02 01:00:00|1.8850021646017705|
# |  Rieti|2021-11-01 05:00:00|2.8075066410404617|
# |   Roma|2021-12-12 02:00:00|2.2928461067359045|
# |  Rieti|2021-12-19 15:00:00| 6.343829013872831|
# |  Rieti|2021-05-20 22:00:00| 1.867738284393064|
# |  Rieti|2021-10-08 15:00:00|1.5961037958381503|
# |   Roma|2021-05-22 11:00:00|3.5715732362017802|
# | Latina|2021-06-10 21:00:00|4.2314189214285705|
# | Latina|2021-12-13 00:00:00| 7.768597213214285|
# |   Roma|2021-10-11 14:00:00|  2.76334225222552|
# |Viterbo|2021-06-27 07:00:00|3.2851764265486727|
# |   Roma|2021-10-11 19:00:00|3.1654847890207707|
# |Viterbo|2021-10-08 00:00:00| 1.489313195353982|
# |  Rieti|2021-10-08 07:00:00| 1.947233283526011|
# |Viterbo|2021-12-07 13:00:00|2.9378791163716818|
# | Latina|2021-05-21 09:00:00| 4.230126760714284|
# |Viterbo|2021-11-29 20:00:00|2.7331635827433627|
# |  Rieti|2021-03-09 07:00:00|0.7547961775144509|
# |  Rieti|2021-11-29 03:00:00|1.5867574882080924|
# | Latina|2021-05-22 04:00:00|2.5972598242857137|
# +-------+-------------------+------------------+
# only showing top 20 rows
#
# root
#  |-- NOME: string (nullable = true)
#  |-- ds: timestamp (nullable = true)
#  |-- y: double (nullable = true)
# The time used for the Spark forecast is  0.5329997539520264

# %%
from pyspark.sql.functions import col, pow, sqrt

# Define cutoff dates
cutoff_dates = {
    "5 Days": "2021-07-05 23:00:00",
    "30 Days": "2021-07-30 23:00:00",
    "90 Days": "2021-09-28 23:00:00",
    "180 Days": "2021-12-27 23:00:00",
    "365 Days": "2022-06-29 23:00:00"
}

# Define a list to store the evaluation results
results = []

# Compute evaluation metrics for each time period and NOME
for period, cutoff in cutoff_dates.items():
    for nome in spark_forecast_PM25.select("NOME").distinct().rdd.flatMap(lambda x: x).collect():
        # Filter the forecast data based on the cutoff date and NOME
        forecast_data_PM25 = spark_forecast_PM25.filter((col("ds") <= cutoff) & (col("NOME") == nome))

        # Calculate MAE
        mae = forecast_data_PM25.select(abs(col("y") - col("yhat")).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MAE") \
                             .collect()[0]["MAE"]

        # Calculate MSE
        mse = forecast_data_PM25.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MSE") \
                             .collect()[0]["MSE"]

        # Calculate RMSE
        rmse = forecast_data_PM25.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                              .agg({"error": "mean"}) \
                              .withColumnRenamed("avg(error)", "MSE") \
                              .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE")) \
                              .collect()[0]["RMSE"]

        # Calculate coverage
        coverage = forecast_data_PM25.filter((col("y") >= col("yhat_lower")) & (col("y") <= col("yhat_upper"))) \
                                  .count() / forecast_data_PM25.count() * 100

        # Add the results to the list
        results.append((period, nome, mse, rmse, mae, coverage))

# Create a Spark DataFrame from the results list
result_df_PM25 = spark.createDataFrame(results, ["Time", "NOME", "MSE", "RMSE", "MAE", "Coverage"])

# Show the results
result_df_PM25.show(100)
# Out:
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 22:36:30 - cmdstanpy - INFO - Chain [1] start processing
# 22:36:30 - cmdstanpy - INFO - Chain [1] start processing
# 22:36:48 - cmdstanpy - INFO - Chain [1] done processing
# 22:36:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 22:36:56 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 22:36:58 - cmdstanpy - INFO - Chain [1] start processing
# 22:37:11 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 22:37:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 22:37:18 - cmdstanpy - INFO - Chain [1] start processing
# 22:37:30 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points================> (116 + 3) / 119]
# Processing group: Frosinone with 29862 data points
# 22:38:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 22:38:10 - cmdstanpy - INFO - Chain [1] start processing
# 22:38:29 - cmdstanpy - INFO - Chain [1] done processing
# 22:38:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 22:38:39 - cmdstanpy - INFO - Chain [1] start processing
# 22:38:41 - cmdstanpy - INFO - Chain [1] start processing
# 22:39:07 - cmdstanpy - INFO - Chain [1] done processing
# 22:39:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 22:39:19 - cmdstanpy - INFO - Chain [1] start processing
# 22:39:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 22:42:07 - cmdstanpy - INFO - Chain [1] start processing
# 22:42:07 - cmdstanpy - INFO - Chain [1] start processing
# 22:42:26 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 22:42:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 22:42:35 - cmdstanpy - INFO - Chain [1] start processing
# 22:42:36 - cmdstanpy - INFO - Chain [1] start processing
# 22:42:56 - cmdstanpy - INFO - Chain [1] done processing
# 22:42:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 22:43:05 - cmdstanpy - INFO - Chain [1] start processing
# 22:43:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 22:45:17 - cmdstanpy - INFO - Chain [1] start processing
# 22:45:17 - cmdstanpy - INFO - Chain [1] start processing
# 22:45:36 - cmdstanpy - INFO - Chain [1] done processing
# 22:45:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 22:45:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 22:45:45 - cmdstanpy - INFO - Chain [1] start processing
# 22:46:00 - cmdstanpy - INFO - Chain [1] done processing
# 22:46:02 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 22:46:10 - cmdstanpy - INFO - Chain [1] start processing
# 22:46:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 22:47:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 22:47:34 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:51 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 22:47:59 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 22:48:01 - cmdstanpy - INFO - Chain [1] start processing
# 22:48:19 - cmdstanpy - INFO - Chain [1] done processing
# 22:48:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 22:48:27 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 22:48:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 22:51:40 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:40 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:59 - cmdstanpy - INFO - Chain [1] done processing
# 22:52:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 22:52:07 - cmdstanpy - INFO - Chain [1] start processing
# 22:52:09 - cmdstanpy - INFO - Chain [1] start processing
# 22:52:24 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 22:52:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 22:52:34 - cmdstanpy - INFO - Chain [1] start processing
# 22:52:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>          (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 22:53:19 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 22:53:19 - cmdstanpy - INFO - Chain [1] start processing
# 22:53:34 - cmdstanpy - INFO - Chain [1] done processing
# 22:53:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 22:53:42 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 22:53:46 - cmdstanpy - INFO - Chain [1] start processing
# 22:54:00 - cmdstanpy - INFO - Chain [1] done processing
# 22:54:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 22:54:10 - cmdstanpy - INFO - Chain [1] start processing
# 22:54:24 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>          (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 22:55:02 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 22:55:02 - cmdstanpy - INFO - Chain [1] start processing
# 22:55:21 - cmdstanpy - INFO - Chain [1] done processing
# 22:55:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 22:55:29 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 22:55:32 - cmdstanpy - INFO - Chain [1] start processing
# 22:55:48 - cmdstanpy - INFO - Chain [1] done processing
# 22:55:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 22:55:58 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 22:56:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points=========>    (110 + 9) / 119]
# Processing group: Rieti with 29862 data points
# 22:56:54 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 22:56:54 - cmdstanpy - INFO - Chain [1] start processing
# 22:57:13 - cmdstanpy - INFO - Chain [1] done processing
# 22:57:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 22:57:23 - cmdstanpy - INFO - Chain [1] start processing
# 22:57:25 - cmdstanpy - INFO - Chain [1] start processing
# 22:57:46 - cmdstanpy - INFO - Chain [1] done processing
# 22:57:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 22:58:00 - cmdstanpy - INFO - Chain [1] start processing
# 22:58:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data pointsProcessing group: Frosinone with 29862 data points
#
# 23:00:56 - cmdstanpy - INFO - Chain [1] start processing
# 23:00:56 - cmdstanpy - INFO - Chain [1] start processing
# 23:01:16 - cmdstanpy - INFO - Chain [1] done processing
# 23:01:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:01:24 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:01:26 - cmdstanpy - INFO - Chain [1] start processing
# 23:01:41 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:01:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 23:01:49 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 23:02:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 23:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 23:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 23:04:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:04:26 - cmdstanpy - INFO - Chain [1] done processing
# 23:04:27 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:04:35 - cmdstanpy - INFO - Chain [1] start processing
# 23:04:47 - cmdstanpy - INFO - Chain [1] done processing
# 23:04:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (0 + 2) / 2]
# 23:04:55 - cmdstanpy - INFO - Chain [1] start processing
# 23:05:08 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 23:07:18 - cmdstanpy - INFO - Chain [1] start processing
# 23:07:18 - cmdstanpy - INFO - Chain [1] start processing
# 23:07:36 - cmdstanpy - INFO - Chain [1] done processing
# 23:07:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:07:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:07:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:08:05 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:08:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 23:08:13 - cmdstanpy - INFO - Chain [1] start processing
# 23:08:26 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 23:09:15 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:09:15 - cmdstanpy - INFO - Chain [1] start processing
# 23:09:32 - cmdstanpy - INFO - Chain [1] done processing
# 23:09:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 23:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 23:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 23:09:55 - cmdstanpy - INFO - Chain [1] done processing
# 23:09:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:10:09 - cmdstanpy - INFO - Chain [1] start processing
# 23:10:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points================> (115 + 4) / 119]
# Processing group: Frosinone with 29862 data points
# 23:11:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:11:00 - cmdstanpy - INFO - Chain [1] start processing
# 23:11:18 - cmdstanpy - INFO - Chain [1] done processing
# 23:11:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 23:11:26 - cmdstanpy - INFO - Chain [1] start processing
# 23:11:28 - cmdstanpy - INFO - Chain [1] start processing
# 23:11:47 - cmdstanpy - INFO - Chain [1] done processing
# 23:11:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:11:58 - cmdstanpy - INFO - Chain [1] start processing
# 23:12:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===============>  (114 + 5) / 119]
# Processing group: Frosinone with 29862 data points
# 23:12:53 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:12:53 - cmdstanpy - INFO - Chain [1] start processing
# 23:13:11 - cmdstanpy - INFO - Chain [1] done processing
# 23:13:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:13:22 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:13:25 - cmdstanpy - INFO - Chain [1] start processing
# 23:13:47 - cmdstanpy - INFO - Chain [1] done processing
# 23:13:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:13:56 - cmdstanpy - INFO - Chain [1] start processing
# 23:14:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (109 + 10) / 119]
# Processing group: Frosinone with 29862 data points
# 23:14:50 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:14:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:15:06 - cmdstanpy - INFO - Chain [1] done processing
# 23:15:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 23:15:16 - cmdstanpy - INFO - Chain [1] start processing
# 23:15:16 - cmdstanpy - INFO - Chain [1] start processing
# 23:15:35 - cmdstanpy - INFO - Chain [1] done processing
# 23:15:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:15:45 - cmdstanpy - INFO - Chain [1] start processing
# 23:15:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 23:18:42 - cmdstanpy - INFO - Chain [1] start processing
# 23:18:43 - cmdstanpy - INFO - Chain [1] start processing
# 23:18:58 - cmdstanpy - INFO - Chain [1] done processing
# 23:19:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 23:19:06 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 23:19:09 - cmdstanpy - INFO - Chain [1] start processing
# 23:19:25 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:19:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:19:35 - cmdstanpy - INFO - Chain [1] start processing
# 23:19:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 23:22:14 - cmdstanpy - INFO - Chain [1] start processing
# 23:22:14 - cmdstanpy - INFO - Chain [1] start processing
# 23:22:32 - cmdstanpy - INFO - Chain [1] done processing
# 23:22:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:22:41 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:22:43 - cmdstanpy - INFO - Chain [1] start processing
# 23:23:01 - cmdstanpy - INFO - Chain [1] done processing
# 23:23:02 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:23:10 - cmdstanpy - INFO - Chain [1] start processing
# 23:23:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 23:24:32 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:24:32 - cmdstanpy - INFO - Chain [1] start processing
# 23:24:50 - cmdstanpy - INFO - Chain [1] done processing
# 23:24:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:24:58 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:25:00 - cmdstanpy - INFO - Chain [1] start processing
# 23:25:17 - cmdstanpy - INFO - Chain [1] done processing
# 23:25:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:25:26 - cmdstanpy - INFO - Chain [1] start processing
# 23:25:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 23:28:25 - cmdstanpy - INFO - Chain [1] start processing
# 23:28:25 - cmdstanpy - INFO - Chain [1] start processing
# 23:28:44 - cmdstanpy - INFO - Chain [1] done processing
# 23:28:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:28:52 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:28:54 - cmdstanpy - INFO - Chain [1] start processing
# 23:29:11 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:29:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:29:20 - cmdstanpy - INFO - Chain [1] start processing
# 23:29:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=============>    (110 + 9) / 119]
# Processing group: Frosinone with 29862 data points
# 23:30:41 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:30:41 - cmdstanpy - INFO - Chain [1] start processing
# 23:30:59 - cmdstanpy - INFO - Chain [1] done processing
# 23:31:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:31:07 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:31:10 - cmdstanpy - INFO - Chain [1] start processing
# 23:31:26 - cmdstanpy - INFO - Chain [1] done processing
# 23:31:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 23:31:34 - cmdstanpy - INFO - Chain [1] start processing
# 23:31:48 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 23:34:32 - cmdstanpy - INFO - Chain [1] start processing
# 23:34:32 - cmdstanpy - INFO - Chain [1] start processing
# 23:34:51 - cmdstanpy - INFO - Chain [1] done processing
# 23:34:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 23:34:59 - cmdstanpy - INFO - Chain [1] start processing
# 23:35:00 - cmdstanpy - INFO - Chain [1] start processing
# 23:35:19 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:35:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 23:35:27 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 23:35:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 23:37:48 - cmdstanpy - INFO - Chain [1] start processing
# 23:37:48 - cmdstanpy - INFO - Chain [1] start processing
# 23:38:02 - cmdstanpy - INFO - Chain [1] done processing
# 23:38:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:38:11 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:38:16 - cmdstanpy - INFO - Chain [1] start processing
# 23:38:31 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:38:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 23:38:39 - cmdstanpy - INFO - Chain [1] start processing
# 23:38:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 23:41:06 - cmdstanpy - INFO - Chain [1] start processing
# 23:41:06 - cmdstanpy - INFO - Chain [1] start processing
# 23:41:20 - cmdstanpy - INFO - Chain [1] done processing
# 23:41:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 23:41:28 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 23:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 23:41:45 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:41:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:41:59 - cmdstanpy - INFO - Chain [1] start processing
# 23:42:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 23:44:14 - cmdstanpy - INFO - Chain [1] start processing
# 23:44:14 - cmdstanpy - INFO - Chain [1] start processing
# 23:44:33 - cmdstanpy - INFO - Chain [1] done processing
# 23:44:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 23:44:41 - cmdstanpy - INFO - Chain [1] start processing
# 23:44:42 - cmdstanpy - INFO - Chain [1] start processing
# 23:45:00 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:45:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:45:09 - cmdstanpy - INFO - Chain [1] start processing
# 23:45:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=================>(117 + 2) / 119]
# Processing group: Frosinone with 29862 data points
# 23:45:59 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:45:59 - cmdstanpy - INFO - Chain [1] start processing
# 23:46:15 - cmdstanpy - INFO - Chain [1] done processing
# 23:46:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 23:46:23 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 23:46:25 - cmdstanpy - INFO - Chain [1] start processing
# 23:46:39 - cmdstanpy - INFO - Chain [1] done processing
# 23:46:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:46:54 - cmdstanpy - INFO - Chain [1] start processing
# 23:47:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points======>          (9 + 2) / 11]
# Processing group: Rieti with 29862 data points
# 23:47:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:47:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:48:07 - cmdstanpy - INFO - Chain [1] done processing
# 23:48:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 23:48:16 - cmdstanpy - INFO - Chain [1] start processing
# 23:48:17 - cmdstanpy - INFO - Chain [1] start processing
# 23:48:43 - cmdstanpy - INFO - Chain [1] done processing
# 23:48:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 23:48:56 - cmdstanpy - INFO - Chain [1] start processing
# 23:49:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=================>(117 + 2) / 119]
# Processing group: Frosinone with 29862 data points
# 23:49:48 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 23:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 23:50:18 - cmdstanpy - INFO - Chain [1] done processing
# 23:50:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:50:26 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:50:30 - cmdstanpy - INFO - Chain [1] start processing
# 23:50:43 - cmdstanpy - INFO - Chain [1] done processing
# 23:50:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (0 + 2) / 2]
# 23:50:51 - cmdstanpy - INFO - Chain [1] start processing
# 23:51:04 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 23:54:06 - cmdstanpy - INFO - Chain [1] start processing
# 23:54:06 - cmdstanpy - INFO - Chain [1] start processing
# 23:54:22 - cmdstanpy - INFO - Chain [1] done processing
# 23:54:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:54:30 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:54:33 - cmdstanpy - INFO - Chain [1] start processing
# 23:54:48 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 23:54:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 23:54:56 - cmdstanpy - INFO - Chain [1] start processing
# 23:55:09 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 23:57:32 - cmdstanpy - INFO - Chain [1] start processing
# 23:57:32 - cmdstanpy - INFO - Chain [1] start processing
# 23:57:50 - cmdstanpy - INFO - Chain [1] done processing
# 23:57:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 23:57:58 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 23:58:01 - cmdstanpy - INFO - Chain [1] start processing
# 23:58:17 - cmdstanpy - INFO - Chain [1] done processing
# 23:58:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (0 + 2) / 2]
# 23:58:25 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 23:58:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 00:00:21 - cmdstanpy - INFO - Chain [1] start processing00:00:21 - cmdstanpy - INFO - Chain [1] start processing
#
# 00:00:36 - cmdstanpy - INFO - Chain [1] done processing
# 00:00:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 00:00:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 00:00:47 - cmdstanpy - INFO - Chain [1] start processing
# 00:01:03 - cmdstanpy - INFO - Chain [1] done processing
# 00:01:08 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:01:16 - cmdstanpy - INFO - Chain [1] start processing
# 00:01:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 00:03:19 - cmdstanpy - INFO - Chain [1] start processing
# 00:03:19 - cmdstanpy - INFO - Chain [1] start processing
# 00:03:36 - cmdstanpy - INFO - Chain [1] done processing
# 00:03:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:03:44 - cmdstanpy - INFO - Chain [1] start processing
# 00:03:45 - cmdstanpy - INFO - Chain [1] start processing
# 00:03:59 - cmdstanpy - INFO - Chain [1] done processing
# 00:04:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:04:11 - cmdstanpy - INFO - Chain [1] start processing
# 00:04:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 00:06:15 - cmdstanpy - INFO - Chain [1] start processing
# 00:06:15 - cmdstanpy - INFO - Chain [1] start processing
# 00:06:34 - cmdstanpy - INFO - Chain [1] done processing
# 00:06:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:06:42 - cmdstanpy - INFO - Chain [1] start processing
# 00:06:44 - cmdstanpy - INFO - Chain [1] start processing
# 00:06:59 - cmdstanpy - INFO - Chain [1] done processing
# 00:07:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (0 + 2) / 2]
# 00:07:07 - cmdstanpy - INFO - Chain [1] start processing
# 00:07:20 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 00:09:17 - cmdstanpy - INFO - Chain [1] start processing
# 00:09:17 - cmdstanpy - INFO - Chain [1] start processing
# 00:09:36 - cmdstanpy - INFO - Chain [1] done processing
# 00:09:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 00:09:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 00:09:46 - cmdstanpy - INFO - Chain [1] start processing
# 00:10:04 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 00:10:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 00:10:12 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:10:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points======>          (9 + 2) / 11]
# Processing group: Rieti with 29862 data points
# 00:11:02 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:11:02 - cmdstanpy - INFO - Chain [1] start processing
# 00:11:21 - cmdstanpy - INFO - Chain [1] done processing
# 00:11:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:11:29 - cmdstanpy - INFO - Chain [1] start processing
# 00:11:29 - cmdstanpy - INFO - Chain [1] start processing
# 00:11:48 - cmdstanpy - INFO - Chain [1] done processing
# 00:11:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:11:58 - cmdstanpy - INFO - Chain [1] start processing
# 00:12:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points================> (116 + 3) / 119]
# Processing group: Frosinone with 29862 data points
# 00:12:44 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:12:44 - cmdstanpy - INFO - Chain [1] start processing
# 00:13:00 - cmdstanpy - INFO - Chain [1] done processing
# 00:13:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# Processing group: Latina with 29862 data points
# 00:13:08 - cmdstanpy - INFO - Chain [1] start processing
# 00:13:09 - cmdstanpy - INFO - Chain [1] start processing
# 00:13:27 - cmdstanpy - INFO - Chain [1] done processing
# 00:13:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:13:40 - cmdstanpy - INFO - Chain [1] start processing
# 00:13:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==============>   (111 + 8) / 119]
# Processing group: Frosinone with 29862 data points
# 00:14:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:14:29 - cmdstanpy - INFO - Chain [1] start processing
# 00:14:48 - cmdstanpy - INFO - Chain [1] done processing
# 00:14:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 00:14:58 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 00:15:00 - cmdstanpy - INFO - Chain [1] start processing
# 00:15:21 - cmdstanpy - INFO - Chain [1] done processing
# 00:15:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:15:32 - cmdstanpy - INFO - Chain [1] start processing
# 00:15:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 00:18:40 - cmdstanpy - INFO - Chain [1] start processing
# 00:18:40 - cmdstanpy - INFO - Chain [1] start processing
# 00:18:59 - cmdstanpy - INFO - Chain [1] done processing
# 00:18:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:19:07 - cmdstanpy - INFO - Chain [1] start processing
# 00:19:07 - cmdstanpy - INFO - Chain [1] start processing
# 00:19:27 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 00:19:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:19:36 - cmdstanpy - INFO - Chain [1] start processing
# 00:19:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 00:20:28 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:20:28 - cmdstanpy - INFO - Chain [1] start processing
# 00:20:46 - cmdstanpy - INFO - Chain [1] done processing
# 00:20:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 00:20:54 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 00:20:56 - cmdstanpy - INFO - Chain [1] start processing
# 00:21:13 - cmdstanpy - INFO - Chain [1] done processing
# 00:21:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 00:21:23 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:21:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=================>(118 + 1) / 119]
# Processing group: Frosinone with 29862 data points
# 00:22:15 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:22:15 - cmdstanpy - INFO - Chain [1] start processing
# 00:22:34 - cmdstanpy - INFO - Chain [1] done processing
# 00:22:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:22:42 - cmdstanpy - INFO - Chain [1] start processing
# 00:22:44 - cmdstanpy - INFO - Chain [1] start processing
# 00:23:01 - cmdstanpy - INFO - Chain [1] done processing
# 00:23:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:23:11 - cmdstanpy - INFO - Chain [1] start processing
# 00:23:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=================>(118 + 1) / 119]
# Processing group: Frosinone with 29862 data points
# 00:24:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:24:04 - cmdstanpy - INFO - Chain [1] start processing
# 00:24:18 - cmdstanpy - INFO - Chain [1] done processing
# 00:24:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 00:24:29 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 00:24:33 - cmdstanpy - INFO - Chain [1] start processing
# 00:24:54 - cmdstanpy - INFO - Chain [1] done processing
# 00:24:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:25:03 - cmdstanpy - INFO - Chain [1] start processing
# 00:25:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 00:27:24 - cmdstanpy - INFO - Chain [1] start processing
# 00:27:24 - cmdstanpy - INFO - Chain [1] start processing
# 00:27:42 - cmdstanpy - INFO - Chain [1] done processing
# 00:27:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:27:50 - cmdstanpy - INFO - Chain [1] start processing
# 00:27:52 - cmdstanpy - INFO - Chain [1] start processing
# 00:28:10 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 00:28:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:28:20 - cmdstanpy - INFO - Chain [1] start processing
# 00:28:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=============>    (110 + 9) / 119]
# Processing group: Frosinone with 29862 data points
# 00:29:11 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:29:11 - cmdstanpy - INFO - Chain [1] start processing
# 00:29:26 - cmdstanpy - INFO - Chain [1] done processing
# 00:29:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 00:29:35 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 00:29:39 - cmdstanpy - INFO - Chain [1] start processing
# 00:29:55 - cmdstanpy - INFO - Chain [1] done processing
# 00:29:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 00:30:05 - cmdstanpy - INFO - Chain [1] start processing
# 00:30:26 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points=======>     (107 + 12) / 119]
# Processing group: Rieti with 29862 data points
# 00:31:02 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:31:02 - cmdstanpy - INFO - Chain [1] start processing
# 00:31:21 - cmdstanpy - INFO - Chain [1] done processing
# 00:31:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:31:31 - cmdstanpy - INFO - Chain [1] start processing
# 00:31:31 - cmdstanpy - INFO - Chain [1] start processing
# 00:31:56 - cmdstanpy - INFO - Chain [1] done processing
# 00:31:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:32:06 - cmdstanpy - INFO - Chain [1] start processing
# 00:32:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 00:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 00:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 00:34:24 - cmdstanpy - INFO - Chain [1] done processing
# 00:34:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 00:34:32 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 00:34:34 - cmdstanpy - INFO - Chain [1] start processing
# 00:34:47 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 00:34:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:34:59 - cmdstanpy - INFO - Chain [1] start processing
# 00:35:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 00:37:20 - cmdstanpy - INFO - Chain [1] start processing
# 00:37:20 - cmdstanpy - INFO - Chain [1] start processing
# 00:37:40 - cmdstanpy - INFO - Chain [1] done processing
# 00:37:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 00:37:48 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 00:37:50 - cmdstanpy - INFO - Chain [1] start processing
# 00:38:04 - cmdstanpy - INFO - Chain [1] done processing
# 00:38:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:38:16 - cmdstanpy - INFO - Chain [1] start processing
# 00:38:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 00:40:43 - cmdstanpy - INFO - Chain [1] start processing
# 00:40:43 - cmdstanpy - INFO - Chain [1] start processing
# 00:41:02 - cmdstanpy - INFO - Chain [1] done processing
# 00:41:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:41:11 - cmdstanpy - INFO - Chain [1] start processing
# 00:41:12 - cmdstanpy - INFO - Chain [1] start processing
# 00:41:30 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 00:41:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 00:41:38 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 00:41:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 00:42:55 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:42:55 - cmdstanpy - INFO - Chain [1] start processing
# 00:43:12 - cmdstanpy - INFO - Chain [1] done processing
# 00:43:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 00:43:21 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 00:43:23 - cmdstanpy - INFO - Chain [1] start processing
# 00:43:38 - cmdstanpy - INFO - Chain [1] done processing
# 00:43:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:43:48 - cmdstanpy - INFO - Chain [1] start processing
# 00:44:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 00:45:57 - cmdstanpy - INFO - Chain [1] start processing
# 00:45:57 - cmdstanpy - INFO - Chain [1] start processing
# 00:46:16 - cmdstanpy - INFO - Chain [1] done processing
# 00:46:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:46:24 - cmdstanpy - INFO - Chain [1] start processing
# 00:46:25 - cmdstanpy - INFO - Chain [1] start processing
# 00:46:40 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 00:46:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:46:51 - cmdstanpy - INFO - Chain [1] start processing
# 00:47:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points========>    (108 + 11) / 119]
# Processing group: Rieti with 29862 data points
# 00:48:16 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 00:48:16 - cmdstanpy - INFO - Chain [1] start processing
# 00:48:33 - cmdstanpy - INFO - Chain [1] done processing
# 00:48:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# Processing group: Latina with 29862 data points
# 00:48:41 - cmdstanpy - INFO - Chain [1] start processing
# 00:48:42 - cmdstanpy - INFO - Chain [1] start processing
# 00:48:59 - cmdstanpy - INFO - Chain [1] done processing
# 00:49:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:49:10 - cmdstanpy - INFO - Chain [1] start processing
# 00:49:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 00:51:04 - cmdstanpy - INFO - Chain [1] start processing
# 00:51:04 - cmdstanpy - INFO - Chain [1] start processing
# 00:51:22 - cmdstanpy - INFO - Chain [1] done processing
# 00:51:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:51:30 - cmdstanpy - INFO - Chain [1] start processing
# 00:51:32 - cmdstanpy - INFO - Chain [1] start processing
# 00:51:45 - cmdstanpy - INFO - Chain [1] done processing
# 00:51:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 00:51:53 - cmdstanpy - INFO - Chain [1] start processing
# 00:52:06 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 00:54:36 - cmdstanpy - INFO - Chain [1] start processing
# 00:54:36 - cmdstanpy - INFO - Chain [1] start processing
# 00:54:53 - cmdstanpy - INFO - Chain [1] done processing
# 00:54:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 00:55:01 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 00:55:03 - cmdstanpy - INFO - Chain [1] start processing
# 00:55:16 - cmdstanpy - INFO - Chain [1] done processing
# 00:55:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 00:55:23 - cmdstanpy - INFO - Chain [1] start processing
# 00:55:34 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 00:57:16 - cmdstanpy - INFO - Chain [1] start processing
# 00:57:16 - cmdstanpy - INFO - Chain [1] start processing
# 00:57:36 - cmdstanpy - INFO - Chain [1] done processing
# 00:57:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 00:57:45 - cmdstanpy - INFO - Chain [1] start processing
# 00:57:45 - cmdstanpy - INFO - Chain [1] start processing
# 00:58:00 - cmdstanpy - INFO - Chain [1] done processing
# 00:58:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 00:58:10 - cmdstanpy - INFO - Chain [1] start processing
# 00:58:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 00:59:49 - cmdstanpy - INFO - Chain [1] start processing
# 00:59:49 - cmdstanpy - INFO - Chain [1] start processing
# 01:00:08 - cmdstanpy - INFO - Chain [1] done processing
# 01:00:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 01:00:16 - cmdstanpy - INFO - Chain [1] start processing
# 01:00:18 - cmdstanpy - INFO - Chain [1] start processing
# 01:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 01:00:34 - cmdstanpy - INFO - Chain [1] done processing
# ...
# 03:25:17 - cmdstanpy - INFO - Chain [1] start processing
# 03:25:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:25:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 03:25:40 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 03:25:45 - cmdstanpy - INFO - Chain [1] start processing
# 03:25:56 - cmdstanpy - INFO - Chain [1] done processing
# 03:25:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 03:26:04 - cmdstanpy - INFO - Chain [1] start processing
# 03:26:15 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (105 + 14) / 119]
# Processing group: Frosinone with 29862 data points
# 03:26:50 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:26:50 - cmdstanpy - INFO - Chain [1] start processing
# 03:27:08 - cmdstanpy - INFO - Chain [1] done processing
# 03:27:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 03:27:16 - cmdstanpy - INFO - Chain [1] start processing
# 03:27:17 - cmdstanpy - INFO - Chain [1] start processing
# 03:27:33 - cmdstanpy - INFO - Chain [1] done processing
# 03:27:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 03:27:41 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 03:27:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 03:28:30 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:28:30 - cmdstanpy - INFO - Chain [1] start processing
# 03:28:43 - cmdstanpy - INFO - Chain [1] done processing
# 03:28:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 03:28:51 - cmdstanpy - INFO - Chain [1] start processing
# 03:28:52 - cmdstanpy - INFO - Chain [1] start processing
# 03:29:05 - cmdstanpy - INFO - Chain [1] done processing
# 03:29:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 03:29:13 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 03:29:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (107 + 12) / 119]
# Processing group: Frosinone with 29862 data points
# 03:29:59 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:29:59 - cmdstanpy - INFO - Chain [1] start processing
# 03:30:15 - cmdstanpy - INFO - Chain [1] done processing
# 03:30:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 03:30:24 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 03:30:27 - cmdstanpy - INFO - Chain [1] start processing
# 03:30:39 - cmdstanpy - INFO - Chain [1] done processing
# 03:30:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 03:30:47 - cmdstanpy - INFO - Chain [1] start processing
# 03:30:57 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points================> (116 + 3) / 119]
# Processing group: Frosinone with 29862 data points
# 03:31:37 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:31:37 - cmdstanpy - INFO - Chain [1] start processing
# 03:31:55 - cmdstanpy - INFO - Chain [1] done processing
# 03:31:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 03:32:03 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 03:32:05 - cmdstanpy - INFO - Chain [1] start processing
# 03:32:23 - cmdstanpy - INFO - Chain [1] done processing
# 03:32:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 03:32:31 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 03:32:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=================>(118 + 1) / 119]
# Processing group: Frosinone with 29862 data points
# 03:33:20 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:33:20 - cmdstanpy - INFO - Chain [1] start processing
# 03:33:37 - cmdstanpy - INFO - Chain [1] done processing
# 03:33:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 03:33:45 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 03:33:47 - cmdstanpy - INFO - Chain [1] start processing
# 03:34:00 - cmdstanpy - INFO - Chain [1] done processing
# 03:34:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 03:34:09 - cmdstanpy - INFO - Chain [1] start processing
# 03:34:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 03:34:57 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:34:57 - cmdstanpy - INFO - Chain [1] start processing
# 03:35:10 - cmdstanpy - INFO - Chain [1] done processing
# 03:35:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 03:35:18 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 03:35:20 - cmdstanpy - INFO - Chain [1] start processing
# 03:35:34 - cmdstanpy - INFO - Chain [1] done processing
# 03:35:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 03:35:43 - cmdstanpy - INFO - Chain [1] start processing
# 03:35:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==============>   (111 + 8) / 119]
# Processing group: Frosinone with 29862 data points
# 03:36:32 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:36:32 - cmdstanpy - INFO - Chain [1] start processing
# 03:36:44 - cmdstanpy - INFO - Chain [1] done processing
# 03:36:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 03:36:52 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 03:36:54 - cmdstanpy - INFO - Chain [1] start processing
# 03:37:07 - cmdstanpy - INFO - Chain [1] done processing
# 03:37:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 03:37:15 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 03:37:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (107 + 12) / 119]
# Processing group: Frosinone with 29862 data points
# 03:38:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:38:03 - cmdstanpy - INFO - Chain [1] start processing
# 03:38:16 - cmdstanpy - INFO - Chain [1] done processing
# 03:38:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 03:38:24 - cmdstanpy - INFO - Chain [1] start processing
# 03:38:25 - cmdstanpy - INFO - Chain [1] start processing
# 03:38:38 - cmdstanpy - INFO - Chain [1] done processing
# 03:38:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 03:38:47 - cmdstanpy - INFO - Chain [1] start processing
# 03:38:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (109 + 10) / 119]
# Processing group: Frosinone with 29862 data points
# 03:39:33 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:39:33 - cmdstanpy - INFO - Chain [1] start processing
# 03:39:45 - cmdstanpy - INFO - Chain [1] done processing
# 03:39:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 03:39:53 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 03:39:56 - cmdstanpy - INFO - Chain [1] start processing
# 03:40:08 - cmdstanpy - INFO - Chain [1] done processing
# 03:40:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 03:40:16 - cmdstanpy - INFO - Chain [1] start processing
# 03:40:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 03:41:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:41:03 - cmdstanpy - INFO - Chain [1] start processing
# 03:41:20 - cmdstanpy - INFO - Chain [1] done processing
# 03:41:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 03:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 03:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 03:41:42 - cmdstanpy - INFO - Chain [1] done processing
# 03:41:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 03:41:54 - cmdstanpy - INFO - Chain [1] start processing
# 03:42:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 03:42:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:42:42 - cmdstanpy - INFO - Chain [1] start processing
# 03:43:00 - cmdstanpy - INFO - Chain [1] done processing
# 03:43:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 03:43:08 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 03:43:10 - cmdstanpy - INFO - Chain [1] start processing
# 03:43:27 - cmdstanpy - INFO - Chain [1] done processing
# 03:43:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 03:43:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:43:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 03:44:22 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:44:22 - cmdstanpy - INFO - Chain [1] start processing
# 03:44:40 - cmdstanpy - INFO - Chain [1] done processing
# 03:44:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 03:44:49 - cmdstanpy - INFO - Chain [1] start processing
# 03:44:50 - cmdstanpy - INFO - Chain [1] start processing
# 03:45:07 - cmdstanpy - INFO - Chain [1] done processing
# 03:45:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 03:45:15 - cmdstanpy - INFO - Chain [1] start processing
# 03:45:26 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===============>  (114 + 5) / 119]
# Processing group: Frosinone with 29862 data points
# 03:46:05 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:46:06 - cmdstanpy - INFO - Chain [1] start processing
# 03:46:23 - cmdstanpy - INFO - Chain [1] done processing
# 03:46:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 03:46:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:46:32 - cmdstanpy - INFO - Chain [1] start processing
# 03:46:50 - cmdstanpy - INFO - Chain [1] done processing
# 03:46:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 03:46:58 - cmdstanpy - INFO - Chain [1] start processing            (1 + 1) / 2]
# 03:47:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 03:47:44 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:47:44 - cmdstanpy - INFO - Chain [1] start processing
# 03:48:02 - cmdstanpy - INFO - Chain [1] done processing
# 03:48:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 03:48:10 - cmdstanpy - INFO - Chain [1] start processing
# 03:48:11 - cmdstanpy - INFO - Chain [1] start processing
# 03:48:24 - cmdstanpy - INFO - Chain [1] done processing
# 03:48:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 03:48:33 - cmdstanpy - INFO - Chain [1] start processing
# 03:48:44 - cmdstanpy - INFO - Chain [1] done processing
# +--------+---------+------------------+------------------+------------------+-----------------+
# |    Time|     NOME|               MSE|              RMSE|               MAE|         Coverage|
# +--------+---------+------------------+------------------+------------------+-----------------+
# |  5 Days|  Viterbo|16.003960724139166|  4.00049505988186| 2.973204787744828|94.27705223880596|
# |  5 Days|    Rieti|10.248351804787955|3.2013047035213558| 2.322585598394069| 95.0839552238806|
# |  5 Days|   Latina| 20.95198798697315| 4.577334157233133|3.3648135928169416|94.10914179104478|
# |  5 Days|Frosinone|21.226793891930374|4.6072544852580455|3.2211363150914343|93.95055970149254|
# |  5 Days|     Roma|28.009525101490844| 5.292402583089352|3.9372356263705406|94.70149253731344|
# | 30 Days|  Viterbo|15.830821758352895|3.9787965213557848| 2.958620307652071|94.45099818511797|
# | 30 Days|    Rieti|10.127774617945962|3.1824164746220696| 2.313476887347684|95.18602540834846|
# | 30 Days|   Latina|20.703560563272596|  4.55011654392199|3.3471901218048545|94.21960072595282|
# | 30 Days|Frosinone| 20.88764654729678| 4.570300487637194|3.1982548758069997|94.11524500907441|
# | 30 Days|     Roma|27.733977290331605|5.2663058485366765|3.9221850436572443|94.82304900181488|
# | 90 Days|  Viterbo|15.371672839118467|  3.92067249832455|2.9271601725671035|94.70187393526406|
# | 90 Days|    Rieti|10.248319236651238|3.2012996168198997| 2.359019240271445|95.45996592844975|
# | 90 Days|   Latina|20.241511003362064|4.4990566792786755|3.3310595764077733|94.61243611584327|
# | 90 Days|Frosinone|20.989206768085808| 4.581397905452636|3.2572874612623535|94.54855195911414|
# | 90 Days|     Roma|27.496609323858543| 5.243720942599686|3.9303802212952172|95.12350936967631|
# |180 Days|  Viterbo|16.145587937449697| 4.018157281323082|3.0504061908500057|95.23066723862263|
# |180 Days|    Rieti|12.223931817938434|3.4962739906847164| 2.609670772090732|95.74152790235152|
# |180 Days|   Latina| 21.35215782572657| 4.620839515253324|3.4755237725226404|95.07467924969777|
# |180 Days|Frosinone| 26.00102753487341| 5.099120270681347| 3.666191821640817|95.00838435440471|
# |180 Days|     Roma|31.578795770715878| 5.619501380969301| 4.257990244970944|  95.499746519518|
# |365 Days|  Viterbo|17.675396610709733| 4.204211770440415| 3.155507109172206|95.90531672693183|
# |365 Days|    Rieti|13.232938597060423|3.6377106258003016|2.7115033544297553| 96.3439132181599|
# |365 Days|   Latina| 22.86308769936046| 4.781536123398051| 3.580196274905541|95.75130574527923|
# |365 Days|Frosinone| 28.50381361550869| 5.338896291885495| 3.862957565730451|95.67764831927146|
# |365 Days|     Roma|34.991957228262685|5.9154000057699125| 4.534959517075816|96.09615642158832|
# +--------+---------+------------------+------------------+------------------+-----------------+

# %%
result_df_PM25_pd = result_df_PM25.pandas_api()
result_df_PM25_pd

# %% [markdown]
# PM10

# %%
from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_PM10_prophet = data_PM10.groupBy("NOME", "original_date_time").agg(avg("c_PM10").alias("avg_c_PM10"))
data_PM10_prophet.show()

data_PM10_prophet_u = data_PM10_prophet.withColumnRenamed("avg_c_PM10", "y").withColumnRenamed("original_date_time", "ds")
# data_PM25_prophet = data_PM25_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss"))
data_PM10_prophet = data_PM10_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

data_PM10_prophet.printSchema()


def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    # Initiate the model
    
    # Convert "ds" column to pandas datetime format and set timezone to Europe/Rome
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    #m.add_country_holidays(country_name="IT")
    
    # Fit the model
    m.fit(group[group['ds'] <= cutoff_date])
    
    
    # Make predictions
    forecast = m.predict(group)

    # Create the directory if it does not exist
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/PM10/'

    if not os.path.exists(path):
        os.makedirs(path)
    
    try:
        fig1 = m.plot(forecast)
        fig1.suptitle(f"PM10 Concentration Forecast for {group['NOME'].iloc[0]}")
        fig1.legend(['Actual', 'Forecasted'], loc='upper right')
        fig1.subplots_adjust(top=0.9)
        
        fig2 = m.plot_components(forecast)
        fig2.suptitle(f"PM10 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        fig2.subplots_adjust(top=0.9)

        # Save the plots as images using Matplotlib's savefig method
        fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/PM10/{group['NOME'].iloc[0]}_prophet_forecast.png")
        fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/PM10/{group['NOME'].iloc[0]}_prophet_components.png")
    except Exception as e:
        print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    #Return the forecasted results
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

# Define the restult schema
result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_PM10_prophet_train = data_PM10_prophet.filter(col('ds') <= cutoff_date)
data_PM10_prophet_test = data_PM10_prophet.filter((col('ds') > cutoff_date))

max_date = data_PM10_prophet_test.agg(max('ds')).collect()[0][0]

period = data_PM10_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_PM10 = data_PM10_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

spark_forecast_PM10.show()
# Out:
# +-------+-------------------+------------------+
# |   NOME| original_date_time|        avg_c_PM10|
# +-------+-------------------+------------------+
# |Viterbo|2022-02-02 01:00:00| 2.305790754424778|
# |  Rieti|2021-11-01 05:00:00| 3.048606228323699|
# |   Roma|2021-12-12 02:00:00| 3.200772948664688|
# |  Rieti|2021-12-19 15:00:00| 6.602085763583815|
# |  Rieti|2021-05-20 22:00:00|2.0480550364161845|
# |  Rieti|2021-10-08 15:00:00|2.2356599597109823|
# |   Roma|2021-05-22 11:00:00| 5.616283332344214|
# | Latina|2021-06-10 21:00:00|  4.90211026642857|
# | Latina|2021-12-13 00:00:00| 8.493514665000001|
# |   Roma|2021-10-11 14:00:00| 3.549662149851631|
# |Viterbo|2021-06-27 07:00:00|3.9166167650442487|
# |   Roma|2021-10-11 19:00:00| 4.065098945103857|
# |Viterbo|2021-10-08 00:00:00| 2.278955902212388|
# |  Rieti|2021-10-08 07:00:00|2.3133043560693642|
# |Viterbo|2021-12-07 13:00:00| 6.111837910619468|
# | Latina|2021-05-21 09:00:00| 4.879802729999999|
# |Viterbo|2021-11-29 20:00:00|3.0105132964601746|
# |  Rieti|2021-03-09 07:00:00|0.7878697720809248|
# |  Rieti|2021-11-29 03:00:00| 8.275177238208089|
# | Latina|2021-05-22 04:00:00|3.4621970585714297|
# +-------+-------------------+------------------+
# only showing top 20 rows
#
# root
#  |-- NOME: string (nullable = true)
#  |-- ds: timestamp (nullable = true)
#  |-- y: double (nullable = true)
# The time used for the Spark forecast is  0.03782367706298828
# Processing group: Rieti with 29862 data points                      (0 + 1) / 1]
# 14:30:51 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:03 - cmdstanpy - INFO - Chain [1] done processing
# +-------------------+-----+------------------+---------+----------+----------+---------+---------+----------+-----------+
# |                 ds| NOME|                 y|     yhat|yhat_upper|yhat_lower|    trend|   yearly|    weekly|      daily|
# +-------------------+-----+------------------+---------+----------+----------+---------+---------+----------+-----------+
# |2019-01-01 01:00:00|Rieti| 8.187913463005781|6.3781853|  15.45299| -2.698246|1.4668721|2.9743783|0.25463605|  1.6822985|
# |2019-01-01 02:00:00|Rieti| 7.400683825433524| 6.099694| 15.202893| -2.624092|1.4721631| 2.975724| 0.2781975|  1.3736093|
# |2019-01-01 03:00:00|Rieti|   6.2553596150289|5.7093377| 14.542471| -3.154002|1.4774541| 2.977095|0.29945415|  0.9553345|
# |2019-01-01 04:00:00|Rieti| 5.694775547976879|5.3087525| 13.922252|-3.5283556|1.4827452|2.9784915| 0.3182476|  0.5292683|
# |2019-01-01 05:00:00|Rieti| 5.556005865895955|5.0067577| 13.895753| -4.597168|1.4880362|2.9799137| 0.3344401| 0.20436773|
# |2019-01-01 06:00:00|Rieti| 5.393969293641618| 4.876593| 13.621591|-3.4593456|1.4933271| 2.981361|0.34791595|0.053989056|
# |2019-01-01 07:00:00|Rieti|5.2691905826589585|4.9015822| 13.253047|-3.8899314|1.4986181|2.9828336|0.35858253|0.061547697|
# |2019-01-01 08:00:00|Rieti|  5.43727978381503| 4.964639| 13.823708|-3.9307978|1.5039091|2.9843316|0.36637163|0.110026866|
# |2019-01-01 09:00:00|Rieti| 6.046711122543352|4.9134493| 13.653552|  -4.35931|1.5092001|2.9858549|0.37124002|0.047154218|
# |2019-01-01 10:00:00|Rieti| 5.246374483236995|4.6656528| 13.256068| -4.619587|1.5144912| 2.987403|0.37317005|-0.20941159|
# |2019-01-01 11:00:00|Rieti| 4.355487366473988| 4.271678| 13.479396| -4.600448|1.5197822|2.9889762|0.37216982| -0.6092501|
# |2019-01-01 12:00:00|Rieti|3.6879982641618496| 3.878711| 13.407313| -4.897313|1.5250732|2.9905744|0.36827335| -1.0052098|
# |2019-01-01 13:00:00|Rieti| 3.369850775722543| 3.621582| 13.154197| -5.402246|1.5303642|2.9921973|0.36154026| -1.2625198|
# |2019-01-01 14:00:00|Rieti|3.2861510497109823|3.5314164| 12.473492|-5.2582545|1.5356551| 2.993845|0.35205516| -1.3501389|
# |2019-01-01 15:00:00|Rieti| 3.275559121387283|3.5384731| 13.057424| -5.251695|1.5409462|2.9955175|0.33992705| -1.3379176|
# |2019-01-01 16:00:00|Rieti|3.3274763809248555|3.5619586| 12.563135|-5.2334714|1.5462372|2.9972143| 0.3252881| -1.3067812|
# |2019-01-01 17:00:00|Rieti| 3.783629030635838|3.6023471| 12.481271| -6.051879|1.5515282| 2.998936| 0.3082926| -1.2564095|
# |2019-01-01 18:00:00|Rieti| 4.732906732369943|3.7514067| 12.399793|-4.7067213|1.5568192|3.0006819| 0.2891154| -1.0952098|
# |2019-01-01 19:00:00|Rieti| 5.418084669364162|4.1109486| 12.489933|-5.3820925|1.5621102|3.0024521|0.26795018|  -0.721564|
# |2019-01-01 20:00:00|Rieti| 5.783492935260113|4.6926007| 13.668174|-3.6860235|1.5674013|3.0042467|0.24500757|-0.12405478|
# +-------------------+-----+------------------+---------+----------+----------+---------+---------+----------+-----------+
# only showing top 20 rows
# Processing group: Viterbo with 29862 data points

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import pow, sqrt
from prophet.diagnostics import performance_metrics


# Calculate MAE
mae_PM10 = spark_forecast_PM10.select(col("NOME"), abs(col("y") - col("yhat")).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MAE")


# Calculate MSE
mse_PM10 = spark_forecast_PM10.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MSE")

# Calculate RMSE
rmse_PM10 = spark_forecast_PM10.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                     .groupBy("NOME") \
                     .agg({"error": "mean"}) \
                     .withColumnRenamed("avg(error)", "MSE") \
                     .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE"))

# Show the results
mae_PM10.show()
mse_PM10.show()
rmse_PM10.show()
# Out:
# 14:31:20 - cmdstanpy - INFO - Chain [1] start processing         (0 + 96) / 119]
# 14:32:00 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# Processing group: Rieti with 29862 data points
# 14:32:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:20 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 14:32:30 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 14:32:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:44 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:53 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 14:33:02 - cmdstanpy - INFO - Chain [1] start processing
# 14:33:18 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+
# |     NOME|               MAE|
# +---------+------------------+
# |  Viterbo| 4.078447906746063|
# |    Rieti|3.1889142430171873|
# |   Latina| 4.374905542398387|
# |Frosinone| 4.444598034469279|
# |     Roma| 4.623973814691109|
# +---------+------------------+
# Processing group: Rieti with 29862 data points==========>          (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 14:34:08 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:34:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:34:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:34:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 14:34:32 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 14:34:38 - cmdstanpy - INFO - Chain [1] start processing
# 14:34:47 - cmdstanpy - INFO - Chain [1] done processing
# 14:34:56 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 14:35:05 - cmdstanpy - INFO - Chain [1] start processing
# 14:35:20 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+
# |     NOME|               MSE|
# +---------+------------------+
# |  Viterbo|  36.4500033022641|
# |    Rieti| 23.69100677132566|
# |   Latina|  40.8396873058619|
# |Frosinone|40.885865194485106|
# |     Roma| 42.31326172784455|
# +---------+------------------+
# Processing group: Rieti with 29862 data points==========>          (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 14:36:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:36:10 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:25 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 14:36:34 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 14:36:41 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:48 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:57 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 14:37:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:37:24 - cmdstanpy - INFO - Chain [1] done processing
# +---------+------------------+------------------+
# |     NOME|               MSE|              RMSE|
# +---------+------------------+------------------+
# |  Viterbo|  36.4500033022641|  6.03738381273413|
# |    Rieti| 23.69100677132566| 4.867340831637503|
# |   Latina|  40.8396873058619|6.3905936583279885|
# |Frosinone|40.885865194485106|6.3942055952624095|
# |     Roma| 42.31326172784455| 6.504864466523845|
# +---------+------------------+------------------+

# %%
#Long and Short Term Forecast

from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_PM10_prophet = data_PM10.groupBy("NOME", "original_date_time").agg(avg("c_PM10").alias("avg_c_PM10"))
data_PM10_prophet.show()

data_PM10_prophet_u = data_PM10_prophet.withColumnRenamed("avg_c_PM10", "y").withColumnRenamed("original_date_time", "ds")
# data_PM25_prophet = data_PM25_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss"))
data_PM10_prophet = data_PM10_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

#data_PM10_prophet.printSchema()


def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    # Initiate the model
    
    # Convert "ds" column to pandas datetime format and set timezone to Europe/Rome
    #group["ds"] = pd.to_datetime(group["ds"]).dt.tz_localize('Europe/Rome').dt.tz_convert(pytz.UTC)
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    #m.add_country_holidays(country_name="IT")
    
    # Fit the model
    m.fit(group[group['ds'] <= cutoff_date])
    
    
    # Make predictions
    forecast = m.predict(group)


    # Create the directory if it does not exist
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/PM10/'

    if not os.path.exists(path):
        os.makedirs(path)
    
    #try:
     #   fig1 = m.plot(forecast)
      #  fig1.suptitle(f"PM10 Concentration Forecast for {group['NOME'].iloc[0]}")
       # fig1.legend(['Actual', 'Forecasted'], loc='upper right')
       # fig1.subplots_adjust(top=0.9)
        
       # fig2 = m.plot_components(forecast)
       # fig2.suptitle(f"PM10 Concentration Component Forecast for {group['NOME'].iloc[0]}")
       # fig2.subplots_adjust(top=0.9)

        # Save the plots as images using Matplotlib's savefig method
        #fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/PM10/{group['NOME'].iloc[0]}_prophet_forecast.png")
       # fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/PM10/{group['NOME'].iloc[0]}_prophet_components.png")
   # except Exception as e:
   #     print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    #Return the forecasted results
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

# Define the restult schema
result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_PM10_prophet_train = data_PM10_prophet.filter(col('ds') <= cutoff_date)
data_PM10_prophet_test = data_PM10_prophet.filter((col('ds') > cutoff_date))

max_date = data_PM10_prophet_test.agg(max('ds')).collect()[0][0]

period = data_PM10_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_PM10 = data_PM10_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

#spark_forecast_PM10.show()
# Out:
# +-------+-------------------+------------------+
# |   NOME| original_date_time|        avg_c_PM10|
# +-------+-------------------+------------------+
# |Viterbo|2022-02-02 01:00:00| 2.305790754424778|
# |  Rieti|2021-11-01 05:00:00| 3.048606228323699|
# |   Roma|2021-12-12 02:00:00| 3.200772948664688|
# |  Rieti|2021-12-19 15:00:00| 6.602085763583815|
# |  Rieti|2021-05-20 22:00:00|2.0480550364161845|
# |  Rieti|2021-10-08 15:00:00|2.2356599597109823|
# |   Roma|2021-05-22 11:00:00| 5.616283332344214|
# | Latina|2021-06-10 21:00:00|  4.90211026642857|
# | Latina|2021-12-13 00:00:00| 8.493514665000001|
# |   Roma|2021-10-11 14:00:00| 3.549662149851631|
# |Viterbo|2021-06-27 07:00:00|3.9166167650442487|
# |   Roma|2021-10-11 19:00:00| 4.065098945103857|
# |Viterbo|2021-10-08 00:00:00| 2.278955902212388|
# |  Rieti|2021-10-08 07:00:00|2.3133043560693642|
# |Viterbo|2021-12-07 13:00:00| 6.111837910619468|
# | Latina|2021-05-21 09:00:00| 4.879802729999999|
# |Viterbo|2021-11-29 20:00:00|3.0105132964601746|
# |  Rieti|2021-03-09 07:00:00|0.7878697720809248|
# |  Rieti|2021-11-29 03:00:00| 8.275177238208089|
# | Latina|2021-05-22 04:00:00|3.4621970585714297|
# +-------+-------------------+------------------+
# only showing top 20 rows
# [Stage 1333:============================================>      (104 + 15) / 119]
# The time used for the Spark forecast is  0.04484677314758301

# %%
from pyspark.sql.functions import col, pow, sqrt

# Define cutoff dates
cutoff_dates = {
    "5 Days": "2021-07-05 23:00:00",
    "30 Days": "2021-07-30 23:00:00",
    "90 Days": "2021-09-28 23:00:00",
    "180 Days": "2021-12-27 23:00:00",
    "365 Days": "2022-06-29 23:00:00"
}

# Define a list to store the evaluation results
results = []

# Compute evaluation metrics for each time period and NOME
for period, cutoff in cutoff_dates.items():
    for nome in spark_forecast_PM10.select("NOME").distinct().rdd.flatMap(lambda x: x).collect():
        # Filter the forecast data based on the cutoff date and NOME
        forecast_data_PM10 = spark_forecast_PM10.filter((col("ds") <= cutoff) & (col("NOME") == nome))

        # Calculate MAE
        mae = forecast_data_PM10.select(abs(col("y") - col("yhat")).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MAE") \
                             .collect()[0]["MAE"]

        # Calculate MSE
        mse = forecast_data_PM10.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MSE") \
                             .collect()[0]["MSE"]

        # Calculate RMSE
        rmse = forecast_data_PM10.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                              .agg({"error": "mean"}) \
                              .withColumnRenamed("avg(error)", "MSE") \
                              .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE")) \
                              .collect()[0]["RMSE"]

        # Calculate coverage
        coverage = forecast_data_PM10.filter((col("y") >= col("yhat_lower")) & (col("y") <= col("yhat_upper"))) \
                                  .count() / forecast_data_PM10.count() * 100

        # Add the results to the list
        results.append((period, nome, mse, rmse, mae, coverage))

# Create a Spark DataFrame from the results list
result_df_PM10 = spark.createDataFrame(results, ["Time", "NOME", "MSE", "RMSE", "MAE", "Coverage"])

# Show the results
result_df_PM10.show(100)
# Out:
# Processing group: Frosinone with 29862 data pointsProcessing group: Rieti with 29862 data points
#
# 03:51:24 - cmdstanpy - INFO - Chain [1] start processing
# 03:51:24 - cmdstanpy - INFO - Chain [1] start processing
# 03:51:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 03:51:43 - cmdstanpy - INFO - Chain [1] start processing
# 03:51:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 03:51:51 - cmdstanpy - INFO - Chain [1] start processing
# 03:51:54 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 03:52:05 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 03:52:13 - cmdstanpy - INFO - Chain [1] start processing
# 03:52:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 03:53:05 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:53:05 - cmdstanpy - INFO - Chain [1] start processing
# 03:53:17 - cmdstanpy - INFO - Chain [1] done processing
# 03:53:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 03:53:25 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 03:53:30 - cmdstanpy - INFO - Chain [1] start processing
# 03:53:36 - cmdstanpy - INFO - Chain [1] done processing
# 03:53:45 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 03:53:53 - cmdstanpy - INFO - Chain [1] start processing
# 03:54:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==============>   (111 + 8) / 119]
# Processing group: Frosinone with 29862 data points
# 03:54:50 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:54:50 - cmdstanpy - INFO - Chain [1] start processing
# 03:55:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 03:55:07 - cmdstanpy - INFO - Chain [1] done processing
# 03:55:08 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 03:55:15 - cmdstanpy - INFO - Chain [1] start processing
# 03:55:20 - cmdstanpy - INFO - Chain [1] done processing
# 03:55:28 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 03:55:36 - cmdstanpy - INFO - Chain [1] start processing
# 03:55:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 03:56:31 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:56:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:56:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 03:56:49 - cmdstanpy - INFO - Chain [1] done processing
# 03:56:49 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 03:56:56 - cmdstanpy - INFO - Chain [1] start processing
# 03:57:01 - cmdstanpy - INFO - Chain [1] done processing
# 03:57:11 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 03:57:18 - cmdstanpy - INFO - Chain [1] start processing
# 03:57:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===============>  (114 + 5) / 119]
# Processing group: Frosinone with 29862 data points
# 03:58:09 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:58:09 - cmdstanpy - INFO - Chain [1] start processing
# 03:58:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 03:58:27 - cmdstanpy - INFO - Chain [1] done processing
# 03:58:27 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 03:58:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:58:39 - cmdstanpy - INFO - Chain [1] done processing
# 03:58:48 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 03:58:55 - cmdstanpy - INFO - Chain [1] start processing
# 03:59:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points==========>   (111 + 8) / 119]
# Processing group: Rieti with 29862 data points
# 03:59:53 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 03:59:53 - cmdstanpy - INFO - Chain [1] start processing
# 04:00:07 - cmdstanpy - INFO - Chain [1] done processing
# 04:00:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:00:15 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:00:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:00:27 - cmdstanpy - INFO - Chain [1] done processing
# 04:00:36 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:00:44 - cmdstanpy - INFO - Chain [1] start processing
# 04:00:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points=====>       (101 + 18) / 119]
# Processing group: Rieti with 29862 data points
# 04:01:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:01:34 - cmdstanpy - INFO - Chain [1] start processing
# 04:01:50 - cmdstanpy - INFO - Chain [1] done processing
# 04:01:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:01:58 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:02:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:02:11 - cmdstanpy - INFO - Chain [1] done processing
# 04:02:18 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:02:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:02:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=================>(118 + 1) / 119]
# Processing group: Frosinone with 29862 data points
# 04:03:18 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:03:18 - cmdstanpy - INFO - Chain [1] start processing
# 04:03:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:03:38 - cmdstanpy - INFO - Chain [1] done processing
# 04:03:38 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:03:46 - cmdstanpy - INFO - Chain [1] start processing
# 04:03:51 - cmdstanpy - INFO - Chain [1] done processing
# 04:04:00 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:04:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:04:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points============> (116 + 3) / 119]
# Processing group: Rieti with 29862 data points
# 04:05:01 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:05:01 - cmdstanpy - INFO - Chain [1] start processing
# 04:05:16 - cmdstanpy - INFO - Chain [1] done processing
# 04:05:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:05:24 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:05:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:05:38 - cmdstanpy - INFO - Chain [1] done processing
# 04:05:45 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:05:53 - cmdstanpy - INFO - Chain [1] start processing
# 04:06:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 04:06:43 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:06:43 - cmdstanpy - INFO - Chain [1] start processing
# 04:06:57 - cmdstanpy - INFO - Chain [1] done processing
# 04:07:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:07:05 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:07:12 - cmdstanpy - INFO - Chain [1] start processing
# 04:07:19 - cmdstanpy - INFO - Chain [1] done processing
# 04:07:27 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:07:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:07:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 04:08:24 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:08:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:08:39 - cmdstanpy - INFO - Chain [1] done processing
# 04:08:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:08:47 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:08:53 - cmdstanpy - INFO - Chain [1] start processing
# 04:08:59 - cmdstanpy - INFO - Chain [1] done processing
# 04:09:07 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:09:15 - cmdstanpy - INFO - Chain [1] start processing
# 04:09:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points=======>     (106 + 13) / 119]
# Processing group: Rieti with 29862 data points
# 04:10:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:10:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:10:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:10:31 - cmdstanpy - INFO - Chain [1] done processing
# 04:10:33 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:10:39 - cmdstanpy - INFO - Chain [1] start processing
# 04:10:47 - cmdstanpy - INFO - Chain [1] done processing
# 04:10:54 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:11:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:11:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===============>  (113 + 6) / 119]
# Processing group: Frosinone with 29862 data points
# 04:11:53 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:11:53 - cmdstanpy - INFO - Chain [1] start processing
# 04:12:07 - cmdstanpy - INFO - Chain [1] done processing
# 04:12:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:12:16 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:12:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:12:26 - cmdstanpy - INFO - Chain [1] done processing
# 04:12:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:12:42 - cmdstanpy - INFO - Chain [1] start processing
# 04:12:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points=====>       (101 + 18) / 119]
# Processing group: Rieti with 29862 data points
# 04:13:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:13:36 - cmdstanpy - INFO - Chain [1] start processing
# 04:13:47 - cmdstanpy - INFO - Chain [1] done processing
# 04:13:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:13:55 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:14:00 - cmdstanpy - INFO - Chain [1] start processing
# 04:14:09 - cmdstanpy - INFO - Chain [1] done processing
# 04:14:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 04:14:23 - cmdstanpy - INFO - Chain [1] start processing
# 04:14:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 04:15:17 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:15:17 - cmdstanpy - INFO - Chain [1] start processing
# 04:15:32 - cmdstanpy - INFO - Chain [1] done processing
# 04:15:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:15:40 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:15:46 - cmdstanpy - INFO - Chain [1] start processing
# 04:15:52 - cmdstanpy - INFO - Chain [1] done processing
# 04:15:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 04:16:06 - cmdstanpy - INFO - Chain [1] start processing
# 04:16:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 04:16:55 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:16:55 - cmdstanpy - INFO - Chain [1] start processing
# 04:17:10 - cmdstanpy - INFO - Chain [1] done processing
# 04:17:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:17:18 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:17:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:17:32 - cmdstanpy - INFO - Chain [1] done processing
# 04:17:40 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:17:48 - cmdstanpy - INFO - Chain [1] start processing
# 04:18:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==============>   (112 + 7) / 119]
# Processing group: Frosinone with 29862 data points
# 04:18:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:18:42 - cmdstanpy - INFO - Chain [1] start processing
# 04:18:54 - cmdstanpy - INFO - Chain [1] done processing
# 04:19:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:19:02 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:19:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:19:15 - cmdstanpy - INFO - Chain [1] done processing
# 04:19:23 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:19:31 - cmdstanpy - INFO - Chain [1] start processing
# 04:19:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 04:20:22 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:20:22 - cmdstanpy - INFO - Chain [1] start processing
# 04:20:36 - cmdstanpy - INFO - Chain [1] done processing
# 04:20:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:20:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:20:50 - cmdstanpy - INFO - Chain [1] start processing
# 04:20:57 - cmdstanpy - INFO - Chain [1] done processing
# 04:21:06 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:21:14 - cmdstanpy - INFO - Chain [1] start processing
# 04:21:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (105 + 14) / 119]
# Processing group: Frosinone with 29862 data points
# 04:22:07 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:22:07 - cmdstanpy - INFO - Chain [1] start processing
# 04:22:20 - cmdstanpy - INFO - Chain [1] done processing
# 04:22:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:22:28 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:22:34 - cmdstanpy - INFO - Chain [1] start processing
# 04:22:42 - cmdstanpy - INFO - Chain [1] done processing
# 04:22:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 04:22:57 - cmdstanpy - INFO - Chain [1] start processing
# 04:23:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 04:23:51 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:23:51 - cmdstanpy - INFO - Chain [1] start processing
# 04:24:06 - cmdstanpy - INFO - Chain [1] done processing
# 04:24:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:24:14 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:24:18 - cmdstanpy - INFO - Chain [1] start processing
# 04:24:25 - cmdstanpy - INFO - Chain [1] done processing
# 04:24:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 04:24:39 - cmdstanpy - INFO - Chain [1] start processing
# 04:24:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 04:25:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:25:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:25:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:25:47 - cmdstanpy - INFO - Chain [1] done processing
# 04:25:47 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:25:55 - cmdstanpy - INFO - Chain [1] start processing
# 04:25:59 - cmdstanpy - INFO - Chain [1] done processing
# 04:26:08 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:26:16 - cmdstanpy - INFO - Chain [1] start processing
# 04:26:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points========>         (98 + 21) / 119]
# Processing group: Frosinone with 29862 data points
# 04:27:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:27:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:27:22 - cmdstanpy - INFO - Chain [1] done processing
# 04:27:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:27:30 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:27:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:27:43 - cmdstanpy - INFO - Chain [1] done processing
# 04:27:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:27:58 - cmdstanpy - INFO - Chain [1] start processing
# 04:28:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 04:28:53 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:28:53 - cmdstanpy - INFO - Chain [1] start processing
# 04:29:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:29:14 - cmdstanpy - INFO - Chain [1] done processing
# 04:29:15 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:29:22 - cmdstanpy - INFO - Chain [1] start processing
# 04:29:29 - cmdstanpy - INFO - Chain [1] done processing
# 04:29:36 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:29:44 - cmdstanpy - INFO - Chain [1] start processing
# 04:29:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==============>   (110 + 9) / 119]
# Processing group: Frosinone with 29862 data points
# 04:30:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:30:36 - cmdstanpy - INFO - Chain [1] start processing
# 04:30:50 - cmdstanpy - INFO - Chain [1] done processing
# 04:30:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:30:59 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:31:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:31:12 - cmdstanpy - INFO - Chain [1] done processing
# 04:31:20 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:31:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:31:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 04:32:20 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:32:20 - cmdstanpy - INFO - Chain [1] start processing
# 04:32:30 - cmdstanpy - INFO - Chain [1] done processing
# 04:32:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:32:38 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:32:43 - cmdstanpy - INFO - Chain [1] start processing
# 04:32:51 - cmdstanpy - INFO - Chain [1] done processing
# 04:32:59 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:33:07 - cmdstanpy - INFO - Chain [1] start processing
# 04:33:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==============>   (111 + 8) / 119]
# Processing group: Frosinone with 29862 data points
# 04:33:57 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:33:57 - cmdstanpy - INFO - Chain [1] start processing
# 04:34:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:34:18 - cmdstanpy - INFO - Chain [1] done processing
# 04:34:19 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:34:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:34:30 - cmdstanpy - INFO - Chain [1] done processing
# 04:34:42 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:34:50 - cmdstanpy - INFO - Chain [1] start processing
# 04:35:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 04:35:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:35:42 - cmdstanpy - INFO - Chain [1] start processing
# 04:35:56 - cmdstanpy - INFO - Chain [1] done processing
# 04:36:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:36:04 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:36:09 - cmdstanpy - INFO - Chain [1] start processing
# 04:36:16 - cmdstanpy - INFO - Chain [1] done processing
# 04:36:24 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:36:32 - cmdstanpy - INFO - Chain [1] start processing
# 04:36:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 04:37:24 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:37:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:37:36 - cmdstanpy - INFO - Chain [1] done processing
# 04:37:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:37:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:37:49 - cmdstanpy - INFO - Chain [1] start processing
# 04:37:56 - cmdstanpy - INFO - Chain [1] done processing
# 04:38:02 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:38:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:38:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==============>   (110 + 9) / 119]
# Processing group: Frosinone with 29862 data points
# 04:39:02 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:39:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:39:15 - cmdstanpy - INFO - Chain [1] done processing
# 04:39:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:39:23 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:39:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:39:37 - cmdstanpy - INFO - Chain [1] done processing
# 04:39:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 04:39:48 - cmdstanpy - INFO - Chain [1] start processing
# 04:40:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 04:40:38 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:40:38 - cmdstanpy - INFO - Chain [1] start processing
# 04:40:50 - cmdstanpy - INFO - Chain [1] done processing
# 04:40:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:40:58 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:41:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:41:10 - cmdstanpy - INFO - Chain [1] done processing
# 04:41:18 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 04:41:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 04:42:21 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:42:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:42:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:42:39 - cmdstanpy - INFO - Chain [1] done processing
# 04:42:40 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:42:47 - cmdstanpy - INFO - Chain [1] start processing
# 04:42:53 - cmdstanpy - INFO - Chain [1] done processing
# 04:43:02 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:43:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:43:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points=====>        (99 + 20) / 119]
# Processing group: Rieti with 29862 data points
# 04:44:02 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:44:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:13 - cmdstanpy - INFO - Chain [1] done processing
# 04:44:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:44:21 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:44:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:31 - cmdstanpy - INFO - Chain [1] done processing
# 04:44:39 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:44:47 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points========>         (98 + 21) / 119]
# Processing group: Frosinone with 29862 data points
# 04:45:40 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:45:40 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:54 - cmdstanpy - INFO - Chain [1] done processing
# 04:46:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:46:02 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:46:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:14 - cmdstanpy - INFO - Chain [1] done processing
# 04:46:21 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:46:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 04:47:19 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:47:19 - cmdstanpy - INFO - Chain [1] start processing
# 04:47:34 - cmdstanpy - INFO - Chain [1] done processing
# 04:47:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:47:42 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:47:47 - cmdstanpy - INFO - Chain [1] start processing
# 04:47:56 - cmdstanpy - INFO - Chain [1] done processing
# 04:48:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 04:48:09 - cmdstanpy - INFO - Chain [1] start processing
# 04:48:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 04:49:01 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:49:01 - cmdstanpy - INFO - Chain [1] start processing
# 04:49:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:49:20 - cmdstanpy - INFO - Chain [1] done processing
# 04:49:20 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:49:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:49:32 - cmdstanpy - INFO - Chain [1] done processing
# 04:49:41 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 04:50:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 04:50:40 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:50:40 - cmdstanpy - INFO - Chain [1] start processing
# 04:50:51 - cmdstanpy - INFO - Chain [1] done processing
# 04:50:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:50:59 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:51:03 - cmdstanpy - INFO - Chain [1] start processing
# 04:51:13 - cmdstanpy - INFO - Chain [1] done processing
# 04:51:19 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:51:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:51:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 04:52:17 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:52:17 - cmdstanpy - INFO - Chain [1] start processing
# 04:52:29 - cmdstanpy - INFO - Chain [1] done processing
# 04:52:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:52:37 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:52:42 - cmdstanpy - INFO - Chain [1] start processing
# 04:52:50 - cmdstanpy - INFO - Chain [1] done processing
# 04:52:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 04:53:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:53:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 04:53:58 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:53:58 - cmdstanpy - INFO - Chain [1] start processing
# 04:54:12 - cmdstanpy - INFO - Chain [1] done processing
# 04:54:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:54:20 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:54:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:54:31 - cmdstanpy - INFO - Chain [1] done processing
# 04:54:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 04:54:44 - cmdstanpy - INFO - Chain [1] start processing
# 04:54:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 04:55:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:55:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:47 - cmdstanpy - INFO - Chain [1] done processing
# 04:55:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:55:55 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:55:59 - cmdstanpy - INFO - Chain [1] start processing
# 04:56:09 - cmdstanpy - INFO - Chain [1] done processing
# 04:56:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 04:56:22 - cmdstanpy - INFO - Chain [1] start processing
# 04:56:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points======>      (103 + 16) / 119]
# Processing group: Rieti with 29862 data points
# 04:57:21 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:57:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:57:36 - cmdstanpy - INFO - Chain [1] done processing
# 04:57:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:57:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:57:49 - cmdstanpy - INFO - Chain [1] start processing
# 04:57:57 - cmdstanpy - INFO - Chain [1] done processing
# 04:58:05 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:58:12 - cmdstanpy - INFO - Chain [1] start processing
# 04:58:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 04:59:02 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 04:59:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:59:13 - cmdstanpy - INFO - Chain [1] done processing
# 04:59:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 04:59:21 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 04:59:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:59:35 - cmdstanpy - INFO - Chain [1] done processing
# 04:59:42 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 04:59:50 - cmdstanpy - INFO - Chain [1] start processing
# 05:00:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>        (99 + 20) / 119]
# Processing group: Frosinone with 29862 data points
# 05:00:40 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:00:40 - cmdstanpy - INFO - Chain [1] start processing
# 05:00:51 - cmdstanpy - INFO - Chain [1] done processing
# 05:00:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:00:59 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:01:04 - cmdstanpy - INFO - Chain [1] start processing
# 05:01:12 - cmdstanpy - INFO - Chain [1] done processing
# 05:01:18 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:01:26 - cmdstanpy - INFO - Chain [1] start processing
# 05:01:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==============>   (112 + 7) / 119]
# Processing group: Frosinone with 29862 data points
# 05:02:21 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:02:21 - cmdstanpy - INFO - Chain [1] start processing
# 05:02:32 - cmdstanpy - INFO - Chain [1] done processing
# 05:02:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:02:40 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:02:45 - cmdstanpy - INFO - Chain [1] start processing
# 05:02:53 - cmdstanpy - INFO - Chain [1] done processing
# 05:02:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 05:03:06 - cmdstanpy - INFO - Chain [1] start processing
# 05:03:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==============>   (112 + 7) / 119]
# Processing group: Frosinone with 29862 data points
# 05:03:58 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:03:58 - cmdstanpy - INFO - Chain [1] start processing
# 05:04:12 - cmdstanpy - INFO - Chain [1] done processing
# 05:04:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:04:20 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:04:25 - cmdstanpy - INFO - Chain [1] start processing
# 05:04:32 - cmdstanpy - INFO - Chain [1] done processing
# 05:04:41 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:04:48 - cmdstanpy - INFO - Chain [1] start processing
# 05:05:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points========>        (100 + 19) / 119]
# Processing group: Frosinone with 29862 data points
# 05:05:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:05:42 - cmdstanpy - INFO - Chain [1] start processing
# 05:05:54 - cmdstanpy - INFO - Chain [1] done processing
# 05:05:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:06:02 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:06:07 - cmdstanpy - INFO - Chain [1] start processing
# 05:06:14 - cmdstanpy - INFO - Chain [1] done processing
# 05:06:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 05:06:28 - cmdstanpy - INFO - Chain [1] start processing
# 05:06:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points================> (115 + 4) / 119]
# Processing group: Frosinone with 29862 data points
# 05:07:20 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:07:20 - cmdstanpy - INFO - Chain [1] start processing
# 05:07:33 - cmdstanpy - INFO - Chain [1] done processing
# 05:07:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:07:41 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:07:47 - cmdstanpy - INFO - Chain [1] start processing
# 05:07:55 - cmdstanpy - INFO - Chain [1] done processing
# 05:08:03 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:08:11 - cmdstanpy - INFO - Chain [1] start processing
# 05:08:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points====>        (100 + 19) / 119]
# Processing group: Rieti with 29862 data points
# 05:09:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:09:03 - cmdstanpy - INFO - Chain [1] start processing
# 05:09:17 - cmdstanpy - INFO - Chain [1] done processing
# 05:09:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:09:25 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:09:31 - cmdstanpy - INFO - Chain [1] start processing
# 05:09:40 - cmdstanpy - INFO - Chain [1] done processing
# 05:09:47 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:09:55 - cmdstanpy - INFO - Chain [1] start processing
# 05:10:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 05:10:46 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:10:46 - cmdstanpy - INFO - Chain [1] start processing
# 05:11:01 - cmdstanpy - INFO - Chain [1] done processing
# 05:11:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:11:09 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:11:15 - cmdstanpy - INFO - Chain [1] start processing
# 05:11:22 - cmdstanpy - INFO - Chain [1] done processing
# 05:11:29 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:11:36 - cmdstanpy - INFO - Chain [1] start processing
# 05:11:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points=====>       (102 + 17) / 119]
# Processing group: Rieti with 29862 data points
# 05:12:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:12:29 - cmdstanpy - INFO - Chain [1] start processing
# 05:12:44 - cmdstanpy - INFO - Chain [1] done processing
# 05:12:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:12:52 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:12:57 - cmdstanpy - INFO - Chain [1] start processing
# 05:13:03 - cmdstanpy - INFO - Chain [1] done processing
# 05:13:11 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:13:19 - cmdstanpy - INFO - Chain [1] start processing
# 05:13:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 05:14:09 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:14:09 - cmdstanpy - INFO - Chain [1] start processing
# 05:14:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:14:30 - cmdstanpy - INFO - Chain [1] done processing
# 05:14:31 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:14:38 - cmdstanpy - INFO - Chain [1] start processing
# 05:14:42 - cmdstanpy - INFO - Chain [1] done processing
# 05:14:52 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:14:59 - cmdstanpy - INFO - Chain [1] start processing
# 05:15:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (105 + 14) / 119]
# Processing group: Frosinone with 29862 data points
# 05:15:51 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:15:51 - cmdstanpy - INFO - Chain [1] start processing
# 05:16:06 - cmdstanpy - INFO - Chain [1] done processing
# 05:16:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:16:14 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:16:18 - cmdstanpy - INFO - Chain [1] start processing
# 05:16:28 - cmdstanpy - INFO - Chain [1] done processing
# 05:16:37 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:16:45 - cmdstanpy - INFO - Chain [1] start processing
# 05:17:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 05:17:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:17:39 - cmdstanpy - INFO - Chain [1] start processing
# 05:17:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:17:58 - cmdstanpy - INFO - Chain [1] done processing
# 05:18:00 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:18:06 - cmdstanpy - INFO - Chain [1] start processing
# 05:18:12 - cmdstanpy - INFO - Chain [1] done processing
# 05:18:21 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:18:29 - cmdstanpy - INFO - Chain [1] start processing
# 05:18:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 05:19:19 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:19:19 - cmdstanpy - INFO - Chain [1] start processing
# 05:19:30 - cmdstanpy - INFO - Chain [1] done processing
# 05:19:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:19:38 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:19:44 - cmdstanpy - INFO - Chain [1] start processing
# 05:19:52 - cmdstanpy - INFO - Chain [1] done processing
# 05:19:58 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:20:06 - cmdstanpy - INFO - Chain [1] start processing
# 05:20:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (109 + 10) / 119]
# Processing group: Frosinone with 29862 data points
# 05:21:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 05:21:00 - cmdstanpy - INFO - Chain [1] start processing
# 05:21:11 - cmdstanpy - INFO - Chain [1] done processing
# 05:21:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 05:21:19 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 05:21:25 - cmdstanpy - INFO - Chain [1] start processing
# 05:21:30 - cmdstanpy - INFO - Chain [1] done processing
# 05:21:38 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 05:21:46 - cmdstanpy - INFO - Chain [1] start processing
# ...
# 07:06:44 - cmdstanpy - INFO - Chain [1] start processing
# 07:06:58 - cmdstanpy - INFO - Chain [1] done processing
# 07:07:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:07:06 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:07:10 - cmdstanpy - INFO - Chain [1] start processing
# 07:07:18 - cmdstanpy - INFO - Chain [1] done processing
# 07:07:26 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:07:34 - cmdstanpy - INFO - Chain [1] start processing
# 07:07:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===============>  (114 + 5) / 119]
# Processing group: Frosinone with 29862 data points
# 07:08:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:08:26 - cmdstanpy - INFO - Chain [1] start processing
# 07:08:38 - cmdstanpy - INFO - Chain [1] done processing
# 07:08:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:08:46 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:08:51 - cmdstanpy - INFO - Chain [1] start processing
# 07:08:57 - cmdstanpy - INFO - Chain [1] done processing
# 07:09:05 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:09:13 - cmdstanpy - INFO - Chain [1] start processing
# 07:09:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 07:10:06 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:10:06 - cmdstanpy - INFO - Chain [1] start processing
# 07:10:22 - cmdstanpy - INFO - Chain [1] done processing
# 07:10:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:10:30 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:10:35 - cmdstanpy - INFO - Chain [1] start processing
# 07:10:41 - cmdstanpy - INFO - Chain [1] done processing
# 07:10:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:10:58 - cmdstanpy - INFO - Chain [1] start processing
# 07:11:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 07:11:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:11:49 - cmdstanpy - INFO - Chain [1] start processing
# 07:12:04 - cmdstanpy - INFO - Chain [1] done processing
# 07:12:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:12:12 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:12:18 - cmdstanpy - INFO - Chain [1] start processing
# 07:12:25 - cmdstanpy - INFO - Chain [1] done processing
# 07:12:34 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:12:42 - cmdstanpy - INFO - Chain [1] start processing
# 07:12:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 07:13:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:13:34 - cmdstanpy - INFO - Chain [1] start processing
# 07:13:49 - cmdstanpy - INFO - Chain [1] done processing
# 07:13:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:13:57 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:14:02 - cmdstanpy - INFO - Chain [1] start processing
# 07:14:09 - cmdstanpy - INFO - Chain [1] done processing
# 07:14:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:14:23 - cmdstanpy - INFO - Chain [1] start processing
# 07:14:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points============>    (109 + 10) / 119]
# Processing group: Frosinone with 29862 data points
# 07:15:15 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:15:15 - cmdstanpy - INFO - Chain [1] start processing
# 07:15:25 - cmdstanpy - INFO - Chain [1] done processing
# 07:15:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:15:33 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:15:39 - cmdstanpy - INFO - Chain [1] start processing
# 07:15:45 - cmdstanpy - INFO - Chain [1] done processing
# 07:15:52 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:16:00 - cmdstanpy - INFO - Chain [1] start processing
# 07:16:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points======>              (8 + 3) / 11]
# Processing group: Frosinone with 29862 data points
# 07:16:52 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:16:52 - cmdstanpy - INFO - Chain [1] start processing
# 07:17:05 - cmdstanpy - INFO - Chain [1] done processing
# 07:17:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:17:13 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:17:17 - cmdstanpy - INFO - Chain [1] start processing
# 07:17:26 - cmdstanpy - INFO - Chain [1] done processing
# 07:17:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 07:17:38 - cmdstanpy - INFO - Chain [1] start processing
# 07:17:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points======>              (8 + 3) / 11]
# Processing group: Frosinone with 29862 data points
# 07:18:32 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:18:32 - cmdstanpy - INFO - Chain [1] start processing
# 07:18:43 - cmdstanpy - INFO - Chain [1] done processing
# 07:18:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:18:51 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:18:57 - cmdstanpy - INFO - Chain [1] start processing
# 07:19:02 - cmdstanpy - INFO - Chain [1] done processing
# 07:19:10 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:19:18 - cmdstanpy - INFO - Chain [1] start processing
# 07:19:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 07:20:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:20:12 - cmdstanpy - INFO - Chain [1] start processing
# 07:20:25 - cmdstanpy - INFO - Chain [1] done processing
# 07:20:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:20:33 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:20:39 - cmdstanpy - INFO - Chain [1] start processing
# 07:20:46 - cmdstanpy - INFO - Chain [1] done processing
# 07:20:53 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:21:01 - cmdstanpy - INFO - Chain [1] start processing
# 07:21:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 07:21:51 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:21:51 - cmdstanpy - INFO - Chain [1] start processing
# 07:22:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:22:13 - cmdstanpy - INFO - Chain [1] done processing
# 07:22:14 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:22:21 - cmdstanpy - INFO - Chain [1] start processing
# 07:22:26 - cmdstanpy - INFO - Chain [1] done processing
# 07:22:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:22:43 - cmdstanpy - INFO - Chain [1] start processing
# 07:22:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points========>        (100 + 19) / 119]
# Processing group: Frosinone with 29862 data points
# 07:23:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:23:35 - cmdstanpy - INFO - Chain [1] start processing
# 07:23:46 - cmdstanpy - INFO - Chain [1] done processing
# 07:23:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:23:54 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:23:59 - cmdstanpy - INFO - Chain [1] start processing
# 07:24:05 - cmdstanpy - INFO - Chain [1] done processing
# 07:24:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 07:24:20 - cmdstanpy - INFO - Chain [1] start processing
# 07:24:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (105 + 14) / 119]
# Processing group: Frosinone with 29862 data points
# 07:25:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:25:11 - cmdstanpy - INFO - Chain [1] start processing
# 07:25:21 - cmdstanpy - INFO - Chain [1] done processing
# 07:25:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:25:29 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:25:35 - cmdstanpy - INFO - Chain [1] start processing
# 07:25:42 - cmdstanpy - INFO - Chain [1] done processing
# 07:25:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:25:57 - cmdstanpy - INFO - Chain [1] start processing
# 07:26:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 07:26:48 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:26:48 - cmdstanpy - INFO - Chain [1] start processing
# 07:27:00 - cmdstanpy - INFO - Chain [1] done processing
# 07:27:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:27:07 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:27:13 - cmdstanpy - INFO - Chain [1] start processing
# 07:27:20 - cmdstanpy - INFO - Chain [1] done processing
# 07:27:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points                       (1 + 1) / 2]
# 07:27:33 - cmdstanpy - INFO - Chain [1] start processing
# 07:27:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 07:28:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:28:26 - cmdstanpy - INFO - Chain [1] start processing
# 07:28:41 - cmdstanpy - INFO - Chain [1] done processing
# 07:28:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:28:49 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Latina with 29862 data points
# 07:28:55 - cmdstanpy - INFO - Chain [1] start processing
# 07:29:01 - cmdstanpy - INFO - Chain [1] done processing
# 07:29:09 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:29:17 - cmdstanpy - INFO - Chain [1] start processing
# 07:29:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 07:30:08 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:30:08 - cmdstanpy - INFO - Chain [1] start processing
# 07:30:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# 07:30:28 - cmdstanpy - INFO - Chain [1] start processing
# 07:30:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 07:30:36 - cmdstanpy - INFO - Chain [1] start processing
# 07:30:41 - cmdstanpy - INFO - Chain [1] done processing
# 07:30:52 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Roma with 29862 data points
# 07:31:00 - cmdstanpy - INFO - Chain [1] start processing
# 07:31:15 - cmdstanpy - INFO - Chain [1] done processing
# +--------+---------+------------------+------------------+------------------+-----------------+
# |    Time|     NOME|               MSE|              RMSE|               MAE|         Coverage|
# +--------+---------+------------------+------------------+------------------+-----------------+
# |  5 Days|  Viterbo|26.844312457867375|5.1811497235524255| 3.594806387887776|96.00746268656717|
# |  5 Days|    Rieti| 20.38033065926595| 4.514457958522368| 3.031855682501042|96.40391791044776|
# |  5 Days|   Latina| 34.89463072468919| 5.907167741370579| 4.122590530941324| 96.0867537313433|
# |  5 Days|Frosinone| 34.76652994378737| 5.896314946115698|3.9815671910379296|96.04944029850746|
# |  5 Days|     Roma| 40.36191354227106|6.3531026705280835| 4.550351683195777| 95.4757462686567|
# | 30 Days|  Viterbo|26.486506043502285| 5.146504254686115| 3.571681776125837|96.00725952813067|
# | 30 Days|    Rieti|20.030732943802104| 4.475570683589089|3.0080590996988046|96.42468239564428|
# | 30 Days|   Latina| 34.33310547116971| 5.859445833111669| 4.085687997706507|96.12976406533575|
# | 30 Days|Frosinone|33.996903669561625| 5.830686380655508|3.9271376092503765|96.17059891107078|
# | 30 Days|     Roma|39.754182960522165|6.3050918280800765| 4.516221358325918|95.60344827586206|
# | 90 Days|  Viterbo| 25.47476855035446| 5.047253565094037|3.5014360408668126|96.31175468483816|
# | 90 Days|    Rieti|19.209666864531407| 4.382883396182405| 2.938070027134921|96.55451448040886|
# | 90 Days|   Latina| 33.20812984161532| 5.762649550477221| 4.014283210832389| 96.3160136286201|
# | 90 Days|Frosinone| 32.80303725510609|5.7273935830450915|3.8742351514774285|96.37989778534923|
# | 90 Days|     Roma|38.519610160571844| 6.206416853593693| 4.459618817817216|95.77086882453152|
# |180 Days|  Viterbo|24.271688490304268| 4.926630541283187|3.4220006505157525|96.54486604531452|
# |180 Days|    Rieti| 18.91075408251916| 4.348649684961892|2.9742060117562947|96.84124322427174|
# |180 Days|   Latina| 32.18136915265879| 5.672862518399224| 3.981350049586619|96.59166244199197|
# |180 Days|Frosinone| 35.72952717739201|  5.97741810294311| 4.165230220643555|96.62286003977694|
# |180 Days|     Roma|37.078858930009154|6.0892412441953025| 4.393615108080099|96.08860117770932|
# |365 Days|  Viterbo|  36.4500033022641|  6.03738381273413| 4.078447906746063|97.00013392259275|
# |365 Days|    Rieti| 23.69100677132566| 4.867340831637503|3.1889142430171873|97.23449845989019|
# |365 Days|   Latina|  40.8396873058619|6.3905936583279885| 4.374905542398387|96.95660907995179|
# |365 Days|Frosinone|40.885865194485106|6.3942055952624095| 4.444598034469279|97.07379134860051|
# |365 Days|     Roma| 42.31326172784455| 6.504864466523845| 4.623973814691109|96.58832194991295|
# +--------+---------+------------------+------------------+------------------+-----------------+

# %%
result_df_PM10_pd = result_df_PM10.pandas_api()
result_df_PM10_pd

# %% [markdown]
# NO2

# %%
from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_NO2_prophet = data_NO2.groupBy("NOME", "original_date_time").agg(avg("c_NO2").alias("avg_c_NO2"))
data_NO2_prophet.show()

data_NO2_prophet_u = data_NO2_prophet.withColumnRenamed("avg_c_NO2", "y").withColumnRenamed("original_date_time", "ds")

data_NO2_prophet = data_NO2_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

data_NO2_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    m.fit(group[group['ds'] <= cutoff_date])
    
    forecast = m.predict(group)
    
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/NO2/'

    if not os.path.exists(path):
        os.makedirs(path)
    
    try:
        fig1 = m.plot(forecast)
        fig1.suptitle(f"NO2 Concentration Forecast for {group['NOME'].iloc[0]}")
        fig1.legend(['Actual', 'Forecasted'], loc='upper right')
        fig1.subplots_adjust(top=0.9)
        
        fig2 = m.plot_components(forecast)
        fig2.suptitle(f"NO2 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        fig2.subplots_adjust(top=0.9)

        fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/NO2/{group['NOME'].iloc[0]}_prophet_forecast.png")
        fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/NO2/{group['NOME'].iloc[0]}_prophet_components.png")
    except Exception as e:
        print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_NO2_prophet_train = data_NO2_prophet.filter(col('ds') <= cutoff_date)
data_NO2_prophet_test = data_NO2_prophet.filter((col('ds') > cutoff_date))

max_date = data_NO2_prophet_test.agg(max('ds')).collect()[0][0]

period = data_NO2_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_NO2 = data_NO2_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

spark_forecast_NO2.show()
# Out:
# +-------+-------------------+------------------+
# |   NOME| original_date_time|         avg_c_NO2|
# +-------+-------------------+------------------+
# |Viterbo|2022-02-02 01:00:00| 1.714137597787611|
# |  Rieti|2021-11-01 05:00:00|0.9745878651445088|
# |   Roma|2021-12-12 02:00:00|1.6926365163798216|
# |  Rieti|2021-12-19 15:00:00| 2.121068303236994|
# |  Rieti|2021-05-20 22:00:00|0.7832120415606936|
# |  Rieti|2021-10-08 15:00:00|0.8941777683815028|
# |   Roma|2021-05-22 11:00:00|1.8448723416023736|
# | Latina|2021-06-10 21:00:00|3.7493962421428577|
# | Latina|2021-12-13 00:00:00|4.7179716296428555|
# |   Roma|2021-10-11 14:00:00|3.7846130554896145|
# |Viterbo|2021-06-27 07:00:00|1.2218618397345131|
# |   Roma|2021-10-11 19:00:00| 8.132516511928783|
# |Viterbo|2021-10-08 00:00:00|1.8678180108407085|
# |  Rieti|2021-10-08 07:00:00|2.0554645594797685|
# |Viterbo|2021-12-07 13:00:00| 2.421045396017698|
# | Latina|2021-05-21 09:00:00| 4.027409731500001|
# |Viterbo|2021-11-29 20:00:00|3.6873097438053106|
# |  Rieti|2021-03-09 07:00:00| 1.130898831734104|
# |  Rieti|2021-11-29 03:00:00| 2.323777139884393|
# | Latina|2021-05-22 04:00:00|1.3272664624285717|
# +-------+-------------------+------------------+
# only showing top 20 rows
#
# root
#  |-- NOME: string (nullable = true)
#  |-- ds: timestamp (nullable = true)
#  |-- y: double (nullable = true)
# The time used for the Spark forecast is  0.03974723815917969
# Processing group: Rieti with 29862 data points                      (0 + 1) / 1]
# 14:41:41 - cmdstanpy - INFO - Chain [1] start processing
# 14:41:53 - cmdstanpy - INFO - Chain [1] done processing
# +-------------------+-----+------------------+---------+----------+-----------+---------+---------+----------+------------+
# |                 ds| NOME|                 y|     yhat|yhat_upper| yhat_lower|    trend|   yearly|    weekly|       daily|
# +-------------------+-----+------------------+---------+----------+-----------+---------+---------+----------+------------+
# |2019-01-01 01:00:00|Rieti| 9.358907479190748| 8.854709| 13.425096|   4.283503| 3.740851|2.0150287| 0.6757538|   2.4230754|
# |2019-01-01 02:00:00|Rieti| 7.972921513294797|8.0530815| 12.637769|  3.6594803|3.7411084|2.0153096| 0.6948589|    1.601805|
# |2019-01-01 03:00:00|Rieti| 5.749612904335258| 7.221477|  11.67015|  2.7575915|3.7413657|2.0155883| 0.7088098|  0.75571316|
# |2019-01-01 04:00:00|Rieti| 4.340772004624278|6.4760404| 10.814097|  2.0253658|3.7416232|2.0158653| 0.7178291|7.2275667E-4|
# |2019-01-01 05:00:00|Rieti|3.7630883457225437|5.8987403| 10.375546|    1.06187|3.7418804|2.0161407|0.72217727|  -0.5814582|
# |2019-01-01 06:00:00|Rieti| 3.408236447976879|5.5370936|  9.941378|  1.3388255| 3.742138| 2.016414| 0.7221485| -0.94360656|
# |2019-01-01 07:00:00|Rieti|3.2078778176300577|5.3801994| 9.5862875| 0.95248824|3.7423952|2.0166852|0.71806663|  -1.0969474|
# |2019-01-01 08:00:00|Rieti| 3.518257806416185|5.3439364|  9.805671| 0.86388534|3.7426524|2.0169547| 0.7102808|  -1.1259516|
# |2019-01-01 09:00:00|Rieti| 4.498938608381502| 5.303554|  9.705373|  0.6334703|  3.74291|2.0172222|0.69916064|  -1.1557388|
# |2019-01-01 10:00:00|Rieti| 3.507382879710982|5.1670213|  9.493453|  0.4906523|3.7431672|2.0174878| 0.6850917|  -1.2787253|
# |2019-01-01 11:00:00|Rieti|2.7552188395953747| 4.934036| 9.5713625| 0.46572486|3.7434247|2.0177512| 0.6684707|  -1.4956108|
# |2019-01-01 12:00:00|Rieti|2.1689212121965307|4.6881914|  9.487126| 0.26828083| 3.743682|2.0180125|0.64970064|  -1.7232039|
# |2019-01-01 13:00:00|Rieti|1.8443023753179189| 4.527395|  9.328351|-0.01731816|3.7439394| 2.018272| 0.6291861|  -1.8640023|
# |2019-01-01 14:00:00|Rieti|1.7580325897687858|4.4957905|   8.99933|0.069007024|3.7441967|2.0185292|0.60732865|  -1.8742641|
# |2019-01-01 15:00:00|Rieti|1.8968891501156075| 4.579704|  9.373777| 0.15266988| 3.744454|2.0187845|0.58452237|  -1.7680571|
# |2019-01-01 16:00:00|Rieti|2.3079590089595374|4.7670355|  9.300341| 0.33735165|3.7447114|2.0190375|0.56114966|  -1.5578631|
# |2019-01-01 17:00:00|Rieti|3.9320696383236995|5.1037793|  9.575514|  0.2415759|3.7449687|2.0192883|0.53757703|  -1.1980548|
# |2019-01-01 18:00:00|Rieti| 6.243787227745665|5.6788125|  10.03444|  1.4190056|3.7452261|2.0195372| 0.5141519|  -0.6001025|
# |2019-01-01 19:00:00|Rieti| 7.514812809826588| 6.535312|10.7552595|  1.7542869|3.7454834|2.0197837|0.49119848|  0.27884644|
# |2019-01-01 20:00:00|Rieti| 7.912730490751444|7.5822635| 12.102674|  3.3624976|3.7457407|2.0200279|0.46901578|    1.347479|
# +-------------------+-----+------------------+---------+----------+-----------+---------+---------+----------+------------+
# only showing top 20 rows
# Processing group: Viterbo with 29862 data points

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import pow, sqrt
from prophet.diagnostics import performance_metrics


# Calculate MAE
mae_NO2 = spark_forecast_NO2.select(col("NOME"), abs(col("y") - col("yhat")).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MAE")

# Calculate MSE
mse_NO2 = spark_forecast_NO2.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MSE")

# Calculate RMSE
rmse_NO2 = spark_forecast_NO2.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                     .groupBy("NOME") \
                     .agg({"error": "mean"}) \
                     .withColumnRenamed("avg(error)", "MSE") \
                     .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE"))

# Show the results
mae_NO2.show()
mse_NO2.show()
rmse_NO2.show()
# Out:
# 14:42:05 - cmdstanpy - INFO - Chain [1] start processing         (0 + 96) / 119]
# 14:42:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 14:42:49 - cmdstanpy - INFO - Chain [1] start processing
# 14:42:49 - cmdstanpy - INFO - Chain [1] start processing
# 14:43:01 - cmdstanpy - INFO - Chain [1] done processing
# 14:43:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 14:43:11 - cmdstanpy - INFO - Chain [1] start processing
# 14:43:12 - cmdstanpy - INFO - Chain [1] start processing
# 14:43:21 - cmdstanpy - INFO - Chain [1] done processing
# 14:43:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 14:43:31 - cmdstanpy - INFO - Chain [1] start processing
# 14:43:37 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+
# |     NOME|               MAE|
# +---------+------------------+
# |  Viterbo| 2.108067556023767|
# |    Rieti|1.5675482441877882|
# |   Latina| 2.919243988286872|
# |Frosinone|3.2363979006302803|
# |     Roma| 6.282921837423628|
# +---------+------------------+
# Processing group: Rieti with 29862 data points==========>          (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 14:44:28 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:44:28 - cmdstanpy - INFO - Chain [1] start processing
# 14:44:41 - cmdstanpy - INFO - Chain [1] done processing
# 14:44:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# Processing group: Latina with 29862 data points
# 14:44:51 - cmdstanpy - INFO - Chain [1] start processing
# 14:44:51 - cmdstanpy - INFO - Chain [1] start processing
# 14:45:02 - cmdstanpy - INFO - Chain [1] done processing
# 14:45:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 14:45:11 - cmdstanpy - INFO - Chain [1] start processing
# 14:45:17 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+
# |     NOME|               MSE|
# +---------+------------------+
# |  Viterbo| 8.659769578120732|
# |    Rieti| 4.817593283788651|
# |   Latina|16.182939430452944|
# |Frosinone| 17.40985050604961|
# |     Roma| 65.03110489057981|
# +---------+------------------+
# Processing group: Rieti with 29862 data points==========>      (105 + 14) / 119]
# Processing group: Frosinone with 29862 data points
# 14:46:09 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:46:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:46:21 - cmdstanpy - INFO - Chain [1] done processing
# 14:46:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 14:46:30 - cmdstanpy - INFO - Chain [1] start processing
# 14:46:32 - cmdstanpy - INFO - Chain [1] start processing
# 14:46:41 - cmdstanpy - INFO - Chain [1] done processing
# 14:46:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 14:46:51 - cmdstanpy - INFO - Chain [1] start processing
# 14:46:57 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+------------------+
# |     NOME|               MSE|              RMSE|
# +---------+------------------+------------------+
# |  Viterbo| 8.659769578120732|2.9427486433810026|
# |    Rieti| 4.817593283788651| 2.194901656974328|
# |   Latina|16.182939430452944| 4.022802434926795|
# |Frosinone| 17.40985050604961| 4.172511294897787|
# |     Roma| 65.03110489057981| 8.064186560997943|
# +---------+------------------+------------------+

# %%
from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_NO2_prophet = data_NO2.groupBy("NOME", "original_date_time").agg(avg("c_NO2").alias("avg_c_NO2"))
#data_NO2_prophet.show()

data_NO2_prophet_u = data_NO2_prophet.withColumnRenamed("avg_c_NO2", "y").withColumnRenamed("original_date_time", "ds")

data_NO2_prophet = data_NO2_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

#data_NO2_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    m.fit(group[group['ds'] <= cutoff_date])
    
    forecast = m.predict(group)
    
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/NO2/'

    if not os.path.exists(path):
        os.makedirs(path)
    
    #try:
     #   fig1 = m.plot(forecast)
      #  fig1.suptitle(f"NO2 Concentration Forecast for {group['NOME'].iloc[0]}")
       # fig1.legend(['Actual', 'Forecasted'], loc='upper right')
        #fig1.subplots_adjust(top=0.9)
        
        #fig2 = m.plot_components(forecast)
        #fig2.suptitle(f"NO2 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        #fig2.subplots_adjust(top=0.9)

        #fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/NO2/{group['NOME'].iloc[0]}_prophet_forecast.png")
        #fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/NO2/{group['NOME'].iloc[0]}_prophet_components.png")
    #except Exception as e:
     #   print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])

# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_NO2_prophet_train = data_NO2_prophet.filter(col('ds') <= cutoff_date)
data_NO2_prophet_test = data_NO2_prophet.filter((col('ds') > cutoff_date))

max_date = data_NO2_prophet_test.agg(max('ds')).collect()[0][0]

period = data_NO2_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_NO2 = data_NO2_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

#spark_forecast_NO2.show()
# Out:
# [Stage 2646:============================================>      (104 + 15) / 119]
# The time used for the Spark forecast is  0.03573036193847656

# %%
from pyspark.sql.functions import col, pow, sqrt

# Define cutoff dates
cutoff_dates = {
    "5 Days": "2021-07-05 23:00:00",
    "30 Days": "2021-07-30 23:00:00",
    "90 Days": "2021-09-28 23:00:00",
    "180 Days": "2021-12-27 23:00:00",
    "365 Days": "2022-06-29 23:00:00"
}

# Define a list to store the evaluation results
results = []

# Compute evaluation metrics for each time period and NOME
for period, cutoff in cutoff_dates.items():
    for nome in spark_forecast_NO2.select("NOME").distinct().rdd.flatMap(lambda x: x).collect():
        # Filter the forecast data based on the cutoff date and NOME
        forecast_data_NO2 = spark_forecast_NO2.filter((col("ds") <= cutoff) & (col("NOME") == nome))

        # Calculate MAE
        mae = forecast_data_NO2.select(abs(col("y") - col("yhat")).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MAE") \
                             .collect()[0]["MAE"]

        # Calculate MSE
        mse = forecast_data_NO2.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MSE") \
                             .collect()[0]["MSE"]

        # Calculate RMSE
        rmse = forecast_data_NO2.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                              .agg({"error": "mean"}) \
                              .withColumnRenamed("avg(error)", "MSE") \
                              .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE")) \
                              .collect()[0]["RMSE"]

        # Calculate coverage
        coverage = forecast_data_NO2.filter((col("y") >= col("yhat_lower")) & (col("y") <= col("yhat_upper"))) \
                                  .count() / forecast_data_NO2.count() * 100

        # Add the results to the list
        results.append((period, nome, mse, rmse, mae, coverage))

# Create a Spark DataFrame from the results list
result_df_NO2 = spark.createDataFrame(results, ["Time", "NOME", "MSE", "RMSE", "MAE", "Coverage"])

# Show the results
result_df_NO2.show(100)
# Out:
# Processing group: Rieti with 29862 data points                      (0 + 2) / 2]
# Processing group: Frosinone with 29862 data points
# 07:33:34 - cmdstanpy - INFO - Chain [1] start processing
# 07:33:34 - cmdstanpy - INFO - Chain [1] start processing
# 07:33:46 - cmdstanpy - INFO - Chain [1] done processing
# 07:33:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:33:54 - cmdstanpy - INFO - Chain [1] start processing
# 07:33:55 - cmdstanpy - INFO - Chain [1] start processing
# 07:34:02 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 07:34:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:34:10 - cmdstanpy - INFO - Chain [1] start processing
# 07:34:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points============> (116 + 3) / 119]
# Processing group: Rieti with 29862 data points
# 07:34:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:34:36 - cmdstanpy - INFO - Chain [1] start processing
# 07:34:48 - cmdstanpy - INFO - Chain [1] done processing
# 07:34:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:34:56 - cmdstanpy - INFO - Chain [1] start processing
# 07:34:56 - cmdstanpy - INFO - Chain [1] start processing
# 07:35:06 - cmdstanpy - INFO - Chain [1] done processing
# 07:35:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:35:13 - cmdstanpy - INFO - Chain [1] start processing
# 07:35:20 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 07:35:57 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:35:57 - cmdstanpy - INFO - Chain [1] start processing
# 07:36:09 - cmdstanpy - INFO - Chain [1] done processing
# 07:36:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:36:17 - cmdstanpy - INFO - Chain [1] start processing
# 07:36:19 - cmdstanpy - INFO - Chain [1] start processing
# 07:36:28 - cmdstanpy - INFO - Chain [1] done processing
# 07:36:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:36:36 - cmdstanpy - INFO - Chain [1] start processing
# 07:36:42 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===============>  (113 + 6) / 119]
# Processing group: Frosinone with 29862 data points
# 07:37:22 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:37:22 - cmdstanpy - INFO - Chain [1] start processing
# 07:37:33 - cmdstanpy - INFO - Chain [1] done processing
# 07:37:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:37:41 - cmdstanpy - INFO - Chain [1] start processing
# 07:37:41 - cmdstanpy - INFO - Chain [1] start processing
# 07:37:50 - cmdstanpy - INFO - Chain [1] done processing
# 07:37:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:37:58 - cmdstanpy - INFO - Chain [1] start processing
# 07:38:04 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 07:38:40 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:38:40 - cmdstanpy - INFO - Chain [1] start processing
# 07:38:52 - cmdstanpy - INFO - Chain [1] done processing
# 07:38:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:39:00 - cmdstanpy - INFO - Chain [1] start processing
# 07:39:00 - cmdstanpy - INFO - Chain [1] start processing
# 07:39:07 - cmdstanpy - INFO - Chain [1] done processing
# 07:39:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:39:15 - cmdstanpy - INFO - Chain [1] start processing
# 07:39:21 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 07:39:57 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:39:57 - cmdstanpy - INFO - Chain [1] start processing
# 07:40:07 - cmdstanpy - INFO - Chain [1] done processing
# 07:40:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:40:15 - cmdstanpy - INFO - Chain [1] start processing
# 07:40:15 - cmdstanpy - INFO - Chain [1] start processing
# 07:40:22 - cmdstanpy - INFO - Chain [1] done processing
# 07:40:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:40:30 - cmdstanpy - INFO - Chain [1] start processing
# 07:40:36 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 07:41:15 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:41:15 - cmdstanpy - INFO - Chain [1] start processing
# 07:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 07:41:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:41:34 - cmdstanpy - INFO - Chain [1] start processing
# 07:41:35 - cmdstanpy - INFO - Chain [1] start processing
# 07:41:44 - cmdstanpy - INFO - Chain [1] done processing
# 07:41:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:41:52 - cmdstanpy - INFO - Chain [1] start processing
# 07:41:58 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points===========>  (114 + 5) / 119]
# Processing group: Rieti with 29862 data points
# 07:42:38 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:42:38 - cmdstanpy - INFO - Chain [1] start processing
# 07:42:50 - cmdstanpy - INFO - Chain [1] done processing
# 07:42:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:42:57 - cmdstanpy - INFO - Chain [1] start processing
# 07:42:59 - cmdstanpy - INFO - Chain [1] start processing
# 07:43:07 - cmdstanpy - INFO - Chain [1] done processing
# 07:43:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:43:15 - cmdstanpy - INFO - Chain [1] start processing
# 07:43:21 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 07:43:58 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:43:58 - cmdstanpy - INFO - Chain [1] start processing
# 07:44:07 - cmdstanpy - INFO - Chain [1] done processing
# 07:44:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:44:15 - cmdstanpy - INFO - Chain [1] start processing
# 07:44:16 - cmdstanpy - INFO - Chain [1] start processing
# 07:44:25 - cmdstanpy - INFO - Chain [1] done processing
# 07:44:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:44:33 - cmdstanpy - INFO - Chain [1] start processing
# 07:44:40 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 07:45:16 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:45:16 - cmdstanpy - INFO - Chain [1] start processing
# 07:45:27 - cmdstanpy - INFO - Chain [1] done processing
# 07:45:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# Processing group: Latina with 29862 data points
# 07:45:35 - cmdstanpy - INFO - Chain [1] start processing
# 07:45:35 - cmdstanpy - INFO - Chain [1] start processing
# 07:45:43 - cmdstanpy - INFO - Chain [1] done processing
# 07:45:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:45:51 - cmdstanpy - INFO - Chain [1] start processing
# 07:45:56 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (107 + 12) / 119]
# Processing group: Frosinone with 29862 data points
# 07:46:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:46:35 - cmdstanpy - INFO - Chain [1] start processing
# 07:46:47 - cmdstanpy - INFO - Chain [1] done processing
# 07:46:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# Processing group: Latina with 29862 data points
# 07:46:55 - cmdstanpy - INFO - Chain [1] start processing
# 07:46:55 - cmdstanpy - INFO - Chain [1] start processing
# 07:47:04 - cmdstanpy - INFO - Chain [1] done processing
# 07:47:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:47:12 - cmdstanpy - INFO - Chain [1] start processing
# 07:47:18 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 07:47:58 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:47:58 - cmdstanpy - INFO - Chain [1] start processing
# 07:48:10 - cmdstanpy - INFO - Chain [1] done processing
# 07:48:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:48:18 - cmdstanpy - INFO - Chain [1] start processing
# 07:48:19 - cmdstanpy - INFO - Chain [1] start processing
# 07:48:27 - cmdstanpy - INFO - Chain [1] done processing
# 07:48:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:48:35 - cmdstanpy - INFO - Chain [1] start processing
# 07:48:41 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (111 + 8) / 119]
# Processing group: Frosinone with 29862 data points
# 07:49:19 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:49:19 - cmdstanpy - INFO - Chain [1] start processing
# 07:49:28 - cmdstanpy - INFO - Chain [1] done processing
# 07:49:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:49:35 - cmdstanpy - INFO - Chain [1] start processing
# 07:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 07:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 07:49:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 07:49:59 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points======>      (103 + 16) / 119]
# Processing group: Rieti with 29862 data points
# 07:50:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:50:36 - cmdstanpy - INFO - Chain [1] start processing
# 07:50:44 - cmdstanpy - INFO - Chain [1] done processing
# 07:50:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:50:52 - cmdstanpy - INFO - Chain [1] start processing
# 07:50:53 - cmdstanpy - INFO - Chain [1] start processing
# 07:50:59 - cmdstanpy - INFO - Chain [1] done processing
# 07:51:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:51:07 - cmdstanpy - INFO - Chain [1] start processing
# 07:51:13 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points====>        (100 + 19) / 119]
# Processing group: Rieti with 29862 data points
# 07:51:52 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:51:52 - cmdstanpy - INFO - Chain [1] start processing
# 07:52:02 - cmdstanpy - INFO - Chain [1] done processing
# 07:52:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 07:52:10 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 07:52:13 - cmdstanpy - INFO - Chain [1] start processing
# 07:52:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:52:25 - cmdstanpy - INFO - Chain [1] start processing
# 07:52:26 - cmdstanpy - INFO - Chain [1] done processing
# 07:52:31 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 07:53:11 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:53:11 - cmdstanpy - INFO - Chain [1] start processing
# 07:53:21 - cmdstanpy - INFO - Chain [1] done processing
# 07:53:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:53:28 - cmdstanpy - INFO - Chain [1] start processing
# 07:53:29 - cmdstanpy - INFO - Chain [1] start processing
# 07:53:36 - cmdstanpy - INFO - Chain [1] done processing
# 07:53:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:53:44 - cmdstanpy - INFO - Chain [1] start processing
# 07:53:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 07:54:27 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:54:27 - cmdstanpy - INFO - Chain [1] start processing
# 07:54:37 - cmdstanpy - INFO - Chain [1] done processing
# 07:54:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:54:45 - cmdstanpy - INFO - Chain [1] start processing
# 07:54:45 - cmdstanpy - INFO - Chain [1] start processing
# 07:54:56 - cmdstanpy - INFO - Chain [1] done processing
# 07:54:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:55:04 - cmdstanpy - INFO - Chain [1] start processing
# 07:55:09 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 07:55:46 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:55:46 - cmdstanpy - INFO - Chain [1] start processing
# 07:55:56 - cmdstanpy - INFO - Chain [1] done processing
# 07:55:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 07:56:04 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 07:56:07 - cmdstanpy - INFO - Chain [1] start processing
# 07:56:12 - cmdstanpy - INFO - Chain [1] done processing
# 07:56:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:56:19 - cmdstanpy - INFO - Chain [1] start processing
# 07:56:26 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (111 + 8) / 119]
# Processing group: Frosinone with 29862 data points
# 07:57:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:57:04 - cmdstanpy - INFO - Chain [1] start processing
# 07:57:15 - cmdstanpy - INFO - Chain [1] done processing
# 07:57:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# Processing group: Latina with 29862 data points
# 07:57:22 - cmdstanpy - INFO - Chain [1] start processing
# 07:57:23 - cmdstanpy - INFO - Chain [1] start processing
# 07:57:31 - cmdstanpy - INFO - Chain [1] done processing
# 07:57:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:57:39 - cmdstanpy - INFO - Chain [1] start processing
# 07:57:45 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=================>(118 + 1) / 119]
# Processing group: Frosinone with 29862 data points
# 07:58:25 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:58:26 - cmdstanpy - INFO - Chain [1] start processing
# 07:58:34 - cmdstanpy - INFO - Chain [1] done processing
# 07:58:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:58:42 - cmdstanpy - INFO - Chain [1] start processing
# 07:58:43 - cmdstanpy - INFO - Chain [1] start processing
# 07:58:49 - cmdstanpy - INFO - Chain [1] done processing
# 07:58:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 07:58:57 - cmdstanpy - INFO - Chain [1] start processing
# 07:59:03 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points========>        (100 + 19) / 119]
# Processing group: Frosinone with 29862 data points
# 07:59:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 07:59:42 - cmdstanpy - INFO - Chain [1] start processing
# 07:59:50 - cmdstanpy - INFO - Chain [1] done processing
# 07:59:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 07:59:58 - cmdstanpy - INFO - Chain [1] start processing
# 07:59:59 - cmdstanpy - INFO - Chain [1] start processing
# 08:00:05 - cmdstanpy - INFO - Chain [1] done processing
# 08:00:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:00:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:00:19 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 08:00:56 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:00:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:01:08 - cmdstanpy - INFO - Chain [1] done processing
# 08:01:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:01:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:01:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:01:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:01:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:01:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:01:39 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===============>  (113 + 6) / 119]
# Processing group: Frosinone with 29862 data points
# 08:02:16 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:02:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:02:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:02:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 08:02:34 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 08:02:37 - cmdstanpy - INFO - Chain [1] start processing
# 08:02:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:02:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:02:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:02:59 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=================>(117 + 2) / 119]
# Processing group: Frosinone with 29862 data points
# 08:03:38 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:03:38 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:48 - cmdstanpy - INFO - Chain [1] done processing
# 08:03:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:03:58 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:04:11 - cmdstanpy - INFO - Chain [1] done processing
# 08:04:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:04:18 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 08:04:56 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:04:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:08 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:05:29 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:05:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:40 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points=====>       (101 + 18) / 119]
# Processing group: Rieti with 29862 data points
# 08:06:15 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:06:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:06:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:06:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:06:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:06:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:06:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:06:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:06:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:06:57 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 08:07:34 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:07:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:07:46 - cmdstanpy - INFO - Chain [1] done processing
# 08:07:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:08:01 - cmdstanpy - INFO - Chain [1] done processing
# 08:08:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:08:09 - cmdstanpy - INFO - Chain [1] start processing
# 08:08:15 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (105 + 14) / 119]
# Processing group: Frosinone with 29862 data points
# 08:08:54 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:08:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:09:07 - cmdstanpy - INFO - Chain [1] done processing
# 08:09:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:09:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:09:15 - cmdstanpy - INFO - Chain [1] start processing
# 08:09:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:09:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:09:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:09:37 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (110 + 9) / 119]
# Processing group: Frosinone with 29862 data points
# 08:10:16 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:10:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:10:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:10:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:10:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:10:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:10:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:10:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:10:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:10:57 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 08:11:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:11:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:11:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:11:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:11:52 - cmdstanpy - INFO - Chain [1] start processing
# 08:11:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:11:59 - cmdstanpy - INFO - Chain [1] done processing
# 08:12:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:12:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:12:13 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 08:12:50 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:12:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:13:02 - cmdstanpy - INFO - Chain [1] done processing
# 08:13:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:13:11 - cmdstanpy - INFO - Chain [1] start processing
# 08:13:11 - cmdstanpy - INFO - Chain [1] start processing
# 08:13:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:13:23 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:13:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:13:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 08:14:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:14:12 - cmdstanpy - INFO - Chain [1] start processing
# 08:14:24 - cmdstanpy - INFO - Chain [1] done processing
# 08:14:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:14:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:14:33 - cmdstanpy - INFO - Chain [1] start processing
# 08:14:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:14:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:14:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:14:55 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 08:15:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:15:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:15:45 - cmdstanpy - INFO - Chain [1] done processing
# 08:15:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:15:53 - cmdstanpy - INFO - Chain [1] start processing
# 08:15:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:16:03 - cmdstanpy - INFO - Chain [1] done processing
# 08:16:08 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:16:11 - cmdstanpy - INFO - Chain [1] start processing
# 08:16:17 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 08:16:56 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:16:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:17:05 - cmdstanpy - INFO - Chain [1] done processing
# 08:17:07 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:17:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:17:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:17:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:17:25 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:17:29 - cmdstanpy - INFO - Chain [1] start processing
# 08:17:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points=====>       (101 + 18) / 119]
# Processing group: Rieti with 29862 data points
# 08:18:13 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:18:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:18:26 - cmdstanpy - INFO - Chain [1] done processing
# 08:18:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:18:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:18:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:18:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:18:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:18:49 - cmdstanpy - INFO - Chain [1] start processing
# 08:18:55 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 08:19:30 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:19:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:19:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:19:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:19:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:19:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:19:58 - cmdstanpy - INFO - Chain [1] done processing
# 08:20:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:20:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:20:12 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 08:20:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:20:49 - cmdstanpy - INFO - Chain [1] start processing
# 08:20:59 - cmdstanpy - INFO - Chain [1] done processing
# 08:21:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:21:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:21:08 - cmdstanpy - INFO - Chain [1] start processing
# 08:21:14 - cmdstanpy - INFO - Chain [1] done processing
# 08:21:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:21:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:21:27 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 08:22:07 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:22:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:22:19 - cmdstanpy - INFO - Chain [1] done processing
# 08:22:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:22:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:22:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:22:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:22:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:22:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:22:48 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (112 + 7) / 119]
# Processing group: Frosinone with 29862 data points
# 08:23:28 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:23:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:23:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:23:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:23:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:23:48 - cmdstanpy - INFO - Chain [1] start processing
# 08:23:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:24:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:24:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:24:11 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (107 + 12) / 119]
# Processing group: Frosinone with 29862 data points
# 08:24:46 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:24:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:24:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:24:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:25:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:25:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:25:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:25:21 - cmdstanpy - INFO - Chain [1] done processing
# 08:25:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:25:29 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 08:26:05 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:26:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:26:16 - cmdstanpy - INFO - Chain [1] done processing
# 08:26:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 08:26:23 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 08:26:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:26:31 - cmdstanpy - INFO - Chain [1] done processing
# 08:26:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:26:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:26:45 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 08:27:22 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:27:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:27:34 - cmdstanpy - INFO - Chain [1] done processing
# 08:27:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# Processing group: Latina with 29862 data points
# 08:27:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:27:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:27:49 - cmdstanpy - INFO - Chain [1] done processing
# 08:27:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:27:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:28:04 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 08:28:45 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:28:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:28:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:28:54 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:29:02 - cmdstanpy - INFO - Chain [1] start processing
# 08:29:02 - cmdstanpy - INFO - Chain [1] start processing
# 08:29:11 - cmdstanpy - INFO - Chain [1] done processing
# 08:29:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:29:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:29:25 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=>                   (7 + 4) / 11]
# Processing group: Frosinone with 29862 data points
# 08:30:06 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:30:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:30:17 - cmdstanpy - INFO - Chain [1] done processing
# 08:30:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:30:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:30:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:30:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:30:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:30:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:30:49 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points==========>   (111 + 8) / 119]
# Processing group: Rieti with 29862 data points
# 08:31:25 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:31:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:31:35 - cmdstanpy - INFO - Chain [1] done processing
# 08:31:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:31:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:31:43 - cmdstanpy - INFO - Chain [1] start processing
# 08:31:50 - cmdstanpy - INFO - Chain [1] done processing
# 08:31:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:31:58 - cmdstanpy - INFO - Chain [1] start processing
# 08:32:03 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===============>  (113 + 6) / 119]
# Processing group: Frosinone with 29862 data points
# 08:32:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:32:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:32:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:32:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:32:59 - cmdstanpy - INFO - Chain [1] start processing
# 08:33:00 - cmdstanpy - INFO - Chain [1] start processing
# 08:33:09 - cmdstanpy - INFO - Chain [1] done processing
# 08:33:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:33:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:33:23 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points=============>(117 + 2) / 119]
# Processing group: Rieti with 29862 data points
# 08:34:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:34:03 - cmdstanpy - INFO - Chain [1] start processing
# 08:34:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:34:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 08:34:21 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 08:34:23 - cmdstanpy - INFO - Chain [1] start processing
# 08:34:28 - cmdstanpy - INFO - Chain [1] done processing
# 08:34:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:34:36 - cmdstanpy - INFO - Chain [1] start processing
# 08:34:43 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 08:35:24 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:35:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:35:36 - cmdstanpy - INFO - Chain [1] done processing
# 08:35:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:35:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:35:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:35:53 - cmdstanpy - INFO - Chain [1] done processing
# 08:35:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:36:01 - cmdstanpy - INFO - Chain [1] start processing
# 08:36:07 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=================>(118 + 1) / 119]
# Processing group: Frosinone with 29862 data points
# 08:36:45 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:36:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:36:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:36:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:37:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:37:05 - cmdstanpy - INFO - Chain [1] start processing
# 08:37:11 - cmdstanpy - INFO - Chain [1] done processing
# 08:37:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:37:20 - cmdstanpy - INFO - Chain [1] start processing
# 08:37:25 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 08:38:03 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:38:03 - cmdstanpy - INFO - Chain [1] start processing
# 08:38:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:38:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 08:38:22 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 08:38:25 - cmdstanpy - INFO - Chain [1] start processing
# 08:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 08:38:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:38:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:38:46 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=================>(117 + 2) / 119]
# Processing group: Frosinone with 29862 data points
# 08:39:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:39:26 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:36 - cmdstanpy - INFO - Chain [1] done processing
# 08:39:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:39:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:45 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:54 - cmdstanpy - INFO - Chain [1] done processing
# 08:39:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:40:02 - cmdstanpy - INFO - Chain [1] start processing
# 08:40:09 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (105 + 14) / 119]
# Processing group: Frosinone with 29862 data points
# 08:40:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:40:49 - cmdstanpy - INFO - Chain [1] start processing
# 08:40:58 - cmdstanpy - INFO - Chain [1] done processing
# 08:40:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:41:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:41:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:41:21 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:27 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 08:42:09 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:42:09 - cmdstanpy - INFO - Chain [1] start processing
# 08:42:20 - cmdstanpy - INFO - Chain [1] done processing
# 08:42:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 08:42:28 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 08:42:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:42:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:42:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:42:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:42:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (107 + 12) / 119]
# Processing group: Frosinone with 29862 data points
# 08:43:27 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 08:43:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:43:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:43:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 08:43:46 - cmdstanpy - INFO - Chain [1] start processing
# 08:43:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:43:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:44:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 08:44:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:44:10 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# ...
# 10:05:26 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:05:26 - cmdstanpy - INFO - Chain [1] start processing
# 10:05:37 - cmdstanpy - INFO - Chain [1] done processing
# 10:05:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:05:45 - cmdstanpy - INFO - Chain [1] start processing
# 10:05:46 - cmdstanpy - INFO - Chain [1] start processing
# 10:05:54 - cmdstanpy - INFO - Chain [1] done processing
# 10:06:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:06:02 - cmdstanpy - INFO - Chain [1] start processing
# 10:06:08 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points======>              (8 + 3) / 11]
# Processing group: Frosinone with 29862 data points
# 10:06:48 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:06:48 - cmdstanpy - INFO - Chain [1] start processing
# 10:06:59 - cmdstanpy - INFO - Chain [1] done processing
# 10:07:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:07:07 - cmdstanpy - INFO - Chain [1] start processing
# 10:07:09 - cmdstanpy - INFO - Chain [1] start processing
# 10:07:15 - cmdstanpy - INFO - Chain [1] done processing
# 10:07:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:07:23 - cmdstanpy - INFO - Chain [1] start processing
# 10:07:29 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 10:08:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:08:04 - cmdstanpy - INFO - Chain [1] start processing
# 10:08:15 - cmdstanpy - INFO - Chain [1] done processing
# 10:08:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:08:24 - cmdstanpy - INFO - Chain [1] start processing
# 10:08:24 - cmdstanpy - INFO - Chain [1] start processing
# 10:08:33 - cmdstanpy - INFO - Chain [1] done processing
# 10:08:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:08:41 - cmdstanpy - INFO - Chain [1] start processing
# 10:08:47 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 10:09:25 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:09:25 - cmdstanpy - INFO - Chain [1] start processing
# 10:09:38 - cmdstanpy - INFO - Chain [1] done processing
# 10:09:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Viterbo with 29862 data points
# Processing group: Latina with 29862 data points
# 10:09:46 - cmdstanpy - INFO - Chain [1] start processing
# 10:09:46 - cmdstanpy - INFO - Chain [1] start processing
# 10:09:56 - cmdstanpy - INFO - Chain [1] done processing
# 10:09:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:10:04 - cmdstanpy - INFO - Chain [1] start processing
# 10:10:10 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 10:10:50 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:10:50 - cmdstanpy - INFO - Chain [1] start processing
# 10:11:00 - cmdstanpy - INFO - Chain [1] done processing
# 10:11:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:11:08 - cmdstanpy - INFO - Chain [1] start processing
# 10:11:08 - cmdstanpy - INFO - Chain [1] start processing
# 10:11:14 - cmdstanpy - INFO - Chain [1] done processing
# 10:11:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:11:22 - cmdstanpy - INFO - Chain [1] start processing
# 10:11:30 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points============>    (109 + 10) / 119]
# Processing group: Frosinone with 29862 data points
# 10:12:06 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:12:06 - cmdstanpy - INFO - Chain [1] start processing
# 10:12:19 - cmdstanpy - INFO - Chain [1] done processing
# 10:12:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:12:27 - cmdstanpy - INFO - Chain [1] start processing
# 10:12:27 - cmdstanpy - INFO - Chain [1] start processing
# 10:12:36 - cmdstanpy - INFO - Chain [1] done processing
# 10:12:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:12:44 - cmdstanpy - INFO - Chain [1] start processing
# 10:12:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 10:13:27 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:13:27 - cmdstanpy - INFO - Chain [1] start processing
# 10:13:35 - cmdstanpy - INFO - Chain [1] done processing
# 10:13:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:13:43 - cmdstanpy - INFO - Chain [1] start processing
# 10:13:44 - cmdstanpy - INFO - Chain [1] start processing
# 10:13:53 - cmdstanpy - INFO - Chain [1] done processing
# 10:13:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:14:01 - cmdstanpy - INFO - Chain [1] start processing
# 10:14:07 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 10:14:44 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:14:45 - cmdstanpy - INFO - Chain [1] start processing
# 10:14:54 - cmdstanpy - INFO - Chain [1] done processing
# 10:14:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:15:02 - cmdstanpy - INFO - Chain [1] start processing
# 10:15:03 - cmdstanpy - INFO - Chain [1] start processing
# 10:15:10 - cmdstanpy - INFO - Chain [1] done processing
# 10:15:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:15:18 - cmdstanpy - INFO - Chain [1] start processing
# 10:15:24 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (105 + 14) / 119]
# Processing group: Frosinone with 29862 data points
# 10:16:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:16:04 - cmdstanpy - INFO - Chain [1] start processing
# 10:16:16 - cmdstanpy - INFO - Chain [1] done processing
# 10:16:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:16:24 - cmdstanpy - INFO - Chain [1] start processing
# 10:16:24 - cmdstanpy - INFO - Chain [1] start processing
# 10:16:31 - cmdstanpy - INFO - Chain [1] done processing
# 10:16:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:16:39 - cmdstanpy - INFO - Chain [1] start processing
# 10:16:45 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 10:17:25 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:17:25 - cmdstanpy - INFO - Chain [1] start processing
# 10:17:35 - cmdstanpy - INFO - Chain [1] done processing
# 10:17:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:17:43 - cmdstanpy - INFO - Chain [1] start processing
# 10:17:44 - cmdstanpy - INFO - Chain [1] start processing
# 10:17:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:17:59 - cmdstanpy - INFO - Chain [1] done processing
# 10:18:00 - cmdstanpy - INFO - Chain [1] start processing
# 10:18:06 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points================> (115 + 4) / 119]
# Processing group: Frosinone with 29862 data points
# 10:18:43 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:18:43 - cmdstanpy - INFO - Chain [1] start processing
# 10:18:55 - cmdstanpy - INFO - Chain [1] done processing
# 10:18:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:19:03 - cmdstanpy - INFO - Chain [1] start processing
# 10:19:03 - cmdstanpy - INFO - Chain [1] start processing
# 10:19:13 - cmdstanpy - INFO - Chain [1] done processing
# 10:19:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:19:21 - cmdstanpy - INFO - Chain [1] start processing
# 10:19:27 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points======>      (103 + 16) / 119]
# Processing group: Rieti with 29862 data points
# 10:20:05 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:20:05 - cmdstanpy - INFO - Chain [1] start processing
# 10:20:17 - cmdstanpy - INFO - Chain [1] done processing
# 10:20:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:20:25 - cmdstanpy - INFO - Chain [1] start processing
# 10:20:25 - cmdstanpy - INFO - Chain [1] start processing
# 10:20:34 - cmdstanpy - INFO - Chain [1] done processing
# 10:20:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:20:42 - cmdstanpy - INFO - Chain [1] start processing
# 10:20:49 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===============>  (113 + 6) / 119]
# Processing group: Frosinone with 29862 data points
# 10:21:27 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:21:27 - cmdstanpy - INFO - Chain [1] start processing
# 10:21:38 - cmdstanpy - INFO - Chain [1] done processing
# 10:21:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:21:46 - cmdstanpy - INFO - Chain [1] start processing
# 10:21:47 - cmdstanpy - INFO - Chain [1] start processing
# 10:21:55 - cmdstanpy - INFO - Chain [1] done processing
# 10:22:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:22:03 - cmdstanpy - INFO - Chain [1] start processing
# 10:22:09 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points==========>   (110 + 9) / 119]
# Processing group: Rieti with 29862 data points
# 10:22:47 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:22:47 - cmdstanpy - INFO - Chain [1] start processing
# 10:22:56 - cmdstanpy - INFO - Chain [1] done processing
# 10:22:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:23:04 - cmdstanpy - INFO - Chain [1] start processing
# 10:23:06 - cmdstanpy - INFO - Chain [1] start processing
# 10:23:11 - cmdstanpy - INFO - Chain [1] done processing
# 10:23:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:23:19 - cmdstanpy - INFO - Chain [1] start processing
# 10:23:26 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 10:24:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:24:04 - cmdstanpy - INFO - Chain [1] start processing
# 10:24:14 - cmdstanpy - INFO - Chain [1] done processing
# 10:24:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:24:22 - cmdstanpy - INFO - Chain [1] start processing
# 10:24:23 - cmdstanpy - INFO - Chain [1] start processing
# 10:24:30 - cmdstanpy - INFO - Chain [1] done processing
# 10:24:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:24:38 - cmdstanpy - INFO - Chain [1] start processing
# 10:24:44 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +--------+---------+------------------+------------------+------------------+-----------------+
# |    Time|     NOME|               MSE|              RMSE|               MAE|         Coverage|
# +--------+---------+------------------+------------------+------------------+-----------------+
# |  5 Days|  Viterbo| 8.875738924614224| 2.979217837724228| 2.048251154129947|94.93003731343283|
# |  5 Days|    Rieti| 5.181367839374911| 2.276261812572295|1.5609797247766006| 95.1445895522388|
# |  5 Days|   Latina|17.217351256519503| 4.149379623090602|2.8951821738924104|94.84141791044776|
# |  5 Days|Frosinone|15.504303402042716|3.9375504316824586| 2.966626252226218|94.15578358208954|
# |  5 Days|     Roma| 57.39852844343018| 7.576181653275625| 5.791052880110181|94.02985074626866|
# | 30 Days|  Viterbo|  8.72059222818815|2.9530648872295626|2.0329940489450093|95.04990925589837|
# | 30 Days|    Rieti| 5.100556286208062|   2.2584411186055|1.5495163157021552|95.28584392014518|
# | 30 Days|   Latina| 17.02210312204571| 4.125785152191726|2.8842466339474373|94.97731397459165|
# | 30 Days|Frosinone|15.434658613420877| 3.928696808538536| 2.967393440034921|94.34210526315789|
# | 30 Days|     Roma|57.812289794240364| 7.603439339814606| 5.817536389197298| 93.8611615245009|
# | 90 Days|  Viterbo| 8.439524041322722| 2.905085892245309|2.0086109562428547|95.38330494037479|
# | 90 Days|    Rieti| 4.935788130095731| 2.221663370111622|1.5300291439545977|95.59625212947189|
# | 90 Days|   Latina| 16.72494775149062| 4.089614621390458|2.8760442690601216|95.25979557069847|
# | 90 Days|Frosinone|15.385378159702892| 3.922419936684864|   2.9788372550343|94.36541737649064|
# | 90 Days|     Roma| 59.31329209519048| 7.701512325198894| 5.906685334398551|93.44548551959114|
# |180 Days|  Viterbo| 8.992489457047261|2.9987479815828575|  2.11802939630717|95.32426003197753|
# |180 Days|    Rieti| 4.911186686625467|2.2161197365272183|1.5424920327770502|95.67523300705845|
# |180 Days|   Latina| 16.70129280543831| 4.086721522863812| 2.913795460861351|95.56214171508793|
# |180 Days|Frosinone|16.074242094131442|4.0092695212633735| 3.066786513936538|94.31033810396599|
# |180 Days|     Roma| 62.89513591465161| 7.930645365583535| 6.106889304431066|93.13652848730648|
# |365 Days|  Viterbo| 8.659769578120732|2.9427486433810026| 2.108067556023767| 96.1229409401366|
# |365 Days|    Rieti| 4.817593283788651| 2.194901656974328|1.5675482441877882|96.16981384759609|
# |365 Days|   Latina|16.182939430452944| 4.022802434926795| 2.919243988286872|96.08946029195126|
# |365 Days|Frosinone| 17.40985050604961| 4.172511294897787|3.2363979006302803|95.08169278157224|
# |365 Days|     Roma| 65.03110489057981| 8.064186560997943| 6.282921837423628| 93.7424668541583|
# +--------+---------+------------------+------------------+------------------+-----------------+

# %%
result_df_NO2_pd = result_df_NO2.pandas_api()
result_df_NO2_pd

# %% [markdown]
# O3

# %%
from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_O3_prophet = data_O3.groupBy("NOME", "original_date_time").agg(avg("c_O3").alias("avg_c_O3"))
data_O3_prophet.show()

data_O3_prophet_u = data_O3_prophet.withColumnRenamed("avg_c_O3", "y").withColumnRenamed("original_date_time", "ds")

data_O3_prophet = data_O3_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

data_O3_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    m.fit(group[group['ds'] <= cutoff_date])
    
    forecast = m.predict(group)
    
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/O3/'

    if not os.path.exists(path):
        os.makedirs(path)
    
    try:
        fig1 = m.plot(forecast)
        fig1.suptitle(f"O3 Concentration Forecast for {group['NOME'].iloc[0]}")
        fig1.legend(['Actual', 'Forecasted'], loc='upper right')
        fig1.subplots_adjust(top=0.9)
        
        fig2 = m.plot_components(forecast)
        fig2.suptitle(f"O3 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        fig2.subplots_adjust(top=0.9)

        fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/O3/{group['NOME'].iloc[0]}_prophet_forecast.png")
        fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/O3/{group['NOME'].iloc[0]}_prophet_components.png")
    except Exception as e:
        print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])


# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_O3_prophet_train = data_O3_prophet.filter(col('ds') <= cutoff_date)
data_O3_prophet_test = data_O3_prophet.filter((col('ds') > cutoff_date))

max_date = data_O3_prophet_test.agg(max('ds')).collect()[0][0]

period = data_O3_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_O3 = data_O3_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

spark_forecast_O3.show()
# Out:
# +-------+-------------------+------------------+
# |   NOME| original_date_time|          avg_c_O3|
# +-------+-------------------+------------------+
# |Viterbo|2022-02-02 01:00:00| 63.41638380530973|
# |  Rieti|2021-11-01 05:00:00|  64.2590848034682|
# |   Roma|2021-12-12 02:00:00|56.866665243323446|
# |  Rieti|2021-12-19 15:00:00| 57.12363293063586|
# |  Rieti|2021-05-20 22:00:00|110.31992742774568|
# |  Rieti|2021-10-08 15:00:00| 67.82324296531792|
# |   Roma|2021-05-22 11:00:00| 105.9227925074184|
# | Latina|2021-06-10 21:00:00|119.86570038571429|
# | Latina|2021-12-13 00:00:00| 56.38928176785714|
# |   Roma|2021-10-11 14:00:00| 64.54337313649849|
# |Viterbo|2021-06-27 07:00:00| 78.74778460176996|
# |   Roma|2021-10-11 19:00:00|58.406855623145425|
# |Viterbo|2021-10-08 00:00:00| 58.10656114380535|
# |  Rieti|2021-10-08 07:00:00| 54.55861143930636|
# |Viterbo|2021-12-07 13:00:00| 56.05801870796459|
# | Latina|2021-05-21 09:00:00|105.94103004285711|
# |Viterbo|2021-11-29 20:00:00| 56.90135650884957|
# |  Rieti|2021-03-09 07:00:00|58.706492913294795|
# |  Rieti|2021-11-29 03:00:00|52.693859150289015|
# | Latina|2021-05-22 04:00:00|102.07917560000007|
# +-------+-------------------+------------------+
# only showing top 20 rows
#
# root
#  |-- NOME: string (nullable = true)
#  |-- ds: timestamp (nullable = true)
#  |-- y: double (nullable = true)
# The time used for the Spark forecast is  0.0502011775970459
# Processing group: Rieti with 29862 data points                      (0 + 1) / 1]
# 14:49:54 - cmdstanpy - INFO - Chain [1] start processing
# 14:50:15 - cmdstanpy - INFO - Chain [1] done processing
# +-------------------+-----+------------------+---------+----------+----------+---------+----------+----------+-----------+
# |                 ds| NOME|                 y|     yhat|yhat_upper|yhat_lower|    trend|    yearly|    weekly|      daily|
# +-------------------+-----+------------------+---------+----------+----------+---------+----------+----------+-----------+
# |2019-01-01 01:00:00|Rieti|37.189024745664746|39.143295|  57.49009| 20.793215| 70.55917|-22.094322|-2.2409546| -7.0805984|
# |2019-01-01 02:00:00|Rieti|41.472894988439286|39.647747|  58.05195| 22.010616|70.553665|-22.103779|-2.2436514| -6.5584908|
# |2019-01-01 03:00:00|Rieti| 48.15371236416185|40.249825| 58.108025| 22.330557| 70.54816|-22.113247|-2.2380228|  -5.947064|
# |2019-01-01 04:00:00|Rieti|  51.5456828901734| 40.67378| 58.087936|  22.80754|70.542656|-22.122728|-2.2240274| -5.5221214|
# |2019-01-01 05:00:00|Rieti| 52.66332410982661|40.856014| 58.827152|  21.43948| 70.53715|-22.132221|-2.2016857| -5.3472276|
# |2019-01-01 06:00:00|Rieti| 53.27276363583815| 40.98014| 58.660156| 24.127134| 70.53164|-22.141726|-2.1710806|  -5.238693|
# |2019-01-01 07:00:00|Rieti| 53.47990858381502| 41.37448| 58.258877| 23.600424| 70.52614|-22.151241|-2.1323571| -4.8680573|
# |2019-01-01 08:00:00|Rieti| 53.28007424855491| 42.32572| 60.236355|  24.34156| 70.52063|-22.160767|-2.0857203| -3.9484196|
# |2019-01-01 09:00:00|Rieti| 52.43899911560692|43.931137| 61.601257| 25.184134| 70.51512|-22.170303|-2.0314333| -2.3822484|
# |2019-01-01 10:00:00|Rieti| 57.82515293063586|46.081726| 63.449215| 27.309488| 70.50962| -22.17985|-1.9698167|-0.27822584|
# |2019-01-01 11:00:00|Rieti|61.205873520231236| 48.56047|  67.17598| 30.623438| 70.50411|-22.189405|-1.9012427|   2.147009|
# |2019-01-01 12:00:00|Rieti| 63.35076249710983|51.149345|  70.41359|   33.4066|70.498604| -22.19897|-1.8261338|   4.675843|
# |2019-01-01 13:00:00|Rieti| 64.67448533526012|53.648613| 72.920975|  35.40488|70.493095|-22.208544|-1.7449577|   7.109017|
# |2019-01-01 14:00:00|Rieti| 65.13874515028901| 55.81216|  73.89061| 38.041832|70.487595|-22.218126|-1.6582229|   9.200917|
# |2019-01-01 15:00:00|Rieti| 64.54328173988439|57.296627|  76.54137|  39.52529|70.482086|-22.227715|-1.5664738|   10.60873|
# |2019-01-01 16:00:00|Rieti| 62.99045916763003|57.719994|  75.91793| 39.938023| 70.47658|-22.237312| -1.470286|  10.951012|
# |2019-01-01 17:00:00|Rieti| 58.04210960693641| 56.82638|  74.77715|  37.30815| 70.47108|-22.246916|-1.3702595|   9.972481|
# |2019-01-01 18:00:00|Rieti|52.744605962427755|54.649734|  72.13443| 37.549694| 70.46557|-22.256527|-1.2670143|   7.707707|
# |2019-01-01 19:00:00|Rieti| 50.72032833641617|51.554924|  68.49496| 32.362568| 70.46006|-22.266142|-1.1611836|   4.522187|
# |2019-01-01 20:00:00|Rieti|50.589100577456634| 48.12192|   66.2681| 31.182615| 70.45456|-22.275764|-1.0534081|  0.9965372|
# +-------------------+-----+------------------+---------+----------+----------+---------+----------+----------+-----------+
# only showing top 20 rows
# Processing group: Viterbo with 29862 data points

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import pow, sqrt
from prophet.diagnostics import performance_metrics


# Calculate MAE
mae_O3 = spark_forecast_O3.select(col("NOME"), abs(col("y") - col("yhat")).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MAE")


# Calculate MSE
mse_O3 = spark_forecast_O3.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                    .groupBy("NOME") \
                    .agg({"error": "mean"}) \
                    .withColumnRenamed("avg(error)", "MSE")

# Calculate RMSE
rmse_O3 = spark_forecast_O3.select(col("NOME"), pow(col("y") - col("yhat"), 2).alias("error")) \
                     .groupBy("NOME") \
                     .agg({"error": "mean"}) \
                     .withColumnRenamed("avg(error)", "MSE") \
                     .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE"))

# Show the results
mae_O3.show()
mse_O3.show()
rmse_O3.show()
# Out:
# 14:50:27 - cmdstanpy - INFO - Chain [1] start processing         (0 + 96) / 119]
# 14:50:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 14:51:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:28 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 14:51:38 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 14:51:42 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 14:52:00 - cmdstanpy - INFO - Chain [1] start processing
# 14:52:14 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+
# |     NOME|               MAE|
# +---------+------------------+
# |  Viterbo| 9.259814227136745|
# |    Rieti|  8.39984605501204|
# |   Latina| 9.545006004330402|
# |Frosinone| 9.452385800198158|
# |     Roma|11.060428338526552|
# +---------+------------------+
# Processing group: Frosinone with 29862 data points======>          (9 + 2) / 11]
# Processing group: Rieti with 29862 data points
# 14:53:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:53:04 - cmdstanpy - INFO - Chain [1] start processing
# 14:53:26 - cmdstanpy - INFO - Chain [1] done processing
# 14:53:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 14:53:36 - cmdstanpy - INFO - Chain [1] start processing
# 14:53:37 - cmdstanpy - INFO - Chain [1] start processing
# 14:53:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:53:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 14:53:59 - cmdstanpy - INFO - Chain [1] start processing
# 14:54:13 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+
# |     NOME|               MSE|
# +---------+------------------+
# |  Viterbo| 142.4690505576954|
# |    Rieti|118.42187160637249|
# |   Latina| 148.2267387124007|
# |Frosinone|150.69700327824347|
# |     Roma|198.17619701425835|
# +---------+------------------+
# Processing group: Rieti with 29862 data points=================>(117 + 2) / 119]
# Processing group: Frosinone with 29862 data points
# 14:55:01 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 14:55:01 - cmdstanpy - INFO - Chain [1] start processing
# 14:55:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:55:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 14:55:32 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 14:55:37 - cmdstanpy - INFO - Chain [1] start processing
# 14:55:45 - cmdstanpy - INFO - Chain [1] done processing
# 14:55:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 14:55:56 - cmdstanpy - INFO - Chain [1] start processing
# 14:56:08 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +---------+------------------+------------------+
# |     NOME|               MSE|              RMSE|
# +---------+------------------+------------------+
# |  Viterbo| 142.4690505576954|11.936039986431656|
# |    Rieti|118.42187160637249|10.882181380880052|
# |   Latina| 148.2267387124007|12.174840397820445|
# |Frosinone|150.69700327824347|12.275870774745206|
# |     Roma|198.17619701425835|14.077506775500353|
# +---------+------------------+------------------+

# %%
from pyspark.sql.functions import *
from time import time
import matplotlib.pyplot as plt
import os

data_O3_prophet = data_O3.groupBy("NOME", "original_date_time").agg(avg("c_O3").alias("avg_c_O3"))
#data_O3_prophet.show()

data_O3_prophet_u = data_O3_prophet.withColumnRenamed("avg_c_O3", "y").withColumnRenamed("original_date_time", "ds")

data_O3_prophet = data_O3_prophet_u.withColumn("ds", to_timestamp("ds", "yyyy-MM-dd HH:mm:ss")) \
                                       .withColumn("ds", from_utc_timestamp("ds", "Europe/Rome"))

#data_O3_prophet.printSchema()

def train_and_forecast(group):
    
    print(f"Processing group: {group['NOME'].iloc[0]} with {len(group)} data points")
    
    group["ds"] = pd.to_datetime(group["ds"])

    m = Prophet(seasonality_mode="additive",
                    yearly_seasonality=True,
                    weekly_seasonality=True,
                    daily_seasonality=True,
                    interval_width=0.95)
    
    m.fit(group[group['ds'] <= cutoff_date])
    
    forecast = m.predict(group)
    
    path = '/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet_lazio/O3/'

    if not os.path.exists(path):
        os.makedirs(path)
    
   # try:
    #    fig1 = m.plot(forecast)
     #   fig1.suptitle(f"O3 Concentration Forecast for {group['NOME'].iloc[0]}")
     #   fig1.legend(['Actual', 'Forecasted'], loc='upper right')
      #  fig1.subplots_adjust(top=0.9)
        
       # fig2 = m.plot_components(forecast)
       # fig2.suptitle(f"O3 Concentration Component Forecast for {group['NOME'].iloc[0]}")
        #fig2.subplots_adjust(top=0.9)

       # fig1.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/O3/{group['NOME'].iloc[0]}_prophet_forecast.png")
        #fig2.savefig(f"/afs/enea.it/por/user/nafis/PFS/por/Thesis/codes/prophet/O3/{group['NOME'].iloc[0]}_prophet_components.png")
    #except Exception as e:
     #   print(f"Error generating plots for group {group['NOME'].iloc[0]}: {str(e)}")
    
    
    f_pd = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','trend', 'yearly', 'weekly', 'daily']].set_index("ds")
 
    group_pd = group[['ds', 'NOME', 'y']].set_index("ds")
    
    result_pd = f_pd.join( group_pd, how = "left")
    result_pd.reset_index(level=0, inplace=True)
    
    result_pd['NOME'] = group['NOME'].iloc[0]
    
    return result_pd[['ds', 'NOME', 'y', 'yhat', 'yhat_upper', 'yhat_lower','trend', 'yearly', 'weekly', 'daily']] 

result_schema =StructType([
    StructField('ds',TimestampType()),
    StructField('NOME', StringType()),
    StructField('y', DoubleType()),
    StructField('yhat',FloatType()),
    StructField('yhat_upper',FloatType()),
    StructField('yhat_lower',FloatType()),
    StructField('trend',FloatType()),
    StructField('yearly',FloatType()),
    StructField('weekly',FloatType()),
    StructField('daily',FloatType())
  ])


# create train and test data based on cutoff date
cutoff_date = "2021-06-30 23:00:00"

data_O3_prophet_train = data_O3_prophet.filter(col('ds') <= cutoff_date)
data_O3_prophet_test = data_O3_prophet.filter((col('ds') > cutoff_date))

max_date = data_O3_prophet_test.agg(max('ds')).collect()[0][0]

period = data_O3_prophet_test.count()

# Start time
start_time = time()
# Train and forecast by ticker 
spark_forecast_O3 = data_O3_prophet.groupBy("NOME").applyInPandas(train_and_forecast, schema=result_schema)
# Processing time
print('The time used for the Spark forecast is ', time()-start_time)

#spark_forecast_O3.show()
# Out:
# [Stage 3959:===================================================>(118 + 1) / 119]
# The time used for the Spark forecast is  0.043535470962524414

# %%
from pyspark.sql.functions import col, pow, sqrt

# Define cutoff dates
cutoff_dates = {
    "5 Days": "2021-07-05 23:00:00",
    "30 Days": "2021-07-30 23:00:00",
    "90 Days": "2021-09-28 23:00:00",
    "180 Days": "2021-12-27 23:00:00",
    "365 Days": "2022-06-29 23:00:00"
}

# Define a list to store the evaluation results
results = []

# Compute evaluation metrics for each time period and NOME
for period, cutoff in cutoff_dates.items():
    for nome in spark_forecast_O3.select("NOME").distinct().rdd.flatMap(lambda x: x).collect():
        # Filter the forecast data based on the cutoff date and NOME
        forecast_data_O3 = spark_forecast_O3.filter((col("ds") <= cutoff) & (col("NOME") == nome))

        # Calculate MAE
        mae = forecast_data_O3.select(abs(col("y") - col("yhat")).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MAE") \
                             .collect()[0]["MAE"]

        # Calculate MSE
        mse = forecast_data_O3.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                             .agg({"error": "mean"}) \
                             .withColumnRenamed("avg(error)", "MSE") \
                             .collect()[0]["MSE"]

        # Calculate RMSE
        rmse = forecast_data_O3.select(pow(col("y") - col("yhat"), 2).alias("error")) \
                              .agg({"error": "mean"}) \
                              .withColumnRenamed("avg(error)", "MSE") \
                              .withColumn("RMSE", sqrt(col("MSE")).alias("RMSE")) \
                              .collect()[0]["RMSE"]

        # Calculate coverage
        coverage = forecast_data_O3.filter((col("y") >= col("yhat_lower")) & (col("y") <= col("yhat_upper"))) \
                                  .count() / forecast_data_O3.count() * 100

        # Add the results to the list
        results.append((period, nome, mse, rmse, mae, coverage))

# Create a Spark DataFrame from the results list
result_df_O3 = spark.createDataFrame(results, ["Time", "NOME", "MSE", "RMSE", "MAE", "Coverage"])

# Show the results
result_df_O3.show()
# Out:
# Processing group: Frosinone with 29862 data points                  (0 + 2) / 2]
# Processing group: Rieti with 29862 data points
# 10:26:50 - cmdstanpy - INFO - Chain [1] start processing
# 10:26:50 - cmdstanpy - INFO - Chain [1] start processing
# 10:27:09 - cmdstanpy - INFO - Chain [1] done processing
# 10:27:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:27:17 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:27:20 - cmdstanpy - INFO - Chain [1] start processing
# 10:27:27 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# 10:27:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:27:35 - cmdstanpy - INFO - Chain [1] start processing
# 10:27:46 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (112 + 7) / 119]
# Processing group: Frosinone with 29862 data points
# 10:28:22 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:28:22 - cmdstanpy - INFO - Chain [1] start processing
# 10:28:41 - cmdstanpy - INFO - Chain [1] done processing
# 10:28:44 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:28:49 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:28:52 - cmdstanpy - INFO - Chain [1] start processing
# 10:28:59 - cmdstanpy - INFO - Chain [1] done processing
# 10:29:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:29:07 - cmdstanpy - INFO - Chain [1] start processing
# 10:29:17 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 10:29:55 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:29:55 - cmdstanpy - INFO - Chain [1] start processing
# 10:30:08 - cmdstanpy - INFO - Chain [1] done processing
# 10:30:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:30:16 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:30:20 - cmdstanpy - INFO - Chain [1] start processing
# 10:30:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:30:33 - cmdstanpy - INFO - Chain [1] done processing
# 10:30:34 - cmdstanpy - INFO - Chain [1] start processing
# 10:30:46 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 10:31:21 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:31:21 - cmdstanpy - INFO - Chain [1] start processing
# 10:31:40 - cmdstanpy - INFO - Chain [1] done processing
# 10:31:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:31:48 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:31:53 - cmdstanpy - INFO - Chain [1] start processing
# 10:31:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:32:05 - cmdstanpy - INFO - Chain [1] start processing
# 10:32:05 - cmdstanpy - INFO - Chain [1] done processing
# 10:32:17 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=================>(117 + 2) / 119]
# Processing group: Frosinone with 29862 data points
# 10:32:56 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:32:56 - cmdstanpy - INFO - Chain [1] start processing
# 10:33:16 - cmdstanpy - INFO - Chain [1] done processing
# 10:33:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:33:24 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:33:27 - cmdstanpy - INFO - Chain [1] start processing
# 10:33:36 - cmdstanpy - INFO - Chain [1] done processing
# 10:33:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:33:44 - cmdstanpy - INFO - Chain [1] start processing
# 10:33:55 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 10:34:21 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:34:21 - cmdstanpy - INFO - Chain [1] start processing
# 10:34:36 - cmdstanpy - INFO - Chain [1] done processing
# 10:34:37 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:34:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:34:45 - cmdstanpy - INFO - Chain [1] start processing
# 10:34:55 - cmdstanpy - INFO - Chain [1] done processing
# 10:34:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:35:03 - cmdstanpy - INFO - Chain [1] start processing
# 10:35:14 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 10:35:51 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:35:51 - cmdstanpy - INFO - Chain [1] start processing
# 10:36:06 - cmdstanpy - INFO - Chain [1] done processing
# 10:36:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:36:13 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:36:18 - cmdstanpy - INFO - Chain [1] start processing
# 10:36:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:36:32 - cmdstanpy - INFO - Chain [1] start processing
# 10:36:33 - cmdstanpy - INFO - Chain [1] done processing
# 10:36:43 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data pointsProcessing group: Frosinone with 29862 data points
#
# 10:37:20 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:37:21 - cmdstanpy - INFO - Chain [1] start processing
# 10:37:39 - cmdstanpy - INFO - Chain [1] done processing
# 10:37:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:37:47 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:37:51 - cmdstanpy - INFO - Chain [1] start processing
# 10:37:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:38:04 - cmdstanpy - INFO - Chain [1] done processing
# 10:38:05 - cmdstanpy - INFO - Chain [1] start processing
# 10:38:16 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (112 + 7) / 119]
# Processing group: Frosinone with 29862 data points
# 10:38:52 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:38:52 - cmdstanpy - INFO - Chain [1] start processing
# 10:39:11 - cmdstanpy - INFO - Chain [1] done processing
# 10:39:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:39:19 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:39:22 - cmdstanpy - INFO - Chain [1] start processing
# 10:39:31 - cmdstanpy - INFO - Chain [1] done processing
# 10:39:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:39:39 - cmdstanpy - INFO - Chain [1] start processing
# 10:39:51 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===============>  (113 + 6) / 119]
# Processing group: Frosinone with 29862 data points
# 10:40:30 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:40:30 - cmdstanpy - INFO - Chain [1] start processing
# 10:40:44 - cmdstanpy - INFO - Chain [1] done processing
# 10:40:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:40:51 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:40:55 - cmdstanpy - INFO - Chain [1] start processing
# 10:41:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:41:09 - cmdstanpy - INFO - Chain [1] done processing
# 10:41:09 - cmdstanpy - INFO - Chain [1] start processing
# 10:41:22 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (105 + 14) / 119]
# Processing group: Frosinone with 29862 data points
# 10:41:58 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:41:58 - cmdstanpy - INFO - Chain [1] start processing
# 10:42:12 - cmdstanpy - INFO - Chain [1] done processing
# 10:42:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:42:20 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:42:23 - cmdstanpy - INFO - Chain [1] start processing
# 10:42:30 - cmdstanpy - INFO - Chain [1] done processing
# 10:42:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:42:39 - cmdstanpy - INFO - Chain [1] start processing
# 10:42:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 10:43:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:43:29 - cmdstanpy - INFO - Chain [1] start processing
# 10:43:42 - cmdstanpy - INFO - Chain [1] done processing
# 10:43:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:43:50 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:43:53 - cmdstanpy - INFO - Chain [1] start processing
# 10:44:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:44:09 - cmdstanpy - INFO - Chain [1] done processing
# 10:44:09 - cmdstanpy - INFO - Chain [1] start processing
# 10:44:21 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 10:44:57 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:44:57 - cmdstanpy - INFO - Chain [1] start processing
# 10:45:15 - cmdstanpy - INFO - Chain [1] done processing
# 10:45:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:45:42 - cmdstanpy - INFO - Chain [1] start processing
# 10:45:42 - cmdstanpy - INFO - Chain [1] start processing
# 10:45:55 - cmdstanpy - INFO - Chain [1] done processing
# 10:45:58 - cmdstanpy - INFO - Chain [1] done processing             (0 + 2) / 2]
# Processing group: Roma with 29862 data points
# 10:46:03 - cmdstanpy - INFO - Chain [1] start processing
# 10:46:14 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (111 + 8) / 119]
# Processing group: Frosinone with 29862 data points
# 10:46:53 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:46:53 - cmdstanpy - INFO - Chain [1] start processing
# 10:47:10 - cmdstanpy - INFO - Chain [1] done processing
# 10:47:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:47:18 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:47:24 - cmdstanpy - INFO - Chain [1] start processing
# 10:47:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:47:35 - cmdstanpy - INFO - Chain [1] done processing
# 10:47:36 - cmdstanpy - INFO - Chain [1] start processing
# 10:47:48 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 10:48:25 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:48:25 - cmdstanpy - INFO - Chain [1] start processing
# 10:48:39 - cmdstanpy - INFO - Chain [1] done processing
# 10:48:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:48:47 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:48:50 - cmdstanpy - INFO - Chain [1] start processing
# 10:48:59 - cmdstanpy - INFO - Chain [1] done processing
# 10:49:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:49:07 - cmdstanpy - INFO - Chain [1] start processing
# 10:49:19 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points========>        (100 + 19) / 119]
# Processing group: Frosinone with 29862 data points
# 10:49:54 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:49:55 - cmdstanpy - INFO - Chain [1] start processing
# 10:50:14 - cmdstanpy - INFO - Chain [1] done processing
# 10:50:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:50:21 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:50:24 - cmdstanpy - INFO - Chain [1] start processing
# 10:50:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:50:40 - cmdstanpy - INFO - Chain [1] done processing
# 10:50:41 - cmdstanpy - INFO - Chain [1] start processing
# 10:50:53 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (110 + 9) / 119]
# Processing group: Frosinone with 29862 data points
# 10:51:29 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:51:29 - cmdstanpy - INFO - Chain [1] start processing
# 10:51:45 - cmdstanpy - INFO - Chain [1] done processing
# 10:51:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:51:53 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:51:56 - cmdstanpy - INFO - Chain [1] start processing
# 10:52:03 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:52:09 - cmdstanpy - INFO - Chain [1] done processing
# 10:52:11 - cmdstanpy - INFO - Chain [1] start processing
# 10:52:22 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 10:53:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:53:00 - cmdstanpy - INFO - Chain [1] start processing
# 10:53:19 - cmdstanpy - INFO - Chain [1] done processing
# 10:53:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:53:27 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:53:30 - cmdstanpy - INFO - Chain [1] start processing
# 10:53:40 - cmdstanpy - INFO - Chain [1] done processing
# 10:53:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:53:47 - cmdstanpy - INFO - Chain [1] start processing
# 10:53:59 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (110 + 9) / 119]
# Processing group: Frosinone with 29862 data points
# 10:54:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:54:35 - cmdstanpy - INFO - Chain [1] start processing
# 10:54:50 - cmdstanpy - INFO - Chain [1] done processing
# 10:54:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:54:57 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:55:01 - cmdstanpy - INFO - Chain [1] start processing
# 10:55:11 - cmdstanpy - INFO - Chain [1] done processing
# 10:55:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:55:19 - cmdstanpy - INFO - Chain [1] start processing
# 10:55:30 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 10:56:09 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:56:09 - cmdstanpy - INFO - Chain [1] start processing
# 10:56:22 - cmdstanpy - INFO - Chain [1] done processing
# 10:56:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:56:30 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:56:34 - cmdstanpy - INFO - Chain [1] start processing
# 10:56:42 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:56:49 - cmdstanpy - INFO - Chain [1] done processing
# 10:56:50 - cmdstanpy - INFO - Chain [1] start processing
# 10:57:00 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (107 + 12) / 119]
# Processing group: Frosinone with 29862 data points
# 10:57:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:57:36 - cmdstanpy - INFO - Chain [1] start processing
# 10:57:56 - cmdstanpy - INFO - Chain [1] done processing
# 10:57:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 10:58:04 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 10:58:07 - cmdstanpy - INFO - Chain [1] start processing
# 10:58:13 - cmdstanpy - INFO - Chain [1] done processing
# 10:58:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:58:21 - cmdstanpy - INFO - Chain [1] start processing
# 10:58:32 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points=======>     (105 + 14) / 119]
# Processing group: Rieti with 29862 data points
# 10:59:07 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 10:59:07 - cmdstanpy - INFO - Chain [1] start processing
# 10:59:23 - cmdstanpy - INFO - Chain [1] done processing
# 10:59:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 10:59:31 - cmdstanpy - INFO - Chain [1] start processing
# 10:59:32 - cmdstanpy - INFO - Chain [1] start processing
# 10:59:42 - cmdstanpy - INFO - Chain [1] done processing
# 10:59:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 10:59:49 - cmdstanpy - INFO - Chain [1] start processing
# 11:00:01 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 11:00:37 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:00:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:00:56 - cmdstanpy - INFO - Chain [1] done processing
# 11:00:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:01:04 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:01:08 - cmdstanpy - INFO - Chain [1] start processing
# 11:01:16 - cmdstanpy - INFO - Chain [1] done processing
# 11:01:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:01:24 - cmdstanpy - INFO - Chain [1] start processing
# 11:01:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 11:02:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:02:12 - cmdstanpy - INFO - Chain [1] start processing
# 11:02:31 - cmdstanpy - INFO - Chain [1] done processing
# 11:02:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:02:39 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:02:41 - cmdstanpy - INFO - Chain [1] start processing
# 11:02:51 - cmdstanpy - INFO - Chain [1] done processing
# 11:02:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:02:59 - cmdstanpy - INFO - Chain [1] start processing
# 11:03:10 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=================>(117 + 2) / 119]
# Processing group: Frosinone with 29862 data points
# 11:03:47 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:03:47 - cmdstanpy - INFO - Chain [1] start processing
# 11:04:06 - cmdstanpy - INFO - Chain [1] done processing
# 11:04:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:04:14 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:04:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:04:26 - cmdstanpy - INFO - Chain [1] done processing
# 11:04:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:04:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:04:45 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points======>      (103 + 16) / 119]
# Processing group: Rieti with 29862 data points
# 11:05:22 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:05:22 - cmdstanpy - INFO - Chain [1] start processing
# 11:05:40 - cmdstanpy - INFO - Chain [1] done processing
# 11:05:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:05:48 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:05:53 - cmdstanpy - INFO - Chain [1] start processing
# 11:06:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:06:08 - cmdstanpy - INFO - Chain [1] done processing
# 11:06:08 - cmdstanpy - INFO - Chain [1] start processing
# 11:06:21 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points======>      (103 + 16) / 119]
# Processing group: Rieti with 29862 data points
# 11:06:58 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:06:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:07:17 - cmdstanpy - INFO - Chain [1] done processing
# 11:07:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:07:25 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:07:28 - cmdstanpy - INFO - Chain [1] start processing
# 11:07:36 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:07:43 - cmdstanpy - INFO - Chain [1] done processing
# 11:07:44 - cmdstanpy - INFO - Chain [1] start processing
# 11:07:56 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 11:08:35 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:08:35 - cmdstanpy - INFO - Chain [1] start processing
# 11:08:49 - cmdstanpy - INFO - Chain [1] done processing
# 11:08:52 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:08:57 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:09:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:09:09 - cmdstanpy - INFO - Chain [1] done processing
# 11:09:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:09:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:09:28 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points======>      (103 + 16) / 119]
# Processing group: Rieti with 29862 data points
# 11:10:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:10:04 - cmdstanpy - INFO - Chain [1] start processing
# 11:10:23 - cmdstanpy - INFO - Chain [1] done processing
# 11:10:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:10:31 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:10:34 - cmdstanpy - INFO - Chain [1] start processing
# 11:10:41 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:10:47 - cmdstanpy - INFO - Chain [1] done processing
# 11:10:49 - cmdstanpy - INFO - Chain [1] start processing
# 11:11:01 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=================>(118 + 1) / 119]
# Processing group: Frosinone with 29862 data points
# 11:11:38 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:11:38 - cmdstanpy - INFO - Chain [1] start processing
# 11:11:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:12:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:12:06 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:12:08 - cmdstanpy - INFO - Chain [1] start processing
# 11:12:16 - cmdstanpy - INFO - Chain [1] done processing
# 11:12:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:12:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:12:34 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points========>    (108 + 11) / 119]
# Processing group: Rieti with 29862 data points
# 11:13:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:13:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:13:24 - cmdstanpy - INFO - Chain [1] done processing
# 11:13:26 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:13:31 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:13:34 - cmdstanpy - INFO - Chain [1] start processing
# 11:13:41 - cmdstanpy - INFO - Chain [1] done processing
# 11:13:46 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:13:49 - cmdstanpy - INFO - Chain [1] start processing
# 11:14:00 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (111 + 8) / 119]
# Processing group: Frosinone with 29862 data points
# 11:14:37 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:14:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:14:52 - cmdstanpy - INFO - Chain [1] done processing
# 11:14:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:15:00 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:15:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:15:14 - cmdstanpy - INFO - Chain [1] done processing
# 11:15:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:15:22 - cmdstanpy - INFO - Chain [1] start processing
# 11:15:33 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (105 + 14) / 119]
# Processing group: Frosinone with 29862 data points
# 11:16:09 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:16:09 - cmdstanpy - INFO - Chain [1] start processing
# 11:16:28 - cmdstanpy - INFO - Chain [1] done processing
# 11:16:30 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 11:16:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:16:38 - cmdstanpy - INFO - Chain [1] start processing
# 11:16:47 - cmdstanpy - INFO - Chain [1] done processing
# 11:16:53 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:16:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:17:05 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>        (99 + 20) / 119]
# Processing group: Frosinone with 29862 data points
# 11:17:44 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:17:44 - cmdstanpy - INFO - Chain [1] start processing
# 11:17:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:18:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:18:06 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:18:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:18:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:18:25 - cmdstanpy - INFO - Chain [1] start processing
# 11:18:25 - cmdstanpy - INFO - Chain [1] done processing
# 11:18:37 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 11:19:12 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:19:12 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:30 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:34 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:19:38 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:19:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:19:57 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:10 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>        (99 + 20) / 119]
# Processing group: Frosinone with 29862 data points
# 11:20:48 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:20:48 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:06 - cmdstanpy - INFO - Chain [1] done processing
# 11:21:12 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:21:14 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:21:20 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:21:32 - cmdstanpy - INFO - Chain [1] start processing
# 11:21:32 - cmdstanpy - INFO - Chain [1] done processing
# 11:21:44 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 11:22:19 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:22:19 - cmdstanpy - INFO - Chain [1] start processing
# 11:22:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:22:40 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:22:45 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:22:49 - cmdstanpy - INFO - Chain [1] start processing
# 11:22:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:23:05 - cmdstanpy - INFO - Chain [1] done processing
# 11:23:06 - cmdstanpy - INFO - Chain [1] start processing
# 11:23:19 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points================> (116 + 3) / 119]
# Processing group: Frosinone with 29862 data points
# 11:23:58 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:23:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:24:13 - cmdstanpy - INFO - Chain [1] done processing
# 11:24:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:24:21 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:24:26 - cmdstanpy - INFO - Chain [1] start processing
# 11:24:33 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:24:41 - cmdstanpy - INFO - Chain [1] start processing
# 11:24:41 - cmdstanpy - INFO - Chain [1] done processing
# 11:24:52 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points============> (116 + 3) / 119]
# Processing group: Rieti with 29862 data points
# 11:25:27 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:25:27 - cmdstanpy - INFO - Chain [1] start processing
# 11:25:44 - cmdstanpy - INFO - Chain [1] done processing
# 11:25:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:25:52 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:25:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:26:05 - cmdstanpy - INFO - Chain [1] done processing
# 11:26:09 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:26:13 - cmdstanpy - INFO - Chain [1] start processing
# 11:26:24 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points============>    (108 + 11) / 119]
# Processing group: Frosinone with 29862 data points
# 11:27:00 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:27:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:19 - cmdstanpy - INFO - Chain [1] done processing
# 11:27:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:27:27 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:27:29 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:40 - cmdstanpy - INFO - Chain [1] done processing
# 11:27:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:27:48 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:00 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 11:28:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:28:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:51 - cmdstanpy - INFO - Chain [1] done processing
# 11:28:56 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:28:59 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:29:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:11 - cmdstanpy - INFO - Chain [1] done processing
# 11:29:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:29:19 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:31 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 11:30:09 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:30:09 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:24 - cmdstanpy - INFO - Chain [1] done processing
# 11:30:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:30:32 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:30:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:30:51 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:52 - cmdstanpy - INFO - Chain [1] done processing
# 11:31:02 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 11:31:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:31:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:32:00 - cmdstanpy - INFO - Chain [1] done processing
# 11:32:01 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 11:32:08 - cmdstanpy - INFO - Chain [1] start processing
# 11:32:09 - cmdstanpy - INFO - Chain [1] start processing
# 11:32:20 - cmdstanpy - INFO - Chain [1] done processing
# 11:32:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:32:28 - cmdstanpy - INFO - Chain [1] start processing
# 11:32:40 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=================>(118 + 1) / 119]
# Processing group: Frosinone with 29862 data points
# 11:33:18 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:33:19 - cmdstanpy - INFO - Chain [1] start processing
# 11:33:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:33:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:33:45 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:33:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:33:55 - cmdstanpy - INFO - Chain [1] done processing
# 11:33:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:34:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:34:14 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 11:34:50 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:34:50 - cmdstanpy - INFO - Chain [1] start processing
# 11:35:11 - cmdstanpy - INFO - Chain [1] done processing
# 11:35:14 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:35:19 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:35:22 - cmdstanpy - INFO - Chain [1] start processing
# 11:35:30 - cmdstanpy - INFO - Chain [1] done processing
# 11:35:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:35:38 - cmdstanpy - INFO - Chain [1] start processing
# 11:35:50 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (102 + 17) / 119]
# Processing group: Frosinone with 29862 data points
# 11:36:28 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:36:28 - cmdstanpy - INFO - Chain [1] start processing
# 11:36:45 - cmdstanpy - INFO - Chain [1] done processing
# 11:36:50 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:36:53 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:36:57 - cmdstanpy - INFO - Chain [1] start processing
# 11:37:04 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:37:10 - cmdstanpy - INFO - Chain [1] done processing
# 11:37:12 - cmdstanpy - INFO - Chain [1] start processing
# 11:37:24 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>     (106 + 13) / 119]
# Processing group: Frosinone with 29862 data points
# 11:38:01 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:38:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:38:17 - cmdstanpy - INFO - Chain [1] done processing
# 11:38:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:38:25 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:38:28 - cmdstanpy - INFO - Chain [1] start processing
# 11:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 11:38:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:38:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:38:54 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 11:39:30 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:39:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:39:45 - cmdstanpy - INFO - Chain [1] done processing
# 11:39:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:39:53 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:39:56 - cmdstanpy - INFO - Chain [1] start processing
# 11:40:07 - cmdstanpy - INFO - Chain [1] done processing
# 11:40:11 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:40:15 - cmdstanpy - INFO - Chain [1] start processing
# 11:40:27 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points=====>       (101 + 18) / 119]
# Processing group: Rieti with 29862 data points
# 11:41:04 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:41:04 - cmdstanpy - INFO - Chain [1] start processing
# 11:41:20 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 11:41:28 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:41:34 - cmdstanpy - INFO - Chain [1] start processing
# 11:41:38 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:41:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:41:47 - cmdstanpy - INFO - Chain [1] done processing
# 11:41:58 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 11:42:36 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:42:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:42:54 - cmdstanpy - INFO - Chain [1] done processing
# 11:42:58 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:43:02 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:43:06 - cmdstanpy - INFO - Chain [1] start processing
# 11:43:13 - cmdstanpy - INFO - Chain [1] done processing
# 11:43:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:43:20 - cmdstanpy - INFO - Chain [1] start processing
# 11:43:34 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points========>        (100 + 19) / 119]
# Processing group: Frosinone with 29862 data points
# 11:44:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:44:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:44:25 - cmdstanpy - INFO - Chain [1] done processing
# 11:44:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 11:44:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:44:34 - cmdstanpy - INFO - Chain [1] start processing
# 11:44:46 - cmdstanpy - INFO - Chain [1] done processing
# 11:44:48 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:44:54 - cmdstanpy - INFO - Chain [1] start processing
# 11:45:04 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points========>        (100 + 19) / 119]
# Processing group: Frosinone with 29862 data points
# 11:45:42 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:45:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:45:57 - cmdstanpy - INFO - Chain [1] done processing
# 11:45:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:46:05 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:46:07 - cmdstanpy - INFO - Chain [1] start processing
# 11:46:16 - cmdstanpy - INFO - Chain [1] done processing
# 11:46:21 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:46:24 - cmdstanpy - INFO - Chain [1] start processing
# 11:46:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 11:47:11 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:47:11 - cmdstanpy - INFO - Chain [1] start processing
# 11:47:25 - cmdstanpy - INFO - Chain [1] done processing
# 11:47:28 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:47:33 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:47:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:47:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:47:50 - cmdstanpy - INFO - Chain [1] start processing
# 11:47:50 - cmdstanpy - INFO - Chain [1] done processing
# 11:48:02 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (110 + 9) / 119]
# Processing group: Frosinone with 29862 data points
# 11:48:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 11:48:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:48:57 - cmdstanpy - INFO - Chain [1] done processing
# 11:49:02 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 11:49:05 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 11:49:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:49:15 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 11:49:22 - cmdstanpy - INFO - Chain [1] start processing
# 11:49:22 - cmdstanpy - INFO - Chain [1] done processing
# 11:49:34 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# ...
# 13:24:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:24:07 - cmdstanpy - INFO - Chain [1] done processing
# 13:24:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:19 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points=========>       (101 + 18) / 119]
# Processing group: Frosinone with 29862 data points
# 13:24:56 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:24:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:14 - cmdstanpy - INFO - Chain [1] done processing
# 13:25:19 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:25:22 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:25:27 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:25:38 - cmdstanpy - INFO - Chain [1] done processing
# 13:25:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:51 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 13:26:28 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:26:28 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:47 - cmdstanpy - INFO - Chain [1] done processing
# 13:26:51 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:26:55 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:26:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:27:05 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:27:13 - cmdstanpy - INFO - Chain [1] done processing
# 13:27:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:27:25 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points======>      (103 + 16) / 119]
# Processing group: Rieti with 29862 data points
# 13:28:01 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:28:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:20 - cmdstanpy - INFO - Chain [1] done processing
# 13:28:24 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:28:28 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:28:32 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:39 - cmdstanpy - INFO - Chain [1] done processing
# 13:28:45 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:28:47 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:59 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points=======>     (107 + 12) / 119]
# Processing group: Rieti with 29862 data points
# 13:29:37 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:29:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:56 - cmdstanpy - INFO - Chain [1] done processing
# 13:30:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:30:04 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:30:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:13 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:30:21 - cmdstanpy - INFO - Chain [1] done processing
# 13:30:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:33 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Frosinone with 29862 data points=======>     (106 + 13) / 119]
# Processing group: Rieti with 29862 data points
# 13:31:10 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:31:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:31:25 - cmdstanpy - INFO - Chain [1] done processing
# 13:31:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:31:33 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:31:35 - cmdstanpy - INFO - Chain [1] start processing
# 13:31:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:31:49 - cmdstanpy - INFO - Chain [1] done processing
# 13:31:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:01 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 13:32:38 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:32:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:56 - cmdstanpy - INFO - Chain [1] done processing
# 13:32:59 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:33:04 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:33:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:33:16 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:33:22 - cmdstanpy - INFO - Chain [1] done processing
# 13:33:24 - cmdstanpy - INFO - Chain [1] start processing
# 13:33:35 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===========>         (9 + 2) / 11]
# Processing group: Frosinone with 29862 data points
# 13:34:13 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:34:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:34:31 - cmdstanpy - INFO - Chain [1] done processing
# 13:34:35 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:34:39 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:34:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:34:50 - cmdstanpy - INFO - Chain [1] done processing
# 13:34:55 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:34:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:35:09 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==============>   (111 + 8) / 119]
# Processing group: Frosinone with 29862 data points
# 13:35:49 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:35:49 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:02 - cmdstanpy - INFO - Chain [1] done processing
# 13:36:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:36:10 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:36:14 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:22 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:36:29 - cmdstanpy - INFO - Chain [1] done processing
# 13:36:30 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:41 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===============>  (114 + 5) / 119]
# Processing group: Frosinone with 29862 data points
# 13:37:17 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:37:17 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:36 - cmdstanpy - INFO - Chain [1] done processing
# 13:37:39 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:37:44 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:37:47 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:55 - cmdstanpy - INFO - Chain [1] done processing
# 13:38:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:38:03 - cmdstanpy - INFO - Chain [1] start processing
# 13:38:14 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===============>  (114 + 5) / 119]
# Processing group: Frosinone with 29862 data points
# 13:38:52 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:38:52 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:09 - cmdstanpy - INFO - Chain [1] done processing
# 13:39:10 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 13:39:17 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:17 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:29 - cmdstanpy - INFO - Chain [1] done processing
# 13:39:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:39:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:49 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (103 + 16) / 119]
# Processing group: Frosinone with 29862 data points
# 13:40:24 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:40:25 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:38 - cmdstanpy - INFO - Chain [1] done processing
# 13:40:43 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:40:46 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:40:51 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:57 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:41:05 - cmdstanpy - INFO - Chain [1] start processing
# 13:41:06 - cmdstanpy - INFO - Chain [1] done processing
# 13:41:18 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points==========>      (104 + 15) / 119]
# Processing group: Frosinone with 29862 data points
# 13:41:55 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:41:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:14 - cmdstanpy - INFO - Chain [1] done processing
# 13:42:18 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:42:22 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:42:26 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:32 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:42:38 - cmdstanpy - INFO - Chain [1] done processing
# 13:42:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:52 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points================> (115 + 4) / 119]
# Processing group: Frosinone with 29862 data points
# 13:43:28 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:43:28 - cmdstanpy - INFO - Chain [1] start processing
# 13:43:47 - cmdstanpy - INFO - Chain [1] done processing
# 13:43:49 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:43:55 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:43:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:44:06 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:44:13 - cmdstanpy - INFO - Chain [1] done processing
# 13:44:14 - cmdstanpy - INFO - Chain [1] start processing
# 13:44:27 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points===============>  (114 + 5) / 119]
# Processing group: Frosinone with 29862 data points
# 13:45:07 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:45:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:45:25 - cmdstanpy - INFO - Chain [1] done processing
# 13:45:27 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# Processing group: Viterbo with 29862 data points
# 13:45:33 - cmdstanpy - INFO - Chain [1] start processing
# 13:45:35 - cmdstanpy - INFO - Chain [1] start processing
# 13:45:42 - cmdstanpy - INFO - Chain [1] done processing
# 13:45:47 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:45:51 - cmdstanpy - INFO - Chain [1] start processing
# 13:46:03 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# Processing group: Rieti with 29862 data points================> (115 + 4) / 119]
# Processing group: Frosinone with 29862 data points
# 13:46:39 - cmdstanpy - INFO - Chain [1] start processing            (0 + 2) / 2]
# 13:46:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:46:58 - cmdstanpy - INFO - Chain [1] done processing
# 13:47:00 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Latina with 29862 data points
# 13:47:06 - cmdstanpy - INFO - Chain [1] start processing
# Processing group: Viterbo with 29862 data points
# 13:47:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:47:17 - cmdstanpy - INFO - Chain [1] done processing
# Processing group: Roma with 29862 data points
# 13:47:24 - cmdstanpy - INFO - Chain [1] done processing
# 13:47:25 - cmdstanpy - INFO - Chain [1] start processing
# 13:47:37 - cmdstanpy - INFO - Chain [1] done processing             (1 + 1) / 2]
# +--------+---------+------------------+------------------+------------------+-----------------+
# |    Time|     NOME|               MSE|              RMSE|               MAE|         Coverage|
# +--------+---------+------------------+------------------+------------------+-----------------+
# |  5 Days|  Viterbo| 89.89646233747999| 9.481374496215198| 7.482670470480355|94.49626865671642|
# |  5 Days|    Rieti| 83.45036222405513| 9.135116979221182| 7.090191673670943| 94.5195895522388|
# |  5 Days|   Latina|117.87761470859238|10.857145790150945| 8.534576418347756|94.68283582089553|
# |  5 Days|Frosinone| 99.38728900784695| 9.969317379231486| 7.790755661968563|94.66417910447761|
# |  5 Days|     Roma| 145.5025510482712|12.062443825704275| 9.616992576412443|95.06996268656717|
# | 30 Days|  Viterbo| 92.35015141139486| 9.609898616083047| 7.582695747373783|94.22867513611615|
# | 30 Days|    Rieti| 86.53355662257624| 9.302341459147597|7.2149940514889455|94.03357531760436|
# | 30 Days|   Latina|121.00364995113667|11.000165905618728| 8.628009086130529|94.31941923774954|
# | 30 Days|Frosinone|103.75879115799455|10.186205925563971|7.9155091620898315| 94.1923774954628|
# | 30 Days|     Roma|148.70463413842882|12.194450956825765| 9.712121091200665|94.67332123411978|
# | 90 Days|  Viterbo|110.41204249604236|10.507713476110888| 8.126854960612345|92.35519591141397|
# | 90 Days|    Rieti| 99.86849479441408| 9.993422576595773| 7.650227287647863|92.60647359454856|
# | 90 Days|   Latina|  137.803057154732|11.738954687480993|  9.09957056049858|92.75127768313457|
# | 90 Days|Frosinone|119.91596947021138|10.950615027029823| 8.379229953814255|92.73850085178876|
# | 90 Days|     Roma|171.43932905956112| 13.09348422153405|10.242571807620466|93.29216354344123|
# |180 Days|  Viterbo|131.92787002974208|11.485985810096672| 8.868634003995835|91.40506181024061|
# |180 Days|    Rieti|110.91303122395918| 10.53152558862956| 8.116446295677495| 92.3916858401903|
# |180 Days|   Latina|145.69787542492213|12.070537495278415| 9.410832018828076|92.82845220917989|
# |180 Days|Frosinone|134.56848274109652|11.600365629629806| 8.908115834810376|92.05631166400187|
# |180 Days|     Roma|189.55048117433367|13.767733334660926|10.772538115834827|92.77775611277931|
# +--------+---------+------------------+------------------+------------------+-----------------+
# only showing top 20 rows

# %%
result_df_O3.show(100)
# Out:
# +--------+---------+------------------+------------------+------------------+-----------------+
# |    Time|     NOME|               MSE|              RMSE|               MAE|         Coverage|
# +--------+---------+------------------+------------------+------------------+-----------------+
# |  5 Days|  Viterbo| 89.89646233747999| 9.481374496215198| 7.482670470480355|94.49626865671642|
# |  5 Days|    Rieti| 83.45036222405513| 9.135116979221182| 7.090191673670943| 94.5195895522388|
# |  5 Days|   Latina|117.87761470859238|10.857145790150945| 8.534576418347756|94.68283582089553|
# |  5 Days|Frosinone| 99.38728900784695| 9.969317379231486| 7.790755661968563|94.66417910447761|
# |  5 Days|     Roma| 145.5025510482712|12.062443825704275| 9.616992576412443|95.06996268656717|
# | 30 Days|  Viterbo| 92.35015141139486| 9.609898616083047| 7.582695747373783|94.22867513611615|
# | 30 Days|    Rieti| 86.53355662257624| 9.302341459147597|7.2149940514889455|94.03357531760436|
# | 30 Days|   Latina|121.00364995113667|11.000165905618728| 8.628009086130529|94.31941923774954|
# | 30 Days|Frosinone|103.75879115799455|10.186205925563971|7.9155091620898315| 94.1923774954628|
# | 30 Days|     Roma|148.70463413842882|12.194450956825765| 9.712121091200665|94.67332123411978|
# | 90 Days|  Viterbo|110.41204249604236|10.507713476110888| 8.126854960612345|92.35519591141397|
# | 90 Days|    Rieti| 99.86849479441408| 9.993422576595773| 7.650227287647863|92.60647359454856|
# | 90 Days|   Latina|  137.803057154732|11.738954687480993|  9.09957056049858|92.75127768313457|
# | 90 Days|Frosinone|119.91596947021138|10.950615027029823| 8.379229953814255|92.73850085178876|
# | 90 Days|     Roma|171.43932905956112| 13.09348422153405|10.242571807620466|93.29216354344123|
# |180 Days|  Viterbo|131.92787002974208|11.485985810096672| 8.868634003995835|91.40506181024061|
# |180 Days|    Rieti|110.91303122395918| 10.53152558862956| 8.116446295677495| 92.3916858401903|
# |180 Days|   Latina|145.69787542492213|12.070537495278415| 9.410832018828076|92.82845220917989|
# |180 Days|Frosinone|134.56848274109652|11.600365629629806| 8.908115834810376|92.05631166400187|
# |180 Days|     Roma|189.55048117433367|13.767733334660926|10.772538115834827|92.77775611277931|
# |365 Days|  Viterbo| 142.4690505576954|11.936039986431656| 9.259814227136745|92.74809160305344|
# |365 Days|    Rieti|118.42187160637249|10.882181380880052|  8.39984605501204|93.60184813177983|
# |365 Days|   Latina| 148.2267387124007|12.174840397820445| 9.545006004330402|93.84625686353287|
# |365 Days|Frosinone|150.69700327824347|12.275870774745206| 9.452385800198158|93.09629034418107|
# |365 Days|     Roma|198.17619701425835|14.077506775500353|11.060428338526552|93.63198071514664|
# +--------+---------+------------------+------------------+------------------+-----------------+

# %%
spark.stop()
